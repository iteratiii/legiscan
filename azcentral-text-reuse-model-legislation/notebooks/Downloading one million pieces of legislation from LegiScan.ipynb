# %% [markdown]
# # Downloading bill data from LegiScan
#
# There is a website called [LegiScan](https://legiscan.com/). From their about page:
#
# > LegiScan launched to support the release of the national LegiScan data service, providing the nation's first impartial real-time legislative tracking service designed for both public citizens and government affairs professionals across all sectors in organizations large and small. Utilizing the LegiScan API, having nearly 20 years of development maturity, allows us to provide monitoring of every bill in the 50 states and Congress. Giving our users and clients a central and uniform interface with the ability to easily track a wide array of legislative information. Paired with one of the country's most powerful national full bill text legislative search engines.
#
# We're using to use their API to **download data on over a million different pieces of legislation in the US.**

# %% [markdown]
# <p class="reading-options">
#   <a class="btn" href="/azcentral-text-reuse-model-legislation/01-downloading-one-million-pieces-of-legislation-from-legiscan">
#     <i class="fa fa-sm fa-book"></i>
#     Read online
#   </a>
#   <a class="btn" href="/azcentral-text-reuse-model-legislation/notebooks/01-Downloading one million pieces of legislation from LegiScan.ipynb">
#     <i class="fa fa-sm fa-download"></i>
#     Download notebook
#   </a>
#   <a class="btn" href="https://colab.research.google.com/github/littlecolumns/ds4j-notebooks/blob/master/azcentral-text-reuse-model-legislation/notebooks/01-Downloading one million pieces of legislation from LegiScan.ipynb" target="_new">
#     <i class="fa fa-sm fa-laptop"></i>
#     Interactive version
#   </a>
# </p>

# %% [markdown]
# ## Imports

# %%
import zipfile
import base64
import io
import glob
import time
import json
import os
import requests
import mimetypes

# %%
import csv

# %%
pip install pypdf
# Out:
# Collecting pypdf
#   Downloading pypdf-3.4.1-py3-none-any.whl (241 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.6/241.6 kB 4.5 MB/s eta 0:00:0000:01
# Requirement already satisfied: typing_extensions>=3.10.0.0 in /Users/gabriel/opt/anaconda3/lib/python3.9/site-packages (from pypdf) (4.3.0)
# Installing collected packages: pypdf
# Successfully installed pypdf-3.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from pypdf import PdfReader

# %%
from base64 import b64decode

# %%
import pandas as pd
import numpy as np

# %%
from bs4 import BeautifulSoup

# %%
# United States of America Python Dictionary to translate States,
# Districts & Territories to Two-Letter codes and vice versa.
#
# Canonical URL: https://gist.github.com/rogerallen/1583593
#
# Dedicated to the public domain.  To the extent possible under law,
# Roger Allen has waived all copyright and related or neighboring
# rights to this code.  Data originally from Wikipedia at the url:
# https://en.wikipedia.org/wiki/ISO_3166-2:US
#
# Automatically Generated 2021-09-11 18:04:36 via Jupyter Notebook from
# https://gist.github.com/rogerallen/d75440e8e5ea4762374dfd5c1ddf84e0 

us_state_to_abbrev = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "American Samoa": "AS",
    "Guam": "GU",
    "Northern Mariana Islands": "MP",
    "Puerto Rico": "PR",
    "United States Minor Outlying Islands": "UM",
    "U.S. Virgin Islands": "VI",
    "US": "US"
}

# %% [markdown]
# ## pylegiscan
#
# To talk to LegiScan's API, we're borrowing some code from [pylegiscan](https://github.com/poliquin/pylegiscan). Since it isn't a package you can install with `pip`, it wound up being easier for distribution to just cut and paste it here.

# %%
# Taken from https://github.com/poliquin/pylegiscan/blob/master/pylegiscan/legiscan.py

import os
import json
import requests
from urllib.parse import urlencode
from urllib.parse import quote_plus

# current aggregate status of bill
BILL_STATUS = {1: "Introduced",
               2: "Engrossed",
               3: "Enrolled",
               4: "Passed",
               5: "Vetoed",
               6: "Failed/Dead"}

# significant steps in bill progress.
BILL_PROGRESS = {1: "Introduced",
                 2: "Engrossed",
                 3: "Enrolled",
                 4: "Passed",
                 5: "Vetoed",
                 6: "Failed/Dead",
                 7: "Veto Override",
                 8: "Chapter/Act/Statute",
                 9: "Committee Referral",
                10: "Committee Report Pass",
                11: "Committee Report DNP"}


"""
Interact with LegiScan API.

"""

# a helpful list of valid legiscan state abbreviations (no Puerto Rico)
STATES = ['ak', 'al', 'ar', 'az', 'ca', 'co', 'ct', 'dc', 'de', 'fl', 'ga',
          'hi', 'ia', 'id', 'il', 'in', 'ks', 'ky', 'la', 'ma', 'md', 'me',
          'mi', 'mn', 'mo', 'ms', 'mt', 'nc', 'nd', 'ne', 'nh', 'nj', 'nm',
          'nv', 'ny', 'oh', 'ok', 'or', 'pa', 'ri', 'sc', 'sd', 'tn', 'tx',
          'ut', 'va', 'vt', 'wa', 'wi', 'wv', 'wy']

class LegiScanError(Exception):
    pass

class LegiScan(object):
    BASE_URL = 'http://api.legiscan.com/?key={0}&op={1}&{2}'

    def __init__(self, apikey=None):
        """LegiScan API.  State parameters should always be passed as
           USPS abbreviations.  Bill numbers and abbreviations are case
           insensitive.  Register for API at http://legiscan.com/legiscan
        """
        # see if API key available as environment variable
        if apikey is None:
            apikey = config.LEGISCAN_API_KEY
        self.key = apikey.strip()

    def _url(self, operation, params=None):
        """Build a URL for querying the API."""
        if not isinstance(params, str) and params is not None:
            params = urlencode(params)
        elif params is None:
            params = ''
        return self.BASE_URL.format(self.key, operation, params)

    def _get(self, url):
        """Get and parse JSON from API for a url."""
        req = requests.get(url)
        if not req.ok:
            raise LegiScanError('Request returned {0}: {1}'\
                    .format(req.status_code, url))
        data = json.loads(req.content)
        if data['status'] == "ERROR":
            raise LegiScanError(data['alert']['message'])
        return data

    def get_session_list(self, state):
        """Get list of available sessions for a state."""
        url = self._url('getSessionList', {'state': state})
        data = self._get(url)
        return data['sessions']

    def get_dataset_list(self, state=None, year=None):
        """Get list of available datasets, with optional state and year filtering.
        """
        if state is not None:
            url = self._url('getDatasetList', {'state': state})
        elif year is not None:
            url = self._url('getDatasetList', {'year': year})
        else:
            url = self._url('getDatasetList')
        data = self._get(url)
        # return a list of the bills
        return data['datasetlist']

    def get_dataset(self, id, access_key):
        """Get list of available datasets, with optional state and year filtering.
        """
        url = self._url('getDataset', {'id': id, 'access_key': access_key})
        data = self._get(url)
        # return a list of the bills
        return data['dataset']
      
    def get_master_list(self, state=None, session_id=None):
        """Get list of bills for the current session in a state or for
           a given session identifier.
        """
        if state is not None:
            url = self._url('getMasterList', {'state': state})
        elif session_id is not None:
            url = self._url('getMasterList', {'id': session_id})
        else:
            raise ValueError('Must specify session identifier or state.')
        data = self._get(url)
        # return a list of the bills
        return [data['masterlist'][i] for i in data['masterlist']]

    def get_bill(self, bill_id=None, state=None, bill_number=None):
        """Get primary bill detail information including sponsors, committee
           references, full history, bill text, and roll call information.

           This function expects either a bill identifier or a state and bill
           number combination.  The bill identifier is preferred, and required
           for fetching bills from prior sessions.
        """
        if bill_id is not None:
            url = self._url('getBill', {'id': bill_id})
        elif state is not None and bill_number is not None:
            url = self._url('getBill', {'state': state, 'bill': bill_number})
        else:
            raise ValueError('Must specify bill_id or state and bill_number.')
        return self._get(url)['bill']

    def get_bill_text(self, doc_id):
        """Get bill text, including date, draft revision information, and
           MIME type.  Bill text is base64 encoded to allow for PDF and Word
           data transfers.
        """
        url = self._url('getBillText', {'id': doc_id})
        return self._get(url)['text']

    def get_amendment(self, amendment_id):
        """Get amendment text including date, adoption status, MIME type, and
           title/description information.  The amendment text is base64 encoded
           to allow for PDF and Word data transfer.
        """
        url = self._url('getAmendment', {'id': amendment_id})
        return self._get(url)['amendment']

    def get_supplement(self, supplement_id):
        """Get supplement text including type of supplement, date, MIME type
           and text/description information.  Supplement text is base64 encoded
           to allow for PDF and Word data transfer.
        """
        url = self._url('getSupplement', {'id': supplement_id})
        return self._get(url)['supplement']

    def get_roll_call(self, roll_call_id):
        """Roll call detail for individual votes and summary information."""
        data = self._get(self._url('getRollcall', {'id': roll_call_id}))
        return data['roll_call']

    def get_sponsor(self, people_id):
        """Sponsor information including name, role, and a followthemoney.org
           person identifier.
        """
        url = self._url('getSponsor', {'id': people_id})
        return self._get(url)['person']

    def search(self, state, bill_number=None, query=None, year=2, page=1):
        """Get a page of results for a search against the LegiScan full text
           engine; returns a paginated result set.

           Specify a bill number or a query string.  Year can be an exact year
           or a number between 1 and 4, inclusive.  These integers have the
           following meanings:
               1 = all years
               2 = current year, the default
               3 = recent years
               4 = prior years
           Page is the result set page number to return.
        """
        if bill_number is not None:
            params = {'state': state, 'bill': bill_number}
        elif query is not None:
            params = {'state': state, 'query': query,
                      'year': year, 'page': page}
        else:
            raise ValueError('Must specify bill_number or query')
        data = self._get(self._url('search', params))['searchresult']
        # return a summary of the search and the results as a dictionary
        summary = data.pop('summary')
        results = {'summary': summary, 'results': [data[i] for i in data]}
        return results

    def __str__(self):
        return '<LegiScan API {0}>'.format(self.key)

    def __repr__(self):
        return str(self)

# %% [markdown]
# # Connect to LegiScan
#
# Using pylegiscan, you just pass your API key to `LegiScan` and you're good to go. I set up an environment variable for mine, but you can also just paste yours at `OR_PUT_YOUR_API_KEY_HERE`.

# %%
import config

api_key = config.LEGISCAN_API_KEY
legis = LegiScan(api_key)

# %% [markdown]
# If you wanted to search for bills based on state or text, that's easy to do.

# %% [markdown]
# ## Search for bills containing "biological sex"

# %%
bills = legis.search(state='ALL', query='biological sex')
bills['summary'] # how many results did we get?
# this returns 173 results; there are 368 in the LGBTQ+ legislative tracker
# https://docs.google.com/spreadsheets/d/1fTxHLjBa86GA7WCT-V6AbEMGRFPMJndnaVGoZZX4PMw/edit#gid=0
# but i think this is ok to start with
# Out:
# {'page': '1 of 4',
#  'range': '1 - 50',
#  'relevancy': '100% - 98%',
#  'count': 173,
#  'page_current': '1',
#  'page_total': 4,
#  'query': '((Zbiolog:(pos=1) AND Zsex:(pos=2)))'}

# %% [markdown]
# ## Print their titles

# %%
for b in bills['results']:
    print(b['title'])
# Out:
# Establishes the "Missouri Save Adolescents from Experimentation (SAFE) Act"
# Gender Reassignment Surgery
# Creates provisions relating to gender transition procedures
# Transgender Medical Treatments and Procedures Amendments
# Creates provisions relating to gender transition procedures
# Gender transition procedures for minors.
# Establishes the "Missouri Save Adolescents from Experimentation (SAFE) Act"
# Health care; creating the Oklahoma Save Adolescents from Experimentation (SAFE) Act; prohibiting gender transition procedures; providing for administrative and civil enforcement. Emergency.
# Adopt the Let Them Grow Act
# Establishes the "Missouri Child and Adolescent Protection Act"
# Prohibiting certain medical practices
# Public health and safety; defining terms; health care professionals; gender transition procedures; referrals; exceptions; public funds; Medicaid program reimbursements; felony penalties; statute of limitations; unprofessional conduct; license revocation; statute of limitations; claims or defenses; civil actions; administrative remedies; attorney fees; Attorney General; codification; effective date.
# Children Deserve Help Not Harm Act established, health benefit plans, etc.
# Save Adolescents from Experimentation (SAFE) Act; established, health benefit plans, etc.
# Professions and Businesses; health care providers from performing specified practices on minors relating to altering a person's appearance relating to gender; prohibit
# Health care; prohibiting certain uses of public funds, public facilities, and public employees. Emergency.
# Prohibiting gender transition procedures for minors, relative to sex and gender in public schools, and relative to the definition of conversion therapy.
# Millstone Act of 2023
# Child removal and gender identity.
# Oklahoma Save Adolescents from Experimentation (SAFE) Act; effective date.
# Gender reassignment
# Enacting the protecting children&#x27;s bodies act.
# Establishes guidelines for student participation in athletic contests organized by sex
# A concurrent resolution urging public schools and public entities, including agencies or departments that collect vital statistics, to protect women's rights by distinguishing between the sexes according to biological sex at birth for the purpose of providing equal opportunities and ensuring the privacy and safety of women and girls.
# Establishes the "Missouri Save Adolescents from Experimentation (SAFE) Act"
# Relating to gender reassignment medical services for minors
# Creates provisions relating to gender transition procedures
# Prohibit certain medical and surgical interventions on minor patients.
# Establishing the women's bill of rights to provide a meaning of biological sex for purposes of statutory construction.
# Public health and safety; health care professionals; prohibiting certain gender transition procedures; exceptions; administrative remedies; emergency.
# Creates provisions relating to gender transition procedures
# Prohibiting Sex Transitioning Procedures on Minors
# K-12 schools/higher ed. institution; designation of interscholastic, etc., sports based on sex, etc.
# AN ACT relating to public school facilities and declaring an emergency.
# Gender transition; prohibitions; hormone therapies
# No Tax Breaks for Radical Corporate Activism Act
# No Tax Breaks for Radical Corporate Activism Act of 2023
# Relating to the required inclusion of a person's sex on a birth certificate and prohibited change of sex on the birth certificate of certain minors.
# K-12 schools/higher ed. institutions; interscholastic, etc., sports, teams based on biological sex.
# AN ACT relating to education.
# AN ACT relating to education.
# Discrimination; creating the Women's Bill of Rights; authorizing distinctions for certain purposes. Effective date.
# Elementary schools, etc.; designation of interscholastic, etc., sports, student participation.
# Discrimination; enacting the Women's Bill of Rights; effective date.
# The Title IX Preservation Act; enact.
# Relating to participation in athletic activities based on biological sex; providing a civil right to action for K-12 athletes and college athletes.
# Parental rights.
# SCH CD-BIO-RESTROOM ACCESS
# Schools; creating the School Establishment Clause Act (SECA); prohibiting creation, enforcement, or endorsement of certain policies. Effective date. Emergency.
# The Title IX Preservation Act; enact.

# %% [markdown]
# ## Get the bill ID and sponsor for the first result

# %%
bill_id = bills['results'][0]['bill_id']
bill_detail = legis.get_bill(bill_id=bill_id)

# %%
people_id = bill_detail['sponsors'][0]['people_id']
sponsor = legis.get_sponsor(people_id)
print(sponsor['name'])
# Out:
# Mike Moon

# %%
doc_id = bill_detail['texts'][0]['doc_id']
doc_id
# Out:
# 2631259

# %% [markdown]
# ## Get all the bill IDs for my search query

# %%
# get all the bill ids for our query
bill_ids = []

for i in range(0,len(bills['results'])):
    bill_ids.append(bills['results'][i]['bill_id'])
    
bill_ids
# Out:
# [1635057,
#  1637125,
#  1675866,
#  1639439,
#  1640339,
#  1650034,
#  1634951,
#  1668356,
#  1662540,
#  1696931,
#  1656233,
#  1634447,
#  1651270,
#  1634198,
#  1702869,
#  1643087,
#  1654313,
#  1665859,
#  1650067,
#  1663548,
#  1635919,
#  1649602,
#  1634572,
#  1683622,
#  1635148,
#  1715006,
#  1640281,
#  1660616,
#  1698406,
#  1668929,
#  1642575,
#  1640216,
#  1633355,
#  1642113,
#  1686385,
#  1674808,
#  1689600,
#  1632730,
#  1645224,
#  1700889,
#  1698754,
#  1659858,
#  1634331,
#  1665893,
#  1649395,
#  1632709,
#  1660515,
#  1699553,
#  1669660,
#  1668972]

# %%
bill_ids = [1635057,
 1637125,
 1675866,
 1639439,
 1640339,
 1650034,
 1634951,
 1668356,
 1662540,
 1696931,
 1656233,
 1634447,
 1651270,
 1634198,
 1702869,
 1643087,
 1654313,
 1665859,
 1650067,
 1663548,
 1635919,
 1649602,
 1634572,
 1683622,
 1635148,
 1715006,
 1640281,
 1660616,
 1698406,
 1668929,
 1642575,
 1640216,
 1633355,
 1642113,
 1686385,
 1674808,
 1689600,
 1632730,
 1645224,
 1700889,
 1698754,
 1659858,
 1634331,
 1665893,
 1649395,
 1632709,
 1660515,
 1699553,
 1669660,
 1668972]

# %% [markdown]
# # Get all the doc IDs for my query

# %%
# get all the doc ids for our query
bill_details = []

for i in range(0,len(bill_ids)):
    bill_details.append(legis.get_bill(bill_id=bill_ids[i]))

# %%
# get all the doc ids for our query
bill_details = []
doc_ids = []

for i in range(0,len(bill_ids)):
    bill_details.append(legis.get_bill(bill_id=bill_ids[i]))
    doc_id = bill_details[i]['texts'][0]['doc_id']
    doc_ids.append(doc_id)
    
doc_ids
# Out:
# [2631259,
#  2616404,
#  2658485,
#  2619414,
#  2620652,
#  2629930,
#  2631144,
#  2650157,
#  2644341,
#  2684043,
#  2637391,
#  2614865,
#  2631317,
#  2614535,
#  2692266,
#  2623314,
#  2637539,
#  2647692,
#  2629969,
#  2645325,
#  2615718,
#  2629675,
#  2614977,
#  2666618,
#  2632040,
#  2708885,
#  2620606,
#  2680361,
#  2686001,
#  2650792,
#  2622929,
#  2620550,
#  2613416,
#  2622424,
#  2670276,
#  2674746,
#  2696929,
#  2612852,
#  2625328,
#  2689368,
#  2686660,
#  2641747,
#  2614708,
#  2647723,
#  2629442,
#  2612832,
#  2642392,
#  2687762,
#  2651535,
#  2650842]

# %% [markdown]
# ## Get all the bill text from these doc IDs

# %%
bill_texts = []

# get bill texts
for i in range(0,len(doc_ids)):
    bill_text = legis.get_bill_text(doc_ids[i])
    bill_texts.append(bill_text)

bill_texts[0:3]
# Out:
# [{'doc_id': 2631259,
#   'bill_id': 1635057,
#   'date': '0000-00-00',
#   'type': 'Introduced',
#   'type_id': 1,
#   'mime': 'application/pdf',
#   'mime_id': 2,
#   'text_size': 347111,
#   'text_hash': '2b017580afa21ca9a37198a3291693d5',
#   'doc': '...',
#   'alt_document': 0,
#   'alt_mime': '',
#   'alt_mime_id': 0,
#   'alt_text_size': 0,
#   'alt_text_hash': '',
#   'alt_doc': ''},
#  {'doc_id': 2616404,
#   'bill_id': 1637125,
#   'date': '2022-12-07',
#   'type': 'Introduced',
#   'type_id': 1,
#   'mime': 'text/html',
#   'mime_id': 1,
#   'text_size': 12810,
#   'text_hash': 'f6317c785ec77b4a4e067c4322d55661',
#   'doc': '...',
#   'alt_document': 0,
#   'alt_mime': '',
#   'alt_mime_id': 0,
#   'alt_text_size': 0,
#   'alt_text_hash': '',
#   'alt_doc': ''},
#  {'doc_id': 2658485,
#   'bill_id': 1675866,
#   'date': '0000-00-00',
#   'type': 'Introduced',
#   'type_id': 1,
#   'mime': 'application/pdf',
#   'mime_id': 2,
#   'text_size': 106325,
#   'text_hash': '2180e2be7c751c872b7ae3434fe4a7e6',
#   'doc': '...',
#   'alt_document': 0,
#   'alt_mime': '',
#   'alt_mime_id': 0,
#   'alt_text_size': 0,
#   'alt_text_hash': '',
#   'alt_doc': ''}]

# %% [markdown]
# ## Check the length of the list

# %%
len(bill_texts)
# Out:
# 50

# %% [markdown]
# ## Function to decode from base64 into PDF file

# %%
# create function
def decodepdf(bill_text):
    # Define the Base64 string of the PDF file
    b64 = bill_text['doc']

    # Decode the Base64 string, making sure that it contains only valid characters
    bytes = b64decode(b64, validate=True)

    # Perform a basic validation to make sure that the result is a valid PDF file
    # Be aware! The magic number (file signature) is not 100% reliable solution to validate PDF files
    # Moreover, if you get Base64 from an untrusted source, you must sanitize the PDF contents
    if bytes[0:4] != b'%PDF':
      raise ValueError('Missing the PDF file signature')
    
    bill_id_name = bill_text['bill_id']
    
    # Write the PDF contents to a local file
    f = open('f'bill_id-'{bill_id_name}.pdf', 'wb')
    f.write(bytes)
    f.close()

# %% [markdown]
# # Merge it with function to get text from PDF and output it to a txt file

# %%
# create function
def decodepdftotext(bill_text):
    # Define the Base64 string of the PDF file
    b64 = bill_text['doc']

    # Decode the Base64 string, making sure that it contains only valid characters
    bytes = b64decode(b64, validate=True)

    # Perform a basic validation to make sure that the result is a valid PDF file
    # Be aware! The magic number (file signature) is not 100% reliable solution to validate PDF files
    # Moreover, if you get Base64 from an untrusted source, you must sanitize the PDF contents
    if bytes[0:4] != b'%PDF':
      raise ValueError('Missing the PDF file signature')
    
    bill_id_name = bill_text['bill_id']
    
    # Write the PDF contents to a local file
    f = open(f"bill_id-{bill_id_name}.pdf", "wb")
    f.write(bytes)
    f.close()
    
    reader = PdfReader(f"bill_id-{bill_id_name}.pdf")
    text=""
    for n in range(0,len(reader.pages)):
        page = reader.pages[n]
        text = text + page.extract_text()
    g = open(f"bill_id-{bill_id_name}.txt", "w")
    g.write(text)
    g.close()

# %% [markdown]
# ## Do it for all the bill texts

# %%
for i in range(0,len(bill_texts)):
    if(bill_texts[i]['mime'] == "application/pdf"):
        decodepdftotext(bill_texts[i])
    else:
        continue

# %% [markdown]
# Finally I extracted all the text from these PDFs. Now how do I deal with the HTML? Let's make a list of just those so I can deal with them properly:

# %%
for i in range(33):
    bill_id = bill_texts[i]['bill_id']

# %% [markdown]
# # Deal with the HTML-formatted bill texts

# %%
htmlbills = []
for i in range(0,len(bill_texts)):
    if(bill_texts[i]['mime'] == "text/html"):
        htmlbills.append(bill_texts[i])
htmlbills[0:3]

# %%
htmlbills[0]

# %%
def b64tohtml(bill_text):
    # Define the Base64 string of the PDF file
    b64 = bill_text['doc']

    # Decode the Base64 string, making sure that it contains only valid characters
    bytes = b64decode(b64, validate=True)

    bill_id_name = bill_text['bill_id']
    
    # Write the PDF contents to a local file
    h = open(f"bill_id-{bill_id_name}.html", "wb")
    print(h)
    h.write(bytes)
    h.close()
    
    with open(f"bill_id-{bill_id_name}.html") as fp:
        soup = BeautifulSoup(fp)
    i = open(f"bill_id-{bill_id_name}.txt", "w")
    i.write(soup.get_text())
    i.close()

# %%
b64tohtml(htmlbills[9])
# Out:
# <_io.BufferedWriter name='bill_id-1686385.html'>
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /var/folders/lj/gz81psj55xg1_fm6jfz2vbn80000gn/T/ipykernel_18615/1431501475.py in <module>
# ----> 1 b64tohtml(htmlbills[9])
#
# /var/folders/lj/gz81psj55xg1_fm6jfz2vbn80000gn/T/ipykernel_18615/2253303534.py in b64tohtml(bill_text)
#      15
#      16     with open(f"bill_id-{bill_id_name}.html") as fp:
# ---> 17         soup = BeautifulSoup(fp)
#      18     i = open(f"bill_id-{bill_id_name}.txt", "w")
#      19     i.write(soup.get_text())
#
# ~/opt/anaconda3/lib/python3.9/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     310
#     311         if hasattr(markup, 'read'):        # It's a file-type object.
# --> 312             markup = markup.read()
#     313         elif len(markup) <= 256 and (
#     314                 (isinstance(markup, bytes) and not b'<' in markup)
#
# ~/opt/anaconda3/lib/python3.9/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa0 in position 8910: invalid start byte

# %%
len(htmlbills)
# Out:
# 17

# %%
for i in range(len(htmlbills)):
    b64tohtml(htmlbills[i])
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /var/folders/lj/gz81psj55xg1_fm6jfz2vbn80000gn/T/ipykernel_18615/1105259835.py in <module>
#       1 for i in range(len(htmlbills)):
# ----> 2     b64tohtml(htmlbills[i])
#
# /var/folders/lj/gz81psj55xg1_fm6jfz2vbn80000gn/T/ipykernel_18615/3980107432.py in b64tohtml(bill_text)
#      14
#      15     with open(f"bill_id-{bill_id_name}.html") as fp:
# ---> 16         soup = BeautifulSoup(fp)
#      17     i = open(f"bill_id-{bill_id_name}.txt", "w")
#      18     i.write(soup.get_text())
#
# ~/opt/anaconda3/lib/python3.9/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     310
#     311         if hasattr(markup, 'read'):        # It's a file-type object.
# --> 312             markup = markup.read()
#     313         elif len(markup) <= 256 and (
#     314                 (isinstance(markup, bytes) and not b'<' in markup)
#
# ~/opt/anaconda3/lib/python3.9/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x96 in position 12504: invalid start byte

# %%
# Out:
# {'doc_id': 2670276,
#  'bill_id': 1686385,
#  'date': '2023-01-30',
#  'type': 'Introduced',
#  'type_id': 1,
#  'mime': 'text/html',
#  'mime_id': 1,
#  'text_size': 14317,
#  'text_hash': '42e6da8617f25b52bfd92053fd37c28a',
#  'doc': '...',
#  'alt_document': 1,
#  'alt_mime': 'text/html',
#  'alt_mime_id': 1,
#  'alt_text_size': 24362,
#  'alt_text_hash': 'b90139177ed91d4ca271a888333e5ccb',
#  'alt_doc': '...'}

# %%
with open('bill_id-1633355.html') as f:
    print(f)
# Out:
# <_io.TextIOWrapper name='bill_id-1633355.html' mode='r' encoding='UTF-8'>

# %%
htmlbills[9]
# Out:
# {'doc_id': 2670276,
#  'bill_id': 1686385,
#  'date': '2023-01-30',
#  'type': 'Introduced',
#  'type_id': 1,
#  'mime': 'text/html',
#  'mime_id': 1,
#  'text_size': 14317,
#  'text_hash': '42e6da8617f25b52bfd92053fd37c28a',
#  'doc': '...',
#  'alt_document': 1,
#  'alt_mime': 'text/html',
#  'alt_mime_id': 1,
#  'alt_text_size': 24362,
#  'alt_text_hash': 'b90139177ed91d4ca271a888333e5ccb',
#  'alt_doc': '...'}

# %%
def b64tohtmlonly(bill_text):
    # Define the Base64 string of the PDF file
    b64 = bill_text['doc']

    # Decode the Base64 string, making sure that it contains only valid characters
    bytes = b64decode(b64, validate=True)

    bill_id_name = bill_text['bill_id']
    
    # Write the PDF contents to a local file
    h = open(f"bill_id-{bill_id_name}.html", "wb")
    print(h)
    h.write(bytes)
    h.close()

# %%
# 8 and 9 are the problematic ones
b64tohtmlonly(htmlbills[8])
b64tohtmlonly(htmlbills[9])
# Out:
# <_io.BufferedWriter name='bill_id-1633355.html'>
# <_io.BufferedWriter name='bill_id-1686385.html'>

# %%
with open('bill_id-1633355.html') as f:
    print(f)
# Out:
# <_io.TextIOWrapper name='bill_id-1633355.html' mode='r' encoding='UTF-8'>

# %%
bill_details[0]
# Out:
# {'bill_id': 1635057,
#  'change_hash': 'e09e6c58de86d4d7f02c80d880b2fd09',
#  'session_id': 2012,
#  'session': {'session_id': 2012,
#   'state_id': 25,
#   'year_start': 2023,
#   'year_end': 2023,
#   'prefile': 0,
#   'sine_die': 0,
#   'prior': 0,
#   'special': 0,
#   'session_tag': 'Regular Session',
#   'session_title': '2023 Regular Session',
#   'session_name': '2023 Regular Session'},
#  'url': 'https://legiscan.com/MO/bill/SB49/2023',
#  'state_link': 'https://www.senate.mo.gov/23info/BTS_Web/Bill.aspx?SessionType=R&BillID=44407',
#  'completed': 0,
#  'status': 1,
#  'status_date': '2023-01-04',
#  'progress': [{'date': '2023-01-04', 'event': 1},
#   {'date': '2023-01-12', 'event': 9}],
#  'state': 'MO',
#  'state_id': 25,
#  'bill_number': 'SB49',
#  'bill_type': 'B',
#  'bill_type_id': '1',
#  'body': 'S',
#  'body_id': 60,
#  'current_body': 'S',
#  'current_body_id': 60,
#  'title': 'Establishes the "Missouri Save Adolescents from Experimentation (SAFE) Act"',
#  'description': 'Establishes the "Missouri Save Adolescents from Experimentation (SAFE) Act"',
#  'pending_committee_id': 0,
#  'committee': [],
#  'referrals': [{'date': '2023-01-12',
#    'committee_id': 4711,
#    'chamber': 'S',
#    'chamber_id': 60,
#    'name': 'Emerging Issues'}],
#  'history': [{'date': '2022-12-01',
#    'action': 'Prefiled',
#    'chamber': 'S',
#    'chamber_id': 60,
#    'importance': 0},
#   {'date': '2023-01-04',
#    'action': 'S First Read',
#    'chamber': 'S',
#    'chamber_id': 60,
#    'importance': 0},
#   {'date': '2023-01-12',
#    'action': 'Second Read and Referred S Emerging Issues Committee',
#    'chamber': 'S',
#    'chamber_id': 60,
#    'importance': 1},
#   {'date': '2023-02-14',
#    'action': 'Hearing Conducted S Emerging Issues Committee',
#    'chamber': 'S',
#    'chamber_id': 60,
#    'importance': 0},
#   {'date': '2023-02-20',
#    'action': 'SCS Voted Do Pass (w/SCSs SB 49, 236, &164) Emerging Issues Committee (0202S.02C)',
#    'chamber': 'S',
#    'chamber_id': 60,
#    'importance': 0},
#   {'date': '2023-02-21',
#    'action': 'Reported from S Emerging Issues Committee w/SCS',
#    'chamber': 'S',
#    'chamber_id': 60,
#    'importance': 0},
#   {'date': '2023-02-27',
#    'action': 'Formal Calendar S Bills for Perfection',
#    'chamber': 'S',
#    'chamber_id': 60,
#    'importance': 0}],
#  'sponsors': [{'people_id': 16177,
#    'person_hash': '3p3wgq6y',
#    'party_id': '2',
#    'state_id': 25,
#    'party': 'R',
#    'role_id': 2,
#    'role': 'Sen',
#    'name': 'Mike Moon',
#    'first_name': 'Mike',
#    'middle_name': '',
#    'last_name': 'Moon',
#    'suffix': '',
#    'nickname': '',
#    'district': 'SD-029',
#    'ftm_eid': 16501211,
#    'votesmart_id': 123397,
#    'opensecrets_id': '',
#    'knowwho_pid': 284786,
#    'ballotpedia': 'Mike_Moon',
#    'bioguide_id': '',
#    'sponsor_type_id': 1,
#    'sponsor_order': 1,
#    'committee_sponsor': 0,
#    'committee_id': 0,
#    'state_federal': 0},
#   {'people_id': 18105,
#    'person_hash': 'wj228jud',
#    'party_id': '2',
#    'state_id': 25,
#    'party': 'R',
#    'role_id': 2,
#    'role': 'Sen',
#    'name': 'William Eigel',
#    'first_name': 'William',
#    'middle_name': '',
#    'last_name': 'Eigel',
#    'suffix': '',
#    'nickname': 'Bill',
#    'district': 'SD-023',
#    'ftm_eid': 39656678,
#    'votesmart_id': 169721,
#    'opensecrets_id': '',
#    'knowwho_pid': 572088,
#    'ballotpedia': 'Bill_Eigel',
#    'bioguide_id': '',
#    'sponsor_type_id': 2,
#    'sponsor_order': 2,
#    'committee_sponsor': 0,
#    'committee_id': 0,
#    'state_federal': 0},
#   {'people_id': 12944,
#    'person_hash': '28x3l5dx',
#    'party_id': '2',
#    'state_id': 25,
#    'party': 'R',
#    'role_id': 2,
#    'role': 'Sen',
#    'name': 'Rick Brattin',
#    'first_name': 'Rick',
#    'middle_name': '',
#    'last_name': 'Brattin',
#    'suffix': '',
#    'nickname': '',
#    'district': 'SD-031',
#    'ftm_eid': 6685174,
#    'votesmart_id': 124815,
#    'opensecrets_id': '',
#    'knowwho_pid': 290178,
#    'ballotpedia': 'Rick_Brattin',
#    'bioguide_id': '',
#    'sponsor_type_id': 2,
#    'sponsor_order': 3,
#    'committee_sponsor': 0,
#    'committee_id': 0,
#    'state_federal': 0}],
#  'sasts': [],
#  'subjects': [],
#  'texts': [{'doc_id': 2631259,
#    'date': '0000-00-00',
#    'type': 'Introduced',
#    'type_id': 1,
#    'mime': 'application/pdf',
#    'mime_id': 2,
#    'url': 'https://legiscan.com/MO/text/SB49/id/2631259',
#    'state_link': 'http://reflect.legiscan.com/Proxy.php',
#    'text_size': 347111,
#    'text_hash': '2b017580afa21ca9a37198a3291693d5'},
#   {'doc_id': 2709450,
#    'date': '0000-00-00',
#    'type': 'Comm Sub',
#    'type_id': 2,
#    'mime': 'application/pdf',
#    'mime_id': 2,
#    'url': 'https://legiscan.com/MO/text/SB49/id/2709450',
#    'state_link': 'http://reflect.legiscan.com/Proxy.php',
#    'text_size': 351371,
#    'text_hash': 'b7b584297edb07bfe2184dd8407fc5c4'},
#   {'doc_id': 2711919,
#    'date': '0000-00-00',
#    'type': 'Comm Sub',
#    'type_id': 2,
#    'mime': 'application/pdf',
#    'mime_id': 2,
#    'url': 'https://legiscan.com/MO/text/SB49/id/2711919',
#    'state_link': 'http://reflect.legiscan.com/Proxy.php',
#    'text_size': 348914,
#    'text_hash': '57166a8f3b9ee5dff170776fe149f1e2'}],
#  'votes': [],
#  'amendments': [],
#  'supplements': [{'supplement_id': 287504,
#    'date': '0000-00-00',
#    'type': 'Analysis',
#    'type_id': 2,
#    'title': 'Analysis',
#    'description': 'Summary: Introduced',
#    'mime': 'text/html',
#    'mime_id': 1,
#    'url': 'https://legiscan.com/MO/supplement/SB49/id/287504',
#    'state_link': 'https://www.senate.mo.gov/23info/BTS_Web/Summary.aspx?SessionType=R&SummaryID=38041&BillID=44407',
#    'supplement_size': 1269,
#    'supplement_hash': 'bd8e841e753965c5351683a602d21b8d'},
#   {'supplement_id': 294419,
#    'date': '0000-00-00',
#    'type': 'Fiscal Note',
#    'type_id': 1,
#    'title': 'Fiscal Note',
#    'description': '0202S.01I.ORG',
#    'mime': 'application/pdf',
#    'mime_id': 2,
#    'url': 'https://legiscan.com/MO/supplement/SB49/id/294419',
#    'state_link': 'https://senate.mo.gov/FiscalNotes/2023-1/0202S.01I.ORG.pdf',
#    'supplement_size': 116277,
#    'supplement_hash': '8e0df154b51d33ddad7fc29b427ed571'},
#   {'supplement_id': 309025,
#    'date': '0000-00-00',
#    'type': 'Analysis',
#    'type_id': 2,
#    'title': 'Analysis',
#    'description': 'Summary: Senate Committee Substitute',
#    'mime': 'text/html',
#    'mime_id': 1,
#    'url': 'https://legiscan.com/MO/supplement/SB49/id/309025',
#    'state_link': 'https://www.senate.mo.gov/23info/BTS_Web/Summary.aspx?SessionType=R&SummaryID=2776259&BillID=44407',
#    'supplement_size': 1298,
#    'supplement_hash': 'fb46acddedaadd6881cecf61df81423e'},
#   {'supplement_id': 310376,
#    'date': '0000-00-00',
#    'type': 'Fiscal Note',
#    'type_id': 1,
#    'title': 'Fiscal Note',
#    'description': '0202S.02C.ORG',
#    'mime': 'application/pdf',
#    'mime_id': 2,
#    'url': 'https://legiscan.com/MO/supplement/SB49/id/310376',
#    'state_link': 'https://senate.mo.gov/FiscalNotes/2023-1/0202S.02C.ORG.pdf',
#    'supplement_size': 117775,
#    'supplement_hash': '790e5fdb7c99259b8367c7503a06e000'}],
#  'calendar': [{'type_id': 1,
#    'type': 'Hearing',
#    'date': '2023-02-14',
#    'time': '10:00',
#    'location': 'SCR 1',
#    'description': 'Emerging Issues Hearing'}]}

# %%
# test one file to see if it'll work
with open("billtxts/1632709.txt", "rb") as f:
    txt = f.readlines()
print(txt)
# Out:
# [b'\n', b'\n', b'\n', b'\xc2\xa0\n', b'\n', b'\n', b'\n', b'\xc2\xa0\n', b'\n', b'\n', b'\xc2\xa0\n', b'\n', b'\t\tBy:\xc2\xa0Swanson\n', b'H.B.\xc2\xa0No.\xc2\xa023\n', b'\n', b'\n', b'\n', b'\n', b'\xc2\xa0\n', b'\n', b'\n', b'\xc2\xa0\n', b'\n', b'\n', b'\n', b'\xc2\xa0\t\t\n', b'\t\t\t\n', b'\n', b'A BILL TO BE ENTITLED\n', b'\n', b'\n', b'\n', b'\n', b'\xc2\xa0\n', b'\t\t\t\n', b'\n', b'AN ACT\n', b'\n', b'\n', b'\n', b'\n', b'\xc2\xa0\n', b'\t\t\t\n', b'relating to participation in athletic activities based on \n', b'\n', b'\n', b'\n', b'\xc2\xa0\n', b'\t\t\t\n', b'biological sex; providing a civil right to action for K-12 athletes \n', b'\n', b'\n', b'\n', b'\xc2\xa0\n', b'\t\t\t\n', b'and college athletes.\n', b'\n', b'\n', b'\n', b'\xc2\xa0\n', b'\t\t\t\n', b'\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0BE IT ENACTED BY THE LEGISLATURE OF THE STATE OF TEXAS:\n', b'\n', b'\n', b'\n', b'\xc2\xa0\n', b'\t\t\t\n', b'\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0SECTION\xc2\xa01.\xc2\xa0\xc2\xa0SHORT TITLE.  This Act may be cited as the Save \n', b'\n', b'\n', b'\n', b'\xc2\xa0\n', b'\t\t\t\n', b"Women's Sports Act.\n", b'\n', b'\n', b'\n', b'\xc2\xa0\n', b'\t\t\t\n', b'\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0SECTION\xc2\xa02.\xc2\xa0\xc2\xa0Section 33.0834, Texas Education Code, is \n', b'\n', b'\n', b'\n', b'\xc2\xa0\n', b'\t\t\t\n', b'amended to read as follows:\n', b'\n', b'\n', b'\n', b'\xc2\xa0\n', b'\t\t\t\n', b'\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0Sec.\xc2\xa033.0834.\xc2\xa0\xc2\xa0INTERSCHOLASTIC ATHLETIC COMPETITION\n', b'\n', b'\n', b'\n', b'\xc2\xa0\n', b'\t\t\t\n', b'PARTICIPATION BASED ON BIOLOGICAL SEX.  (a)  Except as provided by \n', b'\n', b'\n', b'\n', b'\xc2\xa0\n', b'\t\t\t\n', b'Subsection (b), an interscholastic athletic team or sport sponsored \n', b'\n', b'\n', b'\n', b'\xc2\xa0\n', b'\t\t\t\n', b'or authorized by a school district,or open-enrollment charter \n', b'\n', b'\n', b'\n', b'\xc2\xa0\n', b'\t\t\t\n', b'school, or any private school that competes against a public school\n', b'\n', b'\n', b'\n', b'\xc2\xa0\n', b'\t\t\t\n', b'may not allow a student to competeparticipate in an \n', b'\n', b'\n', b'\n', b'\xc2\xa0\n', b'\t\t\t\n', b'interscholastic athletic competitionteam or sport sponsored or \n', b'\n', b'\n', b'\n', b'\xc2\xa0\n', b'\t\t\t\n', b'authorized by the district or school that is designated for the \n', b'\n', b'\n', b'\n', b'\xc2\xa0\n', b'\t\t\t\n', b"biological sex opposite to the student's biological sex as \n", b'\n', b'\n', b'\n', b'\xc2\xa0\n', b'\t\t\t\n', b'correctly stated on:\n', b'\n', b'\n', b'\n', b'\xc2\xa0\n', b'\t\t\t\n', b"\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0(1)\xc2\xa0\xc2\xa0the student's official birth certificate, as \n", b'\n', b'\n', b'\n', b'\xc2\xa0\n', b'\t\t\t\n', b'described by Subsection (c); or\n', b'\n', b'\n', b'\n', b'\xc2\xa0\n', b'\t\t\t\n', b"\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0(2)\xc2\xa0\xc2\xa0if the student's official birth certificate \n", b'\n', b'\n', b'\n', b'\xc2\xa0\n', b'\t\t\t\n', b'described by Subdivision (1) is unobtainable, another government \n', b'\n', b'\n', b'\n', b'\xc2\xa0\n', b'\t\t\t\n', b"record that accurately states the student's biological sex.\n", b'\n', b'\n', b'\n', b'\xc2\xa0\n', b'\t\t\t\n', b'\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0(b)\xc2\xa0\xc2\xa0An interscholastic athletic team or sport described by \n', b'\n', b'\n', b'\n', b'\xc2\xa0\n', b'\t\t\t\n', b'Subsection (a) may allow a female student to competeparticipate in \n', b'\n', b'\n', b'\n', b'\xc2\xa0\n', b'\t\t\t\n', b'an interscholastic athletic competitionteam or sport that is \n', b'\n', b'\n', b'\n', b'\xc2\xa0\n', b'\t\t\t\n', b'designated for male students if a corresponding interscholastic\n', b'\n', b'\n', b'\n', b'\xc2\xa0\n', b'\t\t ...

# %% [markdown]
# # Add text from txt files to bill details

# %%
for i in range(len(bill_details)):
    filename = bill_details[i]['bill_id']
    with open(f"billtxts/{filename}.txt", "rb") as f:
        bill_details[i]['text'] = f.readlines()

# %%
bill_details[0]['text']
# Out:
# [b' \n',
#  b'FIRST REGULAR SESSION  \n',
#  b'SENATE BILL NO. 49  \n',
#  b'102ND GENERAL ASSEMBLY   \n',
#  b'INTRODUCED BY SENATOR MOON.  \n',
#  b'0202S.01I  KRISTINA MARTIN, Secretary   \n',
#  b'AN ACT  \n',
#  b'To amend chapter 191, RSMo, by adding thereto one new section relating to gender transition \n',
#  b'procedures.  \n',
#  b' \n',
#  b'Be it enacted by the General Assembly of the State of Missouri, as follows:  \n',
#  b'     Section A.  Chapter 191, RSMo, is amended by adding thereto 1 \n',
#  b'one new section, to be known as section 191.1720, to read as 2 \n',
#  b'follows: 3 \n',
#  b'     191.1720.   1.  This section shall be known and may be  1 \n',
#  b'cited as the "Missouri Save Adolescents from Experimentation  2 \n',
#  b'(SAFE) Act".  3 \n',
#  b'     2.  For purposes of this section, the following t erms  4 \n',
#  b'mean: 5 \n',
#  b'     (1)  "Biological sex", the biological indication of  6 \n',
#  b'male or female in the context of reproductive potential or  7 \n',
#  b'capacity, such as sex chromosomes, naturally occurring sex  8 \n',
#  b'hormones, gonads, and nonambiguous internal and external  9 \n',
#  b'genitali a present at birth, without regard to an  10 \n',
#  b"individual's psychological, chosen, or subjective experience  11 \n",
#  b'of gender;  12 \n',
#  b'     (2)  "Cross-sex hormones":  13 \n',
#  b'     (a)  Testosterone or other androgens given to  14 \n',
#  b'biological sex females in amounts that are larger or more   15 \n',
#  b'potent than would normally occur naturally in healthy  16 \n',
#  b'biological sex females; and  17 \n',
#  b'     (b)  Estrogen given to biological sex males in amounts  18 \n',
#  b'that are larger or more potent than would normally occur  19 \n',
#  b'naturally in healthy biological sex males;  20  SB 49  2 \n',
#  b'     (3)  "Gender", the psychological, behavioral, social,  21 \n',
#  b'and cultural aspects of being male or female;  22 \n',
#  b'     (4)  "Gender reassignment surgery", any medical or  23 \n',
#  b'surgical service that seeks to surgically alter or remove  24 \n',
#  b'healthy physical or anatomical characterist ics or features  25 \n',
#  b"that are typical for the individual's biological sex in  26 \n",
#  b'order to instill or create physiological or anatomical    27 \n',
#  b'characteristics that resemble a sex different from the  28 \n',
#  b"individual's biological sex, including, but not limited to,  29 \n",
#  b'genital or nongenital gender reassignment surgery performed  30 \n',
#  b'for the purpose of assisting an individual with a gender  31 \n',
#  b'transition;  32 \n',
#  b'     (5)  "Gender transition", the process in which an  33 \n',
#  b'individual transitions from identifying with and living as a  34 \n',
#  b'gender that cor responds to his or her biological sex to  35 \n',
#  b'identifying and living as a gender different from his or her  36 \n',
#  b'biological sex, and may involve social, legal, or physical  37 \n',
#  b'changes;  38 \n',
#  b'     (6)  "Gender transition procedures":  39 \n',
#  b'     (a)  Any medical or surgical service , including, but  40 \n',
#  b"not limited to, physician's services, inpatient and  41 \n",
#  b'outpatient hospital services, or prescribed drugs, related  42 \n',
#  b'to gender transition that seeks to:  43 \n',
#  b'     a.  Alter or remove physical or anatomical  44 \n',
#  b'characteristics or features that are typ ical for the  45 \n',
#  b"individual's biological sex; or  46 \n",
#  b'     b.  Instill or create physiological or anatomical  47 \n',
#  b'characteristics that resemble a sex different from the  48 \n',
#  b"individual's biological sex, including, but not limited to:  49 \n",
#  b'     (i)  Medical services that provid e puberty -blocking  50 \n',
#  b'drugs, cross -sex hormones, or other mechanisms to promote  51  SB 49  3 \n',
#  b'the development of feminizing or masculinizing features in  52 \n',
#  b'the opposite biological sex; or  53 \n',
#  b'     (ii)  Genital or nongenital gender reassignment surgery  54 \n',
#  b'performed for the purpo se of assisting an individual with a  55 \n',
#  b'gender transition;  56 \n',
#  b'     (b)  The term "gender transition procedures" shall not  57 \n',
#  b'include:  58 \n',
#  b'     a.  Services to individuals born with a medically - 59 \n',
#  b'verifiable disorder of sex development, including, but not  60 \n',
#  b'limited to, a n individual with external biological sex  61 \n',
#  b'characteristics that are irresolvably ambiguous, such as  62 \n',
#  b'those born with forty -six XX chromosomes with virilization,  63 \n',
#  b'forty-six XY chromosomes with undervirilization, or having  64 \n',
#  b'both ovarian and testicular tissue ; 65 \n',
#  b'     b.  Services provided when a physician has otherwise  66 \n',
#  b'diagnosed an individual with a disorder of sexual  67 \n',
#  b'development and determined through genetic or biochemical  68 \n',
#  b'testing that the individual does not have normal sex  69 \n',
#  b'chromosome structure, sex stero id hormone production, or sex  70 \n',
#  b'steroid hormone action;  71 \n',
#  b'     c.  The treatment of any infection, injury, disease, or  72 \n',
#  b'disorder that has been caused by or exacerbated by the  73 \n',
#  b'performance of gender transition procedures regardless of  74 \n',
#  b'whether the gender trans ition procedure was performed in  75 \n',
#  b'accordance with state and federal law; or  76 \n',
#  b'     d.  Any procedure undertaken because the individual  77 \n',
#  b'suffers from a physical disorder, physical injury, or  78 \n',
#  b'physical illness that would, as certified by a physician,  79 \n',
#  b'place th e individual in imminent danger of death or  80 \n',
#  b'impairment of a major bodily function unless surgery is    81 \n',
#  b'performed;  82  SB 49  4 \n',
#  b'     (7)  "Genital gender reassignment surgery", a medical  83 \n',
#  b'procedure performed for the purpose of assisting an  84 \n',
#  b'individual with a gender tran sition, including, but not  85 \n',
#  b'limited to:  86 \n',
#  b'     (a)  Surgical procedures such as penectomy,  87 \n',
#  b'orchiectomy, vaginoplasty, clitoroplasty, or vulvoplasty for  88 \n',
#  b'biologically male patients or hysterectomy or ovariectomy  89 \n',
#  b'for biologically female patients;  90 \n',
#  b'     (b)  Reconstruction of the fixed part of the urethra  91 \n',
#  b'with or without a metoidioplasty; or  92 \n',
#  b'     (c)  Phalloplasty, vaginectomy, scrotoplasty, or  93 \n',
#  b'implantation of erection or testicular prostheses for  94 \n',
#  b'biologically female patients;  95 \n',
#  b'     (8)  "Health care provider ", an individual who is  96 \n',
#  b'licensed, certified, or otherwise authorized by the laws of  97 \n',
#  b'this state to administer health care in the ordinary course  98 \n',
#  b'of the practice of his or her profession;  99 \n',
#  b'     (9)  "Nongenital gender reassignment surgery", medical  100 \n',
#  b'procedures performed for the purpose of assisting an  101 \n',
#  b'individual with a gender transition, including, but not  102 \n',
#  b'limited to:  103 \n',
#  b'     (a)  Surgical procedures for biologically male  104 \n',
#  b'patients, such as augmentation mammoplasty, facial  105 \n',
#  b'feminization surgery, liposuction,  lipofilling, voice  106 \n',
#  b'surgery, thyroid cartilage reduction, gluteal augmentation,  107 \n',
#  b'hair reconstruction, or various aesthetic procedures; or  108 \n',
#  b'     (b)  Surgical procedures for biologically female  109 \n',
#  b'patients, such as subcutaneous mastectomy, voice surgery,  110 \n',
#  b'liposuction, lipofilling, pectoral implants, or various  111 \n',
#  b'aesthetic procedures;  112 \n',
#  b'     (10)  "Physician", an individual who is licensed under  113 \n',
#  b'chapter 334;  114  SB 49  5 \n',
#  b'     (11)  "Puberty -blocking drugs", gonadotropin -releasing  115 \n',
#  b'hormone analogues or other synthetic drugs us ed in  116 \n',
#  b'biological sex males to stop luteinizing hormone secretion  117 \n',
#  b'and therefore testosterone secretion, or synthetic drugs  118 \n',
#  b'used in biological sex females that stop the production of  119 \n',
#  b'estrogens and progesterone, when used to delay or suppress  120 \n',
#  b'pubertal de velopment in children for the purpose of  121 \n',
#  b'assisting an individual with a gender transition.  122 \n',
#  b'     3.  A physician or other health care provider shall not  123 \n',
#  b'provide gender transition procedures to any individual under  124 \n',
#  b'eighteen years of age and shall not refe r any individual  125 \n',
#  b'under eighteen years of age to any health care provider for  126 \n',
#  b'gender transition procedures.  127 \n',
#  b'     4.  Any referral for or provision of gender transition  128 \n',
#  b'procedures to an individual under eighteen years of age  129 \n',
#  b'shall be considered unprofess ional conduct and any health  130 \n',
#  b'care provider doing so may be subject to discipline by the  131 \n',
#  b'appropriate licensing entity or disciplinary review board  132 \n',
#  b'with competent jurisdiction in this state.  133 \n',
#  b'     5.  The provision of gender transition procedures to an  134 \n',
#  b'individual under eighteen years of age in violation of the  135 \n',
#  b'provisions of this section shall be considered grounds for a  136 \n',
#  b'cause of action against the health care provider for  137 \n',
#  b'personal injury or death under chapter 538 and such cause of  138 \n',
#  b'action shall be gove rned by the provisions of such chapter.    139 \n',
#  b'An individual under eighteen years of age upon whom gender  140 \n',
#  b'transition procedures were performed in violation of this  141 \n',
#  b'section may bring the cause of action either through a next  142 \n',
#  b'friend or his or her own name, sub ject to the provisions of  143 \n',
#  b'section 516.105.  144 \n',
#  b'\xef\x83\xbc ']

# %%
type(bill_details[0])
# Out:
# dict

# %%
keys = bill_details[0].keys()

with open('bill_details.csv','w',newline='') as output_file:
    dict_writer = csv.DictWriter(output_file,keys)
    dict_writer.writeheader()
    dict_writer.writerows(bill_details)

# %% [markdown]
# # More stuff below

# %% [markdown]
# ## Get the bill info for the first result
# This is a dict.

# %%
print(bills['results'][0])
# Out:
# {'relevance': 100, 'state': 'MO', 'bill_number': 'SB49', 'bill_id': 1635057, 'change_hash': 'e09e6c58de86d4d7f02c80d880b2fd09', 'url': 'https://legiscan.com/MO/bill/SB49/2023', 'text_url': 'https://legiscan.com/MO/text/SB49/2023', 'research_url': 'https://legiscan.com/MO/research/SB49/2023', 'last_action_date': '2023-02-27', 'last_action': 'Formal Calendar S Bills for Perfection', 'title': 'Establishes the "Missouri Save Adolescents from Experimentation (SAFE) Act"'}

# %% [markdown]
# ## Get the bill text for the first result
# This is a base64 encoded PDF, as we can see in 'mime':'application/pdf'.

# %%
testbilltext = legis.get_bill_text(2631259)
print(testbilltext)
# Out:
# {'doc_id': 2631259, 'bill_id': 1635057, 'date': '0000-00-00', 'type': 'Introduced', 'type_id': 1, 'mime': 'application/pdf', 'mime_id': 2, 'text_size': 347111, 'text_hash': '2b017580afa21ca9a37198a3291693d5', 'doc': '...', 'alt_document': 0, 'alt_mime': '', 'alt_mime_id': 0, 'alt_text_size': 0, 'alt_text_hash': '', 'alt_doc': ''}

# %% [markdown]
# I struggled with opening this bill text and finally found the solution [here!](https://base64.guru/developers/python/examples/decode-pdf)

# %%
# Define the Base64 string of the PDF file
b64 = testbilltext['doc']

# Decode the Base64 string, making sure that it contains only valid characters
bytes = b64decode(b64, validate=True)

# Perform a basic validation to make sure that the result is a valid PDF file
# Be aware! The magic number (file signature) is not 100% reliable solution to validate PDF files
# Moreover, if you get Base64 from an untrusted source, you must sanitize the PDF contents
if bytes[0:4] != b'%PDF':
  raise ValueError('Missing the PDF file signature')

# Write the PDF contents to a local file
f = open('2631259.pdf', 'wb')
f.write(bytes)
f.close()

# %% [markdown]
# Finally, extracting the text from the entire PDF by finding the number of pages and getting their text one by one.

# %%
reader = PdfReader("2631259.pdf")
for n in range(0,len(reader.pages)):
    page = reader.pages[n]
    text = text + page.extract_text()

# %%
print(text)
# Out:
#
# FIRST REGULAR SESSION
# SENATE BILL NO. 49
# 102ND GENERAL ASSEMBLY
# INTRODUCED BY SENATOR MOON.
# 0202S.01I  KRISTINA MARTIN, Secretary
# AN ACT
# To amend chapter 191, RSMo, by adding thereto one new section relating to gender transition
# procedures.
#
# Be it enacted by the General Assembly of the State of Missouri, as follows:
#      Section A.  Chapter 191, RSMo, is amended by adding thereto 1
# one new section, to be known as section 191.1720, to read as 2
# follows: 3
#      191.1720.   1.  This section shall be known and may be  1
# cited as the "Missouri Save Adolescents from Experimentation  2
# (SAFE) Act".  3
#      2.  For purposes of this section, the following t erms  4
# mean: 5
#      (1)  "Biological sex", the biological indication of  6
# male or female in the context of reproductive potential or  7
# capacity, such as sex chromosomes, naturally occurring sex  8
# hormones, gonads, and nonambiguous internal and external  9
# genitali a present at birth, without regard to an  10
# individual's psychological, chosen, or subjective experience  11
# of gender;  12
#      (2)  "Cross-sex hormones":  13
#      (a)  Testosterone or other androgens given to  14
# biological sex females in amounts that are larger or more   15
# potent than would normally occur naturally in healthy  16
# biological sex females; and  17
#      (b)  Estrogen given to biological sex males in amounts  18
# that are larger or more potent than would normally occur  19
# naturally in healthy biological sex males;  20  SB 49  2
#      (3)  "Gender", the psychological, behavioral, social,  21
# and cultural aspects of being male or female;  22
#      (4)  "Gender reassignment surgery", any medical or  23
# surgical service that seeks to surgically alter or remove  24
# healthy physical or anatomical characterist ics or features  25
# that are typical for the individual's biological sex in  26
# order to instill or create physiological or anatomical    27
# characteristics that resemble a sex different from the  28
# individual's biological sex, including, but not limited to,  29
# genital or nongenital gender reassignment surgery performed  30
# for the purpose of assisting an individual with a gender  31
# transition;  32
#      (5)  "Gender transition", the process in which an  33
# individual transitions from identifying with and living as a  34
# gender that cor responds to his or her biological sex to  35
# identifying and living as a gender different from his or her  36
# biological sex, and may involve social, legal, or physical  37
# changes;  38
#      (6)  "Gender transition procedures":  39
#      (a)  Any medical or surgical service , including, but  40
# not limited to, physician's services, inpatient and  41
# outpatient hospital services, or prescribed drugs, related  42
# to gender transition that seeks to:  43
#      a.  Alter or remove physical or anatomical  44
# characteristics or features that are typ ical for the  45
# individual's biological sex; or  46
#      b.  Instill or create physiological or anatomical  47
# characteristics that resemble a sex different from the  48
# individual's biological sex, including, but not limited to:  49
#      (i)  Medical services that provid e puberty -blocking  50
# drugs, cross -sex hormones, or other mechanisms to promote  51  SB 49  3
# the development of feminizing or masculinizing features in  52
# the opposite biological sex; or  53
#      (ii)  Genital or nongenital gender reassignment surgery  54
# performed for the purpo se of assisting an individual with a  55
# gender transition;  56
#      (b)  The term "gender transition procedures" shall not  57
# include:  58
#      a.  Services to individuals born with a medically - 59
# verifiable disorder of sex development, including, but not  60
# limited to, a n individual with external biological sex  61
# characteristics that are irresolvably ambiguous, such as  62
# those born with forty -six XX chromosomes with virilization,  63
# forty-six XY chromosomes with undervirilization, or having  64
# both ovarian and testicular tissue ; 65
#      b.  Services provided when a physician has otherwise  66
# diagnosed an individual with a disorder of sexual  67
# development and determined through genetic or biochemical  68
# testing that the individual does not have normal sex  69
# chromosome structure, sex stero id hormone production, or sex  70
# steroid hormone action;  71
#      c.  The treatment of any infection, injury, disease, or  72
# disorder that has been caused by or exacerbated by the  73
# performance of gender transition procedures regardless of  74
# whether the gender trans ition procedure was performed in  75
# accordance with state and federal law; or  76
#      d.  Any procedure undertaken because the individual  77
# suffers from a physical disorder, physical injury, or  78
# physical illness that would, as certified by a physician,  79
# place th e individual in imminent danger of death or  80
# impairment of a major bodily function unless surgery is    81
# performed;  82  SB 49  4
#      (7)  "Genital gender reassignment surgery", a medical  83
# procedure performed for the purpose of assisting an  84
# individual with a gender tran sition, including, but not  85
# limited to:  86
#      (a)  Surgical procedures such as penectomy,  87
# orchiectomy, vaginoplasty, clitoroplasty, or vulvoplasty for  88
# biologically male patients or hysterectomy or ovariectomy  89
# for biologically female patients;  90
#      (b)  Reconstruction of the fixed part of the urethra  91
# with or without a metoidioplasty; or  92
#      (c)  Phalloplasty, vaginectomy, scrotoplasty, or  93
# implantation of erection or testicular prostheses for  94
# biologically female patients;  95
#      (8)  "Health care provider ", an individual who is  96
# licensed, certified, or otherwise authorized by the laws of  97
# this state to administer health care in the ordinary course  98
# of the practice of his or her profession;  99
#      (9)  "Nongenital gender reassignment surgery", medical  100
# procedures performed for the purpose of assisting an  101
# individual with a gender transition, including, but not  102
# limited to:  103
#      (a)  Surgical procedures for biologically male  104
# patients, such as augmentation mammoplasty, facial  105
# feminization surgery, liposuction,  lipofilling, voice  106
# surgery, thyroid cartilage reduction, gluteal augmentation,  107
# hair reconstruction, or various aesthetic procedures; or  108
#      (b)  Surgical procedures for biologically female  109
# patients, such as subcutaneous mastectomy, voice surgery,  110
# liposuction, lipofilling, pectoral implants, or various  111
# aesthetic procedures;  112
#      (10)  "Physician", an individual who is licensed under  113
# chapter 334;  114  SB 49  5
#      (11)  "Puberty -blocking drugs", gonadotropin -releasing  115
# hormone analogues or other synthetic drugs us ed in  116
# biological sex males to stop luteinizing hormone secretion  117
# and therefore testosterone secretion, or synthetic drugs  118
# used in biological sex females that stop the production of  119
# estrogens and progesterone, when used to delay or suppress  120
# pubertal de velopment in children for the purpose of  121
# assisting an individual with a gender transition.  122
#      3.  A physician or other health care provider shall not  123
# provide gender transition procedures to any individual under  124
# eighteen years of age and shall not refe r any individual  125
# under eighteen years of age to any health care provider for  126
# gender transition procedures.  127
#      4.  Any referral for or provision of gender transition  128
# procedures to an individual under eighteen years of age  129
# shall be considered unprofess ional conduct and any health  130
# care provider doing so may be subject to discipline by the  131
# appropriate licensing entity or disciplinary review board  132
# with competent jurisdiction in this state.  133
#      5.  The provision of gender transition procedures to an  134
# individual under eighteen years of age in violation of the  135
# provisions of this section shall be considered grounds for a  136
# cause of action against the health care provider for  137
# personal injury or death under chapter 538 and such cause of  138
# action shall be gove rned by the provisions of such chapter.    139
# An individual under eighteen years of age upon whom gender  140
# transition procedures were performed in violation of this  141
# section may bring the cause of action either through a next  142
# friend or his or her own name, sub ject to the provisions of  143
# section 516.105.  144
# 
# FIRST REGULAR SESSION
# SENATE BILL NO. 49
# 102ND GENERAL ASSEMBLY
# INTRODUCED BY SENATOR MOON.
# 0202S.01I  KRISTINA MARTIN, Secretary
# AN ACT
# To amend chapter 191, RSMo, by adding thereto one new section relating to gender transition
# procedures.
#
# Be it enacted by the General Assembly of the State of Missouri, as follows:
#      Section A.  Chapter 191, RSMo, is amended by adding thereto 1
# one new section, to be known as section 191.1720, to read as 2
# follows: 3
#      191.1720.   1.  This section shall be known and may be  1
# cited as the "Missouri Save Adolescents from Experimentation  2
# (SAFE) Act".  3
#      2.  For purposes of this section, the following t erms  4
# mean: 5
#      (1)  "Biological sex", the biological indication of  6
# male or female in the context of reproductive potential or  7
# capacity, such as sex chromosomes, naturally occurring sex  8
# hormones, gonads, and nonambiguous internal and external  9
# genitali a present at birth, without regard to an  10
# individual's psychological, chosen, or subjective experience  11
# of gender;  12
#      (2)  "Cross-sex hormones":  13
#      (a)  Testosterone or other androgens given to  14
# biological sex females in amounts that are larger or more   15
# potent than would normally occur naturally in healthy  16
# biological sex females; and  17
#      (b)  Estrogen given to biological sex males in amounts  18
# that are larger or more potent than would normally occur  19
# naturally in healthy biological sex males;  20  SB 49  2
#      (3)  "Gender", the psychological, behavioral, social,  21
# and cultural aspects of being male or female;  22
#      (4)  "Gender reassignment surgery", any medical or  23
# surgical service that seeks to surgically alter or remove  24
# healthy physical or anatomical characterist ics or features  25
# that are typical for the individual's biological sex in  26
# order to instill or create physiological or anatomical    27
# characteristics that resemble a sex different from the  28
# individual's biological sex, including, but not limited to,  29
# genital or nongenital gender reassignment surgery performed  30
# for the purpose of assisting an individual with a gender  31
# transition;  32
#      (5)  "Gender transition", the process in which an  33
# individual transitions from identifying with and living as a  34
# gender that cor responds to his or her biological sex to  35
# identifying and living as a gender different from his or her  36
# biological sex, and may involve social, legal, or physical  37
# changes;  38
#      (6)  "Gender transition procedures":  39
#      (a)  Any medical or surgical service , including, but  40
# not limited to, physician's services, inpatient and  41
# outpatient hospital services, or prescribed drugs, related  42
# to gender transition that seeks to:  43
#      a.  Alter or remove physical or anatomical  44
# characteristics or features that are typ ical for the  45
# individual's biological sex; or  46
#      b.  Instill or create physiological or anatomical  47
# characteristics that resemble a sex different from the  48
# individual's biological sex, including, but not limited to:  49
#      (i)  Medical services that provid e puberty -blocking  50
# drugs, cross -sex hormones, or other mechanisms to promote  51  SB 49  3
# the development of feminizing or masculinizing features in  52
# the opposite biological sex; or  53
#      (ii)  Genital or nongenital gender reassignment surgery  54
# performed for the purpo se of assisting an individual with a  55
# gender transition;  56
#      (b)  The term "gender transition procedures" shall not  57
# include:  58
#      a.  Services to individuals born with a medically - 59
# verifiable disorder of sex development, including, but not  60
# limited to, a n individual with external biological sex  61
# characteristics that are irresolvably ambiguous, such as  62
# those born with forty -six XX chromosomes with virilization,  63
# forty-six XY chromosomes with undervirilization, or having  64
# both ovarian and testicular tissue ; 65
#      b.  Services provided when a physician has otherwise  66
# diagnosed an individual with a disorder of sexual  67
# development and determined through genetic or biochemical  68
# testing that the individual does not have normal sex  69
# chromosome structure, sex stero id hormone production, or sex  70
# steroid hormone action;  71
#      c.  The treatment of any infection, injury, disease, or  72
# disorder that has been caused by or exacerbated by the  73
# performance of gender transition procedures regardless of  74
# whether the gender trans ition procedure was performed in  75
# accordance with state and federal law; or  76
#      d.  Any procedure undertaken because the individual  77
# suffers from a physical disorder, physical injury, or  78
# physical illness that would, as certified by a physician,  79
# place th e individual in imminent danger of death or  80
# impairment of a major bodily function unless surgery is    81
# performed;  82  SB 49  4
#      (7)  "Genital gender reassignment surgery", a medical  83
# procedure performed for the purpose of assisting an  84
# individual with a gender tran sition, including, but not  85
# limited to:  86
#      (a)  Surgical procedures such as penectomy,  87
# orchiectomy, vaginoplasty, clitoroplasty, or vulvoplasty for  88
# biologically male patients or hysterectomy or ovariectomy  89
# for biologically female patients;  90
#      (b)  Reconstruction of the fixed part of the urethra  91
# with or without a metoidioplasty; or  92
#      (c)  Phalloplasty, vaginectomy, scrotoplasty, or  93
# implantation of erection or testicular prostheses for  94
# biologically female patients;  95
#      (8)  "Health care provider ", an individual who is  96
# licensed, certified, or otherwise authorized by the laws of  97
# this state to administer health care in the ordinary course  98
# of the practice of his or her profession;  99
#      (9)  "Nongenital gender reassignment surgery", medical  100
# procedures performed for the purpose of assisting an  101
# individual with a gender transition, including, but not  102
# limited to:  103
#      (a)  Surgical procedures for biologically male  104
# patients, such as augmentation mammoplasty, facial  105
# feminization surgery, liposuction,  lipofilling, voice  106
# surgery, thyroid cartilage reduction, gluteal augmentation,  107
# hair reconstruction, or various aesthetic procedures; or  108
#      (b)  Surgical procedures for biologically female  109
# patients, such as subcutaneous mastectomy, voice surgery,  110
# liposuction, lipofilling, pectoral implants, or various  111
# aesthetic procedures;  112
#      (10)  "Physician", an individual who is licensed under  113
# chapter 334;  114  SB 49  5
#      (11)  "Puberty -blocking drugs", gonadotropin -releasing  115
# hormone analogues or other synthetic drugs us ed in  116
# biological sex males to stop luteinizing hormone secretion  117
# and therefore testosterone secretion, or synthetic drugs  118
# used in biological sex females that stop the production of  119
# estrogens and progesterone, when used to delay or suppress  120
# pubertal de velopment in children for the purpose of  121
# assisting an individual with a gender transition.  122
#      3.  A physician or other health care provider shall not  123
# provide gender transition procedures to any individual under  124
# eighteen years of age and shall not refe r any individual  125
# under eighteen years of age to any health care provider for  126
# gender transition procedures.  127
#      4.  Any referral for or provision of gender transition  128
# procedures to an individual under eighteen years of age  129
# shall be considered unprofess ional conduct and any health  130
# care provider doing so may be subject to discipline by the  131
# appropriate licensing entity or disciplinary review board  132
# with competent jurisdiction in this state.  133
#      5.  The provision of gender transition procedures to an  134
# individual under eighteen years of age in violation of the  135
# provisions of this section shall be considered grounds for a  136
# cause of action against the health care provider for  137
# personal injury or death under chapter 538 and such cause of  138
# action shall be gove rned by the provisions of such chapter.    139
# An individual under eighteen years of age upon whom gender  140
# transition procedures were performed in violation of this  141
# section may bring the cause of action either through a next  142
# friend or his or her own name, sub ject to the provisions of  143
# section 516.105.  144
# 

# %%
g = open('2631259.txt', 'w')
g.write(text)
g.close()

# %% [markdown]
# I previously extracted the wrong text, because get_bill_text takes doc_id as the argument and not bill id!

# %% [markdown]
# # Next steps
# I think I need to [create a pandas dataframe](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.from_records.html#pandas.DataFrame.from_records) to hold all the bills['results'] info, then add an empty column for the bill text, then go through each of the bill IDs and download their text, accounting for each data type (some doc, some txt, some PDF, some HTML? check using the get_bill_text 'mime').
#
# Then I have to clean it up, removing things like the numbers above. Then I can begin to use NLP tools to mess around with them.

# %%
df = pd.DataFrame.from_records(bills['results'])
df.shape
# Out:
# (50, 11)

# %% [markdown]
# I just realized that bills is only the first 50 results, from the first page of the search query. To get them all I have to iterate through the pages.

# %%
billslist = []
for i in range(1,10):
    bills = legis.search(state='ALL', query='biological sex', page=i)
    billslist.append(bills)

# %%
for i in range(1,10):
    print(billslist[i]['summary'])
# Out:
# {'page': '2 of 6', 'range': '51 - 100', 'relevancy': '98% - 97%', 'count': 298, 'page_current': '2', 'page_total': 6, 'query': '((Zbiolog:(pos=1) AND Zsex:(pos=2)))'}
# {'page': '3 of 8', 'range': '101 - 150', 'relevancy': '97% - 96%', 'count': 378, 'page_current': '3', 'page_total': 8, 'query': '((Zbiolog:(pos=1) AND Zsex:(pos=2)))'}
# {'page': '4 of 9', 'range': '151 - 200', 'relevancy': '96% - 94%', 'count': 445, 'page_current': '4', 'page_total': 9, 'query': '((Zbiolog:(pos=1) AND Zsex:(pos=2)))'}
# {'page': '5 of 10', 'range': '201 - 250', 'relevancy': '94% - 92%', 'count': 478, 'page_current': '5', 'page_total': 10, 'query': '((Zbiolog:(pos=1) AND Zsex:(pos=2)))'}
# {'page': '6 of 11', 'range': '251 - 300', 'relevancy': '92% - 89%', 'count': 501, 'page_current': '6', 'page_total': 11, 'query': '((Zbiolog:(pos=1) AND Zsex:(pos=2)))'}
# {'page': '7 of 11', 'range': '301 - 350', 'relevancy': '89% - 85%', 'count': 534, 'page_current': '7', 'page_total': 11, 'query': '((Zbiolog:(pos=1) AND Zsex:(pos=2)))'}
# {'page': '8 of 11', 'range': '351 - 400', 'relevancy': '85% - 81%', 'count': 550, 'page_current': '8', 'page_total': 11, 'query': '((Zbiolog:(pos=1) AND Zsex:(pos=2)))'}
# {'page': '9 of 12', 'range': '401 - 450', 'relevancy': '81% - 75%', 'count': 567, 'page_current': '9', 'page_total': 12, 'query': '((Zbiolog:(pos=1) AND Zsex:(pos=2)))'}
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/lj/gz81psj55xg1_fm6jfz2vbn80000gn/T/ipykernel_18615/2389928932.py in <module>
#       1 for i in range(1,10):
# ----> 2     print(billslist[i]['summary'])
#
# IndexError: list index out of range

# %%
len(billslist)
# Out:
# 9

# %%
billslist
# Out:
# [{'summary': {'page': '1 of 4',
#    'range': '1 - 50',
#    'relevancy': '100% - 98%',
#    'count': 173,
#    'page_current': '1',
#    'page_total': 4,
#    'query': '((Zbiolog:(pos=1) AND Zsex:(pos=2)))'},
#   'results': [{'relevance': 100,
#     'state': 'MO',
#     'bill_number': 'SB49',
#     'bill_id': 1635057,
#     'change_hash': 'e09e6c58de86d4d7f02c80d880b2fd09',
#     'url': 'https://legiscan.com/MO/bill/SB49/2023',
#     'text_url': 'https://legiscan.com/MO/text/SB49/2023',
#     'research_url': 'https://legiscan.com/MO/research/SB49/2023',
#     'last_action_date': '2023-02-27',
#     'last_action': 'Formal Calendar S Bills for Perfection',
#     'title': 'Establishes the "Missouri Save Adolescents from Experimentation (SAFE) Act"'},
#    {'relevance': 99,
#     'state': 'SC',
#     'bill_number': 'S0274',
#     'bill_id': 1637125,
#     'change_hash': '613f2f6755636d08d7795134c641ada1',
#     'url': 'https://legiscan.com/SC/bill/S0274/2023',
#     'text_url': 'https://legiscan.com/SC/text/S0274/2023',
#     'research_url': 'https://legiscan.com/SC/research/S0274/2023',
#     'last_action_date': '2023-02-09',
#     'last_action': "Scrivener's error corrected",
#     'title': 'Gender Reassignment Surgery'},
#    {'relevance': 99,
#     'state': 'MO',
#     'bill_number': 'HB916',
#     'bill_id': 1675866,
#     'change_hash': '05c3c4c0a8a3c2542c05e90e74ff24cd',
#     'url': 'https://legiscan.com/MO/bill/HB916/2023',
#     'text_url': 'https://legiscan.com/MO/text/HB916/2023',
#     'research_url': 'https://legiscan.com/MO/research/HB916/2023',
#     'last_action_date': '2023-01-25',
#     'last_action': 'Referred: General Laws(H)',
#     'title': 'Creates provisions relating to gender transition procedures'},
#    {'relevance': 99,
#     'state': 'UT',
#     'bill_number': 'SB0016',
#     'bill_id': 1639439,
#     'change_hash': '08365a8389d5396972c4bf8ea24aba4f',
#     'url': 'https://legiscan.com/UT/bill/SB0016/2023',
#     'text_url': 'https://legiscan.com/UT/text/SB0016/2023',
#     'research_url': 'https://legiscan.com/UT/research/SB0016/2023',
#     'last_action_date': '2023-02-01',
#     'last_action': "LFA/ fiscal note publicly available in Lieutenant Governor's office for filing",
#     'title': 'Transgender Medical Treatments and Procedures Amendments'},
#    {'relevance': 99,
#     'state': 'MO',
#     'bill_number': 'HB419',
#     'bill_id': 1640339,
#     'change_hash': '36f5f692a4392344905d74f770d1e5c7',
#     'url': 'https://legiscan.com/MO/bill/HB419/2023',
#     'text_url': 'https://legiscan.com/MO/text/HB419/2023',
#     'research_url': 'https://legiscan.com/MO/research/HB419/2023',
#     'last_action_date': '2023-02-21',
#     'last_action': 'Referred: Rules - Legislative Oversight(H)',
#     'title': 'Creates provisions relating to gender transition procedures'},
#    {'relevance': 99,
#     'state': 'IN',
#     'bill_number': 'HB1231',
#     'bill_id': 1650034,
#     'change_hash': '316cf640f6556f7e7f03f2811bdd8ad6',
#     'url': 'https://legiscan.com/IN/bill/HB1231/2023',
#     'text_url': 'https://legiscan.com/IN/text/HB1231/2023',
#     'research_url': 'https://legiscan.com/IN/research/HB1231/2023',
#     'last_action_date': '2023-01-19',
#     'last_action': 'Representatives Prescott and Abbott D added as coauthors',
#     'title': 'Gender transition procedures for minors.'},
#    {'relevance': 99,
#     'state': 'MO',
#     'bill_number': 'SB236',
#     'bill_id': 1634951,
#     'change_hash': '9639e5a4ce4064ba8ade8b2df68e8100',
#     'url': 'https://legiscan.com/MO/bill/SB236/2023',
#     'text_url': 'https://legiscan.com/MO/text/SB236/2023',
#     'research_url': 'https://legiscan.com/MO/research/SB236/2023',
#     'last_action_date': '2023-02-20',
#     'last_action': 'Bill Combined w/(SCSs SB 49, 236 & 164)',
#     'title': 'Establishes the "Missouri Save Adolescents from Experimentation (SAFE) Act"'},
#    {'relevance': 99,
#     'state': 'OK',
#     'bill_number': 'SB878',
#     'bill_id': 1668356,
#     'change_hash': '4491b296029623591bc74ecc32b65bbe',
#     'url': 'https://legiscan.com/OK/bill/SB878/2023',
#     'text_url': 'https://legiscan.com/OK/text/SB878/2023',
#     'research_url': 'https://legiscan.com/OK/research/SB878/2023',
#     'last_action_date': '2023-02-07',
#     'last_action': 'Second Reading referred to Rules',
#     'title': 'Health care; creating the Oklahoma Save Adolescents from Experimentation (SAFE) Act; prohibiting gender transition procedures; providing for administrative and civil enforcement. Emergency.'},
#    {'relevance': 99,
#     'state': 'NE',
#     'bill_number': 'LB574',
#     'bill_id': 1662540,
#     'change_hash': '85e2b1a0ac2934bec3d760e1192db6e1',
#     'url': 'https://legiscan.com/NE/bill/LB574/2023',
#     'text_url': 'https://legiscan.com/NE/text/LB574/2023',
#     'research_url': 'https://legiscan.com/NE/research/LB574/2023',
#     'last_action_date': '2023-02-24',
#     'last_action': 'Kauth priority bill',
#     'title': 'Adopt the Let Them Grow Act'},
#    {'relevance': 99,
#     'state': 'MO',
#     'bill_number': 'SB598',
#     'bill_id': 1696931,
#     'change_hash': '1e4ada3a68cbc080b9f1f883410eb86f',
#     'url': 'https://legiscan.com/MO/bill/SB598/2023',
#     'text_url': 'https://legiscan.com/MO/text/SB598/2023',
#     'research_url': 'https://legiscan.com/MO/research/SB598/2023',
#     'last_action_date': '2023-02-06',
#     'last_action': 'S First Read',
#     'title': 'Establishes the "Missouri Child and Adolescent Protection Act"'},
#    {'relevance': 99,
#     'state': 'WV',
#     'bill_number': 'HB2007',
#     'bill_id': 1656233,
#     'change_hash': '32dd2c02a4fcc89851a9d0f466f0e8bf',
#     'url': 'https://legiscan.com/WV/bill/HB2007/2023',
#     'text_url': 'https://legiscan.com/WV/text/HB2007/2023',
#     'research_url': 'https://legiscan.com/WV/research/HB2007/2023',
#     'last_action_date': '2023-02-06',
#     'last_action': 'To Health and Human Resources',
#     'title': 'Prohibiting certain medical practices'},
#    {'relevance': 99,
#     'state': 'OK',
#     'bill_number': 'HB1011',
#     'bill_id': 1634447,
#     'change_hash': '753c0be48715689d9136707673685817',
#     'url': 'https://legiscan.com/OK/bill/HB1011/2023',
#     'text_url': 'https://legiscan.com/OK/text/HB1011/2023',
#     'research_url': 'https://legiscan.com/OK/research/HB1011/2023',
#     'last_action_date': '2023-02-07',
#     'last_action': 'Second Reading referred to Public Health',
#     'title': 'Public health and safety; defining terms; health care professionals; gender transition procedures; referrals; exceptions; public funds; Medicaid program reimbursements; felony penalties; statute of limitations; unprofessional conduct; license revocation; statute of limitations; claims or defenses; civil actions; administrative remedies; attorney fees; Attorney General; codification; effective date.'},
#    {'relevance': 99,
#     'state': 'VA',
#     'bill_number': 'SB1203',
#     'bill_id': 1651270,
#     'change_hash': '02212fd0bd221a4f9f17cbd804c1dbc7',
#     'url': 'https://legiscan.com/VA/bill/SB1203/2023',
#     'text_url': 'https://legiscan.com/VA/text/SB1203/2023',
#     'research_url': 'https://legiscan.com/VA/research/SB1203/2023',
#     'last_action_date': '2023-02-02',
#     'last_action': 'Incorporated by Education and Health ',
#     'title': 'Children Deserve Help Not Harm Act established, health benefit plans, etc.'},
#    {'relevance': 99,
#     'state': 'VA',
#     'bill_number': 'SB791',
#     'bill_id': 1634198,
#     'change_hash': '6600c8bab2669bec471c70b2258de77d',
#     'url': 'https://legiscan.com/VA/bill/SB791/2023',
#     'text_url': 'https://legiscan.com/VA/text/SB791/2023',
#     'research_url': 'https://legiscan.com/VA/research/SB791/2023',
#     'last_action_date': '2023-02-02',
#     'last_action': 'Passed by indefinitely in Education and Health (8-Y 5-N)',
#     'title': 'Save Adolescents from Experimentation (SAFE) Act; established, health benefit plans, etc.'},
#    {'relevance': 99,
#     'state': 'GA',
#     'bill_number': 'SB141',
#     'bill_id': 1702869,
#     'change_hash': '7e91b8c0bfdf541aa03c15a172db6b3a',
#     'url': 'https://legiscan.com/GA/bill/SB141/2023',
#     'text_url': 'https://legiscan.com/GA/text/SB141/2023',
#     'research_url': 'https://legiscan.com/GA/research/SB141/2023',
#     'last_action_date': '2023-02-13',
#     'last_action': 'Senate Read and Referred',
#     'title': "Professions and Businesses; health care providers from performing specified practices on minors relating to altering a person's appearance relating to gender; prohibit"},
#    {'relevance': 99,
#     'state': 'OK',
#     'bill_number': 'SB129',
#     'bill_id': 1643087,
#     'change_hash': 'a30df4aa9d42d7441e263ece9162cc41',
#     'url': 'https://legiscan.com/OK/bill/SB129/2023',
#     'text_url': 'https://legiscan.com/OK/text/SB129/2023',
#     'research_url': 'https://legiscan.com/OK/research/SB129/2023',
#     'last_action_date': '2023-02-13',
#     'last_action': 'Coauthored by Senator Burns',
#     'title': 'Health care; prohibiting certain uses of public funds, public facilities, and public employees. Emergency.'},
#    {'relevance': 99,
#     'state': 'NH',
#     'bill_number': 'HB619',
#     'bill_id': 1654313,
#     'change_hash': '9cd0bfe43c4a736ae2557c8869661c61',
#     'url': 'https://legiscan.com/NH/bill/HB619/2023',
#     'text_url': 'https://legiscan.com/NH/text/HB619/2023',
#     'research_url': 'https://legiscan.com/NH/research/HB619/2023',
#     'last_action_date': '2023-02-08',
#     'last_action': 'Public Hearing: 03/07/2023 10:00 am State House Reps Hall',
#     'title': 'Prohibiting gender transition procedures for minors, relative to sex and gender in public schools, and relative to the definition of conversion therapy.'},
#    {'relevance': 99,
#     'state': 'SC',
#     'bill_number': 'H3730',
#     'bill_id': 1665859,
#     'change_hash': '5a3b041da1aa2b4c1d602731e28fc179',
#     'url': 'https://legiscan.com/SC/bill/H3730/2023',
#     'text_url': 'https://legiscan.com/SC/text/H3730/2023',
#     'research_url': 'https://legiscan.com/SC/research/H3730/2023',
#     'last_action_date': '2023-01-18',
#     'last_action': 'Referred to Committee on Judiciary',
#     'title': 'Millstone Act of 2023'},
#    {'relevance': 99,
#     'state': 'IN',
#     'bill_number': 'HB1232',
#     'bill_id': 1650067,
#     'change_hash': 'f11f848fa36d52e1e2a5718df7d0360b',
#     'url': 'https://legiscan.com/IN/bill/HB1232/2023',
#     'text_url': 'https://legiscan.com/IN/text/HB1232/2023',
#     'research_url': 'https://legiscan.com/IN/research/HB1232/2023',
#     'last_action_date': '2023-01-12',
#     'last_action': 'Representative Davis M added as coauthor',
#     'title': 'Child removal and gender identity.'},
#    {'relevance': 99,
#     'state': 'OK',
#     'bill_number': 'HB1377',
#     'bill_id': 1663548,
#     'change_hash': '0e1d6ec349675d5fd3f6d76d43bf0d80',
#     'url': 'https://legiscan.com/OK/bill/HB1377/2023',
#     'text_url': 'https://legiscan.com/OK/text/HB1377/2023',
#     'research_url': 'https://legiscan.com/OK/research/HB1377/2023',
#     'last_action_date': '2023-02-07',
#     'last_action': 'Second Reading referred to Public Health',
#     'title': 'Oklahoma Save Adolescents from Experimentation (SAFE) Act; effective date.'},
#    {'relevance': 99,
#     'state': 'SC',
#     'bill_number': 'S0243',
#     'bill_id': 1635919,
#     'change_hash': '59b3e382981857cc835c54787c87c247',
#     'url': 'https://legiscan.com/SC/bill/S0243/2023',
#     'text_url': 'https://legiscan.com/SC/text/S0243/2023',
#     'research_url': 'https://legiscan.com/SC/research/S0243/2023',
#     'last_action_date': '2023-01-10',
#     'last_action': 'Referred to Committee on Medical Affairs',
#     'title': 'Gender reassignment'},
#    {'relevance': 99,
#     'state': 'WA',
#     'bill_number': 'HB1214',
#     'bill_id': 1649602,
#     'change_hash': '3815dfbf6527c15a065e2aba08ab14da',
#     'url': 'https://legiscan.com/WA/bill/HB1214/2023',
#     'text_url': 'https://legiscan.com/WA/text/HB1214/2023',
#     'research_url': 'https://legiscan.com/WA/research/HB1214/2023',
#     'last_action_date': '2023-01-10',
#     'last_action': 'First reading, referred to Health Care & Wellness.',
#     'title': 'Enacting the protecting children&#x27;s bodies act.'},
#    {'relevance': 99,
#     'state': 'MO',
#     'bill_number': 'HB183',
#     'bill_id': 1634572,
#     'change_hash': 'd5cf7daa71cf93e447366696b3fa7597',
#     'url': 'https://legiscan.com/MO/bill/HB183/2023',
#     'text_url': 'https://legiscan.com/MO/text/HB183/2023',
#     'research_url': 'https://legiscan.com/MO/research/HB183/2023',
#     'last_action_date': '2023-02-21',
#     'last_action': 'Referred: Rules - Legislative Oversight(H)',
#     'title': 'Establishes guidelines for student participation in athletic contests organized by sex'},
#    {'relevance': 99,
#     'state': 'ND',
#     'bill_number': 'HCR3010',
#     'bill_id': 1683622,
#     'change_hash': '02e88a7adf9985af756fef6202cd66c3',
#     'url': 'https://legiscan.com/ND/bill/HCR3010/2023',
#     'text_url': 'https://legiscan.com/ND/text/HCR3010/2023',
#     'research_url': 'https://legiscan.com/ND/research/HCR3010/2023',
#     'last_action_date': '2023-02-16',
#     'last_action': 'Introduced, first reading, referred to Human Services',
#     'title': "A concurrent resolution urging public schools and public entities, including agencies or departments that collect vital statistics, to protect women's rights by distinguishing between the sexes according to biological sex at birth for the purpose of providing equal opportunities and ensuring the privacy and safety of women and girls."},
#    {'relevance': 99,
#     'state': 'MO',
#     'bill_number': 'SB164',
#     'bill_id': 1635148,
#     'change_hash': 'ecea5e2d8b371fe25f095cd290b56929',
#     'url': 'https://legiscan.com/MO/bill/SB164/2023',
#     'text_url': 'https://legiscan.com/MO/text/SB164/2023',
#     'research_url': 'https://legiscan.com/MO/research/SB164/2023',
#     'last_action_date': '2023-02-20',
#     'last_action': 'Bill Combined w/(SCSs SB 49, 236 & 164)',
#     'title': 'Establishes the "Missouri Save Adolescents from Experimentation (SAFE) Act"'},
#    {'relevance': 99,
#     'state': 'WV',
#     'bill_number': 'SB692',
#     'bill_id': 1715006,
#     'change_hash': '8895d8bd5f9f9b0808e4cd0e6adcd5f1',
#     'url': 'https://legiscan.com/WV/bill/SB692/2023',
#     'text_url': 'https://legiscan.com/WV/text/SB692/2023',
#     'research_url': 'https://legiscan.com/WV/research/SB692/2023',
#     'last_action_date': '2023-02-20',
#     'last_action': 'To Health and Human Resources',
#     'title': 'Relating to gender reassignment medical services for minors'},
#    {'relevance': 99,
#     'state': 'MO',
#     'bill_number': 'HB463',
#     'bill_id': 1640281,
#     'change_hash': '52d58c5203f5a5c21a67d6269e5c185c',
#     'url': 'https://legiscan.com/MO/bill/HB463/2023',
#     'text_url': 'https://legiscan.com/MO/text/HB463/2023',
#     'research_url': 'https://legiscan.com/MO/research/HB463/2023',
#     'last_action_date': '2023-01-24',
#     'last_action': 'Public Hearing Completed (H)',
#     'title': 'Creates provisions relating to gender transition procedures'},
#    {'relevance': 99,
#     'state': 'SD',
#     'bill_number': 'HB1080',
#     'bill_id': 1660616,
#     'change_hash': '39e872fb7e44b687a5c1d5318b6193fe',
#     'url': 'https://legiscan.com/SD/bill/HB1080/2023',
#     'text_url': 'https://legiscan.com/SD/text/HB1080/2023',
#     'research_url': 'https://legiscan.com/SD/research/HB1080/2023',
#     'last_action_date': '2023-02-14',
#     'last_action': 'Signed by the Governor on February 14, 2023 H.J. 290',
#     'title': 'Prohibit certain medical and surgical interventions on minor patients.'},
#    {'relevance': 99,
#     'state': 'KS',
#     'bill_number': 'SB180',
#     'bill_id': 1698406,
#     'change_hash': 'fe2104c0f059a44f052a019b3995873b',
#     'url': 'https://legiscan.com/KS/bill/SB180/2023',
#     'text_url': 'https://legiscan.com/KS/text/SB180/2023',
#     'research_url': 'https://legiscan.com/KS/research/SB180/2023',
#     'last_action_date': '2023-02-23',
#     'last_action': 'Senate Final Action - Passed;  Yea: 26 Nay: 10',
#     'title': "Establishing the women's bill of rights to provide a meaning of biological sex for purposes of statutory construction."},
#    {'relevance': 99,
#     'state': 'OK',
#     'bill_number': 'HB2177',
#     'bill_id': 1668929,
#     'change_hash': 'cf50c8ec57d2eb642caa646af2038094',
#     'url': 'https://legiscan.com/OK/bill/HB2177/2023',
#     'text_url': 'https://legiscan.com/OK/text/HB2177/2023',
#     'research_url': 'https://legiscan.com/OK/research/HB2177/2023',
#     'last_action_date': '2023-02-20',
#     'last_action': 'Emergency added',
#     'title': 'Public health and safety; health care professionals; prohibiting certain gender transition procedures; exceptions; administrative remedies; emergency.'},
#    {'relevance': 99,
#     'state': 'MO',
#     'bill_number': 'HB540',
#     'bill_id': 1642575,
#     'change_hash': '66299c94802b417799fafea8fa4e998f',
#     'url': 'https://legiscan.com/MO/bill/HB540/2023',
#     'text_url': 'https://legiscan.com/MO/text/HB540/2023',
#     'research_url': 'https://legiscan.com/MO/research/HB540/2023',
#     'last_action_date': '2023-01-24',
#     'last_action': 'Public Hearing Completed (H)',
#     'title': 'Creates provisions relating to gender transition procedures'},
#    {'relevance': 99,
#     'state': 'UT',
#     'bill_number': 'HB0132',
#     'bill_id': 1640216,
#     'change_hash': 'd1b2759a0c847a12f70f07a6b8924383',
#     'url': 'https://legiscan.com/UT/bill/HB0132/2023',
#     'text_url': 'https://legiscan.com/UT/text/HB0132/2023',
#     'research_url': 'https://legiscan.com/UT/research/HB0132/2023',
#     'last_action_date': '2023-01-25',
#     'last_action': 'LFA/ fiscal note publicly available in House Health and Human Services Committee',
#     'title': 'Prohibiting Sex Transitioning Procedures on Minors'},
#    {'relevance': 99,
#     'state': 'VA',
#     'bill_number': 'HB1387',
#     'bill_id': 1633355,
#     'change_hash': 'cd10ae03c6a090ebf6047a94fd971b59',
#     'url': 'https://legiscan.com/VA/bill/HB1387/2023',
#     'text_url': 'https://legiscan.com/VA/text/HB1387/2023',
#     'research_url': 'https://legiscan.com/VA/research/HB1387/2023',
#     'last_action_date': '2023-02-16',
#     'last_action': 'Passed by indefinitely in Education and Health (10-Y 5-N)',
#     'title': 'K-12 schools/higher ed. institution; designation of interscholastic, etc., sports based on sex, etc.'},
#    {'relevance': 99,
#     'state': 'KY',
#     'bill_number': 'HB30',
#     'bill_id': 1642113,
#     'change_hash': 'ece470d9dec56bb50c5988c8098dfe7b',
#     'url': 'https://legiscan.com/KY/bill/HB30/2023',
#     'text_url': 'https://legiscan.com/KY/text/HB30/2023',
#     'research_url': 'https://legiscan.com/KY/research/HB30/2023',
#     'last_action_date': '2023-01-03',
#     'last_action': 'to Committee on Committees (H)',
#     'title': 'AN ACT relating to public school facilities and declaring an emergency.'},
#    {'relevance': 99,
#     'state': 'AZ',
#     'bill_number': 'SB1702',
#     'bill_id': 1686385,
#     'change_hash': '8180e70db473f6a0417dd3da580e8790',
#     'url': 'https://legiscan.com/AZ/bill/SB1702/2023',
#     'text_url': 'https://legiscan.com/AZ/text/SB1702/2023',
#     'research_url': 'https://legiscan.com/AZ/research/SB1702/2023',
#     'last_action_date': '2023-02-02',
#     'last_action': 'Senate read second time',
#     'title': 'Gender transition; prohibitions; hormone therapies'},
#    {'relevance': 99,
#     'state': 'US',
#     'bill_number': 'HB429',
#     'bill_id': 1674808,
#     'change_hash': 'b285951b255bd20ba669ed2524b7cff3',
#     'url': 'https://legiscan.com/US/bill/HB429/2023',
#     'text_url': 'https://legiscan.com/US/text/HB429/2023',
#     'research_url': 'https://legiscan.com/US/research/HB429/2023',
#     'last_action_date': '2023-01-20',
#     'last_action': 'Referred to the House Committee on Ways and Means.',
#     'title': 'No Tax Breaks for Radical Corporate Activism Act'},
#    {'relevance': 99,
#     'state': 'US',
#     'bill_number': 'SB187',
#     'bill_id': 1689600,
#     'change_hash': 'df00dcb6c0bdc8c810d073dfd4763d4b',
#     'url': 'https://legiscan.com/US/bill/SB187/2023',
#     'text_url': 'https://legiscan.com/US/text/SB187/2023',
#     'research_url': 'https://legiscan.com/US/research/SB187/2023',
#     'last_action_date': '2023-01-31',
#     'last_action': 'Read twice and referred to the Committee on Finance.',
#     'title': 'No Tax Breaks for Radical Corporate Activism Act of 2023'},
#    {'relevance': 99,
#     'state': 'TX',
#     'bill_number': 'SB162',
#     'bill_id': 1632730,
#     'change_hash': 'e25c1f0e311f3d37c6f6dd76dc72b489',
#     'url': 'https://legiscan.com/TX/bill/SB162/2023',
#     'text_url': 'https://legiscan.com/TX/text/SB162/2023',
#     'research_url': 'https://legiscan.com/TX/research/SB162/2023',
#     'last_action_date': '2023-02-15',
#     'last_action': 'Referred to State Affairs',
#     'title': "Relating to the required inclusion of a person's sex on a birth certificate and prohibited change of sex on the birth certificate of certain minors."},
#    {'relevance': 99,
#     'state': 'VA',
#     'bill_number': 'SB911',
#     'bill_id': 1645224,
#     'change_hash': '9acde0a5045b45421b74a97969ddff0a',
#     'url': 'https://legiscan.com/VA/bill/SB911/2023',
#     'text_url': 'https://legiscan.com/VA/text/SB911/2023',
#     'research_url': 'https://legiscan.com/VA/research/SB911/2023',
#     'last_action_date': '2023-02-02',
#     'last_action': 'Incorporated by Education and Health ',
#     'title': 'K-12 schools/higher ed. institutions; interscholastic, etc., sports, teams based on biological sex.'},
#    {'relevance': 99,
#     'state': 'KY',
#     'bill_number': 'SB102',
#     'bill_id': 1700889,
#     'change_hash': '42d453948958e40957f33dfe9f2b0032',
#     'url': 'https://legiscan.com/KY/bill/SB102/2023',
#     'text_url': 'https://legiscan.com/KY/text/SB102/2023',
#     'research_url': 'https://legiscan.com/KY/research/SB102/2023',
#     'last_action_date': '2023-02-10',
#     'last_action': 'to Education (S)',
#     'title': 'AN ACT relating to education.'},
#    {'relevance': 99,
#     'state': 'KY',
#     'bill_number': 'HB173',
#     'bill_id': 1698754,
#     'change_hash': '7a452cfbaea41a0001af2938f08f8b8b',
#     'url': 'https://legiscan.com/KY/bill/HB173/2023',
#     'text_url': 'https://legiscan.com/KY/text/HB173/2023',
#     'research_url': 'https://legiscan.com/KY/research/HB173/2023',
#     'last_action_date': '2023-02-07',
#     'last_action': 'to Committee on Committees (H)',
#     'title': 'AN ACT relating to education.'},
#    {'relevance': 99,
#     'state': 'OK',
#     'bill_number': 'SB408',
#     'bill_id': 1659858,
#     'change_hash': '208001cf554e702b569c40b35a29cd73',
#     'url': 'https://legiscan.com/OK/bill/SB408/2023',
#     'text_url': 'https://legiscan.com/OK/text/SB408/2023',
#     'research_url': 'https://legiscan.com/OK/research/SB408/2023',
#     'last_action_date': '2023-02-22',
#     'last_action': 'Coauthored by Senator Seifried',
#     'title': "Discrimination; creating the Women's Bill of Rights; authorizing distinctions for certain purposes. Effective date."},
#    {'relevance': 99,
#     'state': 'VA',
#     'bill_number': 'HB1399',
#     'bill_id': 1634331,
#     'change_hash': 'ef8d6ff1a14125611b9f6fb9af2e7928',
#     'url': 'https://legiscan.com/VA/bill/HB1399/2023',
#     'text_url': 'https://legiscan.com/VA/text/HB1399/2023',
#     'research_url': 'https://legiscan.com/VA/research/HB1399/2023',
#     'last_action_date': '2023-02-07',
#     'last_action': 'Left in Education',
#     'title': 'Elementary schools, etc.; designation of interscholastic, etc., sports, student participation.'},
#    {'relevance': 99,
#     'state': 'OK',
#     'bill_number': 'HB1449',
#     'bill_id': 1665893,
#     'change_hash': '222cd3ca9e8b17416ab5f95890bb0342',
#     'url': 'https://legiscan.com/OK/bill/HB1449/2023',
#     'text_url': 'https://legiscan.com/OK/text/HB1449/2023',
#     'research_url': 'https://legiscan.com/OK/research/HB1449/2023',
#     'last_action_date': '2023-02-23',
#     'last_action': 'Authored by Senator Garvin (principal Senate author)',
#     'title': "Discrimination; enacting the Women's Bill of Rights; effective date."},
#    {'relevance': 99,
#     'state': 'MS',
#     'bill_number': 'SB2076',
#     'bill_id': 1649395,
#     'change_hash': '281d643aaedacc77a73273550af480a1',
#     'url': 'https://legiscan.com/MS/bill/SB2076/2023',
#     'text_url': 'https://legiscan.com/MS/text/SB2076/2023',
#     'research_url': 'https://legiscan.com/MS/research/SB2076/2023',
#     'last_action_date': '2023-01-31',
#     'last_action': 'Died In Committee',
#     'title': 'The Title IX Preservation Act; enact.'},
#    {'relevance': 99,
#     'state': 'TX',
#     'bill_number': 'HB23',
#     'bill_id': 1632709,
#     'change_hash': 'ac662ad4160f8321f1862b8666828221',
#     'url': 'https://legiscan.com/TX/bill/HB23/2023',
#     'text_url': 'https://legiscan.com/TX/text/HB23/2023',
#     'research_url': 'https://legiscan.com/TX/research/HB23/2023',
#     'last_action_date': '2023-02-23',
#     'last_action': 'Referred to State Affairs',
#     'title': 'Relating to participation in athletic activities based on biological sex; providing a civil right to action for K-12 athletes and college athletes.'},
#    {'relevance': 98,
#     'state': 'IN',
#     'bill_number': 'HB1407',
#     'bill_id': 1660515,
#     'change_hash': 'aff2bc45c6c0aef065ede357f73bd1af',
#     'url': 'https://legiscan.com/IN/bill/HB1407/2023',
#     'text_url': 'https://legiscan.com/IN/text/HB1407/2023',
#     'research_url': 'https://legiscan.com/IN/research/HB1407/2023',
#     'last_action_date': '2023-02-23',
#     'last_action': 'Referred to the Senate',
#     'title': 'Parental rights.'},
#    {'relevance': 98,
#     'state': 'IL',
#     'bill_number': 'SB1659',
#     'bill_id': 1699553,
#     'change_hash': '9482011fabc0c7267d054c8f37ccf44d',
#     'url': 'https://legiscan.com/IL/bill/SB1659/2023',
#     'text_url': 'https://legiscan.com/IL/text/SB1659/2023',
#     'research_url': 'https://legiscan.com/IL/research/SB1659/2023',
#     'last_action_date': '2023-02-08',
#     'last_action': 'Referred to Assignments',
#     'title': 'SCH CD-BIO-RESTROOM ACCESS'},
#    {'relevance': 98,
#     'state': 'OK',
#     'bill_number': 'SB937',
#     'bill_id': 1669660,
#     'change_hash': '67d6b86212c43f23fee45bde0cf01aee',
#     'url': 'https://legiscan.com/OK/bill/SB937/2023',
#     'text_url': 'https://legiscan.com/OK/text/SB937/2023',
#     'research_url': 'https://legiscan.com/OK/research/SB937/2023',
#     'last_action_date': '2023-02-07',
#     'last_action': 'Second Reading referred to Education',
#     'title': 'Schools; creating the School Establishment Clause Act (SECA); prohibiting creation, enforcement, or endorsement of certain policies. Effective date. Emergency.'},
#    {'relevance': 98,
#     'state': 'MS',
#     'bill_number': 'HB1074',
#     'bill_id': 1668972,
#     'change_hash': 'be418498460347ac81f1d22876d90633',
#     'url': 'https://legiscan.com/MS/bill/HB1074/2023',
#     'text_url': 'https://legiscan.com/MS/text/HB1074/2023',
#     'research_url': 'https://legiscan.com/MS/research/HB1074/2023',
#     'last_action_date': '2023-01-31',
#     'last_action': 'Died In Committee',
#     'title': 'The Title IX Preservation Act; enact.'}]},
#  {'summary': {'page': '2 of 6',
#    'range': '51 - 100',
#    'relevancy': '98% - 97%',
#    'count': 298,
#    'page_current': '2',
#    'page_total': 6,
#    'query': '((Zbiolog:(pos=1) AND Zsex:(pos=2)))'},
#   'results': [{'relevance': 98,
#     'state': 'MS',
#     'bill_number': 'HB1144',
#     'bill_id': 1670368,
#     'change_hash': '7585f7afa04361a9ff968aa76bf0ea33',
#     'url': 'https://legiscan.com/MS/bill/HB1144/2023',
#     'text_url': 'https://legiscan.com/MS/text/HB1144/2023',
#     'research_url': 'https://legiscan.com/MS/research/HB1144/2023',
#     'last_action_date': '2023-01-31',
#     'last_action': 'Died In Committee',
#     'title': 'Title IX Preservation Act; create.'},
#    {'relevance': 98,
#     'state': 'MS',
#     'bill_number': 'SB2773',
#     'bill_id': 1672862,
#     'change_hash': 'ff659357ba19a2f6c6b712016166360a',
#     'url': 'https://legiscan.com/MS/bill/SB2773/2023',
#     'text_url': 'https://legiscan.com/MS/text/SB2773/2023',
#     'research_url': 'https://legiscan.com/MS/research/SB2773/2023',
#     'last_action_date': '2023-01-31',
#     'last_action': 'Died In Committee',
#     'title': 'The Defense of Title IX Act; enact.'},
#    {'relevance': 98,
#     'state': 'AR',
#     'bill_number': 'SB199',
#     'bill_id': 1696352,
#     'change_hash': 'bb3a89875d4cd1642199622867dfe971',
#     'url': 'https://legiscan.com/AR/bill/SB199/2023',
#     'text_url': 'https://legiscan.com/AR/text/SB199/2023',
#     'research_url': 'https://legiscan.com/AR/research/SB199/2023',
#     'last_action_date': '2023-02-21',
#     'last_action': 'Read the first time, rules suspended, read the second time and referred to the Committee on JUDICIARY COMMITTEE- HOUSE',
#     'title': 'Concerning Medical Malpractice And Gender Transition In Minors; And To Create The Protecting Minors From Medical Malpractice Act Of 2023. '},
#    {'relevance': 98,
#     'state': 'SC',
#     'bill_number': 'S0364',
#     'bill_id': 1650877,
#     'change_hash': '6759405b96389d67e08e0c05afea0e10',
#     'url': 'https://legiscan.com/SC/bill/S0364/2023',
#     'text_url': 'https://legiscan.com/SC/text/S0364/2023',
#     'research_url': 'https://legiscan.com/SC/research/S0364/2023',
#     'last_action_date': '2023-01-10',
#     'last_action': 'Referred to Committee on Medical Affairs',
#     'title': 'Vital Statistics - Changes to Birth Certificates'},
#    {'relevance': 98,
#     'state': 'MD',
#     'bill_number': 'HB359',
#     'bill_id': 1681678,
#     'change_hash': 'c8ec189d72e690f189c956832746551e',
#     'url': 'https://legiscan.com/MD/bill/HB359/2023',
#     'text_url': 'https://legiscan.com/MD/text/HB359/2023',
#     'research_url': 'https://legiscan.com/MD/research/HB359/2023',
#     'last_action_date': '2023-02-20',
#     'last_action': 'Unfavorable Report by Ways and Means',
#     'title': 'Education – Interscholastic and Intramural Junior Varsity and Varsity Teams and Sports – Designation Based on Sex (Save Women’s Sports Act)'},
#    {'relevance': 98,
#     'state': 'MO',
#     'bill_number': 'SB134',
#     'bill_id': 1634983,
#     'change_hash': 'adc23d6eedb7caa915bad75150b95903',
#     'url': 'https://legiscan.com/MO/bill/SB134/2023',
#     'text_url': 'https://legiscan.com/MO/text/SB134/2023',
#     'research_url': 'https://legiscan.com/MO/research/SB134/2023',
#     'last_action_date': '2023-02-14',
#     'last_action': 'SCS Voted Do Pass S Education and Workforce Development Committee (0608S.06C)',
#     'title': 'Prohibits the discussion of gender identity or sexual orientation by school personnel'},
#    {'relevance': 98,
#     'state': 'VA',
#     'bill_number': 'SB1186',
#     'bill_id': 1651821,
#     'change_hash': 'ccd7f1795f1ac430ff652554b4c7e846',
#     'url': 'https://legiscan.com/VA/bill/SB1186/2023',
#     'text_url': 'https://legiscan.com/VA/text/SB1186/2023',
#     'research_url': 'https://legiscan.com/VA/research/SB1186/2023',
#     'last_action_date': '2023-02-02',
#     'last_action': 'Passed by indefinitely in Education and Health (10-Y 5-N)',
#     'title': 'K-12 schools/higher ed. institution; designation of interscholastic, etc., sports based on sex, etc.'},
#    {'relevance': 98,
#     'state': 'KY',
#     'bill_number': 'HB120',
#     'bill_id': 1644187,
#     'change_hash': 'abbff23d94c7c9443a2abeae2d4c4fbc',
#     'url': 'https://legiscan.com/KY/bill/HB120/2023',
#     'text_url': 'https://legiscan.com/KY/text/HB120/2023',
#     'research_url': 'https://legiscan.com/KY/research/HB120/2023',
#     'last_action_date': '2023-01-05',
#     'last_action': 'to Committee on Committees (H)',
#     'title': "AN ACT relating to children's health."},
#    {'relevance': 98,
#     'state': 'MS',
#     'bill_number': 'HB1127',
#     'bill_id': 1668816,
#     'change_hash': '5f9f11f413023644f7046ed66f4e9f43',
#     'url': 'https://legiscan.com/MS/bill/HB1127/2023',
#     'text_url': 'https://legiscan.com/MS/text/HB1127/2023',
#     'research_url': 'https://legiscan.com/MS/research/HB1127/2023',
#     'last_action_date': '2023-01-31',
#     'last_action': 'Died In Committee',
#     'title': 'MS Safe Adolescents from Experimentation (SAFE); create to prohibit providing gender transition procedures to minors.'},
#    {'relevance': 98,
#     'state': 'OR',
#     'bill_number': 'SB452',
#     'bill_id': 1647733,
#     'change_hash': 'eb658d18688fc39e992c3d386fc2e599',
#     'url': 'https://legiscan.com/OR/bill/SB452/2023',
#     'text_url': 'https://legiscan.com/OR/text/SB452/2023',
#     'research_url': 'https://legiscan.com/OR/research/SB452/2023',
#     'last_action_date': '2023-01-14',
#     'last_action': 'Referred to Finance and Revenue.',
#     'title': 'Relating to gender reassignment surgery.'},
#    {'relevance': 98,
#     'state': 'CO',
#     'bill_number': 'HB1098',
#     'bill_id': 1676599,
#     'change_hash': '1b9b73bdad306030faca867b1016bb74',
#     'url': 'https://legiscan.com/CO/bill/HB1098/2023',
#     'text_url': 'https://legiscan.com/CO/text/HB1098/2023',
#     'research_url': 'https://legiscan.com/CO/research/HB1098/2023',
#     'last_action_date': '2023-02-13',
#     'last_action': 'House Committee on State, Civic, Military, & Veterans Affairs Postpone Indefinitely',
#     'title': 'Women&#039;s Rights In Athletics'},
#    {'relevance': 98,
#     'state': 'MO',
#     'bill_number': 'HB170',
#     'bill_id': 1634841,
#     'change_hash': 'b8a7a40dabaa85804e06febf4b410701',
#     'url': 'https://legiscan.com/MO/bill/HB170/2023',
#     'text_url': 'https://legiscan.com/MO/text/HB170/2023',
#     'research_url': 'https://legiscan.com/MO/research/HB170/2023',
#     'last_action_date': '2023-01-24',
#     'last_action': 'Public Hearing Completed (H)',
#     'title': 'Establishes guidelines for student participation in athletic contests organized by sex'},
#    {'relevance': 98,
#     'state': 'ID',
#     'bill_number': 'S1100',
#     'bill_id': 1705651,
#     'change_hash': '755d205caf8c1288106482bbb48bf308',
#     'url': 'https://legiscan.com/ID/bill/S1100/2023',
#     'text_url': 'https://legiscan.com/ID/text/S1100/2023',
#     'research_url': 'https://legiscan.com/ID/research/S1100/2023',
#     'last_action_date': '2023-02-24',
#     'last_action': 'Reported out of Committee with Do Pass Recommendation; Filed for second reading',
#     'title': 'Adds to existing law to establish privacy and safety standards in public schools.'},
#    {'relevance': 98,
#     'state': 'ND',
#     'bill_number': 'HB1474',
#     'bill_id': 1667317,
#     'change_hash': '4231a157cadafa2fc1542e74ce0dd49e',
#     'url': 'https://legiscan.com/ND/bill/HB1474/2023',
#     'text_url': 'https://legiscan.com/ND/text/HB1474/2023',
#     'research_url': 'https://legiscan.com/ND/research/HB1474/2023',
#     'last_action_date': '2023-02-21',
#     'last_action': 'Introduced, first reading, referred to Human Services',
#     'title': 'The definition of father, female, male, mother, and sex.'},
#    {'relevance': 98,
#     'state': 'NH',
#     'bill_number': 'HB396',
#     'bill_id': 1646387,
#     'change_hash': 'a78acde834f3263c5476372dde56a0f3',
#     'url': 'https://legiscan.com/NH/bill/HB396/2023',
#     'text_url': 'https://legiscan.com/NH/text/HB396/2023',
#     'research_url': 'https://legiscan.com/NH/research/HB396/2023',
#     'last_action_date': '2023-02-15',
#     'last_action': 'Retained in Committee',
#     'title': 'Relative to state recognition of biological sex.'},
#    {'relevance': 98,
#     'state': 'WV',
#     'bill_number': 'SB697',
#     'bill_id': 1714924,
#     'change_hash': '146bb52851b6c3dd9459205a700c603a',
#     'url': 'https://legiscan.com/WV/bill/SB697/2023',
#     'text_url': 'https://legiscan.com/WV/text/SB697/2023',
#     'research_url': 'https://legiscan.com/WV/research/SB697/2023',
#     'last_action_date': '2023-02-20',
#     'last_action': 'To Health and Human Resources',
#     'title': 'Prohibiting gender transition surgeries, treatments, and therapies to minors'},
#    {'relevance': 98,
#     'state': 'TX',
#     'bill_number': 'SB1082',
#     'bill_id': 1717754,
#     'change_hash': '20f17e923932731c525a60eb63cf323f',
#     'url': 'https://legiscan.com/TX/bill/SB1082/2023',
#     'text_url': 'https://legiscan.com/TX/text/SB1082/2023',
#     'research_url': 'https://legiscan.com/TX/research/SB1082/2023',
#     'last_action_date': '2023-02-22',
#     'last_action': 'Filed',
#     'title': 'Relating to the definition and use of the terms "male" and "female" for purposes of certain government documents.'},
#    {'relevance': 98,
#     'state': 'ID',
#     'bill_number': 'H0071',
#     'bill_id': 1692476,
#     'change_hash': 'd55f28c9c223e7bfdcb46f8fda63e73b',
#     'url': 'https://legiscan.com/ID/bill/H0071/2023',
#     'text_url': 'https://legiscan.com/ID/text/H0071/2023',
#     'research_url': 'https://legiscan.com/ID/research/H0071/2023',
#     'last_action_date': '2023-02-15',
#     'last_action': 'Introduced, read first time; referred to: Judiciary & Rules',
#     'title': 'Amends existing law to revise provisions regarding the crime of genital mutilation of a child.'},
#    {'relevance': 98,
#     'state': 'MS',
#     'bill_number': 'SB2864',
#     'bill_id': 1673543,
#     'change_hash': 'fb23518cc8e585fc93113865ae27a181',
#     'url': 'https://legiscan.com/MS/bill/SB2864/2023',
#     'text_url': 'https://legiscan.com/MS/text/SB2864/2023',
#     'research_url': 'https://legiscan.com/MS/research/SB2864/2023',
#     'last_action_date': '2023-01-31',
#     'last_action': 'Died In Committee',
#     'title': 'State funded health plans and Medicaid; prohibit payment of gender reassignment surgery or services.'},
#    {'relevance': 98,
#     'state': 'TN',
#     'bill_number': 'SB0466',
#     'bill_id': 1679613,
#     'change_hash': 'd8bec855c55d215bedee576acc7ae67a',
#     'url': 'https://legiscan.com/TN/bill/SB0466/2023',
#     'text_url': 'https://legiscan.com/TN/text/SB0466/2023',
#     'research_url': 'https://legiscan.com/TN/research/SB0466/2023',
#     'last_action_date': '2023-01-31',
#     'last_action': 'Sponsor(s) Added.',
#     'title': 'AN ACT to amend Tennessee Code Annotated, Title 49, Chapter 6, relative to student pronouns.'},
#    {'relevance': 98,
#     'state': 'VA',
#     'bill_number': 'SB960',
#     'bill_id': 1645401,
#     'change_hash': 'ed29d7c7ba92e3e82960b17b2ee0d35c',
#     'url': 'https://legiscan.com/VA/bill/SB960/2023',
#     'text_url': 'https://legiscan.com/VA/text/SB960/2023',
#     'research_url': 'https://legiscan.com/VA/research/SB960/2023',
#     'last_action_date': '2023-02-02',
#     'last_action': 'Passed by indefinitely in Education and Health (10-Y 5-N)',
#     'title': 'Youth Health Protection Act; established, civil penalty.'},
#    {'relevance': 98,
#     'state': 'US',
#     'bill_number': 'HR115',
#     'bill_id': 1702925,
#     'change_hash': '55f565cb82a1ed3814eb339a0c3b50be',
#     'url': 'https://legiscan.com/US/bill/HR115/2023',
#     'text_url': 'https://legiscan.com/US/text/HR115/2023',
#     'research_url': 'https://legiscan.com/US/research/HR115/2023',
#     'last_action_date': '2023-02-09',
#     'last_action': 'Referred to the House Committee on the Judiciary.',
#     'title': "Establishing a Women's Bill of Rights to reaffirm legal protections afforded to women under Federal law."},
#    {'relevance': 98,
#     'state': 'US',
#     'bill_number': 'SR53',
#     'bill_id': 1703088,
#     'change_hash': 'c6cc3e1bf08504fc3a0f67dbb97f2fb1',
#     'url': 'https://legiscan.com/US/bill/SR53/2023',
#     'text_url': 'https://legiscan.com/US/text/SR53/2023',
#     'research_url': 'https://legiscan.com/US/research/SR53/2023',
#     'last_action_date': '2023-02-09',
#     'last_action': 'Referred to the Committee on the Judiciary. (text: CR S331)',
#     'title': "A resolution establishing a Women's Bill of Rights to reaffirm legal protections afforded to women under Federal law."},
#    {'relevance': 98,
#     'state': 'TN',
#     'bill_number': 'HB0239',
#     'bill_id': 1661869,
#     'change_hash': '7e903fd42c405132c6784e4b03e3fd56',
#     'url': 'https://legiscan.com/TN/bill/HB0239/2023',
#     'text_url': 'https://legiscan.com/TN/text/HB0239/2023',
#     'research_url': 'https://legiscan.com/TN/research/HB0239/2023',
#     'last_action_date': '2023-02-22',
#     'last_action': 'Placed on cal. Civil Justice Committee for 3/1/2023',
#     'title': 'AN ACT to amend Tennessee Code Annotated, Title 1, Chapter 3 and Title 49, Chapter 2, Part 8, relative to statutory definitions.'},
#    {'relevance': 98,
#     'state': 'SC',
#     'bill_number': 'H3827',
#     'bill_id': 1682099,
#     'change_hash': '6497aa8789789956ff2792fe05038a86',
#     'url': 'https://legiscan.com/SC/bill/H3827/2023',
#     'text_url': 'https://legiscan.com/SC/text/H3827/2023',
#     'research_url': 'https://legiscan.com/SC/research/H3827/2023',
#     'last_action_date': '2023-01-26',
#     'last_action': 'Referred to Committee on Education and Public Works',
#     'title': 'SC Integrity in Education Act'},
#    {'relevance': 98,
#     'state': 'SC',
#     'bill_number': 'S0424',
#     'bill_id': 1668734,
#     'change_hash': '0dc9999d5e7d4ce04006705bbe49c835',
#     'url': 'https://legiscan.com/SC/bill/S0424/2023',
#     'text_url': 'https://legiscan.com/SC/text/S0424/2023',
#     'research_url': 'https://legiscan.com/SC/research/S0424/2023',
#     'last_action_date': '2023-01-19',
#     'last_action': 'Referred to Committee on Education',
#     'title': 'SC Integrity in Education Act'},
#    {'relevance': 98,
#     'state': 'VA',
#     'bill_number': 'HB2432',
#     'bill_id': 1668262,
#     'change_hash': '034ed886805b2d1c972cf4d3ba511498',
#     'url': 'https://legiscan.com/VA/bill/HB2432/2023',
#     'text_url': 'https://legiscan.com/VA/text/HB2432/2023',
#     'research_url': 'https://legiscan.com/VA/research/HB2432/2023',
#     'last_action_date': '2023-02-16',
#     'last_action': 'Passed by indefinitely in Education and Health (9-Y 6-N)',
#     'title': 'Minor students experiencing gender incongruence; parental notification.'},
#    {'relevance': 98,
#     'state': 'MO',
#     'bill_number': 'HB337',
#     'bill_id': 1634768,
#     'change_hash': '243a234229f395058d027ee0aa2bc025',
#     'url': 'https://legiscan.com/MO/bill/HB337/2023',
#     'text_url': 'https://legiscan.com/MO/text/HB337/2023',
#     'research_url': 'https://legiscan.com/MO/research/HB337/2023',
#     'last_action_date': '2023-01-24',
#     'last_action': 'Public Hearing Completed (H)',
#     'title': 'Establishes guidelines for student participation in athletic contests organized by sex'},
#    {'relevance': 98,
#     'state': 'MO',
#     'bill_number': 'SB39',
#     'bill_id': 1635120,
#     'change_hash': 'e79897ff3048da9dd96ee60b4e4502d0',
#     'url': 'https://legiscan.com/MO/bill/SB39/2023',
#     'text_url': 'https://legiscan.com/MO/text/SB39/2023',
#     'research_url': 'https://legiscan.com/MO/research/SB39/2023',
#     'last_action_date': '2023-02-27',
#     'last_action': 'Informal Calendar S Bills for Perfection',
#     'title': 'Establishes guidelines for student participation in athletic contests organized by sex'},
#    {'relevance': 98,
#     'state': 'ND',
#     'bill_number': 'HB1489',
#     'bill_id': 1666321,
#     'change_hash': '3034043c2338567479e55e9cca92ebae',
#     'url': 'https://legiscan.com/ND/bill/HB1489/2023',
#     'text_url': 'https://legiscan.com/ND/text/HB1489/2023',
#     'research_url': 'https://legiscan.com/ND/research/HB1489/2023',
#     'last_action_date': '2023-02-17',
#     'last_action': 'Introduced, first reading, referred to Education',
#     'title': 'Relating to requiring institutions of higher education designating athletic teams and sports for male, female, or coed participation.'},
#    {'relevance': 98,
#     'state': 'MO',
#     'bill_number': 'SB165',
#     'bill_id': 1635152,
#     'change_hash': 'c0b498eaee923c3e545fa15e77e6bc18',
#     'url': 'https://legiscan.com/MO/bill/SB165/2023',
#     'text_url': 'https://legiscan.com/MO/text/SB165/2023',
#     'research_url': 'https://legiscan.com/MO/research/SB165/2023',
#     'last_action_date': '2023-01-31',
#     'last_action': 'Hearing Conducted S Emerging Issues Committee',
#     'title': 'Creates the "Save Women\'s Sports Act" and provisions regarding usage of school locker rooms'},
#    {'relevance': 98,
#     'state': 'MT',
#     'bill_number': 'SB99',
#     'bill_id': 1641379,
#     'change_hash': '6015fd75843649987b1ffaec797a7752',
#     'url': 'https://legiscan.com/MT/bill/SB99/2023',
#     'text_url': 'https://legiscan.com/MT/text/SB99/2023',
#     'research_url': 'https://legiscan.com/MT/research/SB99/2023',
#     'last_action_date': '2023-02-09',
#     'last_action': '(S) Transmitted to House',
#     'title': 'Provide for a youth health protection act'},
#    {'relevance': 98,
#     'state': 'HI',
#     'bill_number': 'HB508',
#     'bill_id': 1673977,
#     'change_hash': '83bacd969db0aaf9f01a3cae997fc94b',
#     'url': 'https://legiscan.com/HI/bill/HB508/2023',
#     'text_url': 'https://legiscan.com/HI/text/HB508/2023',
#     'research_url': 'https://legiscan.com/HI/research/HB508/2023',
#     'last_action_date': '2023-01-27',
#     'last_action': 'Referred to EDN, JHA, FIN, referral sheet 2',
#     'title': 'Relating To Sex-specific Student Athletic Teams.'},
#    {'relevance': 98,
#     'state': 'MO',
#     'bill_number': 'HB498',
#     'bill_id': 1640345,
#     'change_hash': '96070d265ec2d4bc636049f19ef3cad9',
#     'url': 'https://legiscan.com/MO/bill/HB498/2023',
#     'text_url': 'https://legiscan.com/MO/text/HB498/2023',
#     'research_url': 'https://legiscan.com/MO/research/HB498/2023',
#     'last_action_date': '2023-01-24',
#     'last_action': 'Public Hearing Completed (H)',
#     'title': 'Includes businesses that host drag performances in the definition of a sexually oriented business'},
#    {'relevance': 98,
#     'state': 'MO',
#     'bill_number': 'SB429',
#     'bill_id': 1642746,
#     'change_hash': '5f70bb4c2a1220f15fb873a9f6006096',
#     'url': 'https://legiscan.com/MO/bill/SB429/2023',
#     'text_url': 'https://legiscan.com/MO/text/SB429/2023',
#     'research_url': 'https://legiscan.com/MO/research/SB429/2023',
#     'last_action_date': '2023-01-04',
#     'last_action': 'S First Read',
#     'title': 'Modifies provisions relating to sexually oriented businesses'},
#    {'relevance': 98,
#     'state': 'ND',
#     'bill_number': 'HB1254',
#     'bill_id': 1651568,
#     'change_hash': 'caaccf426773f23336060db770f975b7',
#     'url': 'https://legiscan.com/ND/bill/HB1254/2023',
#     'text_url': 'https://legiscan.com/ND/text/HB1254/2023',
#     'research_url': 'https://legiscan.com/ND/research/HB1254/2023',
#     'last_action_date': '2023-02-21',
#     'last_action': 'Introduced, first reading, (emergency), referred to Human Services',
#     'title': 'Relating to the prohibition of certain practices against a minor; to provide a penalty; and to declare an emergency.'},
#    {'relevance': 98,
#     'state': 'HI',
#     'bill_number': 'SB1429',
#     'bill_id': 1678936,
#     'change_hash': '18ec52d3c4eaab908a5d05005dc2a47f',
#     'url': 'https://legiscan.com/HI/bill/SB1429/2023',
#     'text_url': 'https://legiscan.com/HI/text/SB1429/2023',
#     'research_url': 'https://legiscan.com/HI/research/SB1429/2023',
#     'last_action_date': '2023-01-30',
#     'last_action': 'Referred to EDU/HHS/EET, JDC/WAM.',
#     'title': 'Relating To Sex-specific Student Athletic Teams.'},
#    {'relevance': 98,
#     'state': 'MS',
#     'bill_number': 'SB2770',
#     'bill_id': 1673057,
#     'change_hash': 'fa4859021eef1b94db4f1bdb35e387cf',
#     'url': 'https://legiscan.com/MS/bill/SB2770/2023',
#     'text_url': 'https://legiscan.com/MS/text/SB2770/2023',
#     'research_url': 'https://legiscan.com/MS/research/SB2770/2023',
#     'last_action_date': '2023-01-31',
#     'last_action': 'Died In Committee',
#     'title': 'Gender reassignment surgery; criminalize performance of upon minors.'},
#    {'relevance': 98,
#     'state': 'OR',
#     'bill_number': 'SB453',
#     'bill_id': 1647416,
#     'change_hash': '1fe4cda41fda04e3300cb73ec1a2b5cb',
#     'url': 'https://legiscan.com/OR/bill/SB453/2023',
#     'text_url': 'https://legiscan.com/OR/text/SB453/2023',
#     'research_url': 'https://legiscan.com/OR/research/SB453/2023',
#     'last_action_date': '2023-01-11',
#     'last_action': 'Referred to Education.',
#     'title': 'Relating to participation in athletic competitions according to biological sex.'},
#    {'relevance': 97,
#     'state': 'OK',
#     'bill_number': 'SB1007',
#     'bill_id': 1668811,
#     'change_hash': '13e5b06fb533ee7c78f79780fd39fb0d',
#     'url': 'https://legiscan.com/OK/bill/SB1007/2023',
#     'text_url': 'https://legiscan.com/OK/text/SB1007/2023',
#     'research_url': 'https://legiscan.com/OK/research/SB1007/2023',
#     'last_action_date': '2023-02-07',
#     'last_action': 'Second Reading referred to Education',
#     'title': "Student athletics; creating the Save Men's Sports Act; requiring designation of certain athletic teams. Effective date. Emergency."},
# ...
#     'text_url': 'https://legiscan.com/TX/text/HB2668/2023',
#     'research_url': 'https://legiscan.com/TX/research/HB2668/2023',
#     'last_action_date': '2023-02-22',
#     'last_action': 'Filed',
#     'title': 'Relating to the rights of victims of sexual assault and to certain procedures and reimbursements occurring with respect to a sexual assault or other sex offense.'},
#    {'relevance': 79,
#     'state': 'TX',
#     'bill_number': 'HB240',
#     'bill_id': 1632674,
#     'change_hash': '07f0b35e02fa2c6c54f161adbf59c675',
#     'url': 'https://legiscan.com/TX/bill/HB240/2023',
#     'text_url': 'https://legiscan.com/TX/text/HB240/2023',
#     'research_url': 'https://legiscan.com/TX/research/HB240/2023',
#     'last_action_date': '2023-02-23',
#     'last_action': 'Referred to Criminal Jurisprudence',
#     'title': 'Relating to the limitations period for certain criminal offenses involving dating, household, or other family violence.'},
#    {'relevance': 79,
#     'state': 'TX',
#     'bill_number': 'HB467',
#     'bill_id': 1632448,
#     'change_hash': 'e279bd470a8bf807a0f53a6273c646bf',
#     'url': 'https://legiscan.com/TX/bill/HB467/2023',
#     'text_url': 'https://legiscan.com/TX/text/HB467/2023',
#     'research_url': 'https://legiscan.com/TX/research/HB467/2023',
#     'last_action_date': '2023-02-23',
#     'last_action': 'Referred to Criminal Jurisprudence',
#     'title': 'Relating to the limitations period for certain criminal offenses based on assaultive conduct.'},
#    {'relevance': 79,
#     'state': 'MO',
#     'bill_number': 'HB68',
#     'bill_id': 1634655,
#     'change_hash': '1d59f0d094a7888bf1bf3ff0fe19db23',
#     'url': 'https://legiscan.com/MO/bill/HB68/2023',
#     'text_url': 'https://legiscan.com/MO/text/HB68/2023',
#     'research_url': 'https://legiscan.com/MO/research/HB68/2023',
#     'last_action_date': '2023-01-05',
#     'last_action': 'Read Second Time (H)',
#     'title': 'Modifies provisions relating to guardianships and conservatorships'},
#    {'relevance': 79,
#     'state': 'MT',
#     'bill_number': 'HB137',
#     'bill_id': 1638674,
#     'change_hash': 'd2b628df1c8e4aff0e2abc5a68b23701',
#     'url': 'https://legiscan.com/MT/bill/HB137/2023',
#     'text_url': 'https://legiscan.com/MT/text/HB137/2023',
#     'research_url': 'https://legiscan.com/MT/research/HB137/2023',
#     'last_action_date': '2023-01-12',
#     'last_action': '(H) Tabled in Committee (H) Business and Labor',
#     'title': 'Generally revise laws related to the board of behavioral health'},
#    {'relevance': 78,
#     'state': 'NJ',
#     'bill_number': 'A2531',
#     'bill_id': 1584422,
#     'change_hash': '31ac33b256bf28ef75166ce17d3b6c74',
#     'url': 'https://legiscan.com/NJ/bill/A2531/2022',
#     'text_url': 'https://legiscan.com/NJ/text/A2531/2022',
#     'research_url': 'https://legiscan.com/NJ/research/A2531/2022',
#     'last_action_date': '2022-02-14',
#     'last_action': 'Introduced, Referred to Assembly Women and Children Committee',
#     'title': 'Establishes "Support for Victims of Domestic Violence Program"; incentivizes certain businesses to provide support to individuals who are victims of domestic violence.'},
#    {'relevance': 78,
#     'state': 'MT',
#     'bill_number': 'HB37',
#     'bill_id': 1636374,
#     'change_hash': '595f14a138ce05f137c1b4e90340103b',
#     'url': 'https://legiscan.com/MT/bill/HB37/2023',
#     'text_url': 'https://legiscan.com/MT/text/HB37/2023',
#     'research_url': 'https://legiscan.com/MT/research/HB37/2023',
#     'last_action_date': '2023-02-15',
#     'last_action': '(S) First Reading',
#     'title': 'Generally revise child abuse and neglect laws'},
#    {'relevance': 78,
#     'state': 'UT',
#     'bill_number': 'SB0238',
#     'bill_id': 1706741,
#     'change_hash': '4ddc4c16b93f29f30ed7a6ac62b7510e',
#     'url': 'https://legiscan.com/UT/bill/SB0238/2023',
#     'text_url': 'https://legiscan.com/UT/text/SB0238/2023',
#     'research_url': 'https://legiscan.com/UT/research/SB0238/2023',
#     'last_action_date': '2023-02-23',
#     'last_action': 'House/ to standing committee in House Judiciary Committee',
#     'title': 'Court Fee Amendments'},
#    {'relevance': 78,
#     'state': 'KY',
#     'bill_number': 'SB15',
#     'bill_id': 1642115,
#     'change_hash': 'd65bfbd805dc894ab1a0322c36a3cb8f',
#     'url': 'https://legiscan.com/KY/bill/SB15/2023',
#     'text_url': 'https://legiscan.com/KY/text/SB15/2023',
#     'research_url': 'https://legiscan.com/KY/research/SB15/2023',
#     'last_action_date': '2023-02-24',
#     'last_action': '2nd reading, to Rules',
#     'title': 'AN ACT relating to consumer data privacy.'},
#    {'relevance': 78,
#     'state': 'NJ',
#     'bill_number': 'A4719',
#     'bill_id': 1630538,
#     'change_hash': 'f7ef9ec62ee7418e7399221fe6ea650a',
#     'url': 'https://legiscan.com/NJ/bill/A4719/2022',
#     'text_url': 'https://legiscan.com/NJ/text/A4719/2022',
#     'research_url': 'https://legiscan.com/NJ/research/A4719/2022',
#     'last_action_date': '2022-10-11',
#     'last_action': 'Introduced, Referred to Assembly Health Committee',
#     'title': 'Consolidates and makes technical updates to certain definitions used in Title 26 of the Revised Statutes.'},
#    {'relevance': 78,
#     'state': 'IN',
#     'bill_number': 'SB0311',
#     'bill_id': 1655703,
#     'change_hash': 'bf2a78fcc537a476159a8cb7719d567b',
#     'url': 'https://legiscan.com/IN/bill/SB0311/2023',
#     'text_url': 'https://legiscan.com/IN/text/SB0311/2023',
#     'research_url': 'https://legiscan.com/IN/research/SB0311/2023',
#     'last_action_date': '2023-01-12',
#     'last_action': 'First reading: referred to Committee on Health and Provider Services',
#     'title': 'Abortion.'},
#    {'relevance': 78,
#     'state': 'IN',
#     'bill_number': 'HB1554',
#     'bill_id': 1671373,
#     'change_hash': '48fc99ce49ae81e9b9b2d8903bfc09ef',
#     'url': 'https://legiscan.com/IN/bill/HB1554/2023',
#     'text_url': 'https://legiscan.com/IN/text/HB1554/2023',
#     'research_url': 'https://legiscan.com/IN/research/HB1554/2023',
#     'last_action_date': '2023-01-19',
#     'last_action': 'First reading: referred to Committee on Commerce, Small Business and Economic Development',
#     'title': 'Consumer data protection.'},
#    {'relevance': 78,
#     'state': 'KS',
#     'bill_number': 'HB2392',
#     'bill_id': 1703228,
#     'change_hash': 'd67b6f58ef080275ed38d389d2882369',
#     'url': 'https://legiscan.com/KS/bill/HB2392/2023',
#     'text_url': 'https://legiscan.com/KS/text/HB2392/2023',
#     'research_url': 'https://legiscan.com/KS/research/HB2392/2023',
#     'last_action_date': '2023-02-23',
#     'last_action': 'House Emergency Final Action - Passed as amended;  Yea: 121 Nay: 0',
#     'title': 'Updating the Kansas code of military justice relating to certain definitions, unlawful acts and punishment requirements thereof.'},
#    {'relevance': 77,
#     'state': 'CT',
#     'bill_number': 'HB06726',
#     'bill_id': 1711322,
#     'change_hash': '8af7bfa588cf897bc6d4bf4b086c9ee6',
#     'url': 'https://legiscan.com/CT/bill/HB06726/2023',
#     'text_url': 'https://legiscan.com/CT/text/HB06726/2023',
#     'research_url': 'https://legiscan.com/CT/research/HB06726/2023',
#     'last_action_date': '2023-02-22',
#     'last_action': 'Public Hearing 02/27',
#     'title': 'An Act Concerning The Regulation Of Livestock And Certain Rabbit Processing Facilities.'},
#    {'relevance': 77,
#     'state': 'OH',
#     'bill_number': 'SB29',
#     'bill_id': 1679058,
#     'change_hash': '5c5b0a880d814b766191302bacf01b2c',
#     'url': 'https://legiscan.com/OH/bill/SB29/2023',
#     'text_url': 'https://legiscan.com/OH/text/SB29/2023',
#     'research_url': 'https://legiscan.com/OH/research/SB29/2023',
#     'last_action_date': '2023-02-08',
#     'last_action': 'Referred to committee: Education',
#     'title': 'Regards education records and student data privacy'},
#    {'relevance': 77,
#     'state': 'OH',
#     'bill_number': 'HB44',
#     'bill_id': 1710708,
#     'change_hash': 'dd8c782e432cd72bd3cb1aced75162b9',
#     'url': 'https://legiscan.com/OH/bill/HB44/2023',
#     'text_url': 'https://legiscan.com/OH/text/HB44/2023',
#     'research_url': 'https://legiscan.com/OH/research/HB44/2023',
#     'last_action_date': '2023-02-16',
#     'last_action': 'Referred to committee: Criminal Justice',
#     'title': 'Require electronic recordings of parole board hearings'},
#    {'relevance': 77,
#     'state': 'MN',
#     'bill_number': 'SF2122',
#     'bill_id': 1720543,
#     'change_hash': '087be2f2caed01985a1715e771f8e111',
#     'url': 'https://legiscan.com/MN/bill/SF2122/2023',
#     'text_url': 'https://legiscan.com/MN/text/SF2122/2023',
#     'research_url': 'https://legiscan.com/MN/research/SF2122/2023',
#     'last_action_date': '2023-02-27',
#     'last_action': 'Referred to Health and Human Services',
#     'title': 'Provisions modification for hospital physical environment'},
#    {'relevance': 77,
#     'state': 'MN',
#     'bill_number': 'HF1679',
#     'bill_id': 1705225,
#     'change_hash': '40cdcd59dfab3183d5ef7209b8c2e0f5',
#     'url': 'https://legiscan.com/MN/bill/HF1679/2023',
#     'text_url': 'https://legiscan.com/MN/text/HF1679/2023',
#     'research_url': 'https://legiscan.com/MN/research/HF1679/2023',
#     'last_action_date': '2023-02-13',
#     'last_action': 'Introduction and first reading, referred to Health Finance and Policy',
#     'title': 'Hospital physical environment provisions modified.'},
#    {'relevance': 77,
#     'state': 'WA',
#     'bill_number': 'HB1715',
#     'bill_id': 1689170,
#     'change_hash': '382dbcd6012ce0fff25ed9d94735345d',
#     'url': 'https://legiscan.com/WA/bill/HB1715/2023',
#     'text_url': 'https://legiscan.com/WA/text/HB1715/2023',
#     'research_url': 'https://legiscan.com/WA/research/HB1715/2023',
#     'last_action_date': '2023-02-24',
#     'last_action': 'Referred to Rules 2 Review.',
#     'title': 'Enacting comprehensive protections for victims of domestic violence and other violence involving family members or intimate partners.'},
#    {'relevance': 76,
#     'state': 'CA',
#     'bill_number': 'AB1134',
#     'bill_id': 1709834,
#     'change_hash': '98a9bb4286fae193759aa3c4354a7480',
#     'url': 'https://legiscan.com/CA/bill/AB1134/2023',
#     'text_url': 'https://legiscan.com/CA/text/AB1134/2023',
#     'research_url': 'https://legiscan.com/CA/research/AB1134/2023',
#     'last_action_date': '2023-02-16',
#     'last_action': 'From printer. May be heard in committee March 18.',
#     'title': 'Family reunification services.'},
#    {'relevance': 76,
#     'state': 'NY',
#     'bill_number': 'A02210',
#     'bill_id': 1679822,
#     'change_hash': '9ed65e39384b8e78d67a83dc83e7ada1',
#     'url': 'https://legiscan.com/NY/bill/A02210/2023',
#     'text_url': 'https://legiscan.com/NY/text/A02210/2023',
#     'research_url': 'https://legiscan.com/NY/research/A02210/2023',
#     'last_action_date': '2023-01-25',
#     'last_action': 'referred to mental health',
#     'title': 'Creates statewide emergency and crisis response council to work in conjunction with the commissioners of mental health and addiction services to jointly approve emergency and crisis services plans submitted by local governments, and provide supports regarding the operation and financing of high-quality emergency and crisis services provided to persons experiencing a mental health, alcohol use, or substance use crisis.'},
#    {'relevance': 76,
#     'state': 'NY',
#     'bill_number': 'S02398',
#     'bill_id': 1672449,
#     'change_hash': 'e50a0f07f8d40b3c44255fe24a4c938d',
#     'url': 'https://legiscan.com/NY/bill/S02398/2023',
#     'text_url': 'https://legiscan.com/NY/text/S02398/2023',
#     'research_url': 'https://legiscan.com/NY/research/S02398/2023',
#     'last_action_date': '2023-01-20',
#     'last_action': 'REFERRED TO MENTAL HEALTH',
#     'title': 'Creates statewide emergency and crisis response council to work in conjunction with the commissioners of mental health and addiction services to jointly approve emergency and crisis services plans submitted by local governments, and provide supports regarding the operation and financing of high-quality emergency and crisis services provided to persons experiencing a mental health, alcohol use, or substance use crisis.'},
#    {'relevance': 76,
#     'state': 'NH',
#     'bill_number': 'SB255',
#     'bill_id': 1678252,
#     'change_hash': 'd56c2d217c3155efe299133f0b8e49ab',
#     'url': 'https://legiscan.com/NH/bill/SB255/2023',
#     'text_url': 'https://legiscan.com/NH/text/SB255/2023',
#     'research_url': 'https://legiscan.com/NH/research/SB255/2023',
#     'last_action_date': '2023-02-08',
#     'last_action': 'Hearing: 02/14/2023, Room 100, State House, 02:30 pm; Senate Calendar  10',
#     'title': 'Relative to the expectation of privacy.'},
#    {'relevance': 76,
#     'state': 'MO',
#     'bill_number': 'HB544',
#     'bill_id': 1642690,
#     'change_hash': '037e178a7299bf42fbd4aa91e352eaf5',
#     'url': 'https://legiscan.com/MO/bill/HB544/2023',
#     'text_url': 'https://legiscan.com/MO/text/HB544/2023',
#     'research_url': 'https://legiscan.com/MO/research/HB544/2023',
#     'last_action_date': '2023-01-05',
#     'last_action': 'Read Second Time (H)',
#     'title': 'Modifies provisions relating to abortion'},
#    {'relevance': 75,
#     'state': 'OR',
#     'bill_number': 'SB231',
#     'bill_id': 1647205,
#     'change_hash': 'ba537735a4476a3a6366066772b65319',
#     'url': 'https://legiscan.com/OR/bill/SB231/2023',
#     'text_url': 'https://legiscan.com/OR/text/SB231/2023',
#     'research_url': 'https://legiscan.com/OR/research/SB231/2023',
#     'last_action_date': '2023-02-27',
#     'last_action': 'Work Session scheduled.',
#     'title': 'Relating to abuse reporting.'},
#    {'relevance': 75,
#     'state': 'UT',
#     'bill_number': 'SB0120',
#     'bill_id': 1672808,
#     'change_hash': '5d34e780e77eac60a4e1842096ea84a2',
#     'url': 'https://legiscan.com/UT/bill/SB0120/2023',
#     'text_url': 'https://legiscan.com/UT/text/SB0120/2023',
#     'research_url': 'https://legiscan.com/UT/research/SB0120/2023',
#     'last_action_date': '2023-02-24',
#     'last_action': 'House/ 2nd reading in House 3rd Reading Calendar for Senate bills',
#     'title': 'Property and Contraband Amendments'},
#    {'relevance': 75,
#     'state': 'HI',
#     'bill_number': 'HB879',
#     'bill_id': 1676498,
#     'change_hash': 'cc8d468996ad199f8b241a9dbbac952f',
#     'url': 'https://legiscan.com/HI/bill/HB879/2023',
#     'text_url': 'https://legiscan.com/HI/text/HB879/2023',
#     'research_url': 'https://legiscan.com/HI/research/HB879/2023',
#     'last_action_date': '2023-02-07',
#     'last_action': 'Passed Second Reading as amended in HD 1 and referred to the committee(s) on JHA with Representative(s) Garcia voting aye with reservations; none voting no (0) and none excused (0).',
#     'title': 'Relating To The Child Protective Act.'},
#    {'relevance': 75,
#     'state': 'MO',
#     'bill_number': 'HB330',
#     'bill_id': 1634576,
#     'change_hash': '625fd9e99410246ac685a1912ca15f86',
#     'url': 'https://legiscan.com/MO/bill/HB330/2023',
#     'text_url': 'https://legiscan.com/MO/text/HB330/2023',
#     'research_url': 'https://legiscan.com/MO/research/HB330/2023',
#     'last_action_date': '2023-02-07',
#     'last_action': 'Public Hearing Completed (H)',
#     'title': 'Modifies provisions relating to advanced practice registered nurses'},
#    {'relevance': 75,
#     'state': 'IA',
#     'bill_number': 'SSB1145',
#     'bill_id': 1701468,
#     'change_hash': '944562f322be05885eb2796b8895ab5f',
#     'url': 'https://legiscan.com/IA/bill/SSB1145/2023',
#     'text_url': 'https://legiscan.com/IA/text/SSB1145/2023',
#     'research_url': 'https://legiscan.com/IA/research/SSB1145/2023',
#     'last_action_date': '2023-02-23',
#     'last_action': 'Subcommittee recommends amendment and passage. [].',
#     'title': "A bill for an act relating to children and students, including establishing a parent's or guardian's right to make decisions affecting the parent's or guardian's child, modifying provisions related to student health screenings and the curriculum in school districts, accredited nonpublic schools, and charter schools, other duties of school districts, competent private instruction, and special education, making appropriations, and providing civil penalties."}]}]

# %% [markdown]
# ## Different approach
# I don't know what's going on with my queries! I did something weird to the page numbers. Maybe it would make more sense to:
# 1. Download the [tracker](https://docs.google.com/spreadsheets/d/1fTxHLjBa86GA7WCT-V6AbEMGRFPMJndnaVGoZZX4PMw/edit#gid=0) as a CSV
# 2. Use the URL to get the state & bill number for each bill
# 3. Use pylegiscan get_bill to get the bill info, including doc ID
# 4. Add it to a pandas dataframe
# 5. Use the doc ID to get_bill_text
# 6. Download the text and add that to the dataframe
# 7. Clean up all the text
#
# Or, should I try downloading just a few more for now and see what results when I play with them?
#
# Looking at the [code](https://github.com/alliraine/legialerts/blob/main/main.py) used to update the Google Sheet in the first place using the LegiScan API, they pull the legislative session master list and turn that into a CSV.

# %%
mainlist = legis.get_master_list(state=None,session_id=2031)

# %%
len(mainlist)
# Out:
# 10258

# %%
df = pd.DataFrame.from_records(mainlist)

# %%
df.shape
# Out:
# (10258, 21)

# %%
list(df.columns)
# Out:
# ['session_id',
#  'state_id',
#  'year_start',
#  'year_end',
#  'prefile',
#  'sine_die',
#  'prior',
#  'special',
#  'session_tag',
#  'session_title',
#  'session_name',
#  'bill_id',
#  'number',
#  'change_hash',
#  'url',
#  'status_date',
#  'status',
#  'last_action_date',
#  'last_action',
#  'title',
#  'description']

# %%
df[400:425]
# Out:
#      session_id  state_id  year_start  year_end  prefile  sine_die  prior  \
# 400         NaN       NaN         NaN       NaN      NaN       NaN    NaN
# 401         NaN       NaN         NaN       NaN      NaN       NaN    NaN
# 402         NaN       NaN         NaN       NaN      NaN       NaN    NaN
# 403         NaN       NaN         NaN       NaN      NaN       NaN    NaN
# 404         NaN       NaN         NaN       NaN      NaN       NaN    NaN
# 405         NaN       NaN         NaN       NaN      NaN       NaN    NaN
# 406         NaN       NaN         NaN       NaN      NaN       NaN    NaN
# 407         NaN       NaN         NaN       NaN      NaN       NaN    NaN
# 408         NaN       NaN         NaN       NaN      NaN       NaN    NaN
# 409         NaN       NaN         NaN       NaN      NaN       NaN    NaN
# 410         NaN       NaN         NaN       NaN      NaN       NaN    NaN
# 411         NaN       NaN         NaN       NaN      NaN       NaN    NaN
# 412         NaN       NaN         NaN       NaN      NaN       NaN    NaN
# 413         NaN       NaN         NaN       NaN      NaN       NaN    NaN
# 414         NaN       NaN         NaN       NaN      NaN       NaN    NaN
# 415         NaN       NaN         NaN       NaN      NaN       NaN    NaN
# 416         NaN       NaN         NaN       NaN      NaN       NaN    NaN
# 417         NaN       NaN         NaN       NaN      NaN       NaN    NaN
# 418         NaN       NaN         NaN       NaN      NaN       NaN    NaN
# 419         NaN       NaN         NaN       NaN      NaN       NaN    NaN
# 420         NaN       NaN         NaN       NaN      NaN       NaN    NaN
# 421         NaN       NaN         NaN       NaN      NaN       NaN    NaN
# 422         NaN       NaN         NaN       NaN      NaN       NaN    NaN
# 423         NaN       NaN         NaN       NaN      NaN       NaN    NaN
# 424         NaN       NaN         NaN       NaN      NaN       NaN    NaN
#
#      special session_tag session_title  ...    bill_id  number  \
# 400      NaN         NaN           NaN  ...  1646294.0  A00420
# 401      NaN         NaN           NaN  ...  1646271.0  A00421
# 402      NaN         NaN           NaN  ...  1646107.0  A00422
# 403      NaN         NaN           NaN  ...  1646176.0  A00423
# 404      NaN         NaN           NaN  ...  1645968.0  A00424
# 405      NaN         NaN           NaN  ...  1645933.0  A00425
# 406      NaN         NaN           NaN  ...  1645912.0  A00426
# 407      NaN         NaN           NaN  ...  1646244.0  A00427
# 408      NaN         NaN           NaN  ...  1646289.0  A00428
# 409      NaN         NaN           NaN  ...  1646038.0  A00429
# 410      NaN         NaN           NaN  ...  1646290.0  A00430
# 411      NaN         NaN           NaN  ...  1646175.0  A00431
# 412      NaN         NaN           NaN  ...  1646259.0  A00432
# 413      NaN         NaN           NaN  ...  1646254.0  A00433
# 414      NaN         NaN           NaN  ...  1646070.0  A00434
# 415      NaN         NaN           NaN  ...  1646184.0  A00435
# 416      NaN         NaN           NaN  ...  1646000.0  A00436
# 417      NaN         NaN           NaN  ...  1645907.0  A00437
# 418      NaN         NaN           NaN  ...  1645995.0  A00438
# 419      NaN         NaN           NaN  ...  1645949.0  A00439
# 420      NaN         NaN           NaN  ...  1645991.0  A00440
# 421      NaN         NaN           NaN  ...  1645986.0  A00441
# 422      NaN         NaN           NaN  ...  1646258.0  A00442
# 423      NaN         NaN           NaN  ...  1646205.0  A00443
# 424      NaN         NaN           NaN  ...  1646101.0  A00444
#
#                           change_hash  \
# 400  7a963b760f926d3f5aba8427c7b893e2
# 401  1eb78a8ff7c8f6d33a91720d58a84e6c
# 402  9e8a4c2e07217ff373667276d69f3a74
# 403  4bba4871a4d8616414cd7d8377b18d67
# 404  64aacc2367567a4fabb3645e4b46fdda
# 405  47241287756bda7d6482df2e207fd109
# 406  b84fddfd0e3fb8caa986504591b7591b
# 407  7bbf91281a16312f60f2b4bb9351dff0
# 408  39b14084d460d247e688c06fe3546380
# 409  e6275deadea3df44193a294fe6b49b85
# 410  61842b96c4139c39909e8add5afc1733
# 411  16ccc8da1385bc0562f2bbeb877ef170
# 412  24f7e3a9ba9ca64c65a9d75f7ccdcf0c
# 413  362518a7ac408100f973b91fd6e60064
# 414  ca9bbfc9d93d9310bda710515e9d6781
# 415  62670c9f8181aa0c0c9fc666f4bb61d3
# 416  d14641591b7e7a6c669d481134811d6e
# 417  603b1bd8429c75e824e6c76786f565fe
# 418  32ff64529d80d098214581f9ef190b61
# 419  e0830ffef06623a494563067029fdb75
# 420  ae5988367483f565cf4286b0909fefb1
# 421  4bee9821f95496b1a5bb3765a6989dbb
# 422  393b4728b5dbebfe45e6f5ecdbb4d2c0
# 423  7c131a1a48aa007f8e17a564e84cd20f
# 424  76176d3bb5be7f00788f9fbb6f532bdb
#
#                                           url status_date status  \
# 400  https://legiscan.com/NY/bill/A00420/2023  2023-01-09    1.0
# 401  https://legiscan.com/NY/bill/A00421/2023  2023-01-09    1.0
# 402  https://legiscan.com/NY/bill/A00422/2023  2023-01-09    1.0
# 403  https://legiscan.com/NY/bill/A00423/2023  2023-01-09    1.0
# 404  https://legiscan.com/NY/bill/A00424/2023  2023-01-09    1.0
# 405  https://legiscan.com/NY/bill/A00425/2023  2023-01-09    1.0
# 406  https://legiscan.com/NY/bill/A00426/2023  2023-01-09    1.0
# 407  https://legiscan.com/NY/bill/A00427/2023  2023-01-09    1.0
# 408  https://legiscan.com/NY/bill/A00428/2023  2023-01-09    1.0
# 409  https://legiscan.com/NY/bill/A00429/2023  2023-01-09    1.0
# 410  https://legiscan.com/NY/bill/A00430/2023  2023-01-09    1.0
# 411  https://legiscan.com/NY/bill/A00431/2023  2023-01-09    1.0
# 412  https://legiscan.com/NY/bill/A00432/2023  2023-01-09    1.0
# 413  https://legiscan.com/NY/bill/A00433/2023  2023-01-09    1.0
# 414  https://legiscan.com/NY/bill/A00434/2023  2023-01-09    1.0
# 415  https://legiscan.com/NY/bill/A00435/2023  2023-01-09    1.0
# 416  https://legiscan.com/NY/bill/A00436/2023  2023-01-09    1.0
# 417  https://legiscan.com/NY/bill/A00437/2023  2023-01-09    1.0
# 418  https://legiscan.com/NY/bill/A00438/2023  2023-01-09    1.0
# 419  https://legiscan.com/NY/bill/A00439/2023  2023-01-09    1.0
# 420  https://legiscan.com/NY/bill/A00440/2023  2023-01-09    1.0
# 421  https://legiscan.com/NY/bill/A00441/2023  2023-01-09    1.0
# 422  https://legiscan.com/NY/bill/A00442/2023  2023-01-09    1.0
# 423  https://legiscan.com/NY/bill/A00443/2023  2023-01-09    1.0
# 424  https://legiscan.com/NY/bill/A00444/2023  2023-01-09    1.0
#
#      last_action_date                                        last_action  \
# 400        2023-01-09                            referred to agriculture
# 401        2023-01-09                                  referred to codes
# 402        2023-01-09                                referred to housing
# 403        2023-01-09                              referred to education
# 404        2023-01-09                      referred to local governments
# 405        2023-01-09                         referred to transportation
# 406        2023-01-09                         referred to transportation
# 407        2023-01-09                                  referred to labor
# 408        2023-01-09             referred to environmental conservation
# 409        2023-01-09                                  referred to codes
# 410        2023-01-09                           referred to election law
# 411        2023-01-09  referred to corporations, authorities and comm...
# 412        2023-01-09        referred to consumer affairs and protection
# 413        2023-01-09                            referred to agriculture
# 414        2023-01-09                                  referred to labor
# 415        2023-01-09                referred to governmental operations
# 416        2023-01-09                                  referred to codes
# 417        2023-01-09                                  referred to labor
# 418        2023-01-09                              referred to education
# 419        2023-01-09                referred to governmental operations
# 420        2023-01-09                              referred to education
# 421        2023-01-09                 referred to governmental employees
# 422        2023-01-09                                  referred to codes
# 423        2023-01-09  referred to corporations, authorities and comm...
# 424        2023-01-09                            referred to agriculture
#
#                                                  title  \
# 400  Requires the installation and testing of fire ...
# 401  Relates to repeat offenders of driving accidents.
# 402  Relates to eliminating the price index of oper...
# 403  Requires consent prior to sharing personally i...
# 404  Relates to prohibiting police officers from ca...
# 405  Relates to notifying persons renewing their li...
# 406  Provides that whenever the estimate for constr...
# 407  Requires the Olympic regional development auth...
# 408  Relates to the taking of wildlife without a pe...
# 409  Prohibits handcuffing or forcibly restraining ...
# 410  Relates to the procedure for filling a vacancy...
# 411  Relates to the approval of certain public auth...
# 412  Prohibits the manufacture, distribution and sa...
# 413  Prohibits a person convicted of "Buster's Law"...
# 414  Establishes the "New York state lead-safe reno...
# 415  Provides that any review of apportionment by t...
# 416  Relates to interest to be recovered upon a sum...
# 417  Requires sexual harassment training for hotel ...
# 418  Establishes schools dedicated to teaching dysl...
# 419  Requires sign language interpreters during liv...
# 420  Requires public schools to start no earlier th...
# 421  Relates to employment of persons and veterans ...
# 422  Establishes the offense of unlawful possession...
# 423  Provides the New York power authority with the...
# 424  Criminalizes knowingly causing a minor to atte...
#
#                                            description
# 400  Requires the installation and testing of fire ...
# 401  Relates to repeat offenders of driving accidents.
# 402  Relates to eliminating the price index of oper...
# 403  Requires consent prior to sharing personally i...
# 404  Relates to prohibiting police officers from ca...
# 405  Relates to notifying persons renewing their li...
# 406  Provides that whenever the estimate for constr...
# 407  Requires the Olympic regional development auth...
# 408  Relates to the taking of wildlife without a pe...
# 409  Prohibits handcuffing or forcibly restraining ...
# 410  Relates to the procedure for filling a vacancy...
# 411  Relates to the approval of certain public auth...
# 412  Prohibits the manufacture, distribution and sa...
# 413  Prohibits a person convicted of "Buster's Law"...
# 414  Establishes the "New York state lead-safe reno...
# 415  Provides that any review of apportionment by t...
# 416  Relates to interest to be recovered upon a sum...
# 417  Requires sexual harassment training for hotel ...
# 418  Establishes schools dedicated to teaching dysl...
# 419  Requires sign language interpreters during liv...
# 420  Requires public schools to start no earlier th...
# 421  Relates to employment of persons and veterans ...
# 422  Establishes the offense of unlawful possession...
# 423  Provides the New York power authority with the...
# 424  Criminalizes knowingly causing a minor to atte...
#
# [25 rows x 21 columns]

# %%
antibillsdf = pd.read_csv("anti-lgbtq-bills-tracker.csv")
antibillsdf.shape
# Out:
# (367, 37)

# %%
antibillsdf.head()
# Out:
#      State  Number                                            Summary  \
# 0   Alaska    HB27          Designate Sex For School-sponsored Sports
# 1  Arizona  HB2312        Women's shelters; male employees; liability
# 2  Arizona  HB2711  Student information; parental notification; re...
# 3  Arizona  SB1001          Pronouns; biological sex; school policies
# 4  Arizona  SB1026                   State monies; drag shows; minors
#
#                                     Bill Type       Date  \
# 0                            Trans Sports Ban  1/19/2023
# 1  Bans trans people from working at shelters  2/21/2023
# 2                    Forced Outing by Schools   2/8/2023
# 3                    Forced Outing by Schools  1/18/2023
# 4                                    Drag Ban   2/8/2023
#
#                                               Status Erin Reed's State Risk  \
# 0                              REFERRED TO EDUCATION               Moderate
# 1                     House minority caucus: Do pass                    Low
# 2                             House read second time                    Low
# 3  Senate ED Committee action: Do Pass Amended, v...                    Low
# 4  Senate GOV Committee action: Do Pass Amended, ...                    Low
#
#                                                Notes  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Pronoun Ban. It's requires parental permission...
# 4  Bans use of state money at places where drag s...
#
#                                         URL  \
# 0    https://legiscan.com/AK/bill/HB27/2023
# 1  https://legiscan.com/AZ/bill/HB2312/2023
# 2  https://legiscan.com/AZ/bill/HB2711/2023
# 3  https://legiscan.com/AZ/bill/SB1001/2023
# 4  https://legiscan.com/AZ/bill/SB1026/2023
#
#                                             Sponsors  ... Unnamed: 27  \
# 0                                       Thomas McKay  ...         NaN
# 1  Rachel Jones, Lupe Diaz, Liz Harris, Cory McGa...  ...         NaN
# 2                  Alexander Kolodin, Joseph Chaplik  ...         NaN
# 3                                      John Kavanagh  ...         NaN
# 4                                      John Kavanagh  ...         NaN
#
#   Unnamed: 28 Unnamed: 29 Unnamed: 30  Unnamed: 31  Unnamed: 32  Unnamed: 33  \
# 0         NaN         NaN         NaN          NaN          NaN          NaN
# 1         NaN         NaN         NaN          NaN          NaN          NaN
# 2         NaN         NaN         NaN          NaN          NaN          NaN
# 3         NaN         NaN         NaN          NaN          NaN          NaN
# 4         NaN         NaN         NaN          NaN          NaN          NaN
#
#    Unnamed: 34  Unnamed: 35  Unnamed: 36
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN
# 2          NaN          NaN          NaN
# 3          NaN          NaN          NaN
# 4          NaN          NaN          NaN
#
# [5 rows x 37 columns]

# %%
us_state_to_abbrev["Alaska"]
# Out:
# 'AK'

# %%
antibillsdf['State'] = antibillsdf['State'].replace(us_state_to_abbrev)
antibillsdf.head()
# Out:
#   State  Number                                            Summary  \
# 0    AK    HB27          Designate Sex For School-sponsored Sports
# 1    AZ  HB2312        Women's shelters; male employees; liability
# 2    AZ  HB2711  Student information; parental notification; re...
# 3    AZ  SB1001          Pronouns; biological sex; school policies
# 4    AZ  SB1026                   State monies; drag shows; minors
#
#                                     Bill Type       Date  \
# 0                            Trans Sports Ban  1/19/2023
# 1  Bans trans people from working at shelters  2/21/2023
# 2                    Forced Outing by Schools   2/8/2023
# 3                    Forced Outing by Schools  1/18/2023
# 4                                    Drag Ban   2/8/2023
#
#                                               Status Erin Reed's State Risk  \
# 0                              REFERRED TO EDUCATION               Moderate
# 1                     House minority caucus: Do pass                    Low
# 2                             House read second time                    Low
# 3  Senate ED Committee action: Do Pass Amended, v...                    Low
# 4  Senate GOV Committee action: Do Pass Amended, ...                    Low
#
#                                                Notes  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Pronoun Ban. It's requires parental permission...
# 4  Bans use of state money at places where drag s...
#
#                                         URL  \
# 0    https://legiscan.com/AK/bill/HB27/2023
# 1  https://legiscan.com/AZ/bill/HB2312/2023
# 2  https://legiscan.com/AZ/bill/HB2711/2023
# 3  https://legiscan.com/AZ/bill/SB1001/2023
# 4  https://legiscan.com/AZ/bill/SB1026/2023
#
#                                             Sponsors  ... Unnamed: 27  \
# 0                                       Thomas McKay  ...         NaN
# 1  Rachel Jones, Lupe Diaz, Liz Harris, Cory McGa...  ...         NaN
# 2                  Alexander Kolodin, Joseph Chaplik  ...         NaN
# 3                                      John Kavanagh  ...         NaN
# 4                                      John Kavanagh  ...         NaN
#
#   Unnamed: 28 Unnamed: 29 Unnamed: 30  Unnamed: 31  Unnamed: 32  Unnamed: 33  \
# 0         NaN         NaN         NaN          NaN          NaN          NaN
# 1         NaN         NaN         NaN          NaN          NaN          NaN
# 2         NaN         NaN         NaN          NaN          NaN          NaN
# 3         NaN         NaN         NaN          NaN          NaN          NaN
# 4         NaN         NaN         NaN          NaN          NaN          NaN
#
#    Unnamed: 34  Unnamed: 35  Unnamed: 36
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN
# 2          NaN          NaN          NaN
# 3          NaN          NaN          NaN
# 4          NaN          NaN          NaN
#
# [5 rows x 37 columns]

# %%
antibillsdf.columns
# Out:
# Index(['State', 'Number', 'Summary', 'Bill Type', 'Date', 'Status',
#        'Erin Reed's State Risk', 'Notes', 'URL', 'Sponsors', 'Calendar',
#        'History', 'Manual Status', 'Change Hash', 'Unnamed: 14', 'Unnamed: 15',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
#        'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31',
#        'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35',
#        'Unnamed: 36'],
#       dtype='object')

# %%
# get just the state abbrev and bill number from the whole CSV
statebillnodf = antibillsdf.filter(['State','Number','URL'])

# %%
statebillnodf.head()
# Out:
#   State  Number                                       URL
# 0    AK    HB27    https://legiscan.com/AK/bill/HB27/2023
# 1    AZ  HB2312  https://legiscan.com/AZ/bill/HB2312/2023
# 2    AZ  HB2711  https://legiscan.com/AZ/bill/HB2711/2023
# 3    AZ  SB1001  https://legiscan.com/AZ/bill/SB1001/2023
# 4    AZ  SB1026  https://legiscan.com/AZ/bill/SB1026/2023

# %%
len(antibillsdf)
# Out:
# 367

# %%
urllist = list(antibillsdf['URL'])

# %%
stateabbvs = list(antibillsdf['State'])
billnos = list(antibillsdf['Number'])

# %%
stateabbvs[0]
# Out:
# 'AK'

# %%
billnos[0]
# Out:
# 'HB27'

# %% [markdown]
# God this is such a dumb way to do this, but it's the way I know how!

# %%
antibillsdf.URL
# Out:
# 0        https://legiscan.com/AK/bill/HB27/2023
# 1      https://legiscan.com/AZ/bill/HB2312/2023
# 2      https://legiscan.com/AZ/bill/HB2711/2023
# 3      https://legiscan.com/AZ/bill/SB1001/2023
# 4      https://legiscan.com/AZ/bill/SB1026/2023
#                          ...
# 362    https://legiscan.com/WY/bill/SF0111/2023
# 363    https://legiscan.com/WY/bill/SF0117/2023
# 364    https://legiscan.com/WY/bill/SF0133/2023
# 365    https://legiscan.com/WY/bill/SF0144/2023
# 366    https://legiscan.com/WY/bill/SF0159/2023
# Name: URL, Length: 367, dtype: object

# %%
len(antibillsdf.URL)
# Out:
# 367

# %%
billinfos = []
for i in range(len(antibillsdf.URL)):
    if(billnos[i] != "nan"):
        billinfo = legis.get_bill(bill_id=None, state=stateabbvs[i], bill_number=billnos[i])    
        billinfos.append(billinfo)
    else:
        continue
# Out:
# ---------------------------------------------------------------------------
# LegiScanError                             Traceback (most recent call last)
# /var/folders/lj/gz81psj55xg1_fm6jfz2vbn80000gn/T/ipykernel_18615/3994706786.py in <module>
#       2 for i in range(len(antibillsdf.URL)):
#       3     if(billnos[i] != "nan"):
# ----> 4         billinfo = legis.get_bill(bill_id=None, state=stateabbvs[i], bill_number=billnos[i])
#       5         billinfos.append(billinfo)
#       6     else:
#
# /var/folders/lj/gz81psj55xg1_fm6jfz2vbn80000gn/T/ipykernel_18615/3761083699.py in get_bill(self, bill_id, state, bill_number)
#     131         else:
#     132             raise ValueError('Must specify bill_id or state and bill_number.')
# --> 133         return self._get(url)['bill']
#     134
#     135     def get_bill_text(self, doc_id):
#
# /var/folders/lj/gz81psj55xg1_fm6jfz2vbn80000gn/T/ipykernel_18615/3761083699.py in _get(self, url)
#      73         data = json.loads(req.content)
#      74         if data['status'] == "ERROR":
# ---> 75             raise LegiScanError(data['alert']['message'])
#      76         return data
#      77
#
# LegiScanError: Invalid bill id

# %% [markdown]
# # Example code continues below

# %%
# bills = legis.search(state='tx', query='abortion')
# bills['summary'] # how many results did we get?
# Out:
# {'page': '1 of 2',
#  'range': '1 - 50',
#  'relevancy': '100% - 87%',
#  'count': 59,
#  'page_current': '1',
#  'page_total': 2,
#  'query': '(Zabort:(pos=1))'}

# %% [markdown]
# You can also get single bills, one at a time, as long as you know their ID in the LegiScan database.

# %%
legis.get_bill('1635057')
# Out:
# {'bill_id': 1635057,
#  'change_hash': 'e09e6c58de86d4d7f02c80d880b2fd09',
#  'session_id': 2012,
#  'session': {'session_id': 2012,
#   'state_id': 25,
#   'year_start': 2023,
#   'year_end': 2023,
#   'prefile': 0,
#   'sine_die': 0,
#   'prior': 0,
#   'special': 0,
#   'session_tag': 'Regular Session',
#   'session_title': '2023 Regular Session',
#   'session_name': '2023 Regular Session'},
#  'url': 'https://legiscan.com/MO/bill/SB49/2023',
#  'state_link': 'https://www.senate.mo.gov/23info/BTS_Web/Bill.aspx?SessionType=R&BillID=44407',
#  'completed': 0,
#  'status': 1,
#  'status_date': '2023-01-04',
#  'progress': [{'date': '2023-01-04', 'event': 1},
#   {'date': '2023-01-12', 'event': 9}],
#  'state': 'MO',
#  'state_id': 25,
#  'bill_number': 'SB49',
#  'bill_type': 'B',
#  'bill_type_id': '1',
#  'body': 'S',
#  'body_id': 60,
#  'current_body': 'S',
#  'current_body_id': 60,
#  'title': 'Establishes the "Missouri Save Adolescents from Experimentation (SAFE) Act"',
#  'description': 'Establishes the "Missouri Save Adolescents from Experimentation (SAFE) Act"',
#  'pending_committee_id': 0,
#  'committee': [],
#  'referrals': [{'date': '2023-01-12',
#    'committee_id': 4711,
#    'chamber': 'S',
#    'chamber_id': 60,
#    'name': 'Emerging Issues'}],
#  'history': [{'date': '2022-12-01',
#    'action': 'Prefiled',
#    'chamber': 'S',
#    'chamber_id': 60,
#    'importance': 0},
#   {'date': '2023-01-04',
#    'action': 'S First Read',
#    'chamber': 'S',
#    'chamber_id': 60,
#    'importance': 0},
#   {'date': '2023-01-12',
#    'action': 'Second Read and Referred S Emerging Issues Committee',
#    'chamber': 'S',
#    'chamber_id': 60,
#    'importance': 1},
#   {'date': '2023-02-14',
#    'action': 'Hearing Conducted S Emerging Issues Committee',
#    'chamber': 'S',
#    'chamber_id': 60,
#    'importance': 0},
#   {'date': '2023-02-20',
#    'action': 'SCS Voted Do Pass (w/SCSs SB 49, 236, &164) Emerging Issues Committee (0202S.02C)',
#    'chamber': 'S',
#    'chamber_id': 60,
#    'importance': 0},
#   {'date': '2023-02-21',
#    'action': 'Reported from S Emerging Issues Committee w/SCS',
#    'chamber': 'S',
#    'chamber_id': 60,
#    'importance': 0},
#   {'date': '2023-02-27',
#    'action': 'Formal Calendar S Bills for Perfection',
#    'chamber': 'S',
#    'chamber_id': 60,
#    'importance': 0}],
#  'sponsors': [{'people_id': 16177,
#    'person_hash': '3p3wgq6y',
#    'party_id': '2',
#    'state_id': 25,
#    'party': 'R',
#    'role_id': 2,
#    'role': 'Sen',
#    'name': 'Mike Moon',
#    'first_name': 'Mike',
#    'middle_name': '',
#    'last_name': 'Moon',
#    'suffix': '',
#    'nickname': '',
#    'district': 'SD-029',
#    'ftm_eid': 16501211,
#    'votesmart_id': 123397,
#    'opensecrets_id': '',
#    'knowwho_pid': 284786,
#    'ballotpedia': 'Mike_Moon',
#    'bioguide_id': '',
#    'sponsor_type_id': 1,
#    'sponsor_order': 1,
#    'committee_sponsor': 0,
#    'committee_id': 0,
#    'state_federal': 0},
#   {'people_id': 18105,
#    'person_hash': 'wj228jud',
#    'party_id': '2',
#    'state_id': 25,
#    'party': 'R',
#    'role_id': 2,
#    'role': 'Sen',
#    'name': 'William Eigel',
#    'first_name': 'William',
#    'middle_name': '',
#    'last_name': 'Eigel',
#    'suffix': '',
#    'nickname': 'Bill',
#    'district': 'SD-023',
#    'ftm_eid': 39656678,
#    'votesmart_id': 169721,
#    'opensecrets_id': '',
#    'knowwho_pid': 572088,
#    'ballotpedia': 'Bill_Eigel',
#    'bioguide_id': '',
#    'sponsor_type_id': 2,
#    'sponsor_order': 2,
#    'committee_sponsor': 0,
#    'committee_id': 0,
#    'state_federal': 0},
#   {'people_id': 12944,
#    'person_hash': '28x3l5dx',
#    'party_id': '2',
#    'state_id': 25,
#    'party': 'R',
#    'role_id': 2,
#    'role': 'Sen',
#    'name': 'Rick Brattin',
#    'first_name': 'Rick',
#    'middle_name': '',
#    'last_name': 'Brattin',
#    'suffix': '',
#    'nickname': '',
#    'district': 'SD-031',
#    'ftm_eid': 6685174,
#    'votesmart_id': 124815,
#    'opensecrets_id': '',
#    'knowwho_pid': 290178,
#    'ballotpedia': 'Rick_Brattin',
#    'bioguide_id': '',
#    'sponsor_type_id': 2,
#    'sponsor_order': 3,
#    'committee_sponsor': 0,
#    'committee_id': 0,
#    'state_federal': 0}],
#  'sasts': [],
#  'subjects': [],
#  'texts': [{'doc_id': 2631259,
#    'date': '0000-00-00',
#    'type': 'Introduced',
#    'type_id': 1,
#    'mime': 'application/pdf',
#    'mime_id': 2,
#    'url': 'https://legiscan.com/MO/text/SB49/id/2631259',
#    'state_link': 'http://reflect.legiscan.com/Proxy.php',
#    'text_size': 347111,
#    'text_hash': '2b017580afa21ca9a37198a3291693d5'},
#   {'doc_id': 2709450,
#    'date': '0000-00-00',
#    'type': 'Comm Sub',
#    'type_id': 2,
#    'mime': 'application/pdf',
#    'mime_id': 2,
#    'url': 'https://legiscan.com/MO/text/SB49/id/2709450',
#    'state_link': 'http://reflect.legiscan.com/Proxy.php',
#    'text_size': 351371,
#    'text_hash': 'b7b584297edb07bfe2184dd8407fc5c4'},
#   {'doc_id': 2711919,
#    'date': '0000-00-00',
#    'type': 'Comm Sub',
#    'type_id': 2,
#    'mime': 'application/pdf',
#    'mime_id': 2,
#    'url': 'https://legiscan.com/MO/text/SB49/id/2711919',
#    'state_link': 'http://reflect.legiscan.com/Proxy.php',
#    'text_size': 348914,
#    'text_hash': '57166a8f3b9ee5dff170776fe149f1e2'}],
#  'votes': [],
#  'amendments': [],
#  'supplements': [{'supplement_id': 287504,
#    'date': '0000-00-00',
#    'type': 'Analysis',
#    'type_id': 2,
#    'title': 'Analysis',
#    'description': 'Summary: Introduced',
#    'mime': 'text/html',
#    'mime_id': 1,
#    'url': 'https://legiscan.com/MO/supplement/SB49/id/287504',
#    'state_link': 'https://www.senate.mo.gov/23info/BTS_Web/Summary.aspx?SessionType=R&SummaryID=38041&BillID=44407',
#    'supplement_size': 1269,
#    'supplement_hash': 'bd8e841e753965c5351683a602d21b8d'},
#   {'supplement_id': 294419,
#    'date': '0000-00-00',
#    'type': 'Fiscal Note',
#    'type_id': 1,
#    'title': 'Fiscal Note',
#    'description': '0202S.01I.ORG',
#    'mime': 'application/pdf',
#    'mime_id': 2,
#    'url': 'https://legiscan.com/MO/supplement/SB49/id/294419',
#    'state_link': 'https://senate.mo.gov/FiscalNotes/2023-1/0202S.01I.ORG.pdf',
#    'supplement_size': 116277,
#    'supplement_hash': '8e0df154b51d33ddad7fc29b427ed571'},
#   {'supplement_id': 309025,
#    'date': '0000-00-00',
#    'type': 'Analysis',
#    'type_id': 2,
#    'title': 'Analysis',
#    'description': 'Summary: Senate Committee Substitute',
#    'mime': 'text/html',
#    'mime_id': 1,
#    'url': 'https://legiscan.com/MO/supplement/SB49/id/309025',
#    'state_link': 'https://www.senate.mo.gov/23info/BTS_Web/Summary.aspx?SessionType=R&SummaryID=2776259&BillID=44407',
#    'supplement_size': 1298,
#    'supplement_hash': 'fb46acddedaadd6881cecf61df81423e'},
#   {'supplement_id': 310376,
#    'date': '0000-00-00',
#    'type': 'Fiscal Note',
#    'type_id': 1,
#    'title': 'Fiscal Note',
#    'description': '0202S.02C.ORG',
#    'mime': 'application/pdf',
#    'mime_id': 2,
#    'url': 'https://legiscan.com/MO/supplement/SB49/id/310376',
#    'state_link': 'https://senate.mo.gov/FiscalNotes/2023-1/0202S.02C.ORG.pdf',
#    'supplement_size': 117775,
#    'supplement_hash': '790e5fdb7c99259b8367c7503a06e000'}],
#  'calendar': [{'type_id': 1,
#    'type': 'Hearing',
#    'date': '2023-02-14',
#    'time': '10:00',
#    'location': 'SCR 1',
#    'description': 'Emerging Issues Hearing'}]}

# %%
df2.shape
# Out:
# (10258, 21)

# %%
df2[df2.url.isin(urllist)]
# Out:
#    session_id  state_id  year_start  year_end  prefile  sine_die  prior  \
# 0      2031.0      32.0      2023.0    2024.0      0.0       0.0    0.0
#
#    special      session_tag              session_title  ... bill_id  number  \
# 0      0.0  Regular Session  2023-2024 Regular Session  ...     NaN     NaN
#
#   change_hash  url status_date status  last_action_date last_action title  \
# 0         NaN  NaN         NaN    NaN               NaN         NaN   NaN
#
#   description
# 0         NaN
#
# [1 rows x 21 columns]

# %%
df2.url
# Out:
# 0                                             NaN
# 1        https://legiscan.com/NY/bill/A00021/2023
# 2        https://legiscan.com/NY/bill/A00022/2023
# 3        https://legiscan.com/NY/bill/A00023/2023
# 4        https://legiscan.com/NY/bill/A00024/2023
#                            ...
# 10253    https://legiscan.com/NY/bill/J00473/2023
# 10254    https://legiscan.com/NY/bill/J00474/2023
# 10255    https://legiscan.com/NY/bill/J00475/2023
# 10256    https://legiscan.com/NY/bill/J00476/2023
# 10257    https://legiscan.com/NY/bill/C00010/2023
# Name: url, Length: 10258, dtype: object

# %%
df3 = df2['url'].isin(antibillsdf['URL'])

# %% [markdown]
# # LegiScan Datasets
#
# It'd take forever to download the bills one at a time, so we take advantage of LegiScan's [datasets](https://legiscan.com/datasets) capability. They're a whole set of bill data for each session of the legislature.

# %%
datasets = legis.get_dataset_list()
dataset = legis.get_dataset(datasets[20]['session_id'], datasets[20]['access_key'])
dataset.keys()
# Out:
# dict_keys(['state_id', 'session_id', 'session_name', 'dataset_hash', 'dataset_date', 'dataset_size', 'mime_type', 'zip'])

# %%
print(df3)
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10253    False
# 10254    False
# 10255    False
# 10256    False
# 10257    False
# Name: url, Length: 10258, dtype: bool

# %% [markdown]
# They come in a _really_ weird format, though: a [base64-encoded](https://en.wikipedia.org/wiki/Base64) zip file. SO first we need to convert the base64 zipfile into a normal file, then unzip it!

# %%
z_bytes = base64.b64decode(dataset['zip'])
z = zipfile.ZipFile(io.BytesIO(z_bytes))
z.extractall("./sample-data")

# %% [markdown]
# It creates a lot lot lot lot lot of `.json` files. For example, let's take a look at a sample of what we just extracted.

# %%
import glob

filenames = glob.glob("./sample-data/*/*/bill/*", recursive=True)
filenames[:15]
# Out:
# ['./sample-data/AK/2017-2018_30th_Legislature/bill/SCR10.json',
#  './sample-data/AK/2017-2018_30th_Legislature/bill/SB124.json',
#  './sample-data/AK/2017-2018_30th_Legislature/bill/HB65.json',
#  './sample-data/AK/2017-2018_30th_Legislature/bill/HB392.json',
#  './sample-data/AK/2017-2018_30th_Legislature/bill/HB238.json',
#  './sample-data/AK/2017-2018_30th_Legislature/bill/HCR25.json',
#  './sample-data/AK/2017-2018_30th_Legislature/bill/HB111.json',
#  './sample-data/AK/2017-2018_30th_Legislature/bill/HJR2.json',
#  './sample-data/AK/2017-2018_30th_Legislature/bill/HCR1.json',
#  './sample-data/AK/2017-2018_30th_Legislature/bill/HB404.json',
#  './sample-data/AK/2017-2018_30th_Legislature/bill/HB280.json',
#  './sample-data/AK/2017-2018_30th_Legislature/bill/SB173.json',
#  './sample-data/AK/2017-2018_30th_Legislature/bill/SCR9.json',
#  './sample-data/AK/2017-2018_30th_Legislature/bill/HCR401.json',
#  './sample-data/AK/2017-2018_30th_Legislature/bill/HB32.json']

# %% [markdown]
# Each file has all sorts of information about the bill, but **none of the text of the bill itself!** You can see for yourself:

# %%
import json

json_data = json.load(open("./sample-data/AK/2017-2018_30th_Legislature/bill/SCR10.json"))
json_data
# Out:
# {'bill': {'bill_id': 1004624,
#   'change_hash': '557d10e3e229284c17c4354e988bad06',
#   'session_id': 1397,
#   'session': {'session_id': 1397,
#    'session_name': '30th Legislature',
#    'session_title': '30th Legislature',
#    'year_start': 2017,
#    'year_end': 2018,
#    'special': 0},
#   'url': 'https://legiscan.com/AK/bill/SCR10/2017',
#   'state_link': 'http://www.akleg.gov/basis/Bill/Detail/30?Root=SCR10',
#   'completed': 0,
#   'status': 3,
#   'status_date': '2018-04-28',
#   'progress': [{'date': '2017-04-07', 'event': 1},
#    {'date': '2018-02-02', 'event': 10},
#    {'date': '2018-02-09', 'event': 2},
#    {'date': '2018-03-09', 'event': 10},
#    {'date': '2018-04-28', 'event': 3}],
#   'state': 'AK',
#   'state_id': 2,
#   'bill_number': 'SCR10',
#   'bill_type': 'CR',
#   'bill_type_id': '3',
#   'body': 'S',
#   'body_id': 14,
#   'current_body': 'H',
#   'current_body_id': 13,
#   'title': 'Alaska Year Of Innovation',
#   'description': 'Proclaiming 2019 to be the Year of Innovation in Alaska.',
#   'committee': [],
#   'pending_committee_id': 0,
#   'history': [{'date': '2017-04-07',
#     'action': 'READ THE FIRST TIME - REFERRALS',
#     'chamber': 'S',
#     'chamber_id': 14,
#     'importance': 1},
#    {'date': '2017-04-07',
#     'action': 'L&C, STA',
#     'chamber': 'S',
#     'chamber_id': 14,
#     'importance': 0},
#    {'date': '2017-04-07',
#     'action': 'COSPONSOR(S): HUGHES, BEGICH',
#     'chamber': 'S',
#     'chamber_id': 14,
#     'importance': 0},
#    {'date': '2017-04-12',
#     'action': 'L&C RPT CS 4DP 1AM NEW TITLE',
#     'chamber': 'S',
#     'chamber_id': 14,
#     'importance': 0},
#    {'date': '2017-04-12',
#     'action': 'DP: COSTELLO, HUGHES, MEYER, GARDNER',
#     'chamber': 'S',
#     'chamber_id': 14,
#     'importance': 0},
#    {'date': '2017-04-12',
#     'action': 'AM: STEVENS',
#     'chamber': 'S',
#     'chamber_id': 14,
#     'importance': 0},
#    {'date': '2017-04-12',
#     'action': 'FN1: ZERO(LEG)',
#     'chamber': 'S',
#     'chamber_id': 14,
#     'importance': 0},
#    {'date': '2018-02-02',
#     'action': 'STA RPT CS 2DP 2NR NEW TITLE',
#     'chamber': 'S',
#     'chamber_id': 14,
#     'importance': 1},
#    {'date': '2018-02-02',
#     'action': 'DP: MEYER, EGAN',
#     'chamber': 'S',
#     'chamber_id': 14,
#     'importance': 0},
#    {'date': '2018-02-02',
#     'action': 'NR: WILSON, GIESSEL',
#     'chamber': 'S',
#     'chamber_id': 14,
#     'importance': 0},
#    {'date': '2018-02-02',
#     'action': 'FN2: ZERO(LEG)',
#     'chamber': 'S',
#     'chamber_id': 14,
#     'importance': 0},
#    {'date': '2018-02-09',
#     'action': 'RULES TO CALENDAR 2/9/2018',
#     'chamber': 'S',
#     'chamber_id': 14,
#     'importance': 0},
#    {'date': '2018-02-09',
#     'action': 'READ THE SECOND TIME',
#     'chamber': 'S',
#     'chamber_id': 14,
#     'importance': 0},
#    {'date': '2018-02-09',
#     'action': 'STA CS ADOPTED UC',
#     'chamber': 'S',
#     'chamber_id': 14,
#     'importance': 0},
#    {'date': '2018-02-09',
#     'action': 'BEFORE SENATE ON FINAL PASSAGE',
#     'chamber': 'S',
#     'chamber_id': 14,
#     'importance': 0},
#    {'date': '2018-02-09',
#     'action': 'PASSED Y18 N- E1 V1',
#     'chamber': 'S',
#     'chamber_id': 14,
#     'importance': 0},
#    {'date': '2018-02-09',
#     'action': 'TRANSMITTED TO (H)',
#     'chamber': 'S',
#     'chamber_id': 14,
#     'importance': 1},
#    {'date': '2018-02-09',
#     'action': 'VERSION: CSSCR 10(STA)',
#     'chamber': 'S',
#     'chamber_id': 14,
#     'importance': 0},
#    {'date': '2018-02-12',
#     'action': 'READ THE FIRST TIME - REFERRALS',
#     'chamber': 'H',
#     'chamber_id': 13,
#     'importance': 0},
#    {'date': '2018-02-12',
#     'action': 'STA, L&C',
#     'chamber': 'H',
#     'chamber_id': 13,
#     'importance': 0},
#    {'date': '2018-03-09',
#     'action': 'STA RPT 5DP',
#     'chamber': 'H',
#     'chamber_id': 13,
#     'importance': 1},
#    {'date': '2018-03-09',
#     'action': 'DP: LEDOUX, WOOL, JOHNSON, BIRCH, KREISS-TOMKINS',
#     'chamber': 'H',
#     'chamber_id': 13,
#     'importance': 0},
#    {'date': '2018-03-09',
#     'action': 'FN2: ZERO(LEG)',
#     'chamber': 'H',
#     'chamber_id': 13,
#     'importance': 0},
#    {'date': '2018-04-23',
#     'action': 'L&C REFERRAL WAIVED',
#     'chamber': 'H',
#     'chamber_id': 13,
#     'importance': 0},
#    {'date': '2018-04-28',
#     'action': 'RULES TO CALENDAR 4/28/2018',
#     'chamber': 'H',
#     'chamber_id': 13,
#     'importance': 0},
#    {'date': '2018-04-28',
#     'action': 'READ THE SECOND TIME',
#     'chamber': 'H',
#     'chamber_id': 13,
#     'importance': 0},
#    {'date': '2018-04-28',
#     'action': 'PASSED Y35 N1 E4',
#     'chamber': 'H',
#     'chamber_id': 13,
#     'importance': 0},
#    {'date': '2018-04-28',
#     'action': 'RETURN TO (S), TRANSMIT TO GOV NEXT',
#     'chamber': 'H',
#     'chamber_id': 13,
#     'importance': 1},
#    {'date': '2018-04-28',
#     'action': 'VERSION: CSSCR 10(STA)',
#     'chamber': 'H',
#     'chamber_id': 13,
#     'importance': 0},
#    {'date': '2018-04-28',
#     'action': 'CROSS SPONSOR(S): MILLETT, JOSEPHSON, KAWASAKI',
#     'chamber': 'H',
#     'chamber_id': 13,
#     'importance': 0},
#    {'date': '2018-04-30',
#     'action': 'AWAITING TRANSMITTAL TO GOV',
#     'chamber': 'S',
#     'chamber_id': 14,
#     'importance': 0},
#    {'date': '2018-06-28',
#     'action': 'LEGISLATIVE RESOLVE 34',
#     'chamber': 'S',
#     'chamber_id': 14,
#     'importance': 0}],
#   'sponsors': [{'people_id': 11301,
#     'person_hash': '00r0668y',
#     'party_id': 2,
#     'party': 'R',
#     'role_id': 2,
#     'role': 'Sen',
#     'name': 'Mia Costello',
#     'first_name': 'Mia',
#     'middle_name': 'C.',
#     'last_name': 'Costello',
#     'suffix': '',
#     'nickname': '',
#     'district': 'SD-K',
#     'ftm_eid': 6692539,
#     'votesmart_id': 117406,
#     'opensecrets_id': '',
#     'ballotpedia': 'Mia_Costello',
#     'sponsor_type_id': 1,
#     'sponsor_order': 1,
#     'committee_sponsor': 0,
#     'committee_id': '0'},
#    {'people_id': 14388,
#     'person_hash': 'ybr0ht47',
#     'party_id': 2,
#     'party': 'R',
#     'role_id': 2,
#     'role': 'Sen',
#     'name': 'Shelley Hughes',
#     'first_name': 'Shelley',
#     'middle_name': '',
#     'last_name': 'Hughes',
#     'suffix': '',
#     'nickname': '',
#     'district': 'SD-F',
#     'ftm_eid': 13789707,
#     'votesmart_id': 140422,
#     'opensecrets_id': '',
#     'ballotpedia': 'Shelley_Hughes',
#     'sponsor_type_id': 2,
#     'sponsor_order': 2,
#     'committee_sponsor': 0,
#     'committee_id': '0'},
#    {'people_id': 18978,
#     'person_hash': 'dbulwgc3',
#     'party_id': 1,
#     'party': 'D',
#     'role_id': 2,
#     'role': 'Sen',
#     'name': 'Tom Begich',
#     'first_name': 'Tom',
#     'middle_name': '',
#     'last_name': 'Begich',
#     'suffix': '',
#     'nickname': '',
#     'district': 'SD-J',
#     'ftm_eid': 9424831,
#     'votesmart_id': 171468,
#     'opensecrets_id': '',
#     'ballotpedia': 'Tom_Begich',
#     'sponsor_type_id': 2,
#     'sponsor_order': 3,
#     'committee_sponsor': 0,
#     'committee_id': '0'},
#    {'people_id': 6043,
#     'person_hash': 'cpj136u0',
#     'party_id': 2,
#     'party': 'R',
#     'role_id': 1,
#     'role': 'Rep',
#     'name': 'Charisse Millett',
#     'first_name': 'Charisse',
#     'middle_name': 'E.',
#     'last_name': 'Millett',
#     'suffix': '',
#     'nickname': '',
#     'district': 'HD-025',
#     'ftm_eid': 6678391,
#     'votesmart_id': 107815,
#     'opensecrets_id': '',
#     'ballotpedia': 'Charisse_E._Millett',
#     'sponsor_type_id': 2,
#     'sponsor_order': 4,
#     'committee_sponsor': 0,
#     'committee_id': '0'},
#    {'people_id': 14389,
#     'person_hash': '459b60g1',
#     'party_id': 1,
#     'party': 'D',
#     'role_id': 1,
#     'role': 'Rep',
#     'name': 'Andrew Josephson',
#     'first_name': 'Andrew',
#     'middle_name': 'L.',
#     'last_name': 'Josephson',
#     'suffix': '',
#     'nickname': 'Andy',
#     'district': 'HD-017',
#     'ftm_eid': 9400827,
#     'votesmart_id': 140434,
#     'opensecrets_id': '',
#     'ballotpedia': 'Andrew_L._Josephson',
#     'sponsor_type_id': 2,
#     'sponsor_order': 5,
#     'committee_sponsor': 0,
#     'committee_id': '0'},
#    {'people_id': 6052,
#     'person_hash': 'vfp8rwqc',
#     'party_id': 1,
#     'party': 'D',
#     'role_id': 2,
#     'role': 'Sen',
#     'name': 'Scott Kawasaki',
#     'first_name': 'Scott',
#     'middle_name': '',
#     'last_name': 'Kawasaki',
#     'suffix': '',
#     'nickname': '',
#     'district': 'SD-A',
#     'ftm_eid': 6464847,
#     'votesmart_id': 27313,
#     'opensecrets_id': '',
#     'ballotpedia': 'Scott_J._Kawasaki',
#     'sponsor_type_id': 2,
#     'sponsor_order': 6,
#     'committee_sponsor': 0,
#     'committee_id': '0'}],
#   'sasts': [],
#   'subjects': [{'subject_id': 4526, 'subject_name': 'Business'},
#    {'subject_id': 4657, 'subject_name': 'Economic Development'},
#    {'subject_id': 4690, 'subject_name': 'Economy'},
#    {'subject_id': 4702, 'subject_name': 'Partnerships'},
#    {'subject_id': 4527, 'subject_name': 'Proclamations'},
#    {'subject_id': 4553, 'subject_name': 'Science & Technology'}],
#   'texts': [{'doc_id': 1587841,
#     'date': '2017-04-07',
#     'type': 'Introduced',
#     'type_id': 1,
#     'mime': 'application/pdf',
#     'mime_id': 2,
#     'url': 'https://legiscan.com/AK/text/SCR10/id/1587841',
#     'state_link': 'http://www.legis.state.ak.us/PDF/30/Bills/SCR010A.PDF',
#     'text_size': 87767},
#    {'doc_id': 1592227,
#     'date': '2017-04-12',
#     'type': 'Comm Sub',
#     'type_id': 2,
#     'mime': 'application/pdf',
#     'mime_id': 2,
#     'url': 'https://legiscan.com/AK/text/SCR10/id/1592227',
#     'state_link': 'http://www.legis.state.ak.us/PDF/30/Bills/SCR010B.PDF',
#     'text_size': 94024},
#    {'doc_id': 1717195,
#     'date': '2018-02-02',
#     'type': 'Comm Sub',
#     'type_id': 2,
#     'mime': 'application/pdf',
#     'mime_id': 2,
#     'url': 'https://legiscan.com/AK/text/SCR10/id/1717195',
#     'state_link': 'http://www.legis.state.ak.us/PDF/30/Bills/SCR010C.PDF',
#     'text_size': 93179},
#    {'doc_id': 1790359,
#     'date': '2018-05-01',
#     'type': 'Enrolled',
#     'type_id': 5,
#     'mime': 'application/pdf',
#     'mime_id': 2,
#     'url': 'https://legiscan.com/AK/text/SCR10/id/1790359',
#     'state_link': 'http://www.legis.state.ak.us/PDF/30/Bills/SCR010Z.PDF',
#     'text_size': 592822}],
#   'votes': [{'roll_call_id': 698344,
#     'date': '2018-02-09',
#     'desc': 'Senate: Second Reading - Final Passage',
#     'yea': 18,
#     'nay': 0,
#     'nv': 0,
#     'absent': 1,
#     'total': 19,
#     'passed': 1,
#     'chamber': 'S',
#     'chamber_id': 14,
#     'url': 'https://legiscan.com/AK/rollcall/SCR10/id/698344',
#     'state_link': 'http://www.legis.state.ak.us/basis/get_jrn_page.asp?session=30&bill=SCR10&jrn=1972&hse=S'},
#    {'roll_call_id': 745305,
#     'date': '2018-04-28',
#     'desc': 'House: Second Reading Final Passage',
#     'yea': 35,
#     'nay': 1,
#     'nv': 0,
#     'absent': 4,
#     'total': 40,
#     'passed': 1,
#     'chamber': 'H',
#     'chamber_id': 13,
#     'url': 'https://legiscan.com/AK/rollcall/SCR10/id/745305',
#     'state_link': 'http://www.legis.state.ak.us/basis/get_jrn_page.asp?session=30&bill=SCR10&jrn=3481&hse=H'}],
#   'amendments': [],
#   'supplements': [],
#   'calendar': [{'type_id': 1,
#     'type': 'Hearing',
#     'date': '2017-04-10',
#     'time': '09:00',
#     'location': 'Senate Labor & Commerce Hearing',
#     'description': 'Senate Labor & Commerce Hearing'},
#    {'type_id': 1,
#     'type': 'Hearing',
#     'date': '2017-04-11',
#     'time': '09:00',
#     'location': 'Senate Labor & Commerce Hearing',
#     'description': 'Senate Labor & Commerce Hearing'},
#    {'type_id': 1,
#     'type': 'Hearing',
#     'date': '2017-04-11',
#     'time': '13:30',
#     'location': 'Senate Labor & Commerce Hearing',
#     'description': 'Senate Labor & Commerce Hearing'},
#    {'type_id': 1,
#     'type': 'Hearing',
#     'date': '2018-02-01',
#     'time': '15:30',
#     'location': 'Senate State Affairs Hearing',
#     'description': 'Senate State Affairs Hearing'},
#    {'type_id': 1,
#     'type': 'Hearing',
#     'date': '2018-03-06',
#     'time': '15:15',
#     'location': 'House State Affairs Hearing',
#     'description': 'House State Affairs Hearing'},
#    {'type_id': 1,
#     'type': 'Hearing',
#     'date': '2018-03-08',
#     'time': '15:15',
#     'location': 'House State Affairs Hearing',
#     'description': 'House State Affairs Hearing'}]}}

# %% [markdown]
# You _can_ download the bill text if you have the ID, but... for some reason we don't do this. I'm going to be honest: I don't remember why. Maybe it's because they're older versions? They're incomplete? I truly have forgetten.

# %%
doc = legis.get_bill_text('2015157')
contents = base64.b64decode(doc['doc'])
with open("filename.html", "wb") as file:
    file.write(contents)

# %% [markdown]
# What we're going to need is the **URL to the published version.**

# %%
json_data['bill']['texts'][-1]
# Out:
# {'doc_id': 1790359,
#  'date': '2018-05-01',
#  'type': 'Enrolled',
#  'type_id': 5,
#  'mime': 'application/pdf',
#  'mime_id': 2,
#  'url': 'https://legiscan.com/AK/text/SCR10/id/1790359',
#  'state_link': 'http://www.legis.state.ak.us/PDF/30/Bills/SCR010Z.PDF',
#  'text_size': 592822}

# %% [markdown]
# We're going to need the URL to the published version from _every single one of those JSON files_.

# %% [markdown]
# # Download and extract all of the datasets from LegiScan

# %%
datasets = legis.get_dataset_list()
len(datasets)
# Out:
# 583

# %% [markdown]
# Downloading and extracting all 583 is going to take a while, so we'll use a progress bar from [tqdm](https://github.com/tqdm/tqdm) to keep track of where we're at.

# %%
import tqdm

total = len(datasets)
for dataset in tqdm.tqdm_notebook(datasets):
    session_id = dataset['session_id']
    access_key = dataset['access_key']
    details = legis.get_dataset(session_id, access_key)
    z_bytes = base64.b64decode(details['zip'])
    z = zipfile.ZipFile(io.BytesIO(z_bytes))
    z.extractall("./bill_data")
# Out:
# HBox(children=(IntProgress(value=0, max=583), HTML(value='')))

# %%
print(df3.index.where(df3[1] == True))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/lj/gz81psj55xg1_fm6jfz2vbn80000gn/T/ipykernel_18615/2370191121.py in <module>
# ----> 1 print(df3.index.where(df3[1] == True))
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in where(self, cond, other)
#    4922             )
#    4923         cond = np.asarray(cond, dtype=bool)
# -> 4924         return self.putmask(~cond, other)
#    4925
#    4926     # construction helpers
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in putmask(self, mask, value)
#    5162             based on conditional and input values.
#    5163         """
# -> 5164         mask, noop = validate_putmask(self._values, mask)
#    5165         if noop:
#    5166             return self.copy()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/array_algos/putmask.py in validate_putmask(values, mask)
#     158     mask = extract_bool_array(mask)
#     159     if mask.shape != values.shape:
# --> 160         raise ValueError("putmask: mask and data must be the same size")
#     161
#     162     noop = not mask.any()
#
# ValueError: putmask: mask and data must be the same size

# %%
df3.index.isin("True")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/lj/gz81psj55xg1_fm6jfz2vbn80000gn/T/ipykernel_18615/2424196968.py in <module>
# ----> 1 df3.index.isin("True")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in isin(self, values, level)
#    6229         if level is not None:
#    6230             self._validate_index_level(level)
# -> 6231         return algos.isin(self._values, values)
#    6232
#    6233     def _get_string_slice(self, key: str_t):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/algorithms.py in isin(comps, values)
#     466         )
#     467     if not is_list_like(values):
# --> 468         raise TypeError(
#     469             "only list-like objects are allowed to be passed "
#     470             f"to isin(), you passed a [{type(values).__name__}]"
#
# TypeError: only list-like objects are allowed to be passed to isin(), you passed a [str]

# %% [markdown]
# # Converting the many JSON files to single CSV file
#
# The data isn't doing us much good sitting around as a zillion json files, so we'll convert them into a CSV file with the pieces of information we're interested in. Those pieces are:
#
# * State
# * Bill title
# * Bill URL

# %%
filenames = glob.glob("bill_data/*/*/bill/*.json")
len(filenames)
# Out:
# 1253402

# %%
filenames[:5]
# Out:
# ['bill_data/VT/2011-2012_Regular_Session/bill/HCR143.json',
#  'bill_data/VT/2011-2012_Regular_Session/bill/H0291.json',
#  'bill_data/VT/2011-2012_Regular_Session/bill/S0162.json',
#  'bill_data/VT/2011-2012_Regular_Session/bill/S0027.json',
#  'bill_data/VT/2011-2012_Regular_Session/bill/H0784.json']

# %% [markdown]
# If we want to process over a million rows, it's going to take a while! To speed things up we're going to turn to [swifter](https://github.com/jmcarpenter2/swifter), a package that can parallelize work on pandas dataframes. It's pretty easy to use:
#
# **without swifter:**
#
# ```python
# df = pd.Series(filenames).apply(process_json)
# ```
#
# **with swifter:**
#
# ```python
# df = pd.Series(filenames).swifter.apply(process_json)
# ```
#
# And it does all the hard work for you! You just use it and hope for the best.

# %%
import json
import os
import swifter
import pandas as pd

def process_json(filename):
    with open(filename) as file:
        bill_data = {}
        # We need to do a little string replacing so the 
        json_str = file.read().replace('"0000-00-00"', 'null')
        content = json.loads(json_str)['bill']

        bill_data['bill_id'] = content['bill_id']
        bill_data['code'] = os.path.splitext(os.path.basename(filename))[0]
        bill_data['bill_number'] = content['bill_number']
        bill_data['title'] = content['title']
        bill_data['description'] = content['description']
        bill_data['state'] = content['state']
        bill_data['session'] = content['session']['session_name']
        bill_data['filename'] = filename
        bill_data['status'] = content['status']
        bill_data['status_date'] = content['status_date']

        try:
            bill_data['url'] = content['texts'][-1]['state_link']
        except:
            pass

        return pd.Series(bill_data)

df = pd.Series(filenames).swifter.apply(process_json)
df.head()
# Out:
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1253402, style=ProgressStyle(description_w…
#    bill_id    code bill_number  \
# 0   325258  HCR143      HCR143
# 1   285625   H0291       H0291
# 2   398232   S0162       S0162
# 3   243054   S0027       S0027
# 4   417691   H0784       H0784
#
#                                                title  \
# 0  House Concurrent Resolution Congratulating The...
# 1  An Act Relating To Raising The Penalties For A...
# 2              An Act Relating To Powers Of Attorney
# 3  An Act Relating To The Role Of Municipalities ...
# 4  An Act Relating To Approval Of The Adoption An...
#
#                                          description state            session  \
# 0  House Concurrent Resolution Congratulating The...    VT  2011-2012 Session
# 1  An Act Relating To Raising The Penalties For A...    VT  2011-2012 Session
# 2              An Act Relating To Powers Of Attorney    VT  2011-2012 Session
# 3  An Act Relating To The Role Of Municipalities ...    VT  2011-2012 Session
# 4  An Act Relating To Approval Of The Adoption An...    VT  2011-2012 Session
#
#                                             filename  status status_date  \
# 0  bill_data/VT/2011-2012_Regular_Session/bill/HC...       4  2011-04-22
# 1  bill_data/VT/2011-2012_Regular_Session/bill/H0...       1  2011-02-22
# 2  bill_data/VT/2011-2012_Regular_Session/bill/S0...       1  2012-01-03
# 3  bill_data/VT/2011-2012_Regular_Session/bill/S0...       1  2011-01-25
# 4  bill_data/VT/2011-2012_Regular_Session/bill/H0...       4  2012-05-05
#
#                                                  url
# 0  http://www.leg.state.vt.us/docs/2012/Acts/ACTR...
# 1  http://www.leg.state.vt.us/docs/2012/bills/Int...
# 2  http://www.leg.state.vt.us/docs/2012/bills/Int...
# 3  http://www.leg.state.vt.us/docs/2012/bills/Int...
# 4  http://www.leg.state.vt.us/docs/2012/Acts/ACTM...

# %% [markdown]
# And now we'll save it to prepare for the next step: **inserting it into a database.**

# %%
df.to_csv("data/bills-with-urls.csv", index=False)
