# %% [markdown]
# # Accessing Google Sheets API
# Trying to access [this spreadsheet](https://docs.google.com/spreadsheets/d/1fTxHLjBa86GA7WCT-V6AbEMGRFPMJndnaVGoZZX4PMw/edit#gid=0).
# [Python quickstart](https://developers.google.com/sheets/api/quickstart/python).

# %%
pip install --upgrade google-api-python-client google-auth-httplib2 google-auth-oauthlib
# Out:
# Collecting google-api-python-client
#   Downloading google_api_python_client-2.82.0-py2.py3-none-any.whl (11.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 9.5 MB/s eta 0:00:00:00:0100:01
# Collecting google-auth-httplib2
#   Downloading google_auth_httplib2-0.1.0-py2.py3-none-any.whl (9.3 kB)
# Requirement already satisfied: google-auth-oauthlib in /Users/gabriel/opt/anaconda3/lib/python3.9/site-packages (0.4.6)
# Collecting google-auth-oauthlib
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting uritemplate<5,>=3.0.1
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5
#   Downloading google_api_core-2.11.0-py3-none-any.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.3/120.3 kB 3.8 MB/s eta 0:00:00
# Collecting httplib2<1dev,>=0.15.0
#   Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.9/96.9 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in /Users/gabriel/opt/anaconda3/lib/python3.9/site-packages (from google-api-python-client) (2.16.2)
# Requirement already satisfied: six in /Users/gabriel/opt/anaconda3/lib/python3.9/site-packages (from google-auth-httplib2) (1.16.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/gabriel/opt/anaconda3/lib/python3.9/site-packages (from google-auth-oauthlib) (1.3.1)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /Users/gabriel/opt/anaconda3/lib/python3.9/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.28.1)
# Collecting googleapis-common-protos<2.0dev,>=1.56.2
#   Downloading googleapis_common_protos-1.59.0-py2.py3-none-any.whl (223 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.6/223.6 kB 5.6 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /Users/gabriel/opt/anaconda3/lib/python3.9/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.19.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/gabriel/opt/anaconda3/lib/python3.9/site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/gabriel/opt/anaconda3/lib/python3.9/site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/gabriel/opt/anaconda3/lib/python3.9/site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.2.8)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Users/gabriel/opt/anaconda3/lib/python3.9/site-packages (from httplib2<1dev,>=0.15.0->google-api-python-client) (3.0.9)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/gabriel/opt/anaconda3/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.2.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/gabriel/opt/anaconda3/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.4.8)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/gabriel/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/gabriel/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in /Users/gabriel/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/gabriel/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2022.9.24)
# Installing collected packages: uritemplate, httplib2, googleapis-common-protos, google-auth-oauthlib, google-auth-httplib2, google-api-core, google-api-python-client
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 0.4.6
#     Uninstalling google-auth-oauthlib-0.4.6:
#       Successfully uninstalled google-auth-oauthlib-0.4.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorboard 2.11.2 requires google-auth-oauthlib<0.5,>=0.4.1, but you have google-auth-oauthlib 1.0.0 which is incompatible.
# Successfully installed google-api-core-2.11.0 google-api-python-client-2.82.0 google-auth-httplib2-0.1.0 google-auth-oauthlib-1.0.0 googleapis-common-protos-1.59.0 httplib2-0.22.0 uritemplate-4.1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from __future__ import print_function

import os.path

from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# If modifying these scopes, delete the file token.json.
SCOPES = ['https://www.googleapis.com/auth/spreadsheets.readonly']

# The ID and range of a sample spreadsheet.
SPREADSHEET_ID = '1fTxHLjBa86GA7WCT-V6AbEMGRFPMJndnaVGoZZX4PMw'
RANGE_NAME = 'Anti-LGBTQ Bills!A:J'

creds = None
# The file token.json stores the user's access and refresh tokens, and is
# created automatically when the authorization flow completes for the first
# time.
if os.path.exists('token.json'):
    creds = Credentials.from_authorized_user_file('token.json', SCOPES)
# If there are no (valid) credentials available, let the user log in.
if not creds or not creds.valid:
    if creds and creds.expired and creds.refresh_token:
        creds.refresh(Request())
    else:
        flow = InstalledAppFlow.from_client_secrets_file(
            './credentials.json', SCOPES)
        creds = flow.run_local_server(port=0)
    # Save the credentials for the next run
    with open('token.json', 'w') as token:
        token.write(creds.to_json())

try:
    service = build('sheets', 'v4', credentials=creds)

    # Call the Sheets API
    sheet = service.spreadsheets()
    result = sheet.values().get(spreadsheetId=SPREADSHEET_ID,
                                range=RANGE_NAME).execute()
    values = result.get('values', [])

    type(values)

    if not values:
        print('No data found.')

    print(f'Bill Information:')
    for row in values:
        # Print desired columns
        print('%s, %s, %s, %s, %s, %s' % (row[0],row[1],row[3],row[4],row[8],row[9]))
    type(values)

except HttpError as err:
    print(err)
# Out:
# Bill Information:
# State, Number, Bill Type, Date, URL, Sponsors
# Alaska, HB27, Trans Sports Ban, 1/19/2023, https://legiscan.com/AK/bill/HB27/2023, Thomas McKay
# Alaska, SB96, Don't Say Gay/Forced Outing, 3/8/2023, https://legiscan.com/AK/bill/SB96/2023, Rules
# Alaska, HB105, Don't Say Gay/Forced Outing, 3/8/2023, https://legiscan.com/AK/bill/HB105/2023, Rules
# Arizona, SB1028, Drag Ban, 3/22/2023, https://legiscan.com/AZ/bill/SB1028/2023, Anthony Kern
# Arizona, SB1030, Drag Ban, 3/21/2023, https://legiscan.com/AZ/bill/SB1030/2023, Anthony Kern
# Arizona, SB1694, DEI Prohibitation, 3/22/2023, https://legiscan.com/AZ/bill/SB1694/2023, Jake Hoffman, Sonny Borrelli, Anthony Kern, Justine Wadsack, Justin Heap, Rachel Jones, Cory McGarr
# Arizona, SB1700, Book Ban, 3/22/2023, https://legiscan.com/AZ/bill/SB1700/2023, Justine Wadsack, Rachel Jones, Cory McGarr
# Arizona, HB2312, Bans trans people from working at shelters, 3/7/2023, https://legiscan.com/AZ/bill/HB2312/2023, Rachel Jones, Lupe Diaz, Liz Harris, Cory McGarr, Justine Wadsack
# Arizona, SB1001, Forced Outing by Schools, 3/8/2023, https://legiscan.com/AZ/bill/SB1001/2023, John Kavanagh
# Arizona, SB1026, Drag Ban, 3/22/2023, https://legiscan.com/AZ/bill/SB1026/2023, John Kavanagh
# Arizona, SB1040, Trans Bathroom Ban, 3/8/2023, https://legiscan.com/AZ/bill/SB1040/2023, John Kavanagh
# Arizona, SB1698, Drag Ban, 3/22/2023, https://legiscan.com/AZ/bill/SB1698/2023, Justine Wadsack, Rachel Jones, Cory McGarr
# Arizona, HB2711, Forced Outing by Schools, 2/8/2023, https://legiscan.com/AZ/bill/HB2711/2023, Alexander Kolodin, Joseph Chaplik
# Arizona, SB1702, Gender Affirming Care Ban, 2/2/2023, https://legiscan.com/AZ/bill/SB1702/2023, Justine Wadsack, Rachel Jones, Cory McGarr
# Arkansas, HB1156, Trans Bathroom Ban, 3/21/2023, https://legiscan.com/AR/bill/HB1156/2023, Mary Bentley, Dan Sullivan, Karilyn Brown, Cindy Crawford, DeAnna Hodges, Jack Ladyman, Wayne Long, Robin Lundstrum, Mindy McAlindon, Josh Miller, Ryan Rose, Dwight Tosh, Sonia Eubanks Barker
# Arkansas, SB199, Gender Affirming Care Ban, 3/16/2023, https://legiscan.com/AR/bill/SB199/2023, Gary Stubblefield, Mary Bentley
# Arkansas, SB270, Trans Bathroom Ban, 3/7/2023, https://legiscan.com/AR/bill/SB270/2023, John Payton, Cindy Crawford, Ben Gilmore, Missy Irvin, Blake Johnson, Mark Johnson, Matt Stone, David Wallace
# Arkansas, SB294, Don't Say Gay/Forced Outing, 3/14/2023, https://legiscan.com/AR/bill/SB294/2023, Breanne Davis, Keith Brooks, Matthew Shepherd, Austin Mccollum, Brit McKenzie, Aaron Pilkington, Stephen Meeks, Jeff Wardlaw, Jon Eubanks, Bruce Cozart, Richard Womack, Charlene Fite, Robin Lundstrum, Mary Bentley, Justin Gonzales, Rick Beck, Karilyn Brown, Marcus Richmond, Jack Fortner, Frances Cavenaugh, John Maddox, Sonia Eubanks Barker, Johnny Rye, Steve Hollowell, Danny Watson, Roger Lynch, Carlton Wing, Cindy Crawford, Lee Johnson, Cameron Cooper, Harlan Breaux, Brian Evans, Richard McGrew, David Ray, Howard Beaty, Rick McClure, Jon Milligan, Delia Haak, John Carr, Kendon Underwood, Tony Furman, Grant Hodges, Jeremiah Moore, Brandon Achor, Rebecca Burkes, RJ Hawk, Mindy McAlindon, Matt Brown, Ryan Rose, Chad Puryear, Zack Gramlich, Stetson Painter, Matt Duffield, Steve Unger, Scott Richardson, Wade Andrews, Bart Hester, Missy Irvin, Jonathan Dismang, Jane English, Gary Stubblefield, Scott Flippo, Blake Johnson, David Wallace, Ricky Hill, Mark Johnson, Kim Hammer, Dan Sullivan, Ben Gilmore, Matt McKee, Clint Penzo, Justin Boyd, Jim Petty, Joshua Bryant, Steve Crowell, Matt Stone, Tyler Dees, John Payton, Jim Dotson, Alan Clark
# Arkansas, SB43, Drag Ban, 2/27/2023, https://legiscan.com/AR/bill/SB43/2023, Gary Stubblefield, Mary Bentley, Sonia Eubanks Barker, Cameron Cooper, Cindy Crawford, Delia Haak, DeAnna Hodges, Jack Ladyman, Wayne Long, Robin Lundstrum, Mindy McAlindon, Scott Richardson, Ryan Rose, Johnny Rye, Dwight Tosh, Joshua Bryant, Blake Johnson, Kim Hammer, Terry Rice, Scott Flippo, Clint Penzo, Ben Gilmore, Matt Stone, Matt McKee, Alan Clark, Bart Hester, Tyler Dees, Dan Sullivan, Ronald Caldwell, Ricky Hill
# Arkansas, HB1468, Forced Misgendering, 3/15/2023, https://legiscan.com/AR/bill/HB1468/2023, Wayne Long, Mark Johnson, Marcus Richmond, Mary Bentley, Harlan Breaux, Joey Carr, Cindy Crawford, Robin Lundstrum, Mindy McAlindon, Rick McClure, Jon Milligan, Ryan Rose, Johnny Rye
# Arkansas, SB125, Legal Discrimination In Education, 3/15/2023, https://legiscan.com/AR/bill/SB125/2023, Jim Dotson, Rick Beck
# Arkansas, HB1615, Legal Discrimination of LTGBTQ people, 3/13/2023, https://legiscan.com/AR/bill/HB1615/2023, Robin Lundstrum, Gary Stubblefield, Mary Bentley, Cameron Cooper, Cindy Crawford, Jimmie Gazaway, Wayne Long, Jon Milligan, Marcus Richmond, Kendon Underwood, Steve Unger, Danny Watson, Alan Clark
# Colorado, HB1092, Ban on Public Investment in ESG Funds, 2/6/2023, https://legiscan.com/CO/bill/HB1092/2023, Rod Bockenfeld
# Colorado, HB1098, Trans Sports Ban, 2/13/2023, https://legiscan.com/CO/bill/HB1098/2023, Brandi Bradley, Lisa Frizell, Byron Pelton, Ryan Armagost, Anthony Hartsook, Ron Weinberg, Ty Winter
# Connecticut, HB06213, Trans Sports Ban, 1/19/2023, https://legiscan.com/CT/bill/HB06213/2023, Douglas Dubitsky
# Connecticut, HB06331, Forced Misgendering, 1/20/2023, https://legiscan.com/CT/bill/HB06331/2023, Joe Hoxha
# Connecticut, SB00467, Trans Bathroom Ban, 1/18/2023, https://legiscan.com/CT/bill/SB00467/2023, Robert Sampson
# Connecticut, SB00468, Trans Sports Ban, 1/18/2023, https://legiscan.com/CT/bill/SB00468/2023, Robert Sampson
# Connecticut, SB00544, Birth Certificate Change Ban, 1/18/2023, https://legiscan.com/CT/bill/SB00544/2023, Robert Sampson
# Florida, H0991, Defamation Bill, 3/14/2023, https://legiscan.com/FL/bill/H0991/2023, Alex Andrade, Mike Beltran, Dean Black
# Florida, H1069, Legal Discrimination In Education, 3/23/2023, https://legiscan.com/FL/bill/H1069/2023, Education & Employment Committee, Education Quality Subcommittee, Stan McClain, Adam Anderson, Ralph Massullo, Michelle Salzman
# Florida, H1069, Don't Say Gay Expansion, 3/23/2023, https://legiscan.com/FL/bill/H1069/2023, Education & Employment Committee, Education Quality Subcommittee, Stan McClain, Adam Anderson, Ralph Massullo, Michelle Salzman
# Florida, H1223, Don't Say Gay Expansion, 3/16/2023, https://legiscan.com/FL/bill/H1223/2023, Choice & Innovation Subcommittee, Adam Anderson, Jessica Baker, Doug Bankson, Dean Black, Randy Fine, Spencer Roach
# Florida, H1269, Gender Affirming Care Ban, 3/7/2023, https://legiscan.com/FL/bill/H1269/2023, Dan Daley
# Florida, H1421, Gender Affirming Care Ban, 3/23/2023, https://legiscan.com/FL/bill/H1421/2023, Healthcare Regulation Subcommittee, Randy Fine, Ralph Massullo, Doug Bankson, Dean Black, Berny Jacques, Rachel Plakon
# Florida, S0254, Legalizes Abduction of Trans Kids, 3/23/2023, https://legiscan.com/FL/bill/S0254/2023, Health Policy, Clay Yarborough, Keith Perry, Douglas Broxson
# Florida, S0952, Gender Affirming Care Ban, 3/7/2023, https://legiscan.com/FL/bill/S0952/2023, Blaise Ingoglia
# Florida, S1320, Don't Say Gay Expansion, 3/22/2023, https://legiscan.com/FL/bill/S1320/2023, Education Pre-K -12, Clay Yarborough, Keith Perry
# Florida, S1674, Trans Bathroom Ban, 3/14/2023, https://legiscan.com/FL/bill/S1674/2023, Erin Grall, Keith Perry
# Florida, H1265, Gender Affirming Care Ban, 3/7/2023, https://legiscan.com/FL/bill/H1265/2023, Taylor Yarkosky
# Florida, H1521, Trans Bathroom Ban, 3/24/2023, https://legiscan.com/FL/bill/H1521/2023, Rachel Plakon, Dean Black
# Georgia, SB140, Gender Affirming Care Ban, 3/23/2023, https://legiscan.com/GA/bill/SB140/2023, Carden Summers, Ben Watson, Kay Kirkpatrick, John Kennedy, Lee Anderson, Matt Brass, Jason Anavitarte, Billy Hickman, John Albers, Ed Setzler, Shawn Still, Brandon Beach, Russ Goodman, Sam Watson, Chuck Payne, Larry Walker, Blake Tillery, Brian Strickland, Marty Harbin, Ricky Williams, Clint Dixon, Colton Moore, Josh Bonner
# Georgia, HB653, Gender Affirming Care Ban, 3/6/2023, https://legiscan.com/GA/bill/HB653/2023, Josh Bonner, Rick Jasperse, Todd Jones, Mark Newton, Darlene Taylor, Ginny Ehrhart
# Georgia, SB141, Gender Affirming Care Ban, 2/13/2023, https://legiscan.com/GA/bill/SB141/2023, Clint Dixon, Steve Gooch, Marty Harbin, Randy Robertson, Shawn Still, John Albers, Matt Brass, Greg Dolezal, Shelly Echols, Colton Moore, Lee Anderson, Max Burns, Ed Setzler, Sam Watson, Carden Summers
# Georgia, SB88, Don't Say Gay/Forced Outing, 2/6/2023, https://legiscan.com/GA/bill/SB88/2023, Carden Summers, Colton Moore, Brandon Beach, Clint Dixon, Randy Robertson, John Albers, Shawn Still, Lee Anderson, Matt Brass, Chuck Payne, Marty Harbin
# Hawaii, HB291, Birth Certificate Change Ban, 1/25/2023, https://legiscan.com/HI/bill/HB291/2023, David Alcos
# Hawaii, HB508, Trans Sports Ban, 1/27/2023, https://legiscan.com/HI/bill/HB508/2023, Diamond Garcia
# Hawaii, HB509, Don't Say Gay/Forced Outing, 1/27/2023, https://legiscan.com/HI/bill/HB509/2023, Diamond Garcia
# Hawaii, HB891, Gender Affirming Care Ban, 1/30/2023, https://legiscan.com/HI/bill/HB891/2023, Diamond Garcia
# Hawaii, SB1428, Don't Say Gay/Forced Outing, 1/30/2023, https://legiscan.com/HI/bill/SB1428/2023, Brenton Awa
# Hawaii, SB1429, Trans sports Ban, 1/30/2023, https://legiscan.com/HI/bill/SB1429/2023, Brenton Awa
# Idaho, S1100, Trans Bathroom Ban, 3/23/2023, https://legiscan.com/ID/bill/S1100/2023, Education Committee
# Idaho, H0071, Gender Affirming Care Ban, 3/24/2023, https://legiscan.com/ID/bill/H0071/2023, Judiciary, Rules and Administration Committee, Ben Adams, Brent Crane, Daniel Foreman, Kevin Andrus, Glenneda Zuiderveld, Jordan Redman, Tammy Nichols, Brandon Mitchell, Jeff Cornilles, Kenny Wroten, Lance Clow, Jaron Crane, Julianne Young, Joe Alfieri, Vito Barbieri, Heather Scott, Jacyn Gallagher, Mike Kingsley, Dale Hawkins, Charlie Shepherd, Elaine Price
# Idaho, S1016, Trans Bathroom Ban, 3/21/2023, https://legiscan.com/ID/bill/S1016/2023, State Affairs Committee
# Idaho, S1003, Trans Bathroom Ban, 1/17/2023, https://legiscan.com/ID/bill/S1003/2023, State Affairs Committee
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/lj/gz81psj55xg1_fm6jfz2vbn80000gn/T/ipykernel_8093/820856968.py in <module>
#      51     for row in values:
#      52         # Print desired columns
# ---> 53         print('%s, %s, %s, %s, %s, %s' % (row[0],row[1],row[3],row[4],row[8],row[9]))
#      54     type(values)
#      55
#
# IndexError: list index out of range

# %%
# Checking type of values and content of first row
type(values)
# Out:
# list

# %%
values[1]
# Out:
# ['Alaska',
#  'HB27',
#  'Designate Sex For School-sponsored Sports',
#  'Trans Sports Ban',
#  '1/19/2023',
#  'REFERRED TO EDUCATION',
#  'Moderate',
#  '',
#  'https://legiscan.com/AK/bill/HB27/2023',
#  'Thomas McKay']

# %%
# Turn values list into a dataframe
import pandas as pd
df = pd.DataFrame(values)

# Turn first row into names of columns
df.columns=df.iloc[0]

# Drop the first row
# df.iloc[row_start:row_end , column_start:column_end]
df = df.iloc[1:, :]

# Check the first few rows
df.head()
# Out:
# 0    State  Number                                           Summary  \
# 1   Alaska    HB27         Designate Sex For School-sponsored Sports
# 2   Alaska    SB96               Sex/reproduction Education; Schools
# 3   Alaska   HB105               Sex/reproduction Education; Schools
# 4  Arizona  SB1028  Adult cabaret performances; prohibited locations
# 5  Arizona  SB1030        Sexually explicit performances; regulation
#
# 0                    Bill Type       Date                  Status  \
# 1             Trans Sports Ban  1/19/2023   REFERRED TO EDUCATION
# 2  Don't Say Gay/Forced Outing   3/8/2023   REFERRED TO JUDICIARY
# 3  Don't Say Gay/Forced Outing   3/8/2023   REFERRED TO EDUCATION
# 4                     Drag Ban  3/22/2023  House read second time
# 5                     Drag Ban  3/21/2023  House read second time
#
# 0 Erin Reed's State Risk                                              Notes  \
# 1               Moderate
# 2               Moderate                                         In schools
# 3               Moderate                                         In schools
# 4                    Low                Bans trans performers from public.
# 5                    Low  Requires permit for sexual explicit business i...
#
# 0                                       URL      Sponsors
# 1    https://legiscan.com/AK/bill/HB27/2023  Thomas McKay
# 2    https://legiscan.com/AK/bill/SB96/2023         Rules
# 3   https://legiscan.com/AK/bill/HB105/2023         Rules
# 4  https://legiscan.com/AZ/bill/SB1028/2023  Anthony Kern
# 5  https://legiscan.com/AZ/bill/SB1030/2023  Anthony Kern

# %%
# Dataframe is the correct length, same as the spreadsheet # of rows
len(df)
# Out:
# 453

# %%
# A function to pickle the dataframe
# Name the file with the year, month, and date.
# Pickle the df so I can check against it for updates in the future.
# Should I save these in a different folder?
# Should I regularly delete these, or just save one previous pickle?

def datePickle(df):
    timestr = time.strftime("%Y%m%d-%H%M%S")
    df.to_pickle(f'{timestr}-df.pickle')
    print("Pickled")
    
# To summon pickle, use:
# df2 = pd.read_pickle('my_df.pickle')

# %% [markdown]
# # Using df as index to get bill info

# %%
import zipfile
import io
import glob
import json
import os
import requests
import mimetypes
import csv
import pandas as pd
import numpy as np

# %% [markdown]
# # U.S. state names : abbreviations dict

# %%
# United States of America Python Dictionary to translate States,
# Districts & Territories to Two-Letter codes and vice versa.
#
# Canonical URL: https://gist.github.com/rogerallen/1583593
#
# Dedicated to the public domain.  To the extent possible under law,
# Roger Allen has waived all copyright and related or neighboring
# rights to this code.  Data originally from Wikipedia at the url:
# https://en.wikipedia.org/wiki/ISO_3166-2:US

us_state_to_abbrev = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "American Samoa": "AS",
    "Guam": "GU",
    "Northern Mariana Islands": "MP",
    "Puerto Rico": "PR",
    "United States Minor Outlying Islands": "UM",
    "U.S. Virgin Islands": "VI",
    "US": "US"
}

def swapStateAbbrev(state):
    state = us_state_to_abbrev.get(state)
    return state

# %%
# test that it's working 
swapStateAbbrev("Wisconsin")
# Out:
# 'WI'

# %% [markdown]
# ## pylegiscan
#
# To talk to LegiScan's API, we're borrowing some code from [pylegiscan](https://github.com/poliquin/pylegiscan). Since it isn't a package you can install with `pip`, it wound up being easier for distribution to just cut and paste it here.

# %%
# Taken from https://github.com/poliquin/pylegiscan/blob/master/pylegiscan/legiscan.py

# import os
# import json
# import requests
from urllib.parse import urlencode
from urllib.parse import quote_plus

# current aggregate status of bill
BILL_STATUS = {1: "Introduced",
               2: "Engrossed",
               3: "Enrolled",
               4: "Passed",
               5: "Vetoed",
               6: "Failed/Dead"}

# significant steps in bill progress.
BILL_PROGRESS = {1: "Introduced",
                 2: "Engrossed",
                 3: "Enrolled",
                 4: "Passed",
                 5: "Vetoed",
                 6: "Failed/Dead",
                 7: "Veto Override",
                 8: "Chapter/Act/Statute",
                 9: "Committee Referral",
                10: "Committee Report Pass",
                11: "Committee Report DNP"}


"""
Interact with LegiScan API.

"""

# a helpful list of valid legiscan state abbreviations (no Puerto Rico)
STATES = ['ak', 'al', 'ar', 'az', 'ca', 'co', 'ct', 'dc', 'de', 'fl', 'ga',
          'hi', 'ia', 'id', 'il', 'in', 'ks', 'ky', 'la', 'ma', 'md', 'me',
          'mi', 'mn', 'mo', 'ms', 'mt', 'nc', 'nd', 'ne', 'nh', 'nj', 'nm',
          'nv', 'ny', 'oh', 'ok', 'or', 'pa', 'ri', 'sc', 'sd', 'tn', 'tx',
          'ut', 'va', 'vt', 'wa', 'wi', 'wv', 'wy']

class LegiScanError(Exception):
    pass

class LegiScan(object):
    BASE_URL = 'http://api.legiscan.com/?key={0}&op={1}&{2}'

    def __init__(self, apikey=None):
        """LegiScan API.  State parameters should always be passed as
           USPS abbreviations.  Bill numbers and abbreviations are case
           insensitive.  Register for API at http://legiscan.com/legiscan
        """
        # see if API key available as environment variable
        if apikey is None:
            apikey = config.LEGISCAN_API_KEY
        self.key = apikey.strip()

    def _url(self, operation, params=None):
        """Build a URL for querying the API."""
        if not isinstance(params, str) and params is not None:
            params = urlencode(params)
        elif params is None:
            params = ''
        return self.BASE_URL.format(self.key, operation, params)

    def _get(self, url):
        """Get and parse JSON from API for a url."""
        req = requests.get(url)
        if not req.ok:
            raise LegiScanError('Request returned {0}: {1}'\
                    .format(req.status_code, url))
        data = json.loads(req.content)
        if data['status'] == "ERROR":
            raise LegiScanError(data['alert']['message'])
        return data

    def get_session_list(self, state):
        """Get list of available sessions for a state."""
        url = self._url('getSessionList', {'state': state})
        data = self._get(url)
        return data['sessions']

    def get_dataset_list(self, state=None, year=None):
        """Get list of available datasets, with optional state and year filtering.
        """
        if state is not None:
            url = self._url('getDatasetList', {'state': state})
        elif year is not None:
            url = self._url('getDatasetList', {'year': year})
        else:
            url = self._url('getDatasetList')
        data = self._get(url)
        # return a list of the bills
        return data['datasetlist']

    def get_dataset(self, id, access_key):
        """Get list of available datasets, with optional state and year filtering.
        """
        url = self._url('getDataset', {'id': id, 'access_key': access_key})
        data = self._get(url)
        # return a list of the bills
        return data['dataset']
      
    def get_master_list(self, state=None, session_id=None):
        """Get list of bills for the current session in a state or for
           a given session identifier.
        """
        if state is not None:
            url = self._url('getMasterList', {'state': state})
        elif session_id is not None:
            url = self._url('getMasterList', {'id': session_id})
        else:
            raise ValueError('Must specify session identifier or state.')
        data = self._get(url)
        # return a list of the bills
        return [data['masterlist'][i] for i in data['masterlist']]

    def get_bill(self, bill_id=None, state=None, bill_number=None):
        """Get primary bill detail information including sponsors, committee
           references, full history, bill text, and roll call information.

           This function expects either a bill identifier or a state and bill
           number combination.  The bill identifier is preferred, and required
           for fetching bills from prior sessions.
        """
        if bill_id is not None:
            url = self._url('getBill', {'id': bill_id})
        elif state is not None and bill_number is not None:
            url = self._url('getBill', {'state': state, 'bill': bill_number})
        else:
            raise ValueError('Must specify bill_id or state and bill_number.')
        return self._get(url)['bill']

    def get_bill_text(self, doc_id):
        """Get bill text, including date, draft revision information, and
           MIME type.  Bill text is base64 encoded to allow for PDF and Word
           data transfers.
        """
        url = self._url('getBillText', {'id': doc_id})
        return self._get(url)['text']

    def get_amendment(self, amendment_id):
        """Get amendment text including date, adoption status, MIME type, and
           title/description information.  The amendment text is base64 encoded
           to allow for PDF and Word data transfer.
        """
        url = self._url('getAmendment', {'id': amendment_id})
        return self._get(url)['amendment']

    def get_supplement(self, supplement_id):
        """Get supplement text including type of supplement, date, MIME type
           and text/description information.  Supplement text is base64 encoded
           to allow for PDF and Word data transfer.
        """
        url = self._url('getSupplement', {'id': supplement_id})
        return self._get(url)['supplement']

    def get_roll_call(self, roll_call_id):
        """Roll call detail for individual votes and summary information."""
        data = self._get(self._url('getRollcall', {'id': roll_call_id}))
        return data['roll_call']

    def get_sponsor(self, people_id):
        """Sponsor information including name, role, and a followthemoney.org
           person identifier.
        """
        url = self._url('getSponsor', {'id': people_id})
        return self._get(url)['person']

    def search(self, state, bill_number=None, query=None, year=2, page=1):
        """Get a page of results for a search against the LegiScan full text
           engine; returns a paginated result set.

           Specify a bill number or a query string.  Year can be an exact year
           or a number between 1 and 4, inclusive.  These integers have the
           following meanings:
               1 = all years
               2 = current year, the default
               3 = recent years
               4 = prior years
           Page is the result set page number to return.
        """
        if bill_number is not None:
            params = {'state': state, 'bill': bill_number}
        elif query is not None:
            params = {'state': state, 'query': query,
                      'year': year, 'page': page}
        else:
            raise ValueError('Must specify bill_number or query')
        data = self._get(self._url('search', params))['searchresult']
        # return a summary of the search and the results as a dictionary
        summary = data.pop('summary')
        results = {'summary': summary, 'results': [data[i] for i in data]}
        return results

    def __str__(self):
        return '<LegiScan API {0}>'.format(self.key)

    def __repr__(self):
        return str(self)

# %% [markdown]
# # Connect to LegiScan
#
# Using pylegiscan, pass your API key to `LegiScan` through an environment variable.

# %%
import config

api_key = config.LEGISCAN_API_KEY
legis = LegiScan(api_key)

# %%
# Add 'Abbreviation' column and fill with State data
df['Abbreviation'] = df.loc[:,'State']
# Check if it worked
df.head()
# Out:
# 0    State  Number                                           Summary  \
# 1   Alaska    HB27         Designate Sex For School-sponsored Sports
# 2   Alaska    SB96               Sex/reproduction Education; Schools
# 3   Alaska   HB105               Sex/reproduction Education; Schools
# 4  Arizona  SB1028  Adult cabaret performances; prohibited locations
# 5  Arizona  SB1030        Sexually explicit performances; regulation
#
# 0                    Bill Type       Date                  Status  \
# 1             Trans Sports Ban  1/19/2023   REFERRED TO EDUCATION
# 2  Don't Say Gay/Forced Outing   3/8/2023   REFERRED TO JUDICIARY
# 3  Don't Say Gay/Forced Outing   3/8/2023   REFERRED TO EDUCATION
# 4                     Drag Ban  3/22/2023  House read second time
# 5                     Drag Ban  3/21/2023  House read second time
#
# 0 Erin Reed's State Risk                                              Notes  \
# 1               Moderate
# 2               Moderate                                         In schools
# 3               Moderate                                         In schools
# 4                    Low                Bans trans performers from public.
# 5                    Low  Requires permit for sexual explicit business i...
#
# 0                                       URL      Sponsors Abbreviation
# 1    https://legiscan.com/AK/bill/HB27/2023  Thomas McKay       Alaska
# 2    https://legiscan.com/AK/bill/SB96/2023         Rules       Alaska
# 3   https://legiscan.com/AK/bill/HB105/2023         Rules       Alaska
# 4  https://legiscan.com/AZ/bill/SB1028/2023  Anthony Kern      Arizona
# 5  https://legiscan.com/AZ/bill/SB1030/2023  Anthony Kern      Arizona

# %%
# Reorder columns and check if it worked
df = df.reindex(columns=['State','Abbreviation', 'Number', 'Summary', 'Bill Type', 'Date', 'Status', 'Erin Reed\'s State Risk', 'URL', 'Sponsors'])
df.head()
# Out:
# 0    State Abbreviation  Number  \
# 1   Alaska       Alaska    HB27
# 2   Alaska       Alaska    SB96
# 3   Alaska       Alaska   HB105
# 4  Arizona      Arizona  SB1028
# 5  Arizona      Arizona  SB1030
#
# 0                                           Summary  \
# 1         Designate Sex For School-sponsored Sports
# 2               Sex/reproduction Education; Schools
# 3               Sex/reproduction Education; Schools
# 4  Adult cabaret performances; prohibited locations
# 5        Sexually explicit performances; regulation
#
# 0                    Bill Type       Date                  Status  \
# 1             Trans Sports Ban  1/19/2023   REFERRED TO EDUCATION
# 2  Don't Say Gay/Forced Outing   3/8/2023   REFERRED TO JUDICIARY
# 3  Don't Say Gay/Forced Outing   3/8/2023   REFERRED TO EDUCATION
# 4                     Drag Ban  3/22/2023  House read second time
# 5                     Drag Ban  3/21/2023  House read second time
#
# 0 Erin Reed's State Risk                                       URL  \
# 1               Moderate    https://legiscan.com/AK/bill/HB27/2023
# 2               Moderate    https://legiscan.com/AK/bill/SB96/2023
# 3               Moderate   https://legiscan.com/AK/bill/HB105/2023
# 4                    Low  https://legiscan.com/AZ/bill/SB1028/2023
# 5                    Low  https://legiscan.com/AZ/bill/SB1030/2023
#
# 0      Sponsors
# 1  Thomas McKay
# 2         Rules
# 3         Rules
# 4  Anthony Kern
# 5  Anthony Kern

# %%
# Use the swapStateAbbrev function to get all the abbreviations for the states, so we can use this to access bill info
df['Abbreviation'] = df['Abbreviation'].apply(swapStateAbbrev)

# %%
df.head()
# Out:
# 0    State Abbreviation  Number  \
# 1   Alaska           AK    HB27
# 2   Alaska           AK    SB96
# 3   Alaska           AK   HB105
# 4  Arizona           AZ  SB1028
# 5  Arizona           AZ  SB1030
#
# 0                                           Summary  \
# 1         Designate Sex For School-sponsored Sports
# 2               Sex/reproduction Education; Schools
# 3               Sex/reproduction Education; Schools
# 4  Adult cabaret performances; prohibited locations
# 5        Sexually explicit performances; regulation
#
# 0                    Bill Type       Date                  Status  \
# 1             Trans Sports Ban  1/19/2023   REFERRED TO EDUCATION
# 2  Don't Say Gay/Forced Outing   3/8/2023   REFERRED TO JUDICIARY
# 3  Don't Say Gay/Forced Outing   3/8/2023   REFERRED TO EDUCATION
# 4                     Drag Ban  3/22/2023  House read second time
# 5                     Drag Ban  3/21/2023  House read second time
#
# 0 Erin Reed's State Risk                                       URL  \
# 1               Moderate    https://legiscan.com/AK/bill/HB27/2023
# 2               Moderate    https://legiscan.com/AK/bill/SB96/2023
# 3               Moderate   https://legiscan.com/AK/bill/HB105/2023
# 4                    Low  https://legiscan.com/AZ/bill/SB1028/2023
# 5                    Low  https://legiscan.com/AZ/bill/SB1030/2023
#
# 0      Sponsors
# 1  Thomas McKay
# 2         Rules
# 3         Rules
# 4  Anthony Kern
# 5  Anthony Kern

# %%
datePickle(df)
# Out:
# Pickled

# %%
df['Bill Title'] = ''
df.head()
# Out:
# 0    State Abbreviation  Number  \
# 1   Alaska           AK    HB27
# 2   Alaska           AK    SB96
# 3   Alaska           AK   HB105
# 4  Arizona           AZ  SB1028
# 5  Arizona           AZ  SB1030
#
# 0                                           Summary  \
# 1         Designate Sex For School-sponsored Sports
# 2               Sex/reproduction Education; Schools
# 3               Sex/reproduction Education; Schools
# 4  Adult cabaret performances; prohibited locations
# 5        Sexually explicit performances; regulation
#
# 0                    Bill Type       Date                  Status  \
# 1             Trans Sports Ban  1/19/2023   REFERRED TO EDUCATION
# 2  Don't Say Gay/Forced Outing   3/8/2023   REFERRED TO JUDICIARY
# 3  Don't Say Gay/Forced Outing   3/8/2023   REFERRED TO EDUCATION
# 4                     Drag Ban  3/22/2023  House read second time
# 5                     Drag Ban  3/21/2023  House read second time
#
# 0 Erin Reed's State Risk                                       URL  \
# 1               Moderate    https://legiscan.com/AK/bill/HB27/2023
# 2               Moderate    https://legiscan.com/AK/bill/SB96/2023
# 3               Moderate   https://legiscan.com/AK/bill/HB105/2023
# 4                    Low  https://legiscan.com/AZ/bill/SB1028/2023
# 5                    Low  https://legiscan.com/AZ/bill/SB1030/2023
#
# 0      Sponsors Bill ID Bill Text
# 1  Thomas McKay
# 2         Rules
# 3         Rules
# 4  Anthony Kern
# 5  Anthony Kern

# %% [markdown]
# ---
# # Get the bill IDs from state data
# 1. Look at the state abbreviation
# 2. Open and load the corresponding filepath to the JSON
# 3. Find the bill ID
# 4. Add it in this df

# %% [markdown]
# ## Get bill ID for one bill (skip all this stuff when you rerun. It's for building the code.)

# %%
# Look at the first row of the df and the Abbreviation and Number columns
# Print to check 

stateAbbrev = df.iloc[0]['Abbreviation']
billNum = df.iloc[0]['Number']

# %%
stateAbbrev
# Out:
# 'AK'

# %%
billNum
# Out:
# 'HB27'

# %%
# Download the master list for this.
# Get list of bills for the current session in a state.
# I should just make a set from the Abbreviation column and get all the lists.
# But let's just do one for now.
masterlist = legis.get_master_list(stateAbbrev)

# %%
# Check

masterlist
# Out:
# [{'session_id': 2015,
#   'state_id': 2,
#   'year_start': 2023,
#   'year_end': 2024,
#   'prefile': 0,
#   'sine_die': 0,
#   'prior': 0,
#   'special': 0,
#   'session_tag': 'Regular Session',
#   'session_title': '2023-2024 Regular Session',
#   'session_name': '33rd Legislature'},
#  {'bill_id': 1648141,
#   'number': 'HB1',
#   'change_hash': '48895fc89bb2f936b7a0c5e001155fca',
#   'url': 'https://legiscan.com/AK/bill/HB1/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-02-22',
#   'last_action': 'COSPONSOR(S): PRAX',
#   'title': 'Repeal Ballot Measure 2 Voting Chgs',
#   'description': 'An Act relating to elections.'},
#  {'bill_id': 1646412,
#   'number': 'HB2',
#   'change_hash': 'c3e95526966a37e6ee3919b993a1fb69',
#   'url': 'https://legiscan.com/AK/bill/HB2/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-03-17',
#   'last_action': 'REFERRED TO RULES',
#   'title': 'Contracts: Prohibit Israel Discrimination',
#   'description': 'An Act relating to contracts with public agencies; and relating to the State of Israel.'},
#  {'bill_id': 1647362,
#   'number': 'HB3',
#   'change_hash': 'dd3720ef8adf2f4d330cba3114aceefc',
#   'url': 'https://legiscan.com/AK/bill/HB3/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-02-22',
#   'last_action': 'REFERRED TO FINANCE',
#   'title': 'Gold And Silver Specie As Legal Tender',
#   'description': 'An Act relating to specie as legal tender in the state; and relating to borough and city sales and use taxes on specie.'},
#  {'bill_id': 1646807,
#   'number': 'HB4',
#   'change_hash': '8ac4ce76d74b76518edd2be9b10a55ba',
#   'url': 'https://legiscan.com/AK/bill/HB4/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-01-27',
#   'last_action': 'COSPONSOR(S): MCCABE',
#   'title': 'Elections:repeal Rank Choice/open Primary',
#   'description': 'An Act relating to elections.'},
#  {'bill_id': 1646331,
#   'number': 'HB5',
#   'change_hash': 'c04b246c2286cf35ea7f03530fdb4cef',
#   'url': 'https://legiscan.com/AK/bill/HB5/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-01-19',
#   'last_action': 'REFERRED TO COMMUNITY & REGIONAL AFFAIRS',
#   'title': 'Hold Legislative Sessions In Anchorage',
#   'description': 'An Act relating to convening the legislature in Anchorage; relating to the regulation of lobbying; relating to annual student guests of the legislature; relating to locations of sessions of the legislature; relating to the Legislative Ethics Act; relating to the relocation of functions of state government; and providing for an effective date.'},
#  {'bill_id': 1646918,
#   'number': 'HB6',
#   'change_hash': 'e5d4be2d13c820f110549839ccf8032b',
#   'url': 'https://legiscan.com/AK/bill/HB6/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-03-01',
#   'last_action': 'COSPONSOR(S): STORY',
#   'title': 'Public Schools; Opioid Awareness Program',
#   'description': 'An Act relating to the duties of the Department of Education and Early Development; relating to public education; relating to opioid abuse awareness and prevention; and providing for an effective date.'},
#  {'bill_id': 1647753,
#   'number': 'HB7',
#   'change_hash': '4bddbdff86ee3359b59e20b546543bc2',
#   'url': 'https://legiscan.com/AK/bill/HB7/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-01-19',
#   'last_action': 'REFERRED TO STATE AFFAIRS',
#   'title': 'Office Of Administrative Hearings',
#   'description': 'An Act relating to the office of administrative hearings; relating to the types of proceedings handled by the office of administrative hearings; relating to the entities that may use the services of the office of administrative hearings; relating to the duties of the chief administrative law judge, including the power to hire professional staff; relating to the qualifications and powers of administrative law judges, including subpoena power; relating to the compensation of the chief administrative law judge; relating to complaints against administrative law judges and hearing officers; relating to reimbursement for costs incurred by the office of administrative hearings; relating to procedures for requesting and conducting proceedings of the office of administrative hearings; and providing for an effective date.'},
#  {'bill_id': 1646529,
#   'number': 'HB8',
#   'change_hash': '4991b089364059fa599c4e074245fc43',
#   'url': 'https://legiscan.com/AK/bill/HB8/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-03-24',
#   'last_action': 'COSPONSOR(S): GALVIN',
#   'title': 'Electric-assisted Bicycles',
#   'description': 'An Act relating to electric-assisted bicycles.'},
#  {'bill_id': 1648088,
#   'number': 'HB9',
#   'change_hash': '1e6e6488bf7167e8edc5d5a877a03a05',
#   'url': 'https://legiscan.com/AK/bill/HB9/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-03-22',
#   'last_action': 'REFERRED TO JUDICIARY',
#   'title': 'Add Faculty Member Univ Board Of Regents',
#   'description': 'An Act relating to the Board of Regents of the University of Alaska.'},
#  {'bill_id': 1647195,
#   'number': 'HB10',
#   'change_hash': 'df471d121cee3aa3263f12666784d606',
#   'url': 'https://legiscan.com/AK/bill/HB10/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-03-01',
#   'last_action': 'COSPONSOR(S): MINA',
#   'title': 'University: Textbooks/materials Cost',
#   'description': 'An Act relating to costs of and charges for textbooks and other course materials required for University of Alaska courses; and providing for an effective date.'},
#  {'bill_id': 1648308,
#   'number': 'HB11',
#   'change_hash': '0bcb01f4c87cfafff1b084b217ad82bc',
#   'url': 'https://legiscan.com/AK/bill/HB11/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-01-25',
#   'last_action': 'REFERRED TO JUDICIARY',
#   'title': 'Crime: Assault In The Presence Of A Child',
#   'description': 'An Act establishing the crime of assault in the presence of a child.'},
#  {'bill_id': 1647696,
#   'number': 'HB12',
#   'change_hash': '488d53486afcce81693ce363c90151ae',
#   'url': 'https://legiscan.com/AK/bill/HB12/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-01-19',
#   'last_action': 'REFERRED TO COMMUNITY & REGIONAL AFFAIRS',
#   'title': 'Municipal Regulation Of Trapping',
#   'description': 'An Act relating to municipal regulation of trapping; and providing for an effective date.'},
#  {'bill_id': 1648808,
#   'number': 'HB13',
#   'change_hash': '42f5a9cd73d251906c220c3cbb2c30ea',
#   'url': 'https://legiscan.com/AK/bill/HB13/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-02-13',
#   'last_action': 'REFERRED TO JUDICIARY',
#   'title': 'Applicability Of Human Rights Commission',
#   'description': 'An Act relating to the definition of &#39;employer&#39; for the purposes of the State Commission for Human Rights.'},
#  {'bill_id': 1647031,
#   'number': 'HB14',
#   'change_hash': 'ea74279e904702b209750316c19ae4ef',
#   'url': 'https://legiscan.com/AK/bill/HB14/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-02-13',
#   'last_action': 'COSPONSOR(S): ARMSTRONG',
#   'title': 'Aggravating Factors At Sentencing',
#   'description': 'An Act relating to aggravating factors considered at sentencing.'},
#  {'bill_id': 1646451,
#   'number': 'HB15',
#   'change_hash': '453fd23de95a99a57693a95f091b2392',
#   'url': 'https://legiscan.com/AK/bill/HB15/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-03-15',
#   'last_action': 'COSPONSOR(S): FIELDS',
#   'title': 'Peer Support Counseling Program',
#   'description': 'An Act relating to peer support counseling programs for law enforcement agencies, emergency service providers, and the Department of Corrections.'},
#  {'bill_id': 1646550,
#   'number': 'HB16',
#   'change_hash': '59cb134b44684ca3a165cd144f19d5e0',
#   'url': 'https://legiscan.com/AK/bill/HB16/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-03-08',
#   'last_action': 'REFERRED TO HEALTH & SOCIAL SERVICES',
#   'title': 'Medicaid Optional Svcs & Cost Containment',
#   'description': 'An Act requiring the state medical assistance program to provide certain services; relating to cost containment measures for the state medical assistance program; relating to payment for adult dental services; and providing for an effective date.'},
#  {'bill_id': 1646403,
#   'number': 'HB17',
#   'change_hash': '907be01ee7b3674c3f5b9915bd2e4ea2',
#   'url': 'https://legiscan.com/AK/bill/HB17/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-03-24',
#   'last_action': 'COSPONSOR(S): GALVIN',
#   'title': 'Contraceptives Coverage:insure;med Assist',
#   'description': 'An Act relating to insurance coverage for contraceptives and related services; relating to medical assistance coverage for contraceptives and related services; and providing for an effective date.'},
#  {'bill_id': 1646394,
#   'number': 'HB18',
#   'change_hash': '9ccc77d731327e7c5f49e41a25f0ff97',
#   'url': 'https://legiscan.com/AK/bill/HB18/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-02-13',
#   'last_action': 'COSPONSOR(S): ARMSTRONG',
#   'title': 'Fishery Development Assoc.; Assessments',
#   'description': 'An Act relating to regional fishery development associations; and relating to developing fishery management assessments.'},
#  {'bill_id': 1646642,
#   'number': 'HB19',
#   'change_hash': '677f6e50ee4b9a0f7b184cd7165b39f0',
#   'url': 'https://legiscan.com/AK/bill/HB19/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-02-06',
#   'last_action': 'COSPONSOR(S): SCHRAGE',
#   'title': 'Registration Of Boats: Exemption',
#   'description': 'An Act relating to the registration of commercial vessels; and providing for an effective date.'},
#  {'bill_id': 1646749,
#   'number': 'HB20',
#   'change_hash': '3d00b2ad05af466374c90e38cac449b9',
#   'url': 'https://legiscan.com/AK/bill/HB20/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-01-30',
#   'last_action': 'COSPONSOR(S): HIMSCHOOT',
#   'title': 'Conflict Of Interest: Bd Fisheries/game',
#   'description': 'An Act relating to participation in matters before the Board of Fisheries and the Board of Game by the members of the respective boards; and providing for an effective date.'},
#  {'bill_id': 1646478,
#   'number': 'HB21',
#   'change_hash': '76c6298ee4deaf0fcea4a8d3ce7f72f8',
#   'url': 'https://legiscan.com/AK/bill/HB21/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-01-27',
#   'last_action': 'REFERRED TO EDUCATION',
#   'title': 'School/university Employee Health Insur',
#   'description': 'An Act relating to group insurance coverage and self-insurance coverage for school district employees, employees of the University of Alaska, and employees of other governmental units in the state; and providing for an effective date.'},
#  {'bill_id': 1647920,
#   'number': 'HB22',
#   'change_hash': 'c86b11af0cb19b87b53e322f2c7bce55',
#   'url': 'https://legiscan.com/AK/bill/HB22/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-03-01',
#   'last_action': 'COSPONSOR(S): GROH',
#   'title': 'Peace Officer/firefighter Retire Benefits',
#   'description': 'An Act relating to participation of certain peace officers and firefighters in the defined benefit and defined contribution plans of the Public Employees&#39; Retirement System of Alaska; relating to eligibility of peace officers and firefighters for medical, disability, and death benefits; relating to liability of the Public Employees&#39; Retirement System of Alaska; and providing for an effective date.'},
#  {'bill_id': 1646501,
#   'number': 'HB23',
#   'change_hash': 'e062f5de839228ae441cf6c1eea45341',
#   'url': 'https://legiscan.com/AK/bill/HB23/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-03-17',
#   'last_action': 'ARMSTRONG, GRAY, GALVIN',
#   'title': 'Filipino American History Month',
#   'description': 'An Act establishing the month of October as Filipino American History Month.'},
#  {'bill_id': 1647806,
#   'number': 'HB24',
#   'change_hash': '70a4789a4772604677de9989ae0be87b',
#   'url': 'https://legiscan.com/AK/bill/HB24/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-01-27',
#   'last_action': 'COSPONSOR(S): MCCABE',
#   'title': 'Gov Appoint Board Of Governors Of Ak Bar',
#   'description': 'An Act relating to the membership of the Board of Governors of the Alaska Bar.'},
#  {'bill_id': 1647083,
#   'number': 'HB25',
#   'change_hash': 'a400913d885e27a43f57e6934d9a0d53',
#   'url': 'https://legiscan.com/AK/bill/HB25/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-03-24',
#   'last_action': 'COSPONSOR(S): FIELDS',
#   'title': 'Pfd Eligibility Uniformed Services',
#   'description': 'An Act relating to eligibility for the permanent fund dividend; and providing for an effective date.'},
#  {'bill_id': 1648199,
#   'number': 'HB26',
#   'change_hash': 'c10a7851daddf4fd784b0634ce03f348',
#   'url': 'https://legiscan.com/AK/bill/HB26/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-03-22',
#   'last_action': 'REFERRED TO FINANCE',
#   'title': 'Council For Alaska Native Languages',
#   'description': 'An Act renaming the Alaska Native Language Preservation and Advisory Council as the Council for Alaska Native Languages; and relating to the Council for Alaska Native Languages.'},
#  {'bill_id': 1646385,
#   'number': 'HB27',
#   'change_hash': 'd3f1f1326343d7e96d129e70fc3ba09c',
#   'url': 'https://legiscan.com/AK/bill/HB27/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-01-19',
#   'last_action': 'REFERRED TO EDUCATION',
#   'title': 'Designate Sex For School-sponsored Sports',
#   'description': 'An Act relating to school athletics, recreation, athletic teams, and sports.'},
#  {'bill_id': 1648700,
#   'number': 'HB28',
#   'change_hash': 'c62a62e349398d0ed650e297b3f8695f',
#   'url': 'https://legiscan.com/AK/bill/HB28/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-03-24',
#   'last_action': 'COSPONSOR(S): HANNAN',
#   'title': 'Access To Marijuana Conviction Records',
#   'description': 'An Act restricting the release of certain records of convictions; and providing for an effective date.'},
#  {'bill_id': 1646337,
#   'number': 'HB29',
#   'change_hash': '0d6db0f50b8390f8f48ef32741e182c0',
#   'url': 'https://legiscan.com/AK/bill/HB29/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-03-08',
#   'last_action': 'REFERRED TO JUDICIARY',
#   'title': 'Insurance Discrimination',
#   'description': 'An Act relating to insurance discrimination.'},
#  {'bill_id': 1647251,
#   'number': 'HB30',
#   'change_hash': '0391d19f9ff207c386455b4019e36d69',
#   'url': 'https://legiscan.com/AK/bill/HB30/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-01-19',
#   'last_action': 'REFERRED TO COMMUNITY & REGIONAL AFFAIRS',
#   'title': 'Observe Daylight Saving Time All Year',
#   'description': 'An Act relating to daylight saving time; and providing for an effective date.'},
#  {'bill_id': 1647476,
#   'number': 'HB31',
#   'change_hash': 'ff620b689815a0364717e0e7c6fda5ce',
#   'url': 'https://legiscan.com/AK/bill/HB31/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-02-07',
#   'last_action': 'COSPONSOR(S): FIELDS',
#   'title': 'Ak Performance Scholarship; Eligibility',
#   'description': 'An Act relating to the Alaska performance scholarship program.'},
#  {'bill_id': 1648588,
#   'number': 'HB32',
#   'change_hash': '47a6c31116aab659d3b8f287c81cd610',
#   'url': 'https://legiscan.com/AK/bill/HB32/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-01-27',
#   'last_action': 'COSPONSOR(S): MCCABE',
#   'title': 'Oil & Gas Working Group',
#   'description': 'An Act relating to appeals of administrative decisions related to oil or gas; establishing an oil and gas production working group; and providing for an effective date.'},
#  {'bill_id': 1647530,
#   'number': 'HB33',
#   'change_hash': 'c5e762a542eb43951db49faa2aed2ede',
#   'url': 'https://legiscan.com/AK/bill/HB33/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-01-19',
#   'last_action': 'REFERRED TO RESOURCES',
#   'title': 'Oil Spills/pollution:penalties;prevention',
#   'description': 'An Act relating to penalties for discharges of oil and other pollution violations; and providing for an effective date.'},
#  {'bill_id': 1658883,
#   'number': 'HB34',
#   'change_hash': 'ba8b097f2327597a7cb8dfb9a960e233',
#   'url': 'https://legiscan.com/AK/bill/HB34/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-01-19',
#   'last_action': 'REFERRED TO STATE AFFAIRS',
#   'title': 'Confirmation/qualifications Of Judges',
#   'description': 'An Act relating to the selection and retention of court of appeals and district court judges and magistrates; relating to the qualifications of supreme court justices, superior court judges, district court judges, and magistrates; relating to the duties of the judicial council; relating to the duties of the Commission on Judicial Conduct; and repealing Rule 19.1, Alaska Rules of Administration.'},
#  {'bill_id': 1658523,
#   'number': 'HB35',
#   'change_hash': '5a321a31bc74818217d2f4ee88da688b',
#   'url': 'https://legiscan.com/AK/bill/HB35/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-02-10',
#   'last_action': 'REFERRED TO LABOR & COMMERCE',
#   'title': 'Repeal Certificate Of Need Program',
#   'description': 'An Act relating to the certificate of need program for health care facilities; and providing for an effective date.'},
#  {'bill_id': 1658484,
#   'number': 'HB36',
#   'change_hash': 'ca38e6f33897e9ddb26ccd518b508184',
#   'url': 'https://legiscan.com/AK/bill/HB36/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-02-15',
#   'last_action': 'COSPONSOR(S): HIMSCHOOT',
#   'title': 'Apoc; Referenda/recall; Contributions',
#   'description': 'An Act requiring the disclosure of the identity of certain persons, groups, and nongroup entities that expend money in support of or in opposition to an application filed for a state referendum or recall election; relating to political contributions; and providing for an effective date.'},
#  {'bill_id': 1658921,
#   'number': 'HB37',
#   'change_hash': '4caa1e32592a8cca1c36f8033b67c0d9',
#   'url': 'https://legiscan.com/AK/bill/HB37/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-02-24',
#   'last_action': 'COSPONSOR(S): GALVIN',
#   'title': 'Elections, Voting, Ballots',
#   'description': 'An Act relating to elections; relating to voters; relating to the crime of unlawful interference with voting; and providing for an effective date.'},
#  {'bill_id': 1670856,
#   'number': 'HB38',
#   'change_hash': '6fcfeaa7b5f4bcb0913bce636d63d7e4',
#   'url': 'https://legiscan.com/AK/bill/HB38/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-03-08',
#   'last_action': 'COSPONSOR(S): SUMNER',
#   'title': 'Appropriation Limit; Gov Budget',
#   'description': 'An Act relating to an appropriation limit; relating to the budget responsibilities of the governor; and providing for an effective date.'},
#  {'bill_id': 1671022,
#   'number': 'HB39',
#   'change_hash': '0f073a744aa8f04e11b5eaf1f0d1886d',
#   'url': 'https://legiscan.com/AK/bill/HB39/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-01-19',
#   'last_action': 'REFERRED TO FINANCE',
#   'title': 'Approp: Operating Budget/loans/fund; Supp',
#   'description': 'An Act making appropriations for the operating and loan program expenses of state government and for certain programs; capitalizing funds; amending appropriations; making reappropriations; making supplemental appropriations; making appropriations under art. IX, sec. 17(c), Constitution of the State of Alaska, from the constitutional budget reserve fund; and providing for an effective date.'},
#  {'bill_id': 1670863,
#   'number': 'HB40',
#   'change_hash': '1e0a2cd88f8e4779a3e7738fa6835874',
#   'url': 'https://legiscan.com/AK/bill/HB40/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-01-19',
#   'last_action': 'REFERRED TO FINANCE',
#   'title': 'Approp: Capital/supplemental',
#   'description': 'An Act making appropriations, including capital appropriations and other appropriations; making supplemental appropriations; making appropriations to capitalize funds; and providing for an effective date.'},
#  {'bill_id': 1671204,
#   'number': 'HB41',
#   'change_hash': '867a1427a1c326a52563e53f507028d2',
#   'url': 'https://legiscan.com/AK/bill/HB41/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-01-19',
#   'last_action': 'REFERRED TO FINANCE',
#   'title': 'Approp: Mental Health Budget',
#   'description': 'An Act making appropriations for the operating and capital expenses of the state&#39;s integrated comprehensive mental health program; and providing for an effective date.'},
#  {'bill_id': 1675631,
#   'number': 'HB42',
#   'change_hash': 'f2b01b582c93e7330a2e4a0531c26011',
#   'url': 'https://legiscan.com/AK/bill/HB42/2023',
#   'status_date': '2023-01-23',
#   'status': 1,
#   'last_action_date': '2023-01-23',
#   'last_action': 'REFERRED TO STATE AFFAIRS',
#   'title': 'Eliminate Unnecessary Agency Publications',
#   'description': 'An Act relating to the elimination or modification of state agency publications that are outdated, duplicative, or excessive.'},
#  {'bill_id': 1675445,
#   'number': 'HB43',
#   'change_hash': 'eae89bea46bd814963e2aca7e1f6e743',
#   'url': 'https://legiscan.com/AK/bill/HB43/2023',
#   'status_date': '2023-01-23',
#   'status': 1,
#   'last_action_date': '2023-03-17',
#   'last_action': 'COSPONSOR(S): FIELDS',
#   'title': 'Conversion Therapy Prohibitions',
#   'description': 'An Act relating to professional and occupational licensing; and relating to treatment to change the sexual orientations or gender identities of children and vulnerable adults.'},
#  {'bill_id': 1675997,
#   'number': 'HB44',
#   'change_hash': '132645a2616a4a6538be84c1d3fde3ec',
#   'url': 'https://legiscan.com/AK/bill/HB44/2023',
#   'status_date': '2023-01-23',
#   'status': 1,
#   'last_action_date': '2023-02-07',
#   'last_action': 'COSPONSOR(S): DIBERT',
#   'title': 'Cultural Education Program',
#   'description': 'An Act relating to education; relating to public schools and school districts; establishing a cultural education program; and providing for an effective date.'},
#  {'bill_id': 1679943,
#   'number': 'HB45',
#   'change_hash': '836c46a55391b7718e640cd19829ef26',
#   'url': 'https://legiscan.com/AK/bill/HB45/2023',
#   'status_date': '2023-01-25',
#   'status': 1,
#   'last_action_date': '2023-03-01',
#   'last_action': 'COSPONSOR(S): CARRICK',
#   'title': 'Pfd Contributions To General Fund And Pf',
#   'description': 'An Act relating to contributions from permanent fund dividends to the general and permanent funds.'},
#  {'bill_id': 1680371,
#   'number': 'HB46',
#   'change_hash': '80a24165959f8da84a318eb367a49697',
#   'url': 'https://legiscan.com/AK/bill/HB46/2023',
#   'status_date': '2023-01-25',
#   'status': 1,
#   'last_action_date': '2023-03-06',
#   'last_action': 'REFERRED TO HEALTH & SOCIAL SERVICES',
#   'title': 'Child Care Provider Collective Bargaining',
#   'description': 'An Act allowing child care providers that receive state aid to organize and collectively bargain with the Department of Health; and establishing the child care provider fund.'},
#  {'bill_id': 1680050,
#   'number': 'HB47',
#   'change_hash': '2443fa87d0fb5a0e5bafff187d0ef998',
#   'url': 'https://legiscan.com/AK/bill/HB47/2023',
#   'status_date': '2023-01-25',
#   'status': 1,
#   'last_action_date': '2023-03-15',
#   'last_action': 'REFERRED TO LABOR & COMMERCE',
#   'title': 'Direct Health Agreement: Not Insurance',
#   'description': 'An Act relating to insurance; relating to direct health care agreements; and relating to unfair trade practices.'},
#  {'bill_id': 1679836,
#   'number': 'HB48',
#   'change_hash': 'dcb58db4ebf4df23ab83d3a8ca7fe159',
#   'url': 'https://legiscan.com/AK/bill/HB48/2023',
#   'status_date': '2023-01-25',
#   'status': 1,
#   'last_action_date': '2023-02-22',
#   'last_action': 'REFERRED TO RULES',
#   'title': 'Human Rights Commission Annual Report',
#   'description': 'An Act relating to reports from the State Commission for Human Rights.'},
#  {'bill_id': 1684529,
#   'number': 'HB49',
#   'change_hash': '6d7e7c2cbf7e02f6f0ebf101f3fe7873',
#   'url': 'https://legiscan.com/AK/bill/HB49/2023',
#   'status_date': '2023-01-27',
#   'status': 1,
#   'last_action_date': '2023-03-20',
#   'last_action': 'REFERRED TO FINANCE',
#   'title': 'Carbon Offset Program On State Land',
#   'description': 'An Act authorizing the Department of Natural Resources to lease land for carbon management purposes; establishing a carbon offset program for state land; authorizing the sale of carbon offset credits; and providing for an effective date.'},
#  {'bill_id': 1684324,
#   'number': 'HB50',
#   'change_hash': 'd17072c4be819ed2d2983f00da4bbc42',
#   'url': 'https://legiscan.com/AK/bill/HB50/2023',
#   'status_date': '2023-01-27',
#   'status': 1,
#   'last_action_date': '2023-03-13',
#   'last_action': 'REFERRED TO FINANCE',
#   'title': 'Carbon Storage',
#   'description': 'An Act relating to the geologic storage of carbon dioxide; and providing for an effective date.'},
#  {'bill_id': 1685632,
#   'number': 'HB51',
#   'change_hash': '56b7643bb60fbb24eccc041034140a5d',
#   'url': 'https://legiscan.com/AK/bill/HB51/2023',
#   'status_date': '2023-03-01',
#   'status': 2,
#   'last_action_date': '2023-03-06',
#   'last_action': 'REFERRED TO LABOR & COMMERCE',
#   'title': 'Use Of Designated Refrigerants',
#   'description': 'An Act relating to refrigerants designated as acceptable for use under federal law.'},
#  {'bill_id': 1685908,
#   'number': 'HB52',
#   'change_hash': '7a1f268ed77f499180efeabea05d8719',
#   'url': 'https://legiscan.com/AK/bill/HB52/2023',
#   'status_date': '2023-01-30',
#   'status': 1,
#   'last_action_date': '2023-02-01',
#   'last_action': 'COSPONSOR(S): CARPENTER',
#   'title': 'No Patient Left Alone Act',
#   'description': 'An Act relating to the right of patients and residents to have a support person in person during treatment and during stays at certain facilities; and relating to a requirement that health care facilities make certain information available to the public.'},
#  {'bill_id': 1690236,
#   'number': 'HB53',
#   'change_hash': 'a28492c2ce4f85e075f3ad7bbafaf9f2',
#   'url': 'https://legiscan.com/AK/bill/HB53/2023',
#   'status_date': '2023-02-01',
#   'status': 1,
#   'last_action_date': '2023-03-17',
#   'last_action': 'COSPONSOR(S): MEARS',
#   'title': 'State Identification Card For Prisoners',
#   'description': 'An Act relating to state identifications and driver&#39;s licenses for persons in the custody of the Department of Corrections; relating to the duties of the commissioner of corrections; and providing for an effective date.'},
#  {'bill_id': 1690329,
#   'number': 'HB54',
#   'change_hash': '750ef922f9ae272995bcf2f87b11f9bb',
#   'url': 'https://legiscan.com/AK/bill/HB54/2023',
#   'status_date': '2023-02-01',
#   'status': 1,
#   'last_action_date': '2023-02-01',
#   'last_action': 'REFERRED TO FINANCE',
#   'title': 'Approp: Supplemental; Reapprop; Amending',
#   'description': 'An Act making supplemental appropriations, reappropriations, and other appropriations; amending appropriations; capitalizing funds; and providing for an effective date.'},
#  {'bill_id': 1689867,
#   'number': 'HB55',
#   'change_hash': 'db627b19d3e89a0c8af55ebdae108773',
#   'url': 'https://legiscan.com/AK/bill/HB55/2023',
#   'status_date': '2023-02-01',
#   'status': 1,
#   'last_action_date': '2023-02-01',
#   'last_action': 'REFERRED TO EDUCATION',
#   'title': 'Extend Workforce Invest Board Allocations',
#   'description': 'An Act relating to allocations of funding for the Alaska Workforce Investment Board; and providing for an effective date.'},
#  {'bill_id': 1694896,
#   'number': 'HB56',
#   'change_hash': '8a834de82beababa7f26c7aea1437ffb',
#   'url': 'https://legiscan.com/AK/bill/HB56/2023',
#   'status_date': '2023-02-03',
#   'status': 1,
#   'last_action_date': '2023-03-24',
#   'last_action': 'COSPONSOR(S): ARMSTRONG',
#   'title': 'Controlled Sub. Data: Exempt Animal Rx',
#   'description': 'An Act exempting controlled substances prescribed or dispensed by a veterinarian to treat an animal from the requirements of the controlled substance prescription database.'},
#  {'bill_id': 1695329,
#   'number': 'HB57',
#   'change_hash': '82818d3892e3fefedea0fc02cdcc4f0c',
#   'url': 'https://legiscan.com/AK/bill/HB57/2023',
#   'status_date': '2023-02-03',
#   'status': 1,
#   'last_action_date': '2023-03-06',
#   'last_action': 'REFERRED TO HEALTH & SOCIAL SERVICES',
#   'title': 'Emergency Med. Svcs: Review Organizations',
#   'description': 'An Act relating to review organizations and permitting an emergency medical services provider to establish a review organization; and relating to patient records.'},
#  {'bill_id': 1695184,
#   'number': 'HB58',
#   'change_hash': '50957317649723e10a1473299ff16eae',
#   'url': 'https://legiscan.com/AK/bill/HB58/2023',
#   'status_date': '2023-02-03',
#   'status': 1,
#   'last_action_date': '2023-03-17',
#   'last_action': 'REFERRED TO FINANCE',
#   'title': 'Adult Home Care; Med Assistance',
#   'description': 'An Act relating to medical assistance for recipients of Medicaid waivers; establishing an adult care home license and procedures; providing for the transition of individuals from foster care to adult home care settings; and providing for an effective date.'},
#  {'bill_id': 1695044,
#   'number': 'HB59',
#   'change_hash': 'fc006366953188b81d9972145f8faffa',
#   'url': 'https://legiscan.com/AK/bill/HB59/2023',
#   'status_date': '2023-02-03',
#   'status': 1,
#   'last_action_date': '2023-03-08',
#   'last_action': 'REFERRED TO FINANCE',
#   'title': 'Medicaid Eligibility: Postpartum Mothers',
#   'description': 'An Act relating to Medicaid eligibility; expanding eligibility for postpartum mothers; conditioning the expansion of eligibility on approval by the United States Department of Health and Human Services; and providing for an effective date.'},
#  {'bill_id': 1695468,
#   'number': 'HB60',
#   'change_hash': '3e071891fa69741f3ff7f746c713ebb8',
#   'url': 'https://legiscan.com/AK/bill/HB60/2023',
#   'status_date': '2023-02-03',
#   'status': 1,
#   'last_action_date': '2023-02-03',
#   'last_action': 'REFERRED TO HEALTH & SOCIAL SERVICES',
#   'title': 'Runaways; Dfcs/doh: Duties/licensing/info',
#   'description': 'An Act relating to the licensing of runaway shelters; relating to advisors to the board of trustees of the Alaska Mental Health Trust Authority; relating to the sharing of confidential health information between the Department of Health and the Department of Family and Community Services; relating to the duties of the Department of Health and the Department of Family and Community Services; and providing for an effective date.'},
#  {'bill_id': 1696032,
#   'number': 'HB61',
#   'change_hash': '82884899e1df0d5d5db3fbc6a7304391',
#   'url': 'https://legiscan.com/AK/bill/HB61/2023',
#   'status_date': '2023-02-06',
#   'status': 1,
#   'last_action_date': '2023-03-22',
#   'last_action': 'COSPONSOR(S): SHAW, TOMASZEWSKI',
#   'title': 'Limitations On Firearms Restrictions',
#   'description': 'An Act relating to restrictions on firearms and other weapons.'},
#  {'bill_id': 1696087,
#   'number': 'HB62',
#   'change_hash': '6bfae0afa83e1a2fecb3720f8c2ce2fa',
#   'url': 'https://legiscan.com/AK/bill/HB62/2023',
#   'status_date': '2023-03-20',
#   'status': 2,
#   'last_action_date': '2023-03-22',
#   'last_action': 'CLAMAN',
#   'title': 'Renewable Energy Grant Fund',
#   'description': 'An Act relating to the renewable energy grant fund and recommendation program; and providing for an effective date.'},
#  {'bill_id': 1696144,
#   'number': 'HB63',
#   'change_hash': '8355808ed5d6ab5b4143fe1b892267e4',
#   'url': 'https://legiscan.com/AK/bill/HB63/2023',
#   'status_date': '2023-02-06',
#   'status': 1,
#   'last_action_date': '2023-03-20',
#   'last_action': 'FIN REFERRAL ADDED AFTER JUD',
#   'title': "Repeal Workers' Comp Appeals Commission",
#   'description': 'An Act repealing the Workers&#39; Compensation Appeals Commission; relating to decisions and orders of the Workers&#39; Compensation Appeals Commission; relating to superior court jurisdiction over appeals from Alaska Workers&#39; Compensation Board decisions; repealing Rules 201.1, 401.1, and 501.1, Alaska Rules of Appellate Procedure, and amending Rules 202(a), 204(a) - (c), 210(e), 601(b), 602(c) and (h), and 603(a), Alaska Rules of Appellate Procedure; and providing for an effective date.'},
#  {'bill_id': 1700337,
#   'number': 'HB64',
#   'change_hash': 'cfa7c2009efd3e5bb77404feb5b1c18d',
#   'url': 'https://legiscan.com/AK/bill/HB64/2023',
#   'status_date': '2023-02-08',
#   'status': 1,
#   'last_action_date': '2023-02-13',
#   'last_action': 'COSPONSOR(S): WRIGHT',
#   'title': 'Hunting/trapping/fishing: Disabled Vets',
#   'description': 'An Act providing for trapping licenses for active members of the Alaska National Guard and military reserves without charge; making sport fishing, hunting, and trapping permanent identification cards available to certain disabled veterans without charge; and providing for an effective date.'},
#  {'bill_id': 1700415,
#   'number': 'HB65',
#   'change_hash': 'e727d9e6bc99f397f4a254502cc2a1fa',
#   'url': 'https://legiscan.com/AK/bill/HB65/2023',
#   'status_date': '2023-02-08',
#   'status': 1,
#   'last_action_date': '2023-03-23',
#   'last_action': 'EDC RPT RECD W/CS AWAIT TRANSMITTAL NXT',
#   'title': 'Increase Base Student Allocation',
#   'description': 'An Act relating to education; increasing the base student allocation; and providing for an effective date.'},
#  {'bill_id': 1699899,
#   'number': 'HB66',
#   'change_hash': 'bde4174b92994ada1886358157300e68',
#   'url': 'https://legiscan.com/AK/bill/HB66/2023',
#   'status_date': '2023-02-08',
#   'status': 1,
#   'last_action_date': '2023-02-08',
#   'last_action': 'REFERRED TO JUDICIARY',
#   'title': 'Controlled Sub.;homicide;good Time Deduc.',
#   'description': 'An Act relating to homicide resulting from conduct involving controlled substances; relating to the computation of good time; and providing for an effective date.'},
#  {'bill_id': 1699973,
#   'number': 'HB67',
#   'change_hash': '18461bbdeac3e28c89473f677a718b1e',
#   'url': 'https://legiscan.com/AK/bill/HB67/2023',
#   'status_date': '2023-02-08',
#   'status': 1,
#   'last_action_date': '2023-02-08',
#   'last_action': 'REFERRED TO JUDICIARY',
#   'title': 'Harassment; Sex Offenders & Offenses',
#   'description': 'An Act relating to criminal law and procedure; relating to the crime of stalking; relating to consecutive sentencing for violation of conditions of release; relating to the duty to register as a sex offender; amending the definition of &#39;sex offense&#39;; amending the definition of &#39;crime involving domestic violence&#39;; relating to multidisciplinary child protection teams; amending Rule 6(r), Alaska Rules of Criminal Procedure; and providing for an effective date.'},
#  {'bill_id': 1700563,
#   'number': 'HB68',
#   'change_hash': '5f7bc4c0c75c594559f6b7c9fdd02dee',
#   'url': 'https://legiscan.com/AK/bill/HB68/2023',
#   'status_date': '2023-02-08',
#   'status': 1,
#   'last_action_date': '2023-02-08',
#   'last_action': 'REFERRED TO JUDICIARY',
#   'title': 'Crime Of Sex/human Trafficking',
#   'description': 'An Act relating to sex trafficking; establishing the crime of patron of a victim of sex trafficking; relating to the crime of human trafficking; relating to prostitution; relating to sentencing for sex trafficking, patron of a victim of sex trafficking, and human trafficking; establishing the process for vacating judgments for certain convictions of prostitution and misconduct involving a controlled substance; relating to the Council on Domestic Violence and Sexual Assault; relating to permanent fund dividends for certain individuals whose convictions are vacated; and providing for an effective date.'},
#  {'bill_id': 1703793,
#   'number': 'HB69',
#   'change_hash': 'f65391f57d853619dc574a1ec5019686',
#   'url': 'https://legiscan.com/AK/bill/HB69/2023',
#   'status_date': '2023-02-10',
#   'status': 1,
#   'last_action_date': '2023-03-22',
#   'last_action': 'REFERRED TO COMMUNITY & REGIONAL AFFAIRS',
#   'title': 'Reclassification Of First Class Cities',
#   'description': 'An Act relating to the reclassification of first class cities as second class cities; and providing for an effective date.'},
#  {'bill_id': 1705566,
#   'number': 'HB70',
#   'change_hash': 'dcf156d15451bc26650d128c5c691a87',
#   'url': 'https://legiscan.com/AK/bill/HB70/2023',
#   'status_date': '2023-02-13',
#   'status': 1,
#   'last_action_date': '2023-02-13',
#   'last_action': 'REFERRED TO COMMUNITY & REGIONAL AFFAIRS',
#   'title': 'Municipal Property Tax Exemptions',
#   'description': 'An Act relating to property exempt from municipal taxation.'},
#  {'bill_id': 1705255,
#   'number': 'HB71',
#   'change_hash': '9f3be5814f10759a9ebd82a5c174c457',
#   'url': 'https://legiscan.com/AK/bill/HB71/2023',
#   'status_date': '2023-02-13',
#   'status': 1,
#   'last_action_date': '2023-02-13',
#   'last_action': 'REFERRED TO EDUCATION',
#   'title': 'School District Online Checkbook',
#   'description': 'An Act relating to education; and relating to a school district online checkbook.'},
#  {'bill_id': 1708420,
#   'number': 'HB72',
#   'change_hash': '958790b6fe399f694fa0b5227eb83b01',
#   'url': 'https://legiscan.com/AK/bill/HB72/2023',
#   'status_date': '2023-02-15',
#   'status': 1,
#   'last_action_date': '2023-02-15',
#   'last_action': 'REFERRED TO WAYS & MEANS',
#   'title': 'Permanent Fund Dividend; 75/25 Pomv Split',
#   'description': 'An Act relating to use of income of the Alaska permanent fund; relating to the amount of the permanent fund dividend; relating to the duties of the commissioner of revenue; and providing for an effective date.'},
#  {'bill_id': 1708782,
#   'number': 'HB73',
#   'change_hash': '4ead113dacdf673904e0da1b4227ed15',
#   'url': 'https://legiscan.com/AK/bill/HB73/2023',
#   'status_date': '2023-02-15',
#   'status': 1,
#   'last_action_date': '2023-02-15',
#   'last_action': 'REFERRED TO LABOR & COMMERCE',
#   'title': 'Dcced Licensing Investigations',
#   'description': 'An Act relating to investigations conducted by the Department of Commerce, Community, and Economic Development.'},
#  {'bill_id': 1708524,
#   'number': 'HB74',
#   'change_hash': '34c906f8efaa99ac0d9d3403f063944e',
#   'url': 'https://legiscan.com/AK/bill/HB74/2023',
#   'status_date': '2023-02-15',
#   'status': 1,
#   'last_action_date': '2023-03-15',
#   'last_action': 'REFERRED TO FINANCE',
#   'title': 'Geothermal Resources',
#   'description': 'An Act relating to geothermal resources; relating to the definition of &#39;geothermal resources&#39;; and providing for an effective date.'},
#  {'bill_id': 1708633,
#   'number': 'HB75',
#   'change_hash': '75b94c30dc4876966c58460fb877400c',
#   'url': 'https://legiscan.com/AK/bill/HB75/2023',
#   'status_date': '2023-02-15',
#   'status': 1,
#   'last_action_date': '2023-03-17',
#   'last_action': 'REFERRED TO RULES',
#   'title': 'Owner & Contractor Controlled Insurance',
#   'description': 'An Act relating to coverage for additional insureds under owner and contractor controlled insurance programs; and providing for an effective date.'},
#  {'bill_id': 1708683,
#   'number': 'HB76',
#   'change_hash': '948cc4885f15ea3e9f1ffb1209c44a49',
#   'url': 'https://legiscan.com/AK/bill/HB76/2023',
#   'status_date': '2023-02-15',
#   'status': 1,
#   'last_action_date': '2023-03-06',
#   'last_action': 'REFERRED TO FINANCE',
#   'title': 'Pay For Ak Defense Force',
#   'description': 'An Act relating to pay for the Alaska State Defense Force; and providing for an effective date.'},
#  {'bill_id': 1713660,
#   'number': 'HB77',
#   'change_hash': '3df7f85715fa46fcd2c3013aff1c9e63',
#   'url': 'https://legiscan.com/AK/bill/HB77/2023',
#   'status_date': '2023-02-17',
#   'status': 1,
#   'last_action_date': '2023-02-17',
#   'last_action': 'REFERRED TO STATE AFFAIRS',
#   'title': 'Naming Anc Legis Office Bldg',
#   'description': 'An Act naming the Senator Johnny Ellis Jr. Anchorage Legislative Office Building.'},
#  {'bill_id': 1715237,
#   'number': 'HB78',
#   'change_hash': 'a77b5f422ef740f76330cc31d7a1ffc9',
#   'url': 'https://legiscan.com/AK/bill/HB78/2023',
#   'status_date': '2023-02-20',
#   'status': 1,
#   'last_action_date': '2023-03-24',
#   'last_action': 'TECHNICAL SESSION 3/24 - ON 3/27 CALENDAR',
#   'title': 'Ak Community Health Aide Appreciation Day',
#   'description': 'An Act establishing September 10 as Alaska Community Health Aide Appreciation Day.'},
#  {'bill_id': 1715368,
#   'number': 'HB79',
#   'change_hash': '33de171f9b930ffd32f08316e6a84f3c',
#   'url': 'https://legiscan.com/AK/bill/HB79/2023',
#   'status_date': '2023-03-22',
#   'status': 2,
#   'last_action_date': '2023-03-24',
#   'last_action': 'RULES TO CALENDAR PENDING FIN REF',
#   'title': 'Approp: Supplemental',
#   'description': 'An Act making supplemental appropriations and other appropriations; making appropriations under art. IX, sec. 17(c), Constitution of the State of Alaska, from the constitutional budget reserve fund; and providing for an effective date.'},
#  {'bill_id': 1718655,
#   'number': 'HB80',
#   'change_hash': 'b6bad9b60ec2640d1e87abd29e059b0c',
#   'url': 'https://legiscan.com/AK/bill/HB80/2023',
#   'status_date': '2023-02-22',
#   'status': 1,
#   'last_action_date': '2023-02-22',
#   'last_action': 'REFERRED TO HEALTH & SOCIAL SERVICES',
#   'title': 'Incompetency; Civil Commitment',
#   'description': 'An Act relating to competency to stand trial; relating to commitment based on a finding of incompetency; relating to administration of psychotropic medication; and relating to victims&#39; rights during certain civil commitment proceedings.'},
#  {'bill_id': 1718437,
#   'number': 'HB81',
#   'change_hash': 'fe3a6e8b43e19cf29721f158fbdba387',
#   'url': 'https://legiscan.com/AK/bill/HB81/2023',
#   'status_date': '2023-02-22',
#   'status': 1,
#   'last_action_date': '2023-03-08',
#   'last_action': 'REFERRED TO STATE AFFAIRS',
#   'title': 'Vehicles/boats: Transfer On Death Title',
#   'description': 'An Act relating to the transfer of a title on the death of the owner; and providing for an effective date.'},
#  {'bill_id': 1721504,
#   'number': 'HB82',
#   'change_hash': '529111ee52c80a1842d92ba78217369d',
#   'url': 'https://legiscan.com/AK/bill/HB82/2023',
#   'status_date': '2023-02-27',
#   'status': 1,
#   'last_action_date': '2023-02-27',
#   'last_action': 'REFERRED TO JUDICIARY',
#   'title': 'Selection And Review Of Judges',
#   'description': 'An Act relating to the selection, retention, and rejection of judicial officers for the court of appeals and the district court and of magistrates; relating to the duties of the judicial council; and relating to the duties of the Commission on Judicial Conduct.'},
#  {'bill_id': 1721696,
#   'number': 'HB83',
#   'change_hash': '7e0f99edcf2a612f7067ebaf50cbbd3d',
#   'url': 'https://legiscan.com/AK/bill/HB83/2023',
#   'status_date': '2023-02-27',
#   'status': 1,
#   'last_action_date': '2023-03-23',
#   'last_action': 'RES RPT RECD AWAIT TRANSMITTAL NXT',
#   'title': 'Citizen Advisory Comm On Federal Areas',
#   'description': 'An Act reestablishing the Citizens&#39; Advisory Commission on Federal Management Areas in Alaska; and providing for an effective date.'},
#  {'bill_id': 1721572,
#   'number': 'HB84',
#   'change_hash': 'bb8a53d97322b310ede693702fc2f4a1',
#   'url': 'https://legiscan.com/AK/bill/HB84/2023',
#   'status_date': '2023-02-27',
#   'status': 1,
#   'last_action_date': '2023-03-22',
#   'last_action': 'COSPONSOR(S): MEARS',
#   'title': 'Muni Prop Tax Exemption/tax Blighted Prop',
#   'description': 'An Act relating to municipal property tax; and providing for an effective date.'},
#  {'bill_id': 1721307,
#   'number': 'HB85',
#   'change_hash': 'c7ea740bfe787f0f46d44f9ded714d36',
#   'url': 'https://legiscan.com/AK/bill/HB85/2023',
#   'status_date': '2023-02-27',
#   'status': 1,
#   'last_action_date': '2023-03-22',
#   'last_action': 'REFERRED TO MILITARY & VETERANS AFFAIRS',
#   'title': 'Professional Licensing; Temp Permits',
#   'description': 'An Act relating to professional licensing; relating to temporary licenses for some professions; and providing for an effective date.'},
#  {'bill_id': 1721242,
#   'number': 'HB86',
#   'change_hash': '29ee56b65a8250fa2af915ea2f7e85a9',
#   'url': 'https://legiscan.com/AK/bill/HB86/2023',
#   'status_date': '2023-02-27',
#   'status': 1,
#   'last_action_date': '2023-02-27',
#   'last_action': 'REFERRED TO LABOR & COMMERCE',
#   'title': 'Money Transmission; Virtual Currency',
#   'description': 'An Act relating to the business of money transmission; relating to money transmission licenses, licensure requirements, and registration through the Nationwide Multistate Licensing System and Registry; relating to the use of virtual currency for money transmission; relating to authorized delegates of a licensee; relating to acquisition of control of a license; relating to record retention and reporting requirements; authorizing the Department of Commerce, Community, and Economic Development to cooperate with other states in the regulation of money transmission; relating to permissible investments; relating to violations and enforcement of money transmission laws; relating to money transmission license exemptions; relating to payroll processing services; repealing currency exchange licenses; and providing for an effective date.'},
#  {'bill_id': 1721441,
#   'number': 'HB87',
#   'change_hash': '5686e2ec2f31bb93e012449e1cfab2ba',
#   'url': 'https://legiscan.com/AK/bill/HB87/2023',
#   'status_date': '2023-02-27',
#   'status': 1,
#   'last_action_date': '2023-02-27',
#   'last_action': 'REFERRED TO LABOR & COMMERCE',
#   'title': 'Perm Fund; Employment; Eligibility',
#   'description': 'An Act relating to record checks for certain employees of the Department of Revenue; relating to permanent fund dividends; and providing for an effective date.'},
#  {'bill_id': 1721374,
#   'number': 'HB88',
#   'change_hash': '7efc7a1638a741a3457f931cf0502f1c',
#   'url': 'https://legiscan.com/AK/bill/HB88/2023',
#   'status_date': '2023-02-27',
#   'status': 1,
#   'last_action_date': '2023-02-27',
#   'last_action': 'REFERRED TO LABOR & COMMERCE',
#   'title': 'Warehouse Work Quota Information',
#   'description': 'An Act relating to work quotas for employees at warehouse distribution centers; and providing for an effective date.'},
#  {'bill_id': 1721633,
#   'number': 'HB89',
#   'change_hash': 'b515e920ad0eb583b4ea61073aafe88c',
#   'url': 'https://legiscan.com/AK/bill/HB89/2023',
#   'status_date': '2023-02-27',
#   'status': 1,
#   'last_action_date': '2023-03-24',
#   'last_action': 'COSPONSOR(S): GALVIN',
#   'title': 'Day Care Assist./child Care Grant Program',
#   'description': 'An Act relating to the day care assistance program and the child care grant program; and providing for an effective date.'},
#  {'bill_id': 1724242,
#   'number': 'HB90',
#   'change_hash': '0026ccdc4c61ce5c6bc0b11ce2faf294',
#   'url': 'https://legiscan.com/AK/bill/HB90/2023',
#   'status_date': '2023-03-01',
#   'status': 1,
#   'last_action_date': '2023-03-01',
#   'last_action': 'REFERRED TO WAYS & MEANS',
#   'title': 'Permanent Fund Dividend; $1000 Dividend',
#   'description': 'An Act relating to income of the Alaska permanent fund and the amount available for appropriation; relating to appropriations from the earnings reserve account; relating to the amount of the permanent fund dividend; and providing for an effective date.'},
#  {'bill_id': 1723709,
#   'number': 'HB91',
#   'change_hash': 'ff723dc62083f488431f5f84ace84735',
#   'url': 'https://legiscan.com/AK/bill/HB91/2023',
#   'status_date': '2023-03-01',
#   'status': 1,
#   'last_action_date': '2023-03-01',
#   'last_action': 'REFERRED TO LABOR & COMMERCE',
#   'title': "Public Employees' Union Dues Deductions",
# ...
#   'description': 'An Act relating to claims against protection and indemnity insurance policies of vessel owners; and providing for an effective date.'},
#  {'bill_id': 1730517,
#   'number': 'SB94',
#   'change_hash': 'a71c322a3efb859e046eb1e8a62d8860',
#   'url': 'https://legiscan.com/AK/bill/SB94/2023',
#   'status_date': '2023-03-08',
#   'status': 1,
#   'last_action_date': '2023-03-17',
#   'last_action': 'COSPONSOR(S): WIELECHOWSKI',
#   'title': 'Profession Of Pharmacy',
#   'description': 'An Act relating to the Board of Pharmacy; relating to the practice of pharmacy; relating to pharmacies; relating to prescription drug manufacturers; relating to prescriptions for epinephrine; relating to the administration of epinephrine; and providing for an effective date.'},
#  {'bill_id': 1730913,
#   'number': 'SB95',
#   'change_hash': '349921a188727031f17424dbfc40088e',
#   'url': 'https://legiscan.com/AK/bill/SB95/2023',
#   'status_date': '2023-03-08',
#   'status': 1,
#   'last_action_date': '2023-03-10',
#   'last_action': 'COSPONSOR(S): KIEHL',
#   'title': 'License Plates: Specialty Organizations',
#   'description': 'An Act relating to special request specialty organization registration plates; and providing for an effective date.'},
#  {'bill_id': 1730580,
#   'number': 'SB96',
#   'change_hash': '4aeb260a55cb2551cbc7e3d429effcd0',
#   'url': 'https://legiscan.com/AK/bill/SB96/2023',
#   'status_date': '2023-03-08',
#   'status': 1,
#   'last_action_date': '2023-03-08',
#   'last_action': 'REFERRED TO JUDICIARY',
#   'title': 'Sex/reproduction Education; Schools',
#   'description': 'An Act relating to parental rights in a child&#39;s education; relating to access to school records; relating to sex education, human reproduction education, and human sexuality education; relating to school disciplinary and safety programs; and providing for an effective date.'},
#  {'bill_id': 1730730,
#   'number': 'SB97',
#   'change_hash': '03ff82eb985fbce02d0058e905d4744f',
#   'url': 'https://legiscan.com/AK/bill/SB97/2023',
#   'status_date': '2023-03-08',
#   'status': 1,
#   'last_action_date': '2023-03-08',
#   'last_action': 'REFERRED TO EDUCATION',
#   'title': 'Teacher Recruitment; Lump Sum Payment',
#   'description': 'An Act authorizing lump sum payments for certain teachers as retention and recruitment incentives; and providing for an effective date.'},
#  {'bill_id': 1730547,
#   'number': 'SB98',
#   'change_hash': 'cef463be6deaff14807de0b64e3d88ca',
#   'url': 'https://legiscan.com/AK/bill/SB98/2023',
#   'status_date': '2023-03-08',
#   'status': 1,
#   'last_action_date': '2023-03-08',
#   'last_action': 'REFERRED TO FINANCE',
#   'title': 'Power Cost Equalization Endowment Fund',
#   'description': 'An Act relating to the power cost equalization endowment fund; and relating to the Alaska Permanent Fund Corporation.'},
#  {'bill_id': 1734524,
#   'number': 'SB99',
#   'change_hash': 'a17484ae901c7ecfcc4233f07ad7a09c',
#   'url': 'https://legiscan.com/AK/bill/SB99/2023',
#   'status_date': '2023-03-10',
#   'status': 1,
#   'last_action_date': '2023-03-17',
#   'last_action': 'COSPONSOR(S): KAUFMAN',
#   'title': 'Financial Literacy Course In Schools',
#   'description': 'An Act establishing a financial literacy education course for public schools; and providing for an effective date.'},
#  {'bill_id': 1735315,
#   'number': 'SB100',
#   'change_hash': '231879c6878c304fca42594848ae6eed',
#   'url': 'https://legiscan.com/AK/bill/SB100/2023',
#   'status_date': '2023-03-10',
#   'status': 1,
#   'last_action_date': '2023-03-10',
#   'last_action': 'COSPONSOR(S): GRAY-JACKSON',
#   'title': 'Access To Marijuana Conviction Records',
#   'description': 'An Act restricting the release of certain records of convictions; and providing for an effective date.'},
#  {'bill_id': 1742335,
#   'number': 'SB101',
#   'change_hash': '6d67c4694f10a0f5877f66c48db4d9c7',
#   'url': 'https://legiscan.com/AK/bill/SB101/2023',
#   'status_date': '2023-03-15',
#   'status': 1,
#   'last_action_date': '2023-03-15',
#   'last_action': 'COSPONSOR(S): GRAY-JACKSON, KAWASAKI',
#   'title': 'Utilities: Renewable Portfolio Standard',
#   'description': 'An Act relating to a renewable portfolio standard; relating to electrical energy transmission; relating to distributed energy systems; relating to power cost equalization; relating to the Alaska Energy Authority; and providing for an effective date.'},
#  {'bill_id': 1742301,
#   'number': 'SB102',
#   'change_hash': 'ea9d33116d1d52429500ccd32e2979c9',
#   'url': 'https://legiscan.com/AK/bill/SB102/2023',
#   'status_date': '2023-03-15',
#   'status': 1,
#   'last_action_date': '2023-03-15',
#   'last_action': 'REFERRED TO LABOR & COMMERCE',
#   'title': 'Refuse Utility Regulations',
#   'description': 'An Act relating to refuse utility rates and Regulatory Commission of Alaska regulations regarding refuse utilities; and providing for an effective date.'},
#  {'bill_id': 1742169,
#   'number': 'SB103',
#   'change_hash': '47a8fe450845e35525abbacc8e36d288',
#   'url': 'https://legiscan.com/AK/bill/SB103/2023',
#   'status_date': '2023-03-15',
#   'status': 1,
#   'last_action_date': '2023-03-15',
#   'last_action': 'COSPONSOR(S): GRAY-JACKSON',
#   'title': 'Peer Support Counseling Program',
#   'description': 'An Act relating to peer support counseling programs for law enforcement agencies, emergency service providers, and the Department of Corrections.'},
#  {'bill_id': 1742264,
#   'number': 'SB104',
#   'change_hash': 'a8122f261df7c276211749e29e6e75cc',
#   'url': 'https://legiscan.com/AK/bill/SB104/2023',
#   'status_date': '2023-03-15',
#   'status': 1,
#   'last_action_date': '2023-03-20',
#   'last_action': 'COSPONSOR(S): GIESSEL',
#   'title': 'Civil Legal Services Fund',
#   'description': 'An Act relating to appropriations to the civil legal services fund.'},
#  {'bill_id': 1742197,
#   'number': 'SB105',
#   'change_hash': '7064148dd1b2e9e95c52f2ebd2ed0f98',
#   'url': 'https://legiscan.com/AK/bill/SB105/2023',
#   'status_date': '2023-03-15',
#   'status': 1,
#   'last_action_date': '2023-03-15',
#   'last_action': 'REFERRED TO TRANSPORTATION',
#   'title': 'Railroad Corp. Financing',
#   'description': 'An Act authorizing the Alaska Railroad Corporation to issue revenue bonds to finance the replacement of the Alaska Railroad Corporation&#39;s passenger dock and related terminal facility in Seward, Alaska; and providing for an effective date.'},
#  {'bill_id': 1743769,
#   'number': 'SB106',
#   'change_hash': '5c6352974b6bc7e0ab5a38af68989f07',
#   'url': 'https://legiscan.com/AK/bill/SB106/2023',
#   'status_date': '2023-03-17',
#   'status': 1,
#   'last_action_date': '2023-03-17',
#   'last_action': 'COSPONSOR(S): GRAY-JACKSON',
#   'title': 'Home And Community-based Waiver Services',
#   'description': 'An Act relating to home- and community-based services under the medical assistance program; and providing for an effective date.'},
#  {'bill_id': 1743696,
#   'number': 'SB107',
#   'change_hash': '7782e86eac1b13c23790f4eca64c9a5f',
#   'url': 'https://legiscan.com/AK/bill/SB107/2023',
#   'status_date': '2023-03-17',
#   'status': 1,
#   'last_action_date': '2023-03-17',
#   'last_action': 'REFERRED TO FINANCE',
#   'title': 'Permanent Fund Dividend; Pomv Split',
#   'description': 'An Act relating to the Alaska permanent fund; relating to income of the Alaska permanent fund; relating to the amount available for appropriation and appropriations from the earnings reserve account; relating to the permanent fund dividend; and providing for an effective date.'},
#  {'bill_id': 1743716,
#   'number': 'SB108',
#   'change_hash': '49b590fc06f8753fdda5255ecc9d51d5',
#   'url': 'https://legiscan.com/AK/bill/SB108/2023',
#   'status_date': '2023-03-17',
#   'status': 1,
#   'last_action_date': '2023-03-17',
#   'last_action': 'COSPONSOR(S): GRAY-JACKSON, TOBIN, KIEHL, WIELECHOWSKI, CLAMAN, DUNBAR',
#   'title': 'Discrimination: Gender Id.;sexual Orient.',
#   'description': 'An Act relating to and prohibiting discrimination based on sexual orientation or gender identity or expression.'},
#  {'bill_id': 1744262,
#   'number': 'SB109',
#   'change_hash': '556a7fa8e84d4411e39ef35d8e44acd6',
#   'url': 'https://legiscan.com/AK/bill/SB109/2023',
#   'status_date': '2023-03-20',
#   'status': 1,
#   'last_action_date': '2023-03-20',
#   'last_action': 'COSPONSOR(S): DUNBAR, GRAY-JACKSON',
#   'title': 'Employee Rights, Employer Speech',
#   'description': 'An Act relating to employee rights; and providing for an effective date.'},
#  {'bill_id': 1745875,
#   'number': 'SB110',
#   'change_hash': '493b8c369c693ca3eae7a7ab063510df',
#   'url': 'https://legiscan.com/AK/bill/SB110/2023',
#   'status_date': '2023-03-22',
#   'status': 1,
#   'last_action_date': '2023-03-22',
#   'last_action': 'REFERRED TO EDUCATION',
#   'title': 'School/university Employee Health Insur',
#   'description': 'An Act relating to group insurance coverage and self-insurance coverage for school district employees, employees of the University of Alaska, and employees of other governmental units in the state; and providing for an effective date.'},
#  {'bill_id': 1745926,
#   'number': 'SB111',
#   'change_hash': '68a0a82a90cc0969d7561354207b2d60',
#   'url': 'https://legiscan.com/AK/bill/SB111/2023',
#   'status_date': '2023-03-22',
#   'status': 1,
#   'last_action_date': '2023-03-22',
#   'last_action': 'REFERRED TO FINANCE',
#   'title': 'Reject Comm Recomm; Legislator Salaries',
#   'description': 'An Act relating to payment of legislator salaries; disapproving recommendations of the State Officers Compensation Commission; and providing for an effective date.'},
#  {'bill_id': 1745953,
#   'number': 'SB112',
#   'change_hash': 'ba203cdf0ce104420bf643f53474b412',
#   'url': 'https://legiscan.com/AK/bill/SB112/2023',
#   'status_date': '2023-03-22',
#   'status': 1,
#   'last_action_date': '2023-03-24',
#   'last_action': 'COSPONSOR(S): GIESSEL, BJORKMAN, GRAY-JACKSON',
#   'title': 'Digital Product Repair',
#   'description': 'An Act relating to the diagnosis, maintenance, and repair of products that use digital electronics to operate; adding an unlawful act to the Alaska Unfair Trade Practices and Consumer Protection Act; and providing for an effective date.'},
#  {'bill_id': 1745904,
#   'number': 'SB113',
#   'change_hash': 'd0c7205e93bde68f413a16b31bdb9876',
#   'url': 'https://legiscan.com/AK/bill/SB113/2023',
#   'status_date': '2023-03-22',
#   'status': 1,
#   'last_action_date': '2023-03-22',
#   'last_action': 'REFERRED TO EDUCATION',
#   'title': 'Reaa Fund: Mt. Edgecumbe, Teacher Housing',
#   'description': 'An Act relating to the regional educational attendance area and small municipal school district fund; relating to Mt. Edgecumbe High School; and relating to teacher housing.'},
#  {'bill_id': 1747271,
#   'number': 'SB114',
#   'change_hash': 'f2f0375a41473180f3b8881d77362e37',
#   'url': 'https://legiscan.com/AK/bill/SB114/2023',
#   'status_date': '2023-03-24',
#   'status': 1,
#   'last_action_date': '2023-03-24',
#   'last_action': 'REFERRED TO FINANCE',
#   'title': 'Oil & Gas Production Tax; Income Tax',
#   'description': 'An Act establishing an income tax on certain entities producing or transporting oil or gas in the state; relating to the oil and gas production tax; and providing for an effective date.'},
#  {'bill_id': 1664566,
#   'number': 'SR1',
#   'change_hash': 'e198e88be7f02801fc1d11839918036a',
#   'url': 'https://legiscan.com/AK/bill/SR1/2023',
#   'status_date': '2023-01-24',
#   'status': 3,
#   'last_action_date': '2023-01-25',
#   'last_action': 'SENATE RESOLVE NO. 1',
#   'title': 'Senate Special World Trade Committee',
#   'description': 'Senate Special World Trade Committee'},
#  {'bill_id': 1666277,
#   'number': 'SCR1',
#   'change_hash': '9faabae6c255f5c6bb4e3c80eb941be6',
#   'url': 'https://legiscan.com/AK/bill/SCR1/2023',
#   'status_date': '2023-03-01',
#   'status': 4,
#   'last_action_date': '2023-03-01',
#   'last_action': 'PERMANENTLY FILED 2/28 LEGIS RESOLVE 1',
#   'title': "Uniform Rules: Mason's Manual, Committees",
#   'description': 'Mason&#39;s Manual of Legislative Procedure'},
#  {'bill_id': 1648476,
#   'number': 'SJR1',
#   'change_hash': 'c9c5efdc5178c63a2738db0b68e0e54e',
#   'url': 'https://legiscan.com/AK/bill/SJR1/2023',
#   'status_date': '2023-01-18',
#   'status': 1,
#   'last_action_date': '2023-01-18',
#   'last_action': 'REFERRED TO STATE AFFAIRS',
#   'title': 'Const Am: Guarantee Perm Fund Dividend',
#   'description': 'Const Am: Guarantee Perm Fund Dividend'},
#  {'bill_id': 1646862,
#   'number': 'SJR2',
#   'change_hash': '20e4fcc449849a428fdc5f6004fc300c',
#   'url': 'https://legiscan.com/AK/bill/SJR2/2023',
#   'status_date': '2023-01-18',
#   'status': 1,
#   'last_action_date': '2023-01-18',
#   'last_action': 'REFERRED TO JUDICIARY',
#   'title': 'Const. Am: Abortion/funding',
#   'description': 'Const. Am: Abortion/funding'},
#  {'bill_id': 1648532,
#   'number': 'SJR3',
#   'change_hash': 'b9e285cf27417516259d67e7f86da286',
#   'url': 'https://legiscan.com/AK/bill/SJR3/2023',
#   'status_date': '2023-01-18',
#   'status': 1,
#   'last_action_date': '2023-01-18',
#   'last_action': 'REFERRED TO JUDICIARY',
#   'title': 'Const. Am: Approp Limit',
#   'description': 'Const. Am: Approp Limit'},
#  {'bill_id': 1648366,
#   'number': 'SJR4',
#   'change_hash': '7ce01fdf6cfadd2cc31b59609177b692',
#   'url': 'https://legiscan.com/AK/bill/SJR4/2023',
#   'status_date': '2023-01-18',
#   'status': 1,
#   'last_action_date': '2023-03-10',
#   'last_action': 'REFERRED TO JUDICIARY',
#   'title': 'Const. Am: Approp Limit',
#   'description': 'Const. Am: Approp Limit'},
#  {'bill_id': 1658724,
#   'number': 'SJR5',
#   'change_hash': 'b4138c8d7e077a5bf564d934d99c17d0',
#   'url': 'https://legiscan.com/AK/bill/SJR5/2023',
#   'status_date': '2023-01-18',
#   'status': 1,
#   'last_action_date': '2023-03-17',
#   'last_action': 'COSPONSOR(S): MYERS',
#   'title': 'Const. Am: 90 Day Regular Session',
#   'description': 'Const. Am: 90 Day Regular Session'},
#  {'bill_id': 1665992,
#   'number': 'SJR6',
#   'change_hash': 'f4160f5352a0d1b8ba5b7bc5816a7ca6',
#   'url': 'https://legiscan.com/AK/bill/SJR6/2023',
#   'status_date': '2023-01-18',
#   'status': 1,
#   'last_action_date': '2023-03-10',
#   'last_action': 'REFERRED TO RULES',
#   'title': 'Honoring The Alaska-korea Relationship',
#   'description': 'Honoring The Alaska-korea Relationship'},
#  {'bill_id': 1703695,
#   'number': 'SJR7',
#   'change_hash': 'a147caa744f22671cef1197a47e3e066',
#   'url': 'https://legiscan.com/AK/bill/SJR7/2023',
#   'status_date': '2023-02-10',
#   'status': 1,
#   'last_action_date': '2023-02-15',
#   'last_action': 'RES WAIVED PUBLIC HEARING NOTICE,RULE 23',
#   'title': "Nat'l Petroleum Reserve In Alaska",
#   'description': "Nat'l Petroleum Reserve In Alaska"},
#  {'bill_id': 1724010,
#   'number': 'SJR8',
#   'change_hash': '57e98f116d9b32b8861e67797a964a4e',
#   'url': 'https://legiscan.com/AK/bill/SJR8/2023',
#   'status_date': '2023-03-01',
#   'status': 1,
#   'last_action_date': '2023-03-01',
#   'last_action': 'REFERRED TO RESOURCES',
#   'title': "Nat'l Park Service; Hunting In Preserves",
#   'description': "Nat'l Park Service; Hunting In Preserves"},
#  {'bill_id': 1734924,
#   'number': 'SJR9',
#   'change_hash': '9215fabe6258b8938ee915822e38c8de',
#   'url': 'https://legiscan.com/AK/bill/SJR9/2023',
#   'status_date': '2023-03-10',
#   'status': 1,
#   'last_action_date': '2023-03-10',
#   'last_action': 'REFERRED TO JUDICIARY',
#   'title': 'Const. Am: Permanent Fund, Dividends',
#   'description': 'Const. Am: Permanent Fund, Dividends'},
#  {'bill_id': 1737952,
#   'number': 'SJR10',
#   'change_hash': 'e3fba7546c71c452fd0f41782df4d7fd',
#   'url': 'https://legiscan.com/AK/bill/SJR10/2023',
#   'status_date': '2023-03-13',
#   'status': 1,
#   'last_action_date': '2023-03-13',
#   'last_action': 'COSPONSOR(S): GRAY-JACKSON, WIELECHOWSKI, TOBIN, DUNBAR, CLAMAN',
#   'title': 'Medicare Reimbursement',
#   'description': 'Medicare Reimbursement'},
#  {'bill_id': 1747192,
#   'number': 'SJR11',
#   'change_hash': '9e65f3299c769ff0e0342b130de1456f',
#   'url': 'https://legiscan.com/AK/bill/SJR11/2023',
#   'status_date': '2023-03-24',
#   'status': 1,
#   'last_action_date': '2023-03-24',
#   'last_action': 'REFERRED TO TRANSPORTATION',
#   'title': 'Western Ak/arctic Oil Spill Response',
#   'description': 'Western Ak/arctic Oil Spill Response'}]

# %%
type(masterlist)
# Out:
# list

# %%
type(masterlist[2])
# Out:
# dict

# %%
# Okay, what am I doing?
# I'm trying to get the description value from the dict, based on the bill number.
# And I know the state because these are all from AK.
# And I want to... add these to the DF?
# And eventually I can write a function and use df.apply or .map to just pop them in there.

# %%
# Check each dictionary in the masterlist for the bill number
# and print out its description, but skip the first list item
for dictionary in masterlist[1:]:
    if dictionary['number'] == billNum:
        title = dictionary['title']
        desc = dictionary['description']
        print(title)
        print(desc)
        break
    else:
        continue
# Out:
# Designate Sex For School-sponsored Sports
# An Act relating to school athletics, recreation, athletic teams, and sports.

# %%
# YES! I DON'T HAVE TO DO THE BASE64 TO PDF/HTML TO TEXT PIPELINE!
# THANK GOD
# SO MUCH EASIER AND LESS WORK-INTENSIVE FOR THE OLD PI

# %% [markdown]
# # Get master lists for all states in df

# %%
stateset = set(df['Abbreviation'])
stateset
# Out:
# {'AK',
#  'AR',
#  'AZ',
#  'CO',
#  'CT',
#  'FL',
#  'GA',
#  'HI',
#  'IA',
#  'ID',
#  'IL',
#  'IN',
#  'KS',
#  'KY',
#  'LA',
#  'MD',
#  'ME',
#  'MI',
#  'MN',
#  'MO',
#  'MS',
#  'MT',
#  'NC',
#  'ND',
#  'NE',
#  'NH',
#  'NJ',
#  'NM',
#  'NV',
#  'OH',
#  'OK',
#  'OR',
#  'PA',
#  'RI',
#  'SC',
#  'SD',
#  'TN',
#  'TX',
#  'US',
#  'UT',
#  'VA',
#  'VT',
#  'WA',
#  'WI',
#  'WV',
#  'WY'}

# %%
statemasterlists = []

for state in stateset:
    statemasterlists.append(legis.get_master_list(state))

# %%
statedicts = dict(zip(list(stateset),statemasterlists))

# %%
statedicts['AK']
# Out:
# [{'session_id': 2015,
#   'state_id': 2,
#   'year_start': 2023,
#   'year_end': 2024,
#   'prefile': 0,
#   'sine_die': 0,
#   'prior': 0,
#   'special': 0,
#   'session_tag': 'Regular Session',
#   'session_title': '2023-2024 Regular Session',
#   'session_name': '33rd Legislature'},
#  {'bill_id': 1648141,
#   'number': 'HB1',
#   'change_hash': '48895fc89bb2f936b7a0c5e001155fca',
#   'url': 'https://legiscan.com/AK/bill/HB1/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-02-22',
#   'last_action': 'COSPONSOR(S): PRAX',
#   'title': 'Repeal Ballot Measure 2 Voting Chgs',
#   'description': 'An Act relating to elections.'},
#  {'bill_id': 1646412,
#   'number': 'HB2',
#   'change_hash': 'c3e95526966a37e6ee3919b993a1fb69',
#   'url': 'https://legiscan.com/AK/bill/HB2/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-03-17',
#   'last_action': 'REFERRED TO RULES',
#   'title': 'Contracts: Prohibit Israel Discrimination',
#   'description': 'An Act relating to contracts with public agencies; and relating to the State of Israel.'},
#  {'bill_id': 1647362,
#   'number': 'HB3',
#   'change_hash': 'dd3720ef8adf2f4d330cba3114aceefc',
#   'url': 'https://legiscan.com/AK/bill/HB3/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-02-22',
#   'last_action': 'REFERRED TO FINANCE',
#   'title': 'Gold And Silver Specie As Legal Tender',
#   'description': 'An Act relating to specie as legal tender in the state; and relating to borough and city sales and use taxes on specie.'},
#  {'bill_id': 1646807,
#   'number': 'HB4',
#   'change_hash': '8ac4ce76d74b76518edd2be9b10a55ba',
#   'url': 'https://legiscan.com/AK/bill/HB4/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-01-27',
#   'last_action': 'COSPONSOR(S): MCCABE',
#   'title': 'Elections:repeal Rank Choice/open Primary',
#   'description': 'An Act relating to elections.'},
#  {'bill_id': 1646331,
#   'number': 'HB5',
#   'change_hash': 'c04b246c2286cf35ea7f03530fdb4cef',
#   'url': 'https://legiscan.com/AK/bill/HB5/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-01-19',
#   'last_action': 'REFERRED TO COMMUNITY & REGIONAL AFFAIRS',
#   'title': 'Hold Legislative Sessions In Anchorage',
#   'description': 'An Act relating to convening the legislature in Anchorage; relating to the regulation of lobbying; relating to annual student guests of the legislature; relating to locations of sessions of the legislature; relating to the Legislative Ethics Act; relating to the relocation of functions of state government; and providing for an effective date.'},
#  {'bill_id': 1646918,
#   'number': 'HB6',
#   'change_hash': 'e5d4be2d13c820f110549839ccf8032b',
#   'url': 'https://legiscan.com/AK/bill/HB6/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-03-01',
#   'last_action': 'COSPONSOR(S): STORY',
#   'title': 'Public Schools; Opioid Awareness Program',
#   'description': 'An Act relating to the duties of the Department of Education and Early Development; relating to public education; relating to opioid abuse awareness and prevention; and providing for an effective date.'},
#  {'bill_id': 1647753,
#   'number': 'HB7',
#   'change_hash': '4bddbdff86ee3359b59e20b546543bc2',
#   'url': 'https://legiscan.com/AK/bill/HB7/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-01-19',
#   'last_action': 'REFERRED TO STATE AFFAIRS',
#   'title': 'Office Of Administrative Hearings',
#   'description': 'An Act relating to the office of administrative hearings; relating to the types of proceedings handled by the office of administrative hearings; relating to the entities that may use the services of the office of administrative hearings; relating to the duties of the chief administrative law judge, including the power to hire professional staff; relating to the qualifications and powers of administrative law judges, including subpoena power; relating to the compensation of the chief administrative law judge; relating to complaints against administrative law judges and hearing officers; relating to reimbursement for costs incurred by the office of administrative hearings; relating to procedures for requesting and conducting proceedings of the office of administrative hearings; and providing for an effective date.'},
#  {'bill_id': 1646529,
#   'number': 'HB8',
#   'change_hash': '4991b089364059fa599c4e074245fc43',
#   'url': 'https://legiscan.com/AK/bill/HB8/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-03-24',
#   'last_action': 'COSPONSOR(S): GALVIN',
#   'title': 'Electric-assisted Bicycles',
#   'description': 'An Act relating to electric-assisted bicycles.'},
#  {'bill_id': 1648088,
#   'number': 'HB9',
#   'change_hash': '1e6e6488bf7167e8edc5d5a877a03a05',
#   'url': 'https://legiscan.com/AK/bill/HB9/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-03-22',
#   'last_action': 'REFERRED TO JUDICIARY',
#   'title': 'Add Faculty Member Univ Board Of Regents',
#   'description': 'An Act relating to the Board of Regents of the University of Alaska.'},
#  {'bill_id': 1647195,
#   'number': 'HB10',
#   'change_hash': 'df471d121cee3aa3263f12666784d606',
#   'url': 'https://legiscan.com/AK/bill/HB10/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-03-01',
#   'last_action': 'COSPONSOR(S): MINA',
#   'title': 'University: Textbooks/materials Cost',
#   'description': 'An Act relating to costs of and charges for textbooks and other course materials required for University of Alaska courses; and providing for an effective date.'},
#  {'bill_id': 1648308,
#   'number': 'HB11',
#   'change_hash': '0bcb01f4c87cfafff1b084b217ad82bc',
#   'url': 'https://legiscan.com/AK/bill/HB11/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-01-25',
#   'last_action': 'REFERRED TO JUDICIARY',
#   'title': 'Crime: Assault In The Presence Of A Child',
#   'description': 'An Act establishing the crime of assault in the presence of a child.'},
#  {'bill_id': 1647696,
#   'number': 'HB12',
#   'change_hash': '488d53486afcce81693ce363c90151ae',
#   'url': 'https://legiscan.com/AK/bill/HB12/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-01-19',
#   'last_action': 'REFERRED TO COMMUNITY & REGIONAL AFFAIRS',
#   'title': 'Municipal Regulation Of Trapping',
#   'description': 'An Act relating to municipal regulation of trapping; and providing for an effective date.'},
#  {'bill_id': 1648808,
#   'number': 'HB13',
#   'change_hash': '42f5a9cd73d251906c220c3cbb2c30ea',
#   'url': 'https://legiscan.com/AK/bill/HB13/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-02-13',
#   'last_action': 'REFERRED TO JUDICIARY',
#   'title': 'Applicability Of Human Rights Commission',
#   'description': 'An Act relating to the definition of &#39;employer&#39; for the purposes of the State Commission for Human Rights.'},
#  {'bill_id': 1647031,
#   'number': 'HB14',
#   'change_hash': 'ea74279e904702b209750316c19ae4ef',
#   'url': 'https://legiscan.com/AK/bill/HB14/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-02-13',
#   'last_action': 'COSPONSOR(S): ARMSTRONG',
#   'title': 'Aggravating Factors At Sentencing',
#   'description': 'An Act relating to aggravating factors considered at sentencing.'},
#  {'bill_id': 1646451,
#   'number': 'HB15',
#   'change_hash': '453fd23de95a99a57693a95f091b2392',
#   'url': 'https://legiscan.com/AK/bill/HB15/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-03-15',
#   'last_action': 'COSPONSOR(S): FIELDS',
#   'title': 'Peer Support Counseling Program',
#   'description': 'An Act relating to peer support counseling programs for law enforcement agencies, emergency service providers, and the Department of Corrections.'},
#  {'bill_id': 1646550,
#   'number': 'HB16',
#   'change_hash': '59cb134b44684ca3a165cd144f19d5e0',
#   'url': 'https://legiscan.com/AK/bill/HB16/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-03-08',
#   'last_action': 'REFERRED TO HEALTH & SOCIAL SERVICES',
#   'title': 'Medicaid Optional Svcs & Cost Containment',
#   'description': 'An Act requiring the state medical assistance program to provide certain services; relating to cost containment measures for the state medical assistance program; relating to payment for adult dental services; and providing for an effective date.'},
#  {'bill_id': 1646403,
#   'number': 'HB17',
#   'change_hash': '907be01ee7b3674c3f5b9915bd2e4ea2',
#   'url': 'https://legiscan.com/AK/bill/HB17/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-03-24',
#   'last_action': 'COSPONSOR(S): GALVIN',
#   'title': 'Contraceptives Coverage:insure;med Assist',
#   'description': 'An Act relating to insurance coverage for contraceptives and related services; relating to medical assistance coverage for contraceptives and related services; and providing for an effective date.'},
#  {'bill_id': 1646394,
#   'number': 'HB18',
#   'change_hash': '9ccc77d731327e7c5f49e41a25f0ff97',
#   'url': 'https://legiscan.com/AK/bill/HB18/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-02-13',
#   'last_action': 'COSPONSOR(S): ARMSTRONG',
#   'title': 'Fishery Development Assoc.; Assessments',
#   'description': 'An Act relating to regional fishery development associations; and relating to developing fishery management assessments.'},
#  {'bill_id': 1646642,
#   'number': 'HB19',
#   'change_hash': '677f6e50ee4b9a0f7b184cd7165b39f0',
#   'url': 'https://legiscan.com/AK/bill/HB19/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-02-06',
#   'last_action': 'COSPONSOR(S): SCHRAGE',
#   'title': 'Registration Of Boats: Exemption',
#   'description': 'An Act relating to the registration of commercial vessels; and providing for an effective date.'},
#  {'bill_id': 1646749,
#   'number': 'HB20',
#   'change_hash': '3d00b2ad05af466374c90e38cac449b9',
#   'url': 'https://legiscan.com/AK/bill/HB20/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-01-30',
#   'last_action': 'COSPONSOR(S): HIMSCHOOT',
#   'title': 'Conflict Of Interest: Bd Fisheries/game',
#   'description': 'An Act relating to participation in matters before the Board of Fisheries and the Board of Game by the members of the respective boards; and providing for an effective date.'},
#  {'bill_id': 1646478,
#   'number': 'HB21',
#   'change_hash': '76c6298ee4deaf0fcea4a8d3ce7f72f8',
#   'url': 'https://legiscan.com/AK/bill/HB21/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-01-27',
#   'last_action': 'REFERRED TO EDUCATION',
#   'title': 'School/university Employee Health Insur',
#   'description': 'An Act relating to group insurance coverage and self-insurance coverage for school district employees, employees of the University of Alaska, and employees of other governmental units in the state; and providing for an effective date.'},
#  {'bill_id': 1647920,
#   'number': 'HB22',
#   'change_hash': 'c86b11af0cb19b87b53e322f2c7bce55',
#   'url': 'https://legiscan.com/AK/bill/HB22/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-03-01',
#   'last_action': 'COSPONSOR(S): GROH',
#   'title': 'Peace Officer/firefighter Retire Benefits',
#   'description': 'An Act relating to participation of certain peace officers and firefighters in the defined benefit and defined contribution plans of the Public Employees&#39; Retirement System of Alaska; relating to eligibility of peace officers and firefighters for medical, disability, and death benefits; relating to liability of the Public Employees&#39; Retirement System of Alaska; and providing for an effective date.'},
#  {'bill_id': 1646501,
#   'number': 'HB23',
#   'change_hash': 'e062f5de839228ae441cf6c1eea45341',
#   'url': 'https://legiscan.com/AK/bill/HB23/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-03-17',
#   'last_action': 'ARMSTRONG, GRAY, GALVIN',
#   'title': 'Filipino American History Month',
#   'description': 'An Act establishing the month of October as Filipino American History Month.'},
#  {'bill_id': 1647806,
#   'number': 'HB24',
#   'change_hash': '70a4789a4772604677de9989ae0be87b',
#   'url': 'https://legiscan.com/AK/bill/HB24/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-01-27',
#   'last_action': 'COSPONSOR(S): MCCABE',
#   'title': 'Gov Appoint Board Of Governors Of Ak Bar',
#   'description': 'An Act relating to the membership of the Board of Governors of the Alaska Bar.'},
#  {'bill_id': 1647083,
#   'number': 'HB25',
#   'change_hash': 'a400913d885e27a43f57e6934d9a0d53',
#   'url': 'https://legiscan.com/AK/bill/HB25/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-03-24',
#   'last_action': 'COSPONSOR(S): FIELDS',
#   'title': 'Pfd Eligibility Uniformed Services',
#   'description': 'An Act relating to eligibility for the permanent fund dividend; and providing for an effective date.'},
#  {'bill_id': 1648199,
#   'number': 'HB26',
#   'change_hash': 'c10a7851daddf4fd784b0634ce03f348',
#   'url': 'https://legiscan.com/AK/bill/HB26/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-03-22',
#   'last_action': 'REFERRED TO FINANCE',
#   'title': 'Council For Alaska Native Languages',
#   'description': 'An Act renaming the Alaska Native Language Preservation and Advisory Council as the Council for Alaska Native Languages; and relating to the Council for Alaska Native Languages.'},
#  {'bill_id': 1646385,
#   'number': 'HB27',
#   'change_hash': 'd3f1f1326343d7e96d129e70fc3ba09c',
#   'url': 'https://legiscan.com/AK/bill/HB27/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-01-19',
#   'last_action': 'REFERRED TO EDUCATION',
#   'title': 'Designate Sex For School-sponsored Sports',
#   'description': 'An Act relating to school athletics, recreation, athletic teams, and sports.'},
#  {'bill_id': 1648700,
#   'number': 'HB28',
#   'change_hash': 'c62a62e349398d0ed650e297b3f8695f',
#   'url': 'https://legiscan.com/AK/bill/HB28/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-03-24',
#   'last_action': 'COSPONSOR(S): HANNAN',
#   'title': 'Access To Marijuana Conviction Records',
#   'description': 'An Act restricting the release of certain records of convictions; and providing for an effective date.'},
#  {'bill_id': 1646337,
#   'number': 'HB29',
#   'change_hash': '0d6db0f50b8390f8f48ef32741e182c0',
#   'url': 'https://legiscan.com/AK/bill/HB29/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-03-08',
#   'last_action': 'REFERRED TO JUDICIARY',
#   'title': 'Insurance Discrimination',
#   'description': 'An Act relating to insurance discrimination.'},
#  {'bill_id': 1647251,
#   'number': 'HB30',
#   'change_hash': '0391d19f9ff207c386455b4019e36d69',
#   'url': 'https://legiscan.com/AK/bill/HB30/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-01-19',
#   'last_action': 'REFERRED TO COMMUNITY & REGIONAL AFFAIRS',
#   'title': 'Observe Daylight Saving Time All Year',
#   'description': 'An Act relating to daylight saving time; and providing for an effective date.'},
#  {'bill_id': 1647476,
#   'number': 'HB31',
#   'change_hash': 'ff620b689815a0364717e0e7c6fda5ce',
#   'url': 'https://legiscan.com/AK/bill/HB31/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-02-07',
#   'last_action': 'COSPONSOR(S): FIELDS',
#   'title': 'Ak Performance Scholarship; Eligibility',
#   'description': 'An Act relating to the Alaska performance scholarship program.'},
#  {'bill_id': 1648588,
#   'number': 'HB32',
#   'change_hash': '47a6c31116aab659d3b8f287c81cd610',
#   'url': 'https://legiscan.com/AK/bill/HB32/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-01-27',
#   'last_action': 'COSPONSOR(S): MCCABE',
#   'title': 'Oil & Gas Working Group',
#   'description': 'An Act relating to appeals of administrative decisions related to oil or gas; establishing an oil and gas production working group; and providing for an effective date.'},
#  {'bill_id': 1647530,
#   'number': 'HB33',
#   'change_hash': 'c5e762a542eb43951db49faa2aed2ede',
#   'url': 'https://legiscan.com/AK/bill/HB33/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-01-19',
#   'last_action': 'REFERRED TO RESOURCES',
#   'title': 'Oil Spills/pollution:penalties;prevention',
#   'description': 'An Act relating to penalties for discharges of oil and other pollution violations; and providing for an effective date.'},
#  {'bill_id': 1658883,
#   'number': 'HB34',
#   'change_hash': 'ba8b097f2327597a7cb8dfb9a960e233',
#   'url': 'https://legiscan.com/AK/bill/HB34/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-01-19',
#   'last_action': 'REFERRED TO STATE AFFAIRS',
#   'title': 'Confirmation/qualifications Of Judges',
#   'description': 'An Act relating to the selection and retention of court of appeals and district court judges and magistrates; relating to the qualifications of supreme court justices, superior court judges, district court judges, and magistrates; relating to the duties of the judicial council; relating to the duties of the Commission on Judicial Conduct; and repealing Rule 19.1, Alaska Rules of Administration.'},
#  {'bill_id': 1658523,
#   'number': 'HB35',
#   'change_hash': '5a321a31bc74818217d2f4ee88da688b',
#   'url': 'https://legiscan.com/AK/bill/HB35/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-02-10',
#   'last_action': 'REFERRED TO LABOR & COMMERCE',
#   'title': 'Repeal Certificate Of Need Program',
#   'description': 'An Act relating to the certificate of need program for health care facilities; and providing for an effective date.'},
#  {'bill_id': 1658484,
#   'number': 'HB36',
#   'change_hash': 'ca38e6f33897e9ddb26ccd518b508184',
#   'url': 'https://legiscan.com/AK/bill/HB36/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-02-15',
#   'last_action': 'COSPONSOR(S): HIMSCHOOT',
#   'title': 'Apoc; Referenda/recall; Contributions',
#   'description': 'An Act requiring the disclosure of the identity of certain persons, groups, and nongroup entities that expend money in support of or in opposition to an application filed for a state referendum or recall election; relating to political contributions; and providing for an effective date.'},
#  {'bill_id': 1658921,
#   'number': 'HB37',
#   'change_hash': '4caa1e32592a8cca1c36f8033b67c0d9',
#   'url': 'https://legiscan.com/AK/bill/HB37/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-02-24',
#   'last_action': 'COSPONSOR(S): GALVIN',
#   'title': 'Elections, Voting, Ballots',
#   'description': 'An Act relating to elections; relating to voters; relating to the crime of unlawful interference with voting; and providing for an effective date.'},
#  {'bill_id': 1670856,
#   'number': 'HB38',
#   'change_hash': '6fcfeaa7b5f4bcb0913bce636d63d7e4',
#   'url': 'https://legiscan.com/AK/bill/HB38/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-03-08',
#   'last_action': 'COSPONSOR(S): SUMNER',
#   'title': 'Appropriation Limit; Gov Budget',
#   'description': 'An Act relating to an appropriation limit; relating to the budget responsibilities of the governor; and providing for an effective date.'},
#  {'bill_id': 1671022,
#   'number': 'HB39',
#   'change_hash': '0f073a744aa8f04e11b5eaf1f0d1886d',
#   'url': 'https://legiscan.com/AK/bill/HB39/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-01-19',
#   'last_action': 'REFERRED TO FINANCE',
#   'title': 'Approp: Operating Budget/loans/fund; Supp',
#   'description': 'An Act making appropriations for the operating and loan program expenses of state government and for certain programs; capitalizing funds; amending appropriations; making reappropriations; making supplemental appropriations; making appropriations under art. IX, sec. 17(c), Constitution of the State of Alaska, from the constitutional budget reserve fund; and providing for an effective date.'},
#  {'bill_id': 1670863,
#   'number': 'HB40',
#   'change_hash': '1e0a2cd88f8e4779a3e7738fa6835874',
#   'url': 'https://legiscan.com/AK/bill/HB40/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-01-19',
#   'last_action': 'REFERRED TO FINANCE',
#   'title': 'Approp: Capital/supplemental',
#   'description': 'An Act making appropriations, including capital appropriations and other appropriations; making supplemental appropriations; making appropriations to capitalize funds; and providing for an effective date.'},
#  {'bill_id': 1671204,
#   'number': 'HB41',
#   'change_hash': '867a1427a1c326a52563e53f507028d2',
#   'url': 'https://legiscan.com/AK/bill/HB41/2023',
#   'status_date': '2023-01-19',
#   'status': 1,
#   'last_action_date': '2023-01-19',
#   'last_action': 'REFERRED TO FINANCE',
#   'title': 'Approp: Mental Health Budget',
#   'description': 'An Act making appropriations for the operating and capital expenses of the state&#39;s integrated comprehensive mental health program; and providing for an effective date.'},
#  {'bill_id': 1675631,
#   'number': 'HB42',
#   'change_hash': 'f2b01b582c93e7330a2e4a0531c26011',
#   'url': 'https://legiscan.com/AK/bill/HB42/2023',
#   'status_date': '2023-01-23',
#   'status': 1,
#   'last_action_date': '2023-01-23',
#   'last_action': 'REFERRED TO STATE AFFAIRS',
#   'title': 'Eliminate Unnecessary Agency Publications',
#   'description': 'An Act relating to the elimination or modification of state agency publications that are outdated, duplicative, or excessive.'},
#  {'bill_id': 1675445,
#   'number': 'HB43',
#   'change_hash': 'eae89bea46bd814963e2aca7e1f6e743',
#   'url': 'https://legiscan.com/AK/bill/HB43/2023',
#   'status_date': '2023-01-23',
#   'status': 1,
#   'last_action_date': '2023-03-17',
#   'last_action': 'COSPONSOR(S): FIELDS',
#   'title': 'Conversion Therapy Prohibitions',
#   'description': 'An Act relating to professional and occupational licensing; and relating to treatment to change the sexual orientations or gender identities of children and vulnerable adults.'},
#  {'bill_id': 1675997,
#   'number': 'HB44',
#   'change_hash': '132645a2616a4a6538be84c1d3fde3ec',
#   'url': 'https://legiscan.com/AK/bill/HB44/2023',
#   'status_date': '2023-01-23',
#   'status': 1,
#   'last_action_date': '2023-02-07',
#   'last_action': 'COSPONSOR(S): DIBERT',
#   'title': 'Cultural Education Program',
#   'description': 'An Act relating to education; relating to public schools and school districts; establishing a cultural education program; and providing for an effective date.'},
#  {'bill_id': 1679943,
#   'number': 'HB45',
#   'change_hash': '836c46a55391b7718e640cd19829ef26',
#   'url': 'https://legiscan.com/AK/bill/HB45/2023',
#   'status_date': '2023-01-25',
#   'status': 1,
#   'last_action_date': '2023-03-01',
#   'last_action': 'COSPONSOR(S): CARRICK',
#   'title': 'Pfd Contributions To General Fund And Pf',
#   'description': 'An Act relating to contributions from permanent fund dividends to the general and permanent funds.'},
#  {'bill_id': 1680371,
#   'number': 'HB46',
#   'change_hash': '80a24165959f8da84a318eb367a49697',
#   'url': 'https://legiscan.com/AK/bill/HB46/2023',
#   'status_date': '2023-01-25',
#   'status': 1,
#   'last_action_date': '2023-03-06',
#   'last_action': 'REFERRED TO HEALTH & SOCIAL SERVICES',
#   'title': 'Child Care Provider Collective Bargaining',
#   'description': 'An Act allowing child care providers that receive state aid to organize and collectively bargain with the Department of Health; and establishing the child care provider fund.'},
#  {'bill_id': 1680050,
#   'number': 'HB47',
#   'change_hash': '2443fa87d0fb5a0e5bafff187d0ef998',
#   'url': 'https://legiscan.com/AK/bill/HB47/2023',
#   'status_date': '2023-01-25',
#   'status': 1,
#   'last_action_date': '2023-03-15',
#   'last_action': 'REFERRED TO LABOR & COMMERCE',
#   'title': 'Direct Health Agreement: Not Insurance',
#   'description': 'An Act relating to insurance; relating to direct health care agreements; and relating to unfair trade practices.'},
#  {'bill_id': 1679836,
#   'number': 'HB48',
#   'change_hash': 'dcb58db4ebf4df23ab83d3a8ca7fe159',
#   'url': 'https://legiscan.com/AK/bill/HB48/2023',
#   'status_date': '2023-01-25',
#   'status': 1,
#   'last_action_date': '2023-02-22',
#   'last_action': 'REFERRED TO RULES',
#   'title': 'Human Rights Commission Annual Report',
#   'description': 'An Act relating to reports from the State Commission for Human Rights.'},
#  {'bill_id': 1684529,
#   'number': 'HB49',
#   'change_hash': '6d7e7c2cbf7e02f6f0ebf101f3fe7873',
#   'url': 'https://legiscan.com/AK/bill/HB49/2023',
#   'status_date': '2023-01-27',
#   'status': 1,
#   'last_action_date': '2023-03-20',
#   'last_action': 'REFERRED TO FINANCE',
#   'title': 'Carbon Offset Program On State Land',
#   'description': 'An Act authorizing the Department of Natural Resources to lease land for carbon management purposes; establishing a carbon offset program for state land; authorizing the sale of carbon offset credits; and providing for an effective date.'},
#  {'bill_id': 1684324,
#   'number': 'HB50',
#   'change_hash': 'd17072c4be819ed2d2983f00da4bbc42',
#   'url': 'https://legiscan.com/AK/bill/HB50/2023',
#   'status_date': '2023-01-27',
#   'status': 1,
#   'last_action_date': '2023-03-13',
#   'last_action': 'REFERRED TO FINANCE',
#   'title': 'Carbon Storage',
#   'description': 'An Act relating to the geologic storage of carbon dioxide; and providing for an effective date.'},
#  {'bill_id': 1685632,
#   'number': 'HB51',
#   'change_hash': '56b7643bb60fbb24eccc041034140a5d',
#   'url': 'https://legiscan.com/AK/bill/HB51/2023',
#   'status_date': '2023-03-01',
#   'status': 2,
#   'last_action_date': '2023-03-06',
#   'last_action': 'REFERRED TO LABOR & COMMERCE',
#   'title': 'Use Of Designated Refrigerants',
#   'description': 'An Act relating to refrigerants designated as acceptable for use under federal law.'},
#  {'bill_id': 1685908,
#   'number': 'HB52',
#   'change_hash': '7a1f268ed77f499180efeabea05d8719',
#   'url': 'https://legiscan.com/AK/bill/HB52/2023',
#   'status_date': '2023-01-30',
#   'status': 1,
#   'last_action_date': '2023-02-01',
#   'last_action': 'COSPONSOR(S): CARPENTER',
#   'title': 'No Patient Left Alone Act',
#   'description': 'An Act relating to the right of patients and residents to have a support person in person during treatment and during stays at certain facilities; and relating to a requirement that health care facilities make certain information available to the public.'},
#  {'bill_id': 1690236,
#   'number': 'HB53',
#   'change_hash': 'a28492c2ce4f85e075f3ad7bbafaf9f2',
#   'url': 'https://legiscan.com/AK/bill/HB53/2023',
#   'status_date': '2023-02-01',
#   'status': 1,
#   'last_action_date': '2023-03-17',
#   'last_action': 'COSPONSOR(S): MEARS',
#   'title': 'State Identification Card For Prisoners',
#   'description': 'An Act relating to state identifications and driver&#39;s licenses for persons in the custody of the Department of Corrections; relating to the duties of the commissioner of corrections; and providing for an effective date.'},
#  {'bill_id': 1690329,
#   'number': 'HB54',
#   'change_hash': '750ef922f9ae272995bcf2f87b11f9bb',
#   'url': 'https://legiscan.com/AK/bill/HB54/2023',
#   'status_date': '2023-02-01',
#   'status': 1,
#   'last_action_date': '2023-02-01',
#   'last_action': 'REFERRED TO FINANCE',
#   'title': 'Approp: Supplemental; Reapprop; Amending',
#   'description': 'An Act making supplemental appropriations, reappropriations, and other appropriations; amending appropriations; capitalizing funds; and providing for an effective date.'},
#  {'bill_id': 1689867,
#   'number': 'HB55',
#   'change_hash': 'db627b19d3e89a0c8af55ebdae108773',
#   'url': 'https://legiscan.com/AK/bill/HB55/2023',
#   'status_date': '2023-02-01',
#   'status': 1,
#   'last_action_date': '2023-02-01',
#   'last_action': 'REFERRED TO EDUCATION',
#   'title': 'Extend Workforce Invest Board Allocations',
#   'description': 'An Act relating to allocations of funding for the Alaska Workforce Investment Board; and providing for an effective date.'},
#  {'bill_id': 1694896,
#   'number': 'HB56',
#   'change_hash': '8a834de82beababa7f26c7aea1437ffb',
#   'url': 'https://legiscan.com/AK/bill/HB56/2023',
#   'status_date': '2023-02-03',
#   'status': 1,
#   'last_action_date': '2023-03-24',
#   'last_action': 'COSPONSOR(S): ARMSTRONG',
#   'title': 'Controlled Sub. Data: Exempt Animal Rx',
#   'description': 'An Act exempting controlled substances prescribed or dispensed by a veterinarian to treat an animal from the requirements of the controlled substance prescription database.'},
#  {'bill_id': 1695329,
#   'number': 'HB57',
#   'change_hash': '82818d3892e3fefedea0fc02cdcc4f0c',
#   'url': 'https://legiscan.com/AK/bill/HB57/2023',
#   'status_date': '2023-02-03',
#   'status': 1,
#   'last_action_date': '2023-03-06',
#   'last_action': 'REFERRED TO HEALTH & SOCIAL SERVICES',
#   'title': 'Emergency Med. Svcs: Review Organizations',
#   'description': 'An Act relating to review organizations and permitting an emergency medical services provider to establish a review organization; and relating to patient records.'},
#  {'bill_id': 1695184,
#   'number': 'HB58',
#   'change_hash': '50957317649723e10a1473299ff16eae',
#   'url': 'https://legiscan.com/AK/bill/HB58/2023',
#   'status_date': '2023-02-03',
#   'status': 1,
#   'last_action_date': '2023-03-17',
#   'last_action': 'REFERRED TO FINANCE',
#   'title': 'Adult Home Care; Med Assistance',
#   'description': 'An Act relating to medical assistance for recipients of Medicaid waivers; establishing an adult care home license and procedures; providing for the transition of individuals from foster care to adult home care settings; and providing for an effective date.'},
#  {'bill_id': 1695044,
#   'number': 'HB59',
#   'change_hash': 'fc006366953188b81d9972145f8faffa',
#   'url': 'https://legiscan.com/AK/bill/HB59/2023',
#   'status_date': '2023-02-03',
#   'status': 1,
#   'last_action_date': '2023-03-08',
#   'last_action': 'REFERRED TO FINANCE',
#   'title': 'Medicaid Eligibility: Postpartum Mothers',
#   'description': 'An Act relating to Medicaid eligibility; expanding eligibility for postpartum mothers; conditioning the expansion of eligibility on approval by the United States Department of Health and Human Services; and providing for an effective date.'},
#  {'bill_id': 1695468,
#   'number': 'HB60',
#   'change_hash': '3e071891fa69741f3ff7f746c713ebb8',
#   'url': 'https://legiscan.com/AK/bill/HB60/2023',
#   'status_date': '2023-02-03',
#   'status': 1,
#   'last_action_date': '2023-02-03',
#   'last_action': 'REFERRED TO HEALTH & SOCIAL SERVICES',
#   'title': 'Runaways; Dfcs/doh: Duties/licensing/info',
#   'description': 'An Act relating to the licensing of runaway shelters; relating to advisors to the board of trustees of the Alaska Mental Health Trust Authority; relating to the sharing of confidential health information between the Department of Health and the Department of Family and Community Services; relating to the duties of the Department of Health and the Department of Family and Community Services; and providing for an effective date.'},
#  {'bill_id': 1696032,
#   'number': 'HB61',
#   'change_hash': '82884899e1df0d5d5db3fbc6a7304391',
#   'url': 'https://legiscan.com/AK/bill/HB61/2023',
#   'status_date': '2023-02-06',
#   'status': 1,
#   'last_action_date': '2023-03-22',
#   'last_action': 'COSPONSOR(S): SHAW, TOMASZEWSKI',
#   'title': 'Limitations On Firearms Restrictions',
#   'description': 'An Act relating to restrictions on firearms and other weapons.'},
#  {'bill_id': 1696087,
#   'number': 'HB62',
#   'change_hash': '6bfae0afa83e1a2fecb3720f8c2ce2fa',
#   'url': 'https://legiscan.com/AK/bill/HB62/2023',
#   'status_date': '2023-03-20',
#   'status': 2,
#   'last_action_date': '2023-03-22',
#   'last_action': 'CLAMAN',
#   'title': 'Renewable Energy Grant Fund',
#   'description': 'An Act relating to the renewable energy grant fund and recommendation program; and providing for an effective date.'},
#  {'bill_id': 1696144,
#   'number': 'HB63',
#   'change_hash': '8355808ed5d6ab5b4143fe1b892267e4',
#   'url': 'https://legiscan.com/AK/bill/HB63/2023',
#   'status_date': '2023-02-06',
#   'status': 1,
#   'last_action_date': '2023-03-20',
#   'last_action': 'FIN REFERRAL ADDED AFTER JUD',
#   'title': "Repeal Workers' Comp Appeals Commission",
#   'description': 'An Act repealing the Workers&#39; Compensation Appeals Commission; relating to decisions and orders of the Workers&#39; Compensation Appeals Commission; relating to superior court jurisdiction over appeals from Alaska Workers&#39; Compensation Board decisions; repealing Rules 201.1, 401.1, and 501.1, Alaska Rules of Appellate Procedure, and amending Rules 202(a), 204(a) - (c), 210(e), 601(b), 602(c) and (h), and 603(a), Alaska Rules of Appellate Procedure; and providing for an effective date.'},
#  {'bill_id': 1700337,
#   'number': 'HB64',
#   'change_hash': 'cfa7c2009efd3e5bb77404feb5b1c18d',
#   'url': 'https://legiscan.com/AK/bill/HB64/2023',
#   'status_date': '2023-02-08',
#   'status': 1,
#   'last_action_date': '2023-02-13',
#   'last_action': 'COSPONSOR(S): WRIGHT',
#   'title': 'Hunting/trapping/fishing: Disabled Vets',
#   'description': 'An Act providing for trapping licenses for active members of the Alaska National Guard and military reserves without charge; making sport fishing, hunting, and trapping permanent identification cards available to certain disabled veterans without charge; and providing for an effective date.'},
#  {'bill_id': 1700415,
#   'number': 'HB65',
#   'change_hash': 'cdd18eeb32df0608980459bd513f3962',
#   'url': 'https://legiscan.com/AK/bill/HB65/2023',
#   'status_date': '2023-02-08',
#   'status': 1,
#   'last_action_date': '2023-03-27',
#   'last_action': 'REFERRED TO FINANCE',
#   'title': 'Increase Base Student Allocation',
#   'description': 'An Act relating to education; increasing the base student allocation; and providing for an effective date.'},
#  {'bill_id': 1699899,
#   'number': 'HB66',
#   'change_hash': 'c07de6c1d1e61a79fbf0caff4deb37ca',
#   'url': 'https://legiscan.com/AK/bill/HB66/2023',
#   'status_date': '2023-02-08',
#   'status': 1,
#   'last_action_date': '2023-03-27',
#   'last_action': 'REFERRED TO FINANCE',
#   'title': 'Controlled Sub.;homicide;good Time Deduc.',
#   'description': 'An Act relating to homicide resulting from conduct involving controlled substances; relating to the computation of good time; and providing for an effective date.'},
#  {'bill_id': 1699973,
#   'number': 'HB67',
#   'change_hash': '18461bbdeac3e28c89473f677a718b1e',
#   'url': 'https://legiscan.com/AK/bill/HB67/2023',
#   'status_date': '2023-02-08',
#   'status': 1,
#   'last_action_date': '2023-02-08',
#   'last_action': 'REFERRED TO JUDICIARY',
#   'title': 'Harassment; Sex Offenders & Offenses',
#   'description': 'An Act relating to criminal law and procedure; relating to the crime of stalking; relating to consecutive sentencing for violation of conditions of release; relating to the duty to register as a sex offender; amending the definition of &#39;sex offense&#39;; amending the definition of &#39;crime involving domestic violence&#39;; relating to multidisciplinary child protection teams; amending Rule 6(r), Alaska Rules of Criminal Procedure; and providing for an effective date.'},
#  {'bill_id': 1700563,
#   'number': 'HB68',
#   'change_hash': '5f7bc4c0c75c594559f6b7c9fdd02dee',
#   'url': 'https://legiscan.com/AK/bill/HB68/2023',
#   'status_date': '2023-02-08',
#   'status': 1,
#   'last_action_date': '2023-02-08',
#   'last_action': 'REFERRED TO JUDICIARY',
#   'title': 'Crime Of Sex/human Trafficking',
#   'description': 'An Act relating to sex trafficking; establishing the crime of patron of a victim of sex trafficking; relating to the crime of human trafficking; relating to prostitution; relating to sentencing for sex trafficking, patron of a victim of sex trafficking, and human trafficking; establishing the process for vacating judgments for certain convictions of prostitution and misconduct involving a controlled substance; relating to the Council on Domestic Violence and Sexual Assault; relating to permanent fund dividends for certain individuals whose convictions are vacated; and providing for an effective date.'},
#  {'bill_id': 1703793,
#   'number': 'HB69',
#   'change_hash': 'f65391f57d853619dc574a1ec5019686',
#   'url': 'https://legiscan.com/AK/bill/HB69/2023',
#   'status_date': '2023-02-10',
#   'status': 1,
#   'last_action_date': '2023-03-22',
#   'last_action': 'REFERRED TO COMMUNITY & REGIONAL AFFAIRS',
#   'title': 'Reclassification Of First Class Cities',
#   'description': 'An Act relating to the reclassification of first class cities as second class cities; and providing for an effective date.'},
#  {'bill_id': 1705566,
#   'number': 'HB70',
#   'change_hash': 'dcf156d15451bc26650d128c5c691a87',
#   'url': 'https://legiscan.com/AK/bill/HB70/2023',
#   'status_date': '2023-02-13',
#   'status': 1,
#   'last_action_date': '2023-02-13',
#   'last_action': 'REFERRED TO COMMUNITY & REGIONAL AFFAIRS',
#   'title': 'Municipal Property Tax Exemptions',
#   'description': 'An Act relating to property exempt from municipal taxation.'},
#  {'bill_id': 1705255,
#   'number': 'HB71',
#   'change_hash': '9f3be5814f10759a9ebd82a5c174c457',
#   'url': 'https://legiscan.com/AK/bill/HB71/2023',
#   'status_date': '2023-02-13',
#   'status': 1,
#   'last_action_date': '2023-02-13',
#   'last_action': 'REFERRED TO EDUCATION',
#   'title': 'School District Online Checkbook',
#   'description': 'An Act relating to education; and relating to a school district online checkbook.'},
#  {'bill_id': 1708420,
#   'number': 'HB72',
#   'change_hash': '958790b6fe399f694fa0b5227eb83b01',
#   'url': 'https://legiscan.com/AK/bill/HB72/2023',
#   'status_date': '2023-02-15',
#   'status': 1,
#   'last_action_date': '2023-02-15',
#   'last_action': 'REFERRED TO WAYS & MEANS',
#   'title': 'Permanent Fund Dividend; 75/25 Pomv Split',
#   'description': 'An Act relating to use of income of the Alaska permanent fund; relating to the amount of the permanent fund dividend; relating to the duties of the commissioner of revenue; and providing for an effective date.'},
#  {'bill_id': 1708782,
#   'number': 'HB73',
#   'change_hash': '4ead113dacdf673904e0da1b4227ed15',
#   'url': 'https://legiscan.com/AK/bill/HB73/2023',
#   'status_date': '2023-02-15',
#   'status': 1,
#   'last_action_date': '2023-02-15',
#   'last_action': 'REFERRED TO LABOR & COMMERCE',
#   'title': 'Dcced Licensing Investigations',
#   'description': 'An Act relating to investigations conducted by the Department of Commerce, Community, and Economic Development.'},
#  {'bill_id': 1708524,
#   'number': 'HB74',
#   'change_hash': '34c906f8efaa99ac0d9d3403f063944e',
#   'url': 'https://legiscan.com/AK/bill/HB74/2023',
#   'status_date': '2023-02-15',
#   'status': 1,
#   'last_action_date': '2023-03-15',
#   'last_action': 'REFERRED TO FINANCE',
#   'title': 'Geothermal Resources',
#   'description': 'An Act relating to geothermal resources; relating to the definition of &#39;geothermal resources&#39;; and providing for an effective date.'},
#  {'bill_id': 1708633,
#   'number': 'HB75',
#   'change_hash': '75b94c30dc4876966c58460fb877400c',
#   'url': 'https://legiscan.com/AK/bill/HB75/2023',
#   'status_date': '2023-02-15',
#   'status': 1,
#   'last_action_date': '2023-03-17',
#   'last_action': 'REFERRED TO RULES',
#   'title': 'Owner & Contractor Controlled Insurance',
#   'description': 'An Act relating to coverage for additional insureds under owner and contractor controlled insurance programs; and providing for an effective date.'},
#  {'bill_id': 1708683,
#   'number': 'HB76',
#   'change_hash': '948cc4885f15ea3e9f1ffb1209c44a49',
#   'url': 'https://legiscan.com/AK/bill/HB76/2023',
#   'status_date': '2023-02-15',
#   'status': 1,
#   'last_action_date': '2023-03-06',
#   'last_action': 'REFERRED TO FINANCE',
#   'title': 'Pay For Ak Defense Force',
#   'description': 'An Act relating to pay for the Alaska State Defense Force; and providing for an effective date.'},
#  {'bill_id': 1713660,
#   'number': 'HB77',
#   'change_hash': '3df7f85715fa46fcd2c3013aff1c9e63',
#   'url': 'https://legiscan.com/AK/bill/HB77/2023',
#   'status_date': '2023-02-17',
#   'status': 1,
#   'last_action_date': '2023-02-17',
#   'last_action': 'REFERRED TO STATE AFFAIRS',
#   'title': 'Naming Anc Legis Office Bldg',
#   'description': 'An Act naming the Senator Johnny Ellis Jr. Anchorage Legislative Office Building.'},
#  {'bill_id': 1715237,
#   'number': 'HB78',
#   'change_hash': 'a77b5f422ef740f76330cc31d7a1ffc9',
#   'url': 'https://legiscan.com/AK/bill/HB78/2023',
#   'status_date': '2023-02-20',
#   'status': 1,
#   'last_action_date': '2023-03-24',
#   'last_action': 'TECHNICAL SESSION 3/24 - ON 3/27 CALENDAR',
#   'title': 'Ak Community Health Aide Appreciation Day',
#   'description': 'An Act establishing September 10 as Alaska Community Health Aide Appreciation Day.'},
#  {'bill_id': 1715368,
#   'number': 'HB79',
#   'change_hash': '33de171f9b930ffd32f08316e6a84f3c',
#   'url': 'https://legiscan.com/AK/bill/HB79/2023',
#   'status_date': '2023-03-22',
#   'status': 2,
#   'last_action_date': '2023-03-24',
#   'last_action': 'RULES TO CALENDAR PENDING FIN REF',
#   'title': 'Approp: Supplemental',
#   'description': 'An Act making supplemental appropriations and other appropriations; making appropriations under art. IX, sec. 17(c), Constitution of the State of Alaska, from the constitutional budget reserve fund; and providing for an effective date.'},
#  {'bill_id': 1718655,
#   'number': 'HB80',
#   'change_hash': 'b6bad9b60ec2640d1e87abd29e059b0c',
#   'url': 'https://legiscan.com/AK/bill/HB80/2023',
#   'status_date': '2023-02-22',
#   'status': 1,
#   'last_action_date': '2023-02-22',
#   'last_action': 'REFERRED TO HEALTH & SOCIAL SERVICES',
#   'title': 'Incompetency; Civil Commitment',
#   'description': 'An Act relating to competency to stand trial; relating to commitment based on a finding of incompetency; relating to administration of psychotropic medication; and relating to victims&#39; rights during certain civil commitment proceedings.'},
#  {'bill_id': 1718437,
#   'number': 'HB81',
#   'change_hash': 'fe3a6e8b43e19cf29721f158fbdba387',
#   'url': 'https://legiscan.com/AK/bill/HB81/2023',
#   'status_date': '2023-02-22',
#   'status': 1,
#   'last_action_date': '2023-03-08',
#   'last_action': 'REFERRED TO STATE AFFAIRS',
#   'title': 'Vehicles/boats: Transfer On Death Title',
#   'description': 'An Act relating to the transfer of a title on the death of the owner; and providing for an effective date.'},
#  {'bill_id': 1721504,
#   'number': 'HB82',
#   'change_hash': '529111ee52c80a1842d92ba78217369d',
#   'url': 'https://legiscan.com/AK/bill/HB82/2023',
#   'status_date': '2023-02-27',
#   'status': 1,
#   'last_action_date': '2023-02-27',
#   'last_action': 'REFERRED TO JUDICIARY',
#   'title': 'Selection And Review Of Judges',
#   'description': 'An Act relating to the selection, retention, and rejection of judicial officers for the court of appeals and the district court and of magistrates; relating to the duties of the judicial council; and relating to the duties of the Commission on Judicial Conduct.'},
#  {'bill_id': 1721696,
#   'number': 'HB83',
#   'change_hash': '7e0f99edcf2a612f7067ebaf50cbbd3d',
#   'url': 'https://legiscan.com/AK/bill/HB83/2023',
#   'status_date': '2023-02-27',
#   'status': 1,
#   'last_action_date': '2023-03-23',
#   'last_action': 'RES RPT RECD AWAIT TRANSMITTAL NXT',
#   'title': 'Citizen Advisory Comm On Federal Areas',
#   'description': 'An Act reestablishing the Citizens&#39; Advisory Commission on Federal Management Areas in Alaska; and providing for an effective date.'},
#  {'bill_id': 1721572,
#   'number': 'HB84',
#   'change_hash': 'bb8a53d97322b310ede693702fc2f4a1',
#   'url': 'https://legiscan.com/AK/bill/HB84/2023',
#   'status_date': '2023-02-27',
#   'status': 1,
#   'last_action_date': '2023-03-22',
#   'last_action': 'COSPONSOR(S): MEARS',
#   'title': 'Muni Prop Tax Exemption/tax Blighted Prop',
#   'description': 'An Act relating to municipal property tax; and providing for an effective date.'},
#  {'bill_id': 1721307,
#   'number': 'HB85',
#   'change_hash': 'c7ea740bfe787f0f46d44f9ded714d36',
#   'url': 'https://legiscan.com/AK/bill/HB85/2023',
#   'status_date': '2023-02-27',
#   'status': 1,
#   'last_action_date': '2023-03-22',
#   'last_action': 'REFERRED TO MILITARY & VETERANS AFFAIRS',
#   'title': 'Professional Licensing; Temp Permits',
#   'description': 'An Act relating to professional licensing; relating to temporary licenses for some professions; and providing for an effective date.'},
#  {'bill_id': 1721242,
#   'number': 'HB86',
#   'change_hash': '29ee56b65a8250fa2af915ea2f7e85a9',
#   'url': 'https://legiscan.com/AK/bill/HB86/2023',
#   'status_date': '2023-02-27',
#   'status': 1,
#   'last_action_date': '2023-02-27',
#   'last_action': 'REFERRED TO LABOR & COMMERCE',
#   'title': 'Money Transmission; Virtual Currency',
#   'description': 'An Act relating to the business of money transmission; relating to money transmission licenses, licensure requirements, and registration through the Nationwide Multistate Licensing System and Registry; relating to the use of virtual currency for money transmission; relating to authorized delegates of a licensee; relating to acquisition of control of a license; relating to record retention and reporting requirements; authorizing the Department of Commerce, Community, and Economic Development to cooperate with other states in the regulation of money transmission; relating to permissible investments; relating to violations and enforcement of money transmission laws; relating to money transmission license exemptions; relating to payroll processing services; repealing currency exchange licenses; and providing for an effective date.'},
#  {'bill_id': 1721441,
#   'number': 'HB87',
#   'change_hash': '5686e2ec2f31bb93e012449e1cfab2ba',
#   'url': 'https://legiscan.com/AK/bill/HB87/2023',
#   'status_date': '2023-02-27',
#   'status': 1,
#   'last_action_date': '2023-02-27',
#   'last_action': 'REFERRED TO LABOR & COMMERCE',
#   'title': 'Perm Fund; Employment; Eligibility',
#   'description': 'An Act relating to record checks for certain employees of the Department of Revenue; relating to permanent fund dividends; and providing for an effective date.'},
#  {'bill_id': 1721374,
#   'number': 'HB88',
#   'change_hash': '7efc7a1638a741a3457f931cf0502f1c',
#   'url': 'https://legiscan.com/AK/bill/HB88/2023',
#   'status_date': '2023-02-27',
#   'status': 1,
#   'last_action_date': '2023-02-27',
#   'last_action': 'REFERRED TO LABOR & COMMERCE',
#   'title': 'Warehouse Work Quota Information',
#   'description': 'An Act relating to work quotas for employees at warehouse distribution centers; and providing for an effective date.'},
#  {'bill_id': 1721633,
#   'number': 'HB89',
#   'change_hash': 'b515e920ad0eb583b4ea61073aafe88c',
#   'url': 'https://legiscan.com/AK/bill/HB89/2023',
#   'status_date': '2023-02-27',
#   'status': 1,
#   'last_action_date': '2023-03-24',
#   'last_action': 'COSPONSOR(S): GALVIN',
#   'title': 'Day Care Assist./child Care Grant Program',
#   'description': 'An Act relating to the day care assistance program and the child care grant program; and providing for an effective date.'},
#  {'bill_id': 1724242,
#   'number': 'HB90',
#   'change_hash': '0026ccdc4c61ce5c6bc0b11ce2faf294',
#   'url': 'https://legiscan.com/AK/bill/HB90/2023',
#   'status_date': '2023-03-01',
#   'status': 1,
#   'last_action_date': '2023-03-01',
#   'last_action': 'REFERRED TO WAYS & MEANS',
#   'title': 'Permanent Fund Dividend; $1000 Dividend',
#   'description': 'An Act relating to income of the Alaska permanent fund and the amount available for appropriation; relating to appropriations from the earnings reserve account; relating to the amount of the permanent fund dividend; and providing for an effective date.'},
#  {'bill_id': 1723709,
#   'number': 'HB91',
#   'change_hash': 'ff723dc62083f488431f5f84ace84735',
#   'url': 'https://legiscan.com/AK/bill/HB91/2023',
#   'status_date': '2023-03-01',
#   'status': 1,
#   'last_action_date': '2023-03-01',
#   'last_action': 'REFERRED TO LABOR & COMMERCE',
#   'title': "Public Employees' Union Dues Deductions",
# ...
#   'description': 'An Act relating to the Board of Pharmacy; relating to the practice of pharmacy; relating to pharmacies; relating to prescription drug manufacturers; relating to prescriptions for epinephrine; relating to the administration of epinephrine; and providing for an effective date.'},
#  {'bill_id': 1730913,
#   'number': 'SB95',
#   'change_hash': '349921a188727031f17424dbfc40088e',
#   'url': 'https://legiscan.com/AK/bill/SB95/2023',
#   'status_date': '2023-03-08',
#   'status': 1,
#   'last_action_date': '2023-03-10',
#   'last_action': 'COSPONSOR(S): KIEHL',
#   'title': 'License Plates: Specialty Organizations',
#   'description': 'An Act relating to special request specialty organization registration plates; and providing for an effective date.'},
#  {'bill_id': 1730580,
#   'number': 'SB96',
#   'change_hash': '4aeb260a55cb2551cbc7e3d429effcd0',
#   'url': 'https://legiscan.com/AK/bill/SB96/2023',
#   'status_date': '2023-03-08',
#   'status': 1,
#   'last_action_date': '2023-03-08',
#   'last_action': 'REFERRED TO JUDICIARY',
#   'title': 'Sex/reproduction Education; Schools',
#   'description': 'An Act relating to parental rights in a child&#39;s education; relating to access to school records; relating to sex education, human reproduction education, and human sexuality education; relating to school disciplinary and safety programs; and providing for an effective date.'},
#  {'bill_id': 1730730,
#   'number': 'SB97',
#   'change_hash': '03ff82eb985fbce02d0058e905d4744f',
#   'url': 'https://legiscan.com/AK/bill/SB97/2023',
#   'status_date': '2023-03-08',
#   'status': 1,
#   'last_action_date': '2023-03-08',
#   'last_action': 'REFERRED TO EDUCATION',
#   'title': 'Teacher Recruitment; Lump Sum Payment',
#   'description': 'An Act authorizing lump sum payments for certain teachers as retention and recruitment incentives; and providing for an effective date.'},
#  {'bill_id': 1730547,
#   'number': 'SB98',
#   'change_hash': 'cef463be6deaff14807de0b64e3d88ca',
#   'url': 'https://legiscan.com/AK/bill/SB98/2023',
#   'status_date': '2023-03-08',
#   'status': 1,
#   'last_action_date': '2023-03-08',
#   'last_action': 'REFERRED TO FINANCE',
#   'title': 'Power Cost Equalization Endowment Fund',
#   'description': 'An Act relating to the power cost equalization endowment fund; and relating to the Alaska Permanent Fund Corporation.'},
#  {'bill_id': 1734524,
#   'number': 'SB99',
#   'change_hash': 'a17484ae901c7ecfcc4233f07ad7a09c',
#   'url': 'https://legiscan.com/AK/bill/SB99/2023',
#   'status_date': '2023-03-10',
#   'status': 1,
#   'last_action_date': '2023-03-17',
#   'last_action': 'COSPONSOR(S): KAUFMAN',
#   'title': 'Financial Literacy Course In Schools',
#   'description': 'An Act establishing a financial literacy education course for public schools; and providing for an effective date.'},
#  {'bill_id': 1735315,
#   'number': 'SB100',
#   'change_hash': '231879c6878c304fca42594848ae6eed',
#   'url': 'https://legiscan.com/AK/bill/SB100/2023',
#   'status_date': '2023-03-10',
#   'status': 1,
#   'last_action_date': '2023-03-10',
#   'last_action': 'COSPONSOR(S): GRAY-JACKSON',
#   'title': 'Access To Marijuana Conviction Records',
#   'description': 'An Act restricting the release of certain records of convictions; and providing for an effective date.'},
#  {'bill_id': 1742335,
#   'number': 'SB101',
#   'change_hash': '6d67c4694f10a0f5877f66c48db4d9c7',
#   'url': 'https://legiscan.com/AK/bill/SB101/2023',
#   'status_date': '2023-03-15',
#   'status': 1,
#   'last_action_date': '2023-03-15',
#   'last_action': 'COSPONSOR(S): GRAY-JACKSON, KAWASAKI',
#   'title': 'Utilities: Renewable Portfolio Standard',
#   'description': 'An Act relating to a renewable portfolio standard; relating to electrical energy transmission; relating to distributed energy systems; relating to power cost equalization; relating to the Alaska Energy Authority; and providing for an effective date.'},
#  {'bill_id': 1742301,
#   'number': 'SB102',
#   'change_hash': 'ea9d33116d1d52429500ccd32e2979c9',
#   'url': 'https://legiscan.com/AK/bill/SB102/2023',
#   'status_date': '2023-03-15',
#   'status': 1,
#   'last_action_date': '2023-03-15',
#   'last_action': 'REFERRED TO LABOR & COMMERCE',
#   'title': 'Refuse Utility Regulations',
#   'description': 'An Act relating to refuse utility rates and Regulatory Commission of Alaska regulations regarding refuse utilities; and providing for an effective date.'},
#  {'bill_id': 1742169,
#   'number': 'SB103',
#   'change_hash': '47a8fe450845e35525abbacc8e36d288',
#   'url': 'https://legiscan.com/AK/bill/SB103/2023',
#   'status_date': '2023-03-15',
#   'status': 1,
#   'last_action_date': '2023-03-15',
#   'last_action': 'COSPONSOR(S): GRAY-JACKSON',
#   'title': 'Peer Support Counseling Program',
#   'description': 'An Act relating to peer support counseling programs for law enforcement agencies, emergency service providers, and the Department of Corrections.'},
#  {'bill_id': 1742264,
#   'number': 'SB104',
#   'change_hash': 'a8122f261df7c276211749e29e6e75cc',
#   'url': 'https://legiscan.com/AK/bill/SB104/2023',
#   'status_date': '2023-03-15',
#   'status': 1,
#   'last_action_date': '2023-03-20',
#   'last_action': 'COSPONSOR(S): GIESSEL',
#   'title': 'Civil Legal Services Fund',
#   'description': 'An Act relating to appropriations to the civil legal services fund.'},
#  {'bill_id': 1742197,
#   'number': 'SB105',
#   'change_hash': '7064148dd1b2e9e95c52f2ebd2ed0f98',
#   'url': 'https://legiscan.com/AK/bill/SB105/2023',
#   'status_date': '2023-03-15',
#   'status': 1,
#   'last_action_date': '2023-03-15',
#   'last_action': 'REFERRED TO TRANSPORTATION',
#   'title': 'Railroad Corp. Financing',
#   'description': 'An Act authorizing the Alaska Railroad Corporation to issue revenue bonds to finance the replacement of the Alaska Railroad Corporation&#39;s passenger dock and related terminal facility in Seward, Alaska; and providing for an effective date.'},
#  {'bill_id': 1743769,
#   'number': 'SB106',
#   'change_hash': '5c6352974b6bc7e0ab5a38af68989f07',
#   'url': 'https://legiscan.com/AK/bill/SB106/2023',
#   'status_date': '2023-03-17',
#   'status': 1,
#   'last_action_date': '2023-03-17',
#   'last_action': 'COSPONSOR(S): GRAY-JACKSON',
#   'title': 'Home And Community-based Waiver Services',
#   'description': 'An Act relating to home- and community-based services under the medical assistance program; and providing for an effective date.'},
#  {'bill_id': 1743696,
#   'number': 'SB107',
#   'change_hash': '7782e86eac1b13c23790f4eca64c9a5f',
#   'url': 'https://legiscan.com/AK/bill/SB107/2023',
#   'status_date': '2023-03-17',
#   'status': 1,
#   'last_action_date': '2023-03-17',
#   'last_action': 'REFERRED TO FINANCE',
#   'title': 'Permanent Fund Dividend; Pomv Split',
#   'description': 'An Act relating to the Alaska permanent fund; relating to income of the Alaska permanent fund; relating to the amount available for appropriation and appropriations from the earnings reserve account; relating to the permanent fund dividend; and providing for an effective date.'},
#  {'bill_id': 1743716,
#   'number': 'SB108',
#   'change_hash': '49b590fc06f8753fdda5255ecc9d51d5',
#   'url': 'https://legiscan.com/AK/bill/SB108/2023',
#   'status_date': '2023-03-17',
#   'status': 1,
#   'last_action_date': '2023-03-17',
#   'last_action': 'COSPONSOR(S): GRAY-JACKSON, TOBIN, KIEHL, WIELECHOWSKI, CLAMAN, DUNBAR',
#   'title': 'Discrimination: Gender Id.;sexual Orient.',
#   'description': 'An Act relating to and prohibiting discrimination based on sexual orientation or gender identity or expression.'},
#  {'bill_id': 1744262,
#   'number': 'SB109',
#   'change_hash': '556a7fa8e84d4411e39ef35d8e44acd6',
#   'url': 'https://legiscan.com/AK/bill/SB109/2023',
#   'status_date': '2023-03-20',
#   'status': 1,
#   'last_action_date': '2023-03-20',
#   'last_action': 'COSPONSOR(S): DUNBAR, GRAY-JACKSON',
#   'title': 'Employee Rights, Employer Speech',
#   'description': 'An Act relating to employee rights; and providing for an effective date.'},
#  {'bill_id': 1745875,
#   'number': 'SB110',
#   'change_hash': '493b8c369c693ca3eae7a7ab063510df',
#   'url': 'https://legiscan.com/AK/bill/SB110/2023',
#   'status_date': '2023-03-22',
#   'status': 1,
#   'last_action_date': '2023-03-22',
#   'last_action': 'REFERRED TO EDUCATION',
#   'title': 'School/university Employee Health Insur',
#   'description': 'An Act relating to group insurance coverage and self-insurance coverage for school district employees, employees of the University of Alaska, and employees of other governmental units in the state; and providing for an effective date.'},
#  {'bill_id': 1745926,
#   'number': 'SB111',
#   'change_hash': '68a0a82a90cc0969d7561354207b2d60',
#   'url': 'https://legiscan.com/AK/bill/SB111/2023',
#   'status_date': '2023-03-22',
#   'status': 1,
#   'last_action_date': '2023-03-22',
#   'last_action': 'REFERRED TO FINANCE',
#   'title': 'Reject Comm Recomm; Legislator Salaries',
#   'description': 'An Act relating to payment of legislator salaries; disapproving recommendations of the State Officers Compensation Commission; and providing for an effective date.'},
#  {'bill_id': 1745953,
#   'number': 'SB112',
#   'change_hash': 'ba203cdf0ce104420bf643f53474b412',
#   'url': 'https://legiscan.com/AK/bill/SB112/2023',
#   'status_date': '2023-03-22',
#   'status': 1,
#   'last_action_date': '2023-03-24',
#   'last_action': 'COSPONSOR(S): GIESSEL, BJORKMAN, GRAY-JACKSON',
#   'title': 'Digital Product Repair',
#   'description': 'An Act relating to the diagnosis, maintenance, and repair of products that use digital electronics to operate; adding an unlawful act to the Alaska Unfair Trade Practices and Consumer Protection Act; and providing for an effective date.'},
#  {'bill_id': 1745904,
#   'number': 'SB113',
#   'change_hash': 'd0c7205e93bde68f413a16b31bdb9876',
#   'url': 'https://legiscan.com/AK/bill/SB113/2023',
#   'status_date': '2023-03-22',
#   'status': 1,
#   'last_action_date': '2023-03-22',
#   'last_action': 'REFERRED TO EDUCATION',
#   'title': 'Reaa Fund: Mt. Edgecumbe, Teacher Housing',
#   'description': 'An Act relating to the regional educational attendance area and small municipal school district fund; relating to Mt. Edgecumbe High School; and relating to teacher housing.'},
#  {'bill_id': 1747271,
#   'number': 'SB114',
#   'change_hash': 'f2f0375a41473180f3b8881d77362e37',
#   'url': 'https://legiscan.com/AK/bill/SB114/2023',
#   'status_date': '2023-03-24',
#   'status': 1,
#   'last_action_date': '2023-03-24',
#   'last_action': 'REFERRED TO FINANCE',
#   'title': 'Oil & Gas Production Tax; Income Tax',
#   'description': 'An Act establishing an income tax on certain entities producing or transporting oil or gas in the state; relating to the oil and gas production tax; and providing for an effective date.'},
#  {'bill_id': 1747851,
#   'number': 'SB115',
#   'change_hash': 'ab1da9c8b1ca067673bba54474583442',
#   'url': 'https://legiscan.com/AK/bill/SB115/2023',
#   'status_date': '2023-03-27',
#   'status': 1,
#   'last_action_date': '2023-03-27',
#   'last_action': 'REFERRED TO HEALTH & SOCIAL SERVICES',
#   'title': 'Physician Assistant Scope Of Practice',
#   'description': 'An Act relating to physician assistants; relating to physicians; and relating to health care insurance policies.'},
#  {'bill_id': 1664566,
#   'number': 'SR1',
#   'change_hash': 'e198e88be7f02801fc1d11839918036a',
#   'url': 'https://legiscan.com/AK/bill/SR1/2023',
#   'status_date': '2023-01-24',
#   'status': 3,
#   'last_action_date': '2023-01-25',
#   'last_action': 'SENATE RESOLVE NO. 1',
#   'title': 'Senate Special World Trade Committee',
#   'description': 'Senate Special World Trade Committee'},
#  {'bill_id': 1666277,
#   'number': 'SCR1',
#   'change_hash': '9faabae6c255f5c6bb4e3c80eb941be6',
#   'url': 'https://legiscan.com/AK/bill/SCR1/2023',
#   'status_date': '2023-03-01',
#   'status': 4,
#   'last_action_date': '2023-03-01',
#   'last_action': 'PERMANENTLY FILED 2/28 LEGIS RESOLVE 1',
#   'title': "Uniform Rules: Mason's Manual, Committees",
#   'description': 'Mason&#39;s Manual of Legislative Procedure'},
#  {'bill_id': 1648476,
#   'number': 'SJR1',
#   'change_hash': 'c9c5efdc5178c63a2738db0b68e0e54e',
#   'url': 'https://legiscan.com/AK/bill/SJR1/2023',
#   'status_date': '2023-01-18',
#   'status': 1,
#   'last_action_date': '2023-01-18',
#   'last_action': 'REFERRED TO STATE AFFAIRS',
#   'title': 'Const Am: Guarantee Perm Fund Dividend',
#   'description': 'Const Am: Guarantee Perm Fund Dividend'},
#  {'bill_id': 1646862,
#   'number': 'SJR2',
#   'change_hash': '20e4fcc449849a428fdc5f6004fc300c',
#   'url': 'https://legiscan.com/AK/bill/SJR2/2023',
#   'status_date': '2023-01-18',
#   'status': 1,
#   'last_action_date': '2023-01-18',
#   'last_action': 'REFERRED TO JUDICIARY',
#   'title': 'Const. Am: Abortion/funding',
#   'description': 'Const. Am: Abortion/funding'},
#  {'bill_id': 1648532,
#   'number': 'SJR3',
#   'change_hash': 'b9e285cf27417516259d67e7f86da286',
#   'url': 'https://legiscan.com/AK/bill/SJR3/2023',
#   'status_date': '2023-01-18',
#   'status': 1,
#   'last_action_date': '2023-01-18',
#   'last_action': 'REFERRED TO JUDICIARY',
#   'title': 'Const. Am: Approp Limit',
#   'description': 'Const. Am: Approp Limit'},
#  {'bill_id': 1648366,
#   'number': 'SJR4',
#   'change_hash': '7ce01fdf6cfadd2cc31b59609177b692',
#   'url': 'https://legiscan.com/AK/bill/SJR4/2023',
#   'status_date': '2023-01-18',
#   'status': 1,
#   'last_action_date': '2023-03-10',
#   'last_action': 'REFERRED TO JUDICIARY',
#   'title': 'Const. Am: Approp Limit',
#   'description': 'Const. Am: Approp Limit'},
#  {'bill_id': 1658724,
#   'number': 'SJR5',
#   'change_hash': 'b4138c8d7e077a5bf564d934d99c17d0',
#   'url': 'https://legiscan.com/AK/bill/SJR5/2023',
#   'status_date': '2023-01-18',
#   'status': 1,
#   'last_action_date': '2023-03-17',
#   'last_action': 'COSPONSOR(S): MYERS',
#   'title': 'Const. Am: 90 Day Regular Session',
#   'description': 'Const. Am: 90 Day Regular Session'},
#  {'bill_id': 1665992,
#   'number': 'SJR6',
#   'change_hash': 'f4160f5352a0d1b8ba5b7bc5816a7ca6',
#   'url': 'https://legiscan.com/AK/bill/SJR6/2023',
#   'status_date': '2023-01-18',
#   'status': 1,
#   'last_action_date': '2023-03-10',
#   'last_action': 'REFERRED TO RULES',
#   'title': 'Honoring The Alaska-korea Relationship',
#   'description': 'Honoring The Alaska-korea Relationship'},
#  {'bill_id': 1703695,
#   'number': 'SJR7',
#   'change_hash': 'a147caa744f22671cef1197a47e3e066',
#   'url': 'https://legiscan.com/AK/bill/SJR7/2023',
#   'status_date': '2023-02-10',
#   'status': 1,
#   'last_action_date': '2023-02-15',
#   'last_action': 'RES WAIVED PUBLIC HEARING NOTICE,RULE 23',
#   'title': "Nat'l Petroleum Reserve In Alaska",
#   'description': "Nat'l Petroleum Reserve In Alaska"},
#  {'bill_id': 1724010,
#   'number': 'SJR8',
#   'change_hash': '57e98f116d9b32b8861e67797a964a4e',
#   'url': 'https://legiscan.com/AK/bill/SJR8/2023',
#   'status_date': '2023-03-01',
#   'status': 1,
#   'last_action_date': '2023-03-01',
#   'last_action': 'REFERRED TO RESOURCES',
#   'title': "Nat'l Park Service; Hunting In Preserves",
#   'description': "Nat'l Park Service; Hunting In Preserves"},
#  {'bill_id': 1734924,
#   'number': 'SJR9',
#   'change_hash': '9215fabe6258b8938ee915822e38c8de',
#   'url': 'https://legiscan.com/AK/bill/SJR9/2023',
#   'status_date': '2023-03-10',
#   'status': 1,
#   'last_action_date': '2023-03-10',
#   'last_action': 'REFERRED TO JUDICIARY',
#   'title': 'Const. Am: Permanent Fund, Dividends',
#   'description': 'Const. Am: Permanent Fund, Dividends'},
#  {'bill_id': 1737952,
#   'number': 'SJR10',
#   'change_hash': 'e3fba7546c71c452fd0f41782df4d7fd',
#   'url': 'https://legiscan.com/AK/bill/SJR10/2023',
#   'status_date': '2023-03-13',
#   'status': 1,
#   'last_action_date': '2023-03-13',
#   'last_action': 'COSPONSOR(S): GRAY-JACKSON, WIELECHOWSKI, TOBIN, DUNBAR, CLAMAN',
#   'title': 'Medicare Reimbursement',
#   'description': 'Medicare Reimbursement'},
#  {'bill_id': 1747192,
#   'number': 'SJR11',
#   'change_hash': '9e65f3299c769ff0e0342b130de1456f',
#   'url': 'https://legiscan.com/AK/bill/SJR11/2023',
#   'status_date': '2023-03-24',
#   'status': 1,
#   'last_action_date': '2023-03-24',
#   'last_action': 'REFERRED TO TRANSPORTATION',
#   'title': 'Western Ak/arctic Oil Spill Response',
#   'description': 'Western Ak/arctic Oil Spill Response'}]

# %% [markdown]
# # Add bill title and description to df
# Get bill title and description for each bill and fill it in

# %%
# Write the function to snag bill title and desc from the state:masterlist dict
def getBillTitle(stateAbbrev,billNum):
    masterlist = statedicts[f'{stateAbbrev}']
    # Check each dictionary in the masterlist for the bill number
    # and print out its description, but skip the first list item
    for dictionary in masterlist[1:]:
        if dictionary['number'] == billNum:
#             title = dictionary['title']
            desc = dictionary['description']
#             titledesc = f"{title}, {desc}"
            return desc
#             return desc
            break
        else:
            continue

# %%
# Check that it works for one instance
getBillTitle(df['Abbreviation'][5],df['Number'][5])
# Out:
# 'Sexually explicit performances; regulation'

# %%
# Make a quick backup
df2=df

# %%
# Apply it to the full column
df['Bill Title'] = df.apply(lambda row: getBillTitle(row['Abbreviation'],row['Number']), axis=1)

# %%
df.head()
# Out:
# 0    State Abbreviation  Number  \
# 1   Alaska           AK    HB27
# 2   Alaska           AK    SB96
# 3   Alaska           AK   HB105
# 4  Arizona           AZ  SB1028
# 5  Arizona           AZ  SB1030
#
# 0                                           Summary  \
# 1         Designate Sex For School-sponsored Sports
# 2               Sex/reproduction Education; Schools
# 3               Sex/reproduction Education; Schools
# 4  Adult cabaret performances; prohibited locations
# 5        Sexually explicit performances; regulation
#
# 0                    Bill Type       Date                  Status  \
# 1             Trans Sports Ban  1/19/2023   REFERRED TO EDUCATION
# 2  Don't Say Gay/Forced Outing   3/8/2023   REFERRED TO JUDICIARY
# 3  Don't Say Gay/Forced Outing   3/8/2023   REFERRED TO EDUCATION
# 4                     Drag Ban  3/22/2023  House read second time
# 5                     Drag Ban  3/21/2023  House read second time
#
# 0 Erin Reed's State Risk                                       URL  \
# 1               Moderate    https://legiscan.com/AK/bill/HB27/2023
# 2               Moderate    https://legiscan.com/AK/bill/SB96/2023
# 3               Moderate   https://legiscan.com/AK/bill/HB105/2023
# 4                    Low  https://legiscan.com/AZ/bill/SB1028/2023
# 5                    Low  https://legiscan.com/AZ/bill/SB1030/2023
#
# 0      Sponsors                                         Bill Title
# 1  Thomas McKay  An Act relating to school athletics, recreatio...
# 2         Rules  An Act relating to parental rights in a child&...
# 3         Rules  An Act relating to parental rights in a child&...
# 4  Anthony Kern   Adult cabaret performances; prohibited locations
# 5  Anthony Kern         Sexually explicit performances; regulation

# %%
datePickle(df)
# Out:
# Pickled

# %%
timestr = time.strftime("%Y%m%d-%H%M%S")

# %%
df.to_csv(f'{timestr}.csv')

# %% [markdown]
# # A good place to stop for the night!
# Next steps for Cutter:
# - [x] Create scheme for translations of bill type
# - [x] Add column to dataframe and translate
# - [ ] Figure out Hershey Text + AxiDraw bits
#
# Curser:
# - [ ] Turn sponsor list into set
# - [ ] Curse text (trivial)
# - [ ] Connect to thermal printer and print out
#
# Logic / triggers:
# - [ ] Clean up code
# - [ ] Figure out what is necessary to run when. For example, when the Google Sheet has a new row added, look at the state and re-download the master list to get the new info and append it to the df? Check the Google Sheets API to see if there's a function for that.

# %%
# Read in the latest pickle.
df = pd.read_pickle('20230327-024939-df.pickle')

# %%
df.head()
# Out:
# 0    State Abbreviation  Number  \
# 1   Alaska           AK    HB27
# 2   Alaska           AK    SB96
# 3   Alaska           AK   HB105
# 4  Arizona           AZ  SB1028
# 5  Arizona           AZ  SB1030
#
# 0                                           Summary  \
# 1         Designate Sex For School-sponsored Sports
# 2               Sex/reproduction Education; Schools
# 3               Sex/reproduction Education; Schools
# 4  Adult cabaret performances; prohibited locations
# 5        Sexually explicit performances; regulation
#
# 0                    Bill Type       Date                  Status  \
# 1             Trans Sports Ban  1/19/2023   REFERRED TO EDUCATION
# 2  Don't Say Gay/Forced Outing   3/8/2023   REFERRED TO JUDICIARY
# 3  Don't Say Gay/Forced Outing   3/8/2023   REFERRED TO EDUCATION
# 4                     Drag Ban  3/22/2023  House read second time
# 5                     Drag Ban  3/21/2023  House read second time
#
# 0 Erin Reed's State Risk                                       URL  \
# 1               Moderate    https://legiscan.com/AK/bill/HB27/2023
# 2               Moderate    https://legiscan.com/AK/bill/SB96/2023
# 3               Moderate   https://legiscan.com/AK/bill/HB105/2023
# 4                    Low  https://legiscan.com/AZ/bill/SB1028/2023
# 5                    Low  https://legiscan.com/AZ/bill/SB1030/2023
#
# 0      Sponsors                                         Bill Title
# 1  Thomas McKay  An Act relating to school athletics, recreatio...
# 2         Rules  An Act relating to parental rights in a child&...
# 3         Rules  An Act relating to parental rights in a child&...
# 4  Anthony Kern   Adult cabaret performances; prohibited locations
# 5  Anthony Kern         Sexually explicit performances; regulation

# %%
billtypeset = set(df['Bill Type'])

# %%
billtypeset
# Out:
# {'Allows Parents to change schools based on LGBTQ Curriculum',
#  'Anti-Boycotts Act',
#  'Anti-LGBTQ Resolution',
#  'Ban on Public Investment in ESG Funds',
#  'Bans trans people from working at shelters',
#  'Birth Certificate Change Ban',
#  'Book Ban',
#  'Conversion Therapy Legalization',
#  'DEI Prohibitation',
#  'Defamation Bill',
#  'Defining Trans People Out of the Law',
#  "Denial of GAC can't be considered Child Abuse",
#  'Documentation Change Ban',
#  "Don't Say Gay Expansion",
#  "Don't Say Gay/Forced Outing",
#  "Don't Say Trans",
#  'Drag Ban',
#  'Eliminates Human Rights Enforcement',
#  'Ends tax deductions for Gender Affirming Care',
#  'Forced Misgendering',
#  'Forced Outing by Schools',
#  'Gender Affirming Care Ban',
#  'Legal Discrimination In Education',
#  'Legal Discrimination in Healthcare',
#  'Legal Discrimination of LTGBTQ people',
#  'Legalizes Abduction of Trans Kids',
#  'Medicaid Ban',
#  'Military Service Ban',
#  'No Tax Breaks for Gender Affirming Care',
#  'Prison Placement',
#  'Prohibition of federal funds for gender inclusive language',
#  'Prohibits Gender Identity Instruction',
#  'Resolution for LGBTQ discrimination',
#  'Resolution for bathroom bans',
#  'Same-Sex Marriage Discrimination',
#  'Social Transition Ban',
#  'Tax Related',
#  'Trans Bathroom Ban',
#  'Trans Sports Ban',
#  'Trans sports Ban'}

# %%
billtypeset = list(billtypeset)

# %%
billtypeset.sort()

# %%
billintent = ["YOU DO NOT EXIST",
"WE WILL SILENCE YOUR ALLIES",
"YOU DO NOT EXIST",
"WE WILL EMPOWER YOUR ENEMIES",
"WE WILL CIRCUMSCRIBE THE SPACES YOU WALK IN",
"WE WILL DENY YOU YOUR NAME",
"YOU DO NOT EXIST",
"WE WILL TAKE YOUR MIND FROM YOU",
"WE WILL SILENCE YOUR ALLIES",
"WE WILL EMPOWER YOUR ENEMIES",
"YOUR EXISTENCE IS A PERVERSION",
"WE WILL TAKE YOUR BODY FROM YOU",
"THE NAME YOU CALL YOURSELF BY IS A LIE",
"NO ONE WILL SEE YOU FOR WHO YOU ARE",
"WE WILL EMPOWER YOUR ENEMIES",
"YOU DO NOT EXIST",
"YOUR PRESENCE IS A PERVERSION",
"WE WILL SILENCE YOUR ALLIES",
"WE WILL TAKE YOUR BODY FROM YOU",
"ALL THOSE AROUND YOU WILL JOIN HANDS TO MOCK YOU",
"WE WILL DENY YOU YOUR NAME",
"WE WILL TAKE YOUR BODY FROM YOU",
"WE WILL EMPOWER YOUR ENEMIES",
"WE WILL TAKE YOUR BODY FROM YOU",
"WE WILL EMPOWER YOUR ENEMIES",
"WE WILL SEPARATE YOU FROM THOSE YOU LOVE",
"WE WILL TAKE YOUR BODY FROM YOU",
"WE WILL CIRCUMSCRIBE THE SPACES YOU WALK IN",
"WE WILL TAKE YOUR BODY FROM YOU",
"YOU WILL LIVE IN FEAR OF ALL",
"NO ONE WILL SEE YOU FOR WHO YOU ARE",
"WE WILL SHUT YOU OUT OF PUBLIC LIFE",
"YOUR EXISTENCE IS A PERVERSION",
"WE WILL NARROW YOUR WORLD",
"WE WILL EMPOWER YOUR ENEMIES",
"NO ONE WILL SEE YOU FOR WHO YOU ARE",
"WE WILL SILENCE YOUR ALLIES",
"WE WILL CIRCUMSCRIBE THE SPACES YOU WALK IN",
"WE WILL SHUT YOU OUT OF PUBLIC LIFE",
"WE WILL SHUT YOU OUT OF PUBLIC LIFE"]

# %%
bill_type_intent_dict = dict(zip(billtypeset,billintent))

# %%
bill_type_intent_dict
# Out:
# {'Allows Parents to change schools based on LGBTQ Curriculum': 'YOU DO NOT EXIST',
#  'Anti-Boycotts Act': 'WE WILL SILENCE YOUR ALLIES',
#  'Anti-LGBTQ Resolution': 'YOU DO NOT EXIST',
#  'Ban on Public Investment in ESG Funds': 'WE WILL EMPOWER YOUR ENEMIES',
#  'Bans trans people from working at shelters': 'WE WILL CIRCUMSCRIBE THE SPACES YOU WALK IN',
#  'Birth Certificate Change Ban': 'WE WILL DENY YOU YOUR NAME',
#  'Book Ban': 'YOU DO NOT EXIST',
#  'Conversion Therapy Legalization': 'WE WILL TAKE YOUR MIND FROM YOU',
#  'DEI Prohibitation': 'WE WILL SILENCE YOUR ALLIES',
#  'Defamation Bill': 'WE WILL EMPOWER YOUR ENEMIES',
#  'Defining Trans People Out of the Law': 'YOUR EXISTENCE IS A PERVERSION',
#  "Denial of GAC can't be considered Child Abuse": 'WE WILL TAKE YOUR BODY FROM YOU',
#  'Documentation Change Ban': 'THE NAME YOU CALL YOURSELF BY IS A LIE',
#  "Don't Say Gay Expansion": 'NO ONE WILL SEE YOU FOR WHO YOU ARE',
#  "Don't Say Gay/Forced Outing": 'WE WILL EMPOWER YOUR ENEMIES',
#  "Don't Say Trans": 'YOU DO NOT EXIST',
#  'Drag Ban': 'YOUR PRESENCE IS A PERVERSION',
#  'Eliminates Human Rights Enforcement': 'WE WILL SILENCE YOUR ALLIES',
#  'Ends tax deductions for Gender Affirming Care': 'WE WILL TAKE YOUR BODY FROM YOU',
#  'Forced Misgendering': 'ALL THOSE AROUND YOU WILL JOIN HANDS TO MOCK YOU',
#  'Forced Outing by Schools': 'WE WILL DENY YOU YOUR NAME',
#  'Gender Affirming Care Ban': 'WE WILL TAKE YOUR BODY FROM YOU',
#  'Legal Discrimination In Education': 'WE WILL EMPOWER YOUR ENEMIES',
#  'Legal Discrimination in Healthcare': 'WE WILL TAKE YOUR BODY FROM YOU',
#  'Legal Discrimination of LTGBTQ people': 'WE WILL EMPOWER YOUR ENEMIES',
#  'Legalizes Abduction of Trans Kids': 'WE WILL SEPARATE YOU FROM THOSE YOU LOVE',
#  'Medicaid Ban': 'WE WILL TAKE YOUR BODY FROM YOU',
#  'Military Service Ban': 'WE WILL CIRCUMSCRIBE THE SPACES YOU WALK IN',
#  'No Tax Breaks for Gender Affirming Care': 'WE WILL TAKE YOUR BODY FROM YOU',
#  'Prison Placement': 'YOU WILL LIVE IN FEAR OF ALL',
#  'Prohibition of federal funds for gender inclusive language': 'NO ONE WILL SEE YOU FOR WHO YOU ARE',
#  'Prohibits Gender Identity Instruction': 'WE WILL SHUT YOU OUT OF PUBLIC LIFE',
#  'Resolution for LGBTQ discrimination': 'YOUR EXISTENCE IS A PERVERSION',
#  'Resolution for bathroom bans': 'WE WILL NARROW YOUR WORLD',
#  'Same-Sex Marriage Discrimination': 'WE WILL EMPOWER YOUR ENEMIES',
#  'Social Transition Ban': 'NO ONE WILL SEE YOU FOR WHO YOU ARE',
#  'Tax Related': 'WE WILL SILENCE YOUR ALLIES',
#  'Trans Bathroom Ban': 'WE WILL CIRCUMSCRIBE THE SPACES YOU WALK IN',
#  'Trans Sports Ban': 'WE WILL SHUT YOU OUT OF PUBLIC LIFE',
#  'Trans sports Ban': 'WE WILL SHUT YOU OUT OF PUBLIC LIFE'}

# %%
# create json object from dictionary
json = json.dumps(bill_type_intent_dict)

# open file for writing, "w" 
f = open("bill_type_intent_dict.json","w")

# write json object to file
f.write(json)

# close file
f.close()

# %%
df2 = df

# %%
df['Bill Intent'] = df['Bill Type'].map(bill_type_intent_dict)

# %%
df.head()
# Out:
# 0    State Abbreviation  Number  \
# 1   Alaska           AK    HB27
# 2   Alaska           AK    SB96
# 3   Alaska           AK   HB105
# 4  Arizona           AZ  SB1028
# 5  Arizona           AZ  SB1030
#
# 0                                           Summary  \
# 1         Designate Sex For School-sponsored Sports
# 2               Sex/reproduction Education; Schools
# 3               Sex/reproduction Education; Schools
# 4  Adult cabaret performances; prohibited locations
# 5        Sexually explicit performances; regulation
#
# 0                    Bill Type       Date                  Status  \
# 1             Trans Sports Ban  1/19/2023   REFERRED TO EDUCATION
# 2  Don't Say Gay/Forced Outing   3/8/2023   REFERRED TO JUDICIARY
# 3  Don't Say Gay/Forced Outing   3/8/2023   REFERRED TO EDUCATION
# 4                     Drag Ban  3/22/2023  House read second time
# 5                     Drag Ban  3/21/2023  House read second time
#
# 0 Erin Reed's State Risk                                       URL  \
# 1               Moderate    https://legiscan.com/AK/bill/HB27/2023
# 2               Moderate    https://legiscan.com/AK/bill/SB96/2023
# 3               Moderate   https://legiscan.com/AK/bill/HB105/2023
# 4                    Low  https://legiscan.com/AZ/bill/SB1028/2023
# 5                    Low  https://legiscan.com/AZ/bill/SB1030/2023
#
# 0      Sponsors                                         Bill Title  \
# 1  Thomas McKay  An Act relating to school athletics, recreatio...
# 2         Rules  An Act relating to parental rights in a child&...
# 3         Rules  An Act relating to parental rights in a child&...
# 4  Anthony Kern   Adult cabaret performances; prohibited locations
# 5  Anthony Kern         Sexually explicit performances; regulation
#
# 0                          Bill Intent
# 1  WE WILL SHUT YOU OUT OF PUBLIC LIFE
# 2         WE WILL EMPOWER YOUR ENEMIES
# 3         WE WILL EMPOWER YOUR ENEMIES
# 4        YOUR PRESENCE IS A PERVERSION
# 5        YOUR PRESENCE IS A PERVERSION

# %%
datePickle(df)
# Out:
# Pickled

# %%
df = pd.read_pickle('20230327-231505-df.pickle')

# %%
df.head()
# Out:
# 0    State Abbreviation  Number  \
# 1   Alaska           AK    HB27
# 2   Alaska           AK    SB96
# 3   Alaska           AK   HB105
# 4  Arizona           AZ  SB1028
# 5  Arizona           AZ  SB1030
#
# 0                                           Summary  \
# 1         Designate Sex For School-sponsored Sports
# 2               Sex/reproduction Education; Schools
# 3               Sex/reproduction Education; Schools
# 4  Adult cabaret performances; prohibited locations
# 5        Sexually explicit performances; regulation
#
# 0                    Bill Type       Date                  Status  \
# 1             Trans Sports Ban  1/19/2023   REFERRED TO EDUCATION
# 2  Don't Say Gay/Forced Outing   3/8/2023   REFERRED TO JUDICIARY
# 3  Don't Say Gay/Forced Outing   3/8/2023   REFERRED TO EDUCATION
# 4                     Drag Ban  3/22/2023  House read second time
# 5                     Drag Ban  3/21/2023  House read second time
#
# 0 Erin Reed's State Risk                                       URL  \
# 1               Moderate    https://legiscan.com/AK/bill/HB27/2023
# 2               Moderate    https://legiscan.com/AK/bill/SB96/2023
# 3               Moderate   https://legiscan.com/AK/bill/HB105/2023
# 4                    Low  https://legiscan.com/AZ/bill/SB1028/2023
# 5                    Low  https://legiscan.com/AZ/bill/SB1030/2023
#
# 0      Sponsors                                         Bill Title  \
# 1  Thomas McKay  An Act relating to school athletics, recreatio...
# 2         Rules  An Act relating to parental rights in a child&...
# 3         Rules  An Act relating to parental rights in a child&...
# 4  Anthony Kern   Adult cabaret performances; prohibited locations
# 5  Anthony Kern         Sexually explicit performances; regulation
#
# 0                          Bill Intent
# 1  WE WILL SHUT YOU OUT OF PUBLIC LIFE
# 2         WE WILL EMPOWER YOUR ENEMIES
# 3         WE WILL EMPOWER YOUR ENEMIES
# 4        YOUR PRESENCE IS A PERVERSION
# 5        YOUR PRESENCE IS A PERVERSION

# %%
df.iloc[0]['Bill Title']
# Out:
# 'An Act relating to school athletics, recreation, athletic teams, and sports.'

# %%
df.iloc[4]['Bill Title']
# Out:
# 'Sexually explicit performances; regulation'

# %%
# For Curser, I'll need to turn everyone from the Sponsors column into a set, splitting with "," (and maybe whitespace?) and omit Rules
# I should keep track of who the last person cursed (printed) was, so they go in order
