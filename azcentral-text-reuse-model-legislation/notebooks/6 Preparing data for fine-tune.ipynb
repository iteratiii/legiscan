# %%
import pandas as pd

# %%
df = pd.read_csv('20230408-oxforded2.csv')

# %%
df.head()
# Out:
#      State Abbreviation  Number  \
# 0   Alaska           AK   HB105
# 1   Alaska           AK    HB27
# 2   Alaska           AK    SB96
# 3  Arizona           AZ  HB2312
# 4  Arizona           AZ  HB2711
#
#                                              Summary  \
# 0                Sex/reproduction Education; Schools
# 1          Designate Sex For School-sponsored Sports
# 2                Sex/reproduction Education; Schools
# 3        Women's shelters; male employees; liability
# 4  Student information; parental notification; re...
#
#                                     Bill Type       Date  \
# 0                 Don't Say Gay/Forced Outing   3/8/2023
# 1                            Trans Sports Ban  1/19/2023
# 2                 Don't Say Gay/Forced Outing   3/8/2023
# 3  Bans trans people from working at shelters   3/7/2023
# 4                    Forced Outing by Schools   2/8/2023
#
#                     Status Erin Reed's State Risk  \
# ...

# %%
df2 = df[['State', 'Bill Title']].copy()

# %%
df2.head()
# Out:
#      State                                         Bill Title
# 0   Alaska  An Act relating to parental rights in a child'...
# 1   Alaska  An Act relating to school athletics, recreatio...
# 2   Alaska  An Act relating to parental rights in a child'...
# 3  Arizona        Women's shelters; male employees; liability
# 4  Arizona  Student information; parental notification; re...

# %%
df2 = df2.rename(columns={"State": "prompt", "Bill Title": "response"}, errors="raise")

# %%
df2.to_csv("billtitles.csv", index=False)
