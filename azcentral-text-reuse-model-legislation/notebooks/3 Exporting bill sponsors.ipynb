# %% [markdown]
# # Get text from the last pickle to convert

# %%
import pandas as pd

# %%
# My pickling function.
def datePickle(df):
    timestr = time.strftime("%Y%m%d-%H%M%S")
    df.to_pickle(f'{timestr}-df.pickle')
    print("Pickled")
    
# To summon pickle, use:
# df = pd.read_pickle('my_df.pickle')

# %%
df = pd.read_pickle('20230327-235802-df.pickle')
df.head()
# Out:
# 0    State Abbreviation  Number  \
# 1   Alaska           AK    HB27
# 2   Alaska           AK    SB96
# 3   Alaska           AK   HB105
# 4  Arizona           AZ  SB1028
# 5  Arizona           AZ  SB1030
#
# 0                                           Summary  \
# 1         Designate Sex For School-sponsored Sports
# 2               Sex/reproduction Education; Schools
# 3               Sex/reproduction Education; Schools
# 4  Adult cabaret performances; prohibited locations
# 5        Sexually explicit performances; regulation
#
# 0                    Bill Type       Date                  Status  \
# 1             Trans Sports Ban  1/19/2023   REFERRED TO EDUCATION
# 2  Don't Say Gay/Forced Outing   3/8/2023   REFERRED TO JUDICIARY
# 3  Don't Say Gay/Forced Outing   3/8/2023   REFERRED TO EDUCATION
# 4                     Drag Ban  3/22/2023  House read second time
# 5                     Drag Ban  3/21/2023  House read second time
#
# ...

# %%
sponsors = set(df['Sponsors'])

# %%
sponsors
# Out:
# {'Aaron Aylward, Tom Pischke, Julie Frye-Mueller, Phil Jensen, Elizabeth May, Carl Perry, John Sjaarda',
#  'Abby Angelos, John Bear, Donald Burkhart, Jeremy Haroldson, Scott Heiner, Mark Jennings, Jared Olsen, Rachel Rodriguez-Williams, Jeanette Ward, Dennis Biteman, Ogden Driskill, Lynn Hutchings, Cheri Steinmetz',
#  'Al Novstrup, Bethany Soye, Julie Auch, Aaron Aylward, Jessica Bahmuller, Jim Bolin, Byron Callies, Fred Deutsch, Julie Frye-Mueller, Randy Gross, Jon Hansen, Brent Hoffman, Kevin Jensen, Phil Jensen, Chris Karr, Ben Krohmer, David Kull, Trish Ladner, Karla Lems, Elizabeth May, John Mills, Scott Moore, Tina Mulally, Scott Odenbach, Ernie Otten, Marty Overweg, Carl Perry, Sue Lucas-Peterson, Neal Pinnow, Tom Pischke, Tony Randolph, Rebecca Reimer, Brandei Schaefbauer, John Sjaarda, Jim Stalzer, John Wiik, Larry Zikmund',
#  'Alex Andrade, Mike Beltran, Dean Black',
#  'Alexander Kolodin, Joseph Chaplik',
#  'Amanda Chase',
# ...

# %%
sponsors = list(sponsors)

# %%
type(sponsors[0])
# Out:
# str

# %%
flatlist = []
for stringlist in sponsors:
    sublist = stringlist.split(", ")
    print(sublist)
    for item in sublist:
        flatlist.append(item)
# Out:
# ['Mark Pody']
# ['Jack Johnson', 'Rusty Crowe', 'Janince Bowling', 'Ferrell Haile', 'Joseph Hensley', 'Ken Yager', 'Paul Bailey', 'Edward Jackson', 'John Stevens', 'Frank Niceley', 'Shane Reeves', 'Brent Taylor', 'Mark Pody', 'Paul Rose', 'Bo Watson', 'Kerry Roberts']
# ['Savannah Maddox', 'Felicia Rabourn', 'Ryan Dotson']
# ['Bob Hall', 'Tan Parker', 'Charles Perry']
# ['Joshua Kimbrell', 'Brian Adams']
# ['Scott Odenbach', 'Tom Pischke', 'Julie Auch', 'Aaron Aylward', 'Arch Beal', 'Fred Deutsch', 'Julie Frye-Mueller', 'Randy Gross', 'Jon Hansen', 'Brent Hoffman', 'Kevin Jensen', 'Phil Jensen', 'Chris Karr', 'Ben Krohmer', 'Karla Lems', 'Elizabeth May', 'Jim Mehlhaff', 'John Mills', 'Scott Moore', 'Tina Mulally', 'Marty Overweg', 'Carl Perry', 'Tony Randolph', 'John Sjaarda', 'Bethany Soye', 'Jim Stalzer']
# ['Mark Higley', 'Anne Donahue', 'Arthur Peterson', 'Terri Williams', 'Charles Wilson']
# ['Andrew Chesney']
# ['Valoree Swanson']
# ...

# %%
flatlist = list(set(flatlist))

# %%
flatlist
# Out:
# ['Lynn Hutchings',
#  'Mark Pody',
#  'Shane Baker',
#  'Justine Wadsack',
#  'Ogden Driskill',
#  'Larry Luick',
#  'Steve Carra',
#  'Ed Thompson',
#  'Ralph Massullo',
#  'Bill Wiley',
#  'Stan Kitzman',
#  'Gary Stubblefield',
#  'Thomas Huff',
#  'Art Robinson',
#  'Mike Carey',
#  'Melissa Oremus',
#  'Monica De La Cruz',
#  'Steven Doan',
#  'Todd Longanacre',
#  'Stephanie Bice',
#  'Mike Wilson',
#  'Cathy McMorris Rodgers',
#  'Danny Carroll',
#  'Ann Wagner',
#  'Anna Novak',
#  'Martin Carbaugh',
#  'Bob Paulson',
#  'Nathaniel Moran',
#  'Pete Stauber',
#  'Aaron Freeman',
#  'Jay Taylor',
#  'Scott DeLano',
#  'Brian Adams',
#  'Drew Springer',
#  'Andrew Chesney',
#  'Lance Clow',
#  'Ben Adams',
#  'Rick Girdler',
#  'Frederick Frazier',
#  'Valoree Swanson',
#  'Frank Niceley',
#  'Tony Randolph',
#  'Brian Mulder',
#  'Chris Brown',
#  'Julia Letlow',
#  'Lindsey Tichenor',
#  'Gary Click',
#  'Missy Irvin',
#  'Kathleen Kauth',
#  'Dwight Loftis',
# ...

# %%
flatlist.sort()

# %%
flatlist
# Out:
# ['Aaron Aylward',
#  'Aaron Bean',
#  'Aaron Freeman',
#  'Aaron Pilkington',
#  'Abby Angelos',
#  'Adam Anderson',
#  'Adam Bird',
#  'Adam Holmes',
#  'Adam Mathews',
#  'Adam Morgan',
#  'Adrienne Southworth',
#  'Al Novstrup',
#  'Alan Clark',
#  'Alan Martinez',
#  'Alan Morgan',
#  'Albert Sommers',
#  'Alessandro Cutrona',
#  'Alexander Kolodin',
#  'Alexander Mooney',
#  'Amy Neighbors',
#  'Andrea Reeb',
#  'Andrew Chesney',
#  'Andrew Farmer',
#  'Andrew Marschall',
#  'Andrew Murr',
#  'Andrew Ogles',
#  'Andy Biggs',
#  'Angela Burks Hill',
#  'Angela King',
#  'Angela Paxton',
#  'Angela Rigas',
#  'Angelia Orr',
#  'Anita Hall',
#  'Ann Kelley',
#  'Ann Wagner',
#  'Anna Luna',
#  'Anna Novak',
#  'Anna Scharf',
#  'Anne Donahue',
#  'Anne Osmundson',
#  'Anne Thayer',
#  'Annette Sweeney',
#  'Anthony Bouchard',
#  "Anthony D'Esposito",
#  'Anthony Kern',
#  'April Cromer',
#  'Arch Beal',
#  'Art Robinson',
#  'Arthur Peterson',
#  'Ashley Hinson',
# ...

# %%
import csv
with open('billsponsors-20230330.csv', 'w') as f:
    write = csv.writer(f)
    for sponsor in flatlist:  
        write.writerow([sponsor])

# %%
# Just make sure to remove all the Committees, Education, etc.
# ['Aaron Aylward',
#  'Aaron Bean',
#  'Aaron Freeman',
#  'Aaron Pilkington',
#  'Abby Angelos',
#  'Adam Anderson',
#  'Adam Bird',
#  'Adam Holmes',
#  'Adam Mathews',
#  'Adam Morgan',
#  'Adrienne Southworth',
#  'Al Novstrup',
#  'Alan Clark',
#  'Alan Martinez',
#  'Alan Morgan',
#  'Albert Sommers',
#  'Alessandro Cutrona',
#  'Alexander Kolodin',
#  'Alexander Mooney',
#  'Amy Neighbors',
#  'Andrea Reeb',
#  'Andrew Chesney',
#  'Andrew Farmer',
#  'Andrew Marschall',
#  'Andrew Murr',
#  'Andrew Ogles',
#  'Andy Biggs',
#  'Angela Burks Hill',
#  'Angela King',
#  'Angela Paxton',
#  'Angela Rigas',
#  'Angelia Orr',
#  'Anita Hall',
#  'Ann Kelley',
#  'Ann Wagner',
#  'Anna Luna',
#  'Anna Novak',
#  'Anna Scharf',
#  'Anne Donahue',
#  'Anne Osmundson',
#  'Anne Thayer',
#  'Annette Sweeney',
#  'Anthony Bouchard',
#  "Anthony D'Esposito",
#  'Anthony Kern',
#  'April Cromer',
#  'Arch Beal',
#  'Art Robinson',
#  'Arthur Peterson',
#  'Ashley Hinson',
#  'Ashley Trantham',
#  'August Pfluger',
#  'Austen Schauer',
#  'Austin Mccollum',
#  'Austin Scott',
#  'Barry Crago',
#  'Barry Moore',
#  'Bart Hester',
#  'Bart Williams',
#  'Ben Adams',
#  'Ben Bumgarner',
#  'Ben Cline',
#  'Ben Gilmore',
#  'Ben Hornok',
#  'Ben Koppelman',
#  'Ben Krohmer',
#  'Benjamin Suber',
#  'Bernard Willis',
#  'Bernie Perryman',
#  'Bernie Satrom',
#  'Beth Lear',
#  'Bethanne McCarthy Patrick',
#  'Bethany Soye',
#  'Bill Dean',
#  'Bill Huizenga',
#  'Bill Kinkade',
#  'Bill Posey',
#  'Bill Tveit',
#  'Bill Wiley',
#  'Billy Wesley',
#  'Blake Doriot',
#  'Blake Johnson',
#  'Bo Watson',
#  'Bob Hall',
#  'Bob Paulson',
#  'Bob Phalen',
#  'Bobby Cox',
#  'Bobby Kaufmann',
#  'Bobby Levy',
#  'Bobby McCool',
#  'Boomer Wright',
#  'Brad Buckley',
#  'Brad Finstad',
#  'Brad Wenstrup',
#  'Brad Zaun',
#  'Brady Williamson',
#  'Brandei Schaefbauer',
#  'Brandon Achor',
#  'Brandon Mitchell',
#  'Brandon Prichard',
#  'Brandon Reed',
#  'Brandon Storm',
#  'Brandon Williams',
#  'Braxton Mitchell',
#  'Breanne Davis',
#  'Brent Crane',
#  'Brent Hoffman',
#  'Brent Taylor',
#  'Brenton Awa',
#  'Brett Guthrie',
#  'Brian Adams',
#  'Brian Babin',
#  'Brian Birdwell',
#  'Brian Evans',
#  'Brian Harrison',
#  'Brian Lampton',
#  'Brian Lawson',
#  'Brian Mulder',
#  'Brian Stewart',
#  'Briscoe Cain',
#  'Brit McKenzie',
#  'Brooke Boden',
#  'Brooks Landgraf',
#  'Bruce Cozart',
#  'Bruce Westerman',
#  'Bryan Hughes',
#  'Bryan Slaton',
#  'Bryan Steil',
#  'Bryce Reeves',
#  'Burgess Owens',
#  'Caleb Hanna',
#  'Cameron Cooper',
#  'Cameron Sexton',
#  'Candy Massaroni',
#  'Candy Noble',
#  'Carden Summers',
#  'Carl Glimm',
#  'Carl Perry',
#  'Carl Tepper',
#  'Carlos Gimenez',
#  'Carlton Wing',
#  'Caroline Harris',
#  'Carrie Isaac',
#  'Cathrynn Brown',
#  'Cathy McMorris Rodgers',
#  'Cecil Bell',
#  'Chad Puryear',
#  'Charlene Fite',
#  'Charles Anderson',
#  'Charles Creighton',
#  'Charles Cunningham',
#  'Charles Fleischmann',
#  'Charles Horst',
#  'Charles Perry',
#  'Charles Schwertner',
#  'Charles Wilson',
#  'Charles Younger',
#  'Charley Thomson',
#  'Charlie Geren',
#  'Charlie Shepherd',
#  'Cheri Steinmetz',
#  'Cherielynn Westrich',
#  'Chris Brown',
#  'Chris Caughman',
#  'Chris Cournoyer',
#  'Chris Freeland',
#  'Chris Fugate',
#  'Chris Jeter',
#  'Chris Karr',
#  'Chris McDaniel',
#  'Chris Phillips',
#  'Chris Pritt',
#  'Chris Runion',
#  'Chris Todd',
#  'Christine Goodwin',
#  'Christopher Smith',
#  'Christopher Wooten',
#  'Chuck Edwards',
#  'Cindy Crawford',
#  'Cindy Golding',
#  'Cindy Hyde-Smith',
#  'Claire Cory',
#  'Clarence Styvar',
#  'Claudia Tenney',
#  'Clay Higgins',
#  'Clay Yarborough',
#  'Clint Dixon',
#  'Clint Penzo',
#  'Cody Harris',
#  'Cody Vasut',
#  'Cole Conley',
#  'Cole Hefner',
#  'Colton Moore',
#  'Cory McGarr',
#  'Craig Goldman',
#  'Craig Johnson',
#  'Curtis Bramble',
#  'Cyndi Buchheit-Courtway',
#  'Cyndy Jacobsen',
#  'D. J. Swearingen',
#  'DJ Johnson',
#  'Dale DeVon',
#  'Dale Hawkins',
#  'Dallas Harris',
#  'Dan Crenshaw',
#  'Dan Dockstader',
#  'Dan Eubanks',
#  'Dan Laursen',
#  'Dan Meuser',
#  'Dan Newhouse',
#  'Dan Ruby',
#  'Dan Sullivan',
#  'Daniel Elliott',
#  'Daniel Fister',
#  'Daniel Foreman',
#  'Daniel Gibson',
#  'Daniel Singh',
#  'Daniel Webster',
#  'Danny Bentley',
#  'Danny Carroll',
#  'Danny Verdin',
#  'Danny Watson',
#  'Danny Williams',
#  'Darin LaHood',
#  'Darrell Kick',
#  'Darren Thorne',
#  'Dave Deyoe',
#  'Dave LaRock',
#  'Dave Rowley',
#  'Dave Testerman',
#  'David Bullard',
#  'David Clemens',
#  'David Cook',
#  'David Friess',
#  'David Hale',
#  'David Kustoff',
#  "David O'Neal",
#  'David Ray',
#  'David Rouzer',
#  'David Rust',
#  'David Smith',
#  'David Spiller',
#  'David Valadao',
#  'David Vaughan',
#  'David Wallace',
#  'Dean Black',
#  'Dean Fisher',
#  'Deanna Frazier Gordon',
#  'Debbie Lesko',
#  'Delia Haak',
#  'Dennis Biteman',
#  'Dennis DeBar',
#  'Dennis Guth',
#  'Dennis Linthicum',
#  'Dennis Paul',
#  'Derek Merrin',
#  'Derek Wulf',
#  'Derrick Van Orden',
#  'Devon Wood',
#  'Dewayne Burns',
#  'Diana Harshbarger',
#  'Dick Anderson',
#  'Dick Stein',
#  'Dina Neal',
#  'Donald McCabe',
#  'Donna Campbell',
#  'Doug Bankson',
#  'Doug Gilliam',
#  'Doug LaMalfa',
#  'Doug Lamborn',
#  'Douglas Broxson',
#  'Drew Ferguson',
#  'Drew Springer',
#  'Dusty Johnson',
#  'Dwight Loftis',
#  'Earl Carter',
#  'Ed  Diehl',
#  'Ed Setzler',
#  'Ed Thompson',
#  'Eddie Andrews',
#  'Edgar Flores',
#  'Edward Jackson',
#  'Elaine Morgan',
#  'Elaine Price',
#  'Elias Coop-Gonzalez',
#  'Elise Stefanik',
#  'Elizabeth May',
#  'Ellen Troxclair',
#  'Emily Callaway',
#  'Emily McIntire',
#  'Eric Crawford',
#  'Erik Peterson',
#  'Erin Grall',
#  'Erin Houchin',
#  'Ernest Gonzales',
#  'Felicia Rabourn',
#  'Ferrell Haile',
#  'Frances Cavenaugh',
#  'Frank Niceley',
#  'Fred Deutsch',
#  'Frederick Frazier',
#  'Garland Barr',
#  'Garret Graves',
#  'Gary Boswell',
#  'Gary Byrne',
#  'Gary Click',
#  'Gary Gates',
#  'Gary Howell',
#  'Gary Stubblefield',
#  'Gary Vandeaver',
#  'Geanie Morrison',
#  'Gene Newman',
#  'George Burns',
#  'George Campsen',
#  'George Santos',
#  'George Wise',
#  'Gerard Scharfenberger',
#  'Gex Williams',
#  'Gino Bulso',
#  'Giovanni Capriglione',
#  'Glenn Grothman',
#  'Glenn Rogers',
#  'Glenn Thompson',
#  'Glenneda Zuiderveld',
#  'Grant Hodges',
#  'Greg Bonnen',
#  'Greg Dolezal',
#  'Greg Murphy',
#  'Greg Steube',
#  'Gregory McGuckin',
#  'Guy Reschenthaler',
#  'Hardy Billington',
#  'Harlan Breaux',
#  'Harlan Vincent',
#  'Harriet Hageman',
#  'Harry Niska',
#  'Heather Crawford',
#  'Heather Hora',
#  'Heather Scott',
#  'Helena Hayes',
#  'Henry Dillon',
#  'Henry Stone',
#  'Howard Beaty',
#  'Hugh Shine',
#  'J.D. Vance',
#  'J.M. Lozano',
#  'Jacey Jetton',
#  'Jack Bergman',
#  'Jack Fortner',
#  'Jack Johnson',
#  'Jacob Bossman',
#  'Jacob Laturner',
#  'Jacyn Gallagher',
#  'Jake Ellzey',
#  'Jake Hoffman',
#  'Jake Teshka',
#  'James Baird',
#  'James Burns',
#  'James Comer',
#  'James DeSana',
#  'James Frank',
#  'James Hieb',
#  'James Hoops',
#  'James Kasper',
#  'James Lankford',
#  'James Ohrenschall',
#  'James Risch',
#  'James Tipton',
#  'James Townsend',
#  'Jami Cate',
#  'Jamie Burger',
#  'Jane English',
#  'Janie Lopez',
#  'Janince Bowling',
#  'Janne Myrdal',
#  'Jared Patterson',
#  'Jaron Crane',
#  'Jason Barrett',
#  'Jason Petrie',
#  'Jason Smith',
#  'Jay Dean',
#  'Jay Edwards',
#  'Jay Kilmartin',
#  'Jay Taylor',
#  'Jean Schmidt',
#  'Jeanette Ward',
#  'Jeff Cornilles',
#  'Jeff Duncan',
#  'Jeff LaRe',
#  'Jeff Leach',
#  'Jeff Raatz',
#  'Jeff Reichman',
#  'Jeff Shipley',
#  'Jeff Tate',
#  'Jeff Taylor',
#  'Jeff Van Drew',
#  'Jeff Wardlaw',
#  'Jena Powell',
#  'Jenifer Jones',
#  'Jennifer Branning',
#  'Jennifer Gross',
#  'Jennifer Henson Decker',
#  'Jenniffer Gonzalez-Colon',
#  'Jenny Graham',
#  'Jeremiah Moore',
#  'Jeremy England',
#  'Jeremy Haroldson',
#  'Jerry Carl',
#  'Jesse Green',
#  'Jessica Baker',
#  'Jill Carter',
#  'Jill Ford',
#  'Jim Banks',
#  'Jim Dotson',
#  'Jim Gooch',
#  'Jim Mehlhaff',
#  'Jim Olsen',
#  'Jim Petty',
#  'Jim Stalzer',
#  'Jim Thomas',
#  'Jim Walsh',
#  'Joan Huffman',
#  'Joanna King',
#  'Jody Arrington',
#  'Jody Barrett',
#  'Joe Alfieri',
#  'Joe White',
#  'Joe Wilson',
#  'Joel Carter',
#  'Joel Fry',
#  'Joel McEntire',
#  'Joey Fillingane',
#  'John Albers',
#  'John Block',
#  'John Carr',
#  'John Carter',
#  'John Catalano',
#  'John Cosgrove',
#  'John Curtis',
#  'John Fuller',
#  'John Hodgson',
#  'John Joyce',
#  'John Kolb',
#  'John Kuempel',
#  'John Lujan',
#  'John Maddox',
#  'John McGuire',
#  'John Mccravy',
#  'John Mills',
#  'John Moolenaar',
#  'John Payton',
#  'John Raney',
#  'John Rose',
#  'John Rutherford',
#  'John Schickel',
#  'John Sjaarda',
#  'John Smithee',
#  'John Stevens',
#  'John Winter',
#  'Johnnie Turner',
#  'Johnny Rye',
#  'Jon Eubanks',
#  'Jon Hansen',
#  'Jon Milligan',
#  'Jonathan Dismang',
#  'Jordan Pace',
#  'Jordan Redman',
#  'Joseph Chaplik',
#  'Joseph Fox',
#  'Joseph Hensley',
#  'Joseph Seymour',
#  'Josh Calloway',
#  'Josh Williams',
#  'Joshua Bryant',
#  'Joshua Kimbrell',
#  'Joshua Meggers',
#  'Juan Ciscomani',
#  'Judiciary',
#  'Judy Estenson',
#  'Julia Letlow',
#  'Julian Garrett',
#  'Julianne Young',
#  'Julie Auch',
#  'Julie Daniels',
#  'Julie Frye-Mueller',
#  'Julie Pazina',
#  'Justin Boyd',
#  'Justin Gonzales',
#  'Justin Heap',
#  'Justin Holland',
#  'Justine Wadsack',
#  'Karen Karls',
#  'Karen Rohr',
#  'Karilyn Brown',
#  'Karla Lems',
#  'Kat Cammack',
#  'Kathleen Kauth',
#  'Kathy Chism',
#  'Kathy Frelich',
#  'Kathy Landing',
#  'Katy Hall',
#  'Keith Bell',
#  'Keith Boehm',
#  'Keith Brooks',
#  'Keith Perry',
#  'Keith Self',
#  'Kelly Hancock',
#  'Ken Buck',
#  'Ken Calvert',
#  'Ken King',
#  'Ken Pendergraft',
#  'Ken Rozenboom',
#  'Ken Upchurch',
#  'Ken Yager',
#  'Kendon Underwood',
#  'Kenny Wroten',
#  'Kerry Roberts',
#  'Kevin Alons',
#  'Kevin Andrus',
#  'Kevin Blackwell',
#  'Kevin Hern',
#  'Kevin Jackson',
#  'Kevin Jensen',
#  'Kevin Mannix',
#  'Kevin McDugle',
#  'Kevin Miller',
#  'Kevin Sparks',
#  'Kevin West',
#  'Kim Hammer',
#  'Kim King',
#  'Kim Thatcher',
#  'Kimberly Wallan',
#  'Kip Capley',
#  'Kris Jordan',
#  'Kristin Robbins',
#  'Kronda Thimesch',
#  'Kyle Kacal',
#  'Lacey Hull',
#  'Lance Clow',
#  'Lance Gooden',
#  'Lane Allred',
#  'Larry Bellew',
#  'Larry Bucshon',
#  'Larry Hicks',
#  'Larry Kump',
#  'Larry Luick',
#  'Laurel Lee',
#  'Lauren Boebert',
#  'Lawrence Grooms',
#  'Lawrence Klemin',
#  'Lee Anderson',
#  'Lee Johnson',
#  'Lily Morgan',
#  'Lindsay Patterson',
#  'Lindsey Graham',
#  'Lindsey Tichenor',
#  'Lisa McClain',
#  'Lisa Meier',
#  'Lloyd Smucker',
#  'Lois Kolkhorst',
#  'Lori Chavez-DeRemer',
#  'Lori VanWinkle',
#  'Luke Meerman',
#  'Lydia Chassaniol',
#  'Lynn Evans',
#  'Lynn Findley',
#  'Lynn Hutchings',
#  'Lynn Stucky',
#  'Mano DeAyala',
#  'Marco Rubio',
#  'Marcus Molinaro',
#  'Marcus Richmond',
#  'Marianne Proctor',
#  'Mariannette Miller-Meeks',
#  'Marie March',
#  'Marilyn John',
#  'Mario Diaz-Balart',
#  'Marjorie Greene',
#  'Mark Amodei',
#  'Mark Dorazio',
#  'Mark Green',
#  'Mark Hart',
#  'Mark Higley',
#  'Mark Jennings',
#  'Mark Johnson',
#  'Mark Lepak',
#  'Mark Lofgren',
#  'Mark Maynard',
#  'Mark McBride',
#  'Mark Peake',
#  'Mark Pody',
#  'Mark Ross',
#  'Mark Steffen',
#  'Mark Tullos',
#  'Mark Willis',
#  'Markwayne Mullin',
#  'Marsha Blackburn',
#  'Martha Lawley',
#  'Martin Carbaugh',
#  'Martin Graber',
#  'Marty Harbin',
#  'Marty Overweg',
#  'Marvin Smith',
#  'Mary Bentley',
#  'Mary Imes',
#  'Mary Miller',
#  'Matt Brass',
#  'Matt Brown',
#  'Matt Duffield',
#  'Matt Gaetz',
#  'Matt Lockett',
#  'Matt McKee',
#  'Matt Schaefer',
#  'Matt Stone',
#  'Matt Windschitl',
#  'Matthew Heilman',
#  'Matthew Leber',
#  'Matthew Ruby',
#  'Matthew Shaheen',
#  'Matthew Shepherd',
#  'Max Burns',
#  'Max Miller',
#  'Mayes Middleton',
#  'Mazzie Boyd',
#  'Melanie Miller',
#  'Melanie Scheible',
#  'Melanie Sojourner',
#  'Melissa Oremus',
#  'Michael Burgess',
#  'Michael Guest',
#  'Michael Hornby',
#  'Michael Kennedy',
#  'Michael Lawler',
#  'Michael McCaul',
#  'Michael McLendon',
#  'Michael Motschenbacher',
#  'Michael Petersen',
#  'Michael Pollock',
#  'Michael Waltz',
#  'Micheal Bergstrom',
#  'Michelle Fischbach',
#  'Michelle Salzman',
#  'Michelle Steel',
#  'Michelle Strinden',
#  'Mike Azinger',
#  'Mike Bost',
#  'Mike Braun',
#  'Mike Carey',
#  'Mike Cierpiot',
#  'Mike Crapo',
#  'Mike Devault',
#  'Mike Dwyer',
#  'Mike Ezell',
#  'Mike Garcia',
#  'Mike Hoadley',
#  'Mike Johnson',
#  'Mike Kelly',
#  'Mike Kingsley',
#  'Mike Thompson',
#  'Mike Volz',
#  'Mike Vondran',
#  'Mike Wilson',
#  'Mike Wobbema',
#  'Mindy McAlindon',
#  'Missy Irvin',
#  'Monica De La Cruz',
#  'Monica Robb Blasdel',
#  'Morgan Griffith',
#  'Morgan Meyer',
#  'Nancy Mace',
#  'Nancy Tate',
#  'Natalie Zeleznikar',
#  'Nate Schatzline',
#  'Nathan Dahm',
#  'Nathaniel Moran',
#  'Neal Dunn',
#  'Neil Friske',
#  'Neil Whaley',
#  'Nicholas Langworthy',
#  'Nick Bain',
#  'Nick LaLota',
#  'Nick Santucci',
#  'Nicole Malliotakis',
#  'Norlin Mommsen',
#  'Ogden Driskill',
#  'Pat Grassley',
#  'Pat McGeehan',
#  'Patricia Spearman',
#  'Patrick Fallon',
#  'Patrick Flannery',
#  'Patrick Haddon',
#  'Patti Anderson',
#  'Paul Bailey',
#  'Paul Bettencourt',
#  'Paul Gosar',
#  'Paul Novotny',
#  'Paul Rose',
#  'Peggy Scott',
#  'Pepper Ottman',
#  'Pete Stauber',
#  'Peter Flores',
#  'Phil Jensen',
#  'Phil King',
#  'Phil Plummer',
#  'Philip Gunn',
#  'Philip Moran',
#  'Phillip Wheeler',
#  'RJ Hawk',
#  'Rachel Jones',
#  'Rachel Plakon',
#  'Rachel Rodriguez-Williams',
#  'Rachelle Smit',
#  'Ralph Massullo',
#  'Ralph Norman',
#  'Randall Patterson',
#  'Randy Bridges',
#  'Randy Feenstra',
#  'Randy Fine',
#  'Randy Gross',
#  'Randy Lemm',
#  'Randy Robertson',
#  'Randy Weber',
#  'Rebecca Burkes',
#  'Rebecca Raymer',
#  'Reggie Smith',
#  'Reggie Stoltzfus',
#  'Reuben Tarver',
#  'Rex Rice',
#  'Rex Shipp',
#  'Richard Hayes',
#  'Richard Heath',
#  'Richard Hudson',
#  'Richard McCormick',
#  'Richard McGrew',
#  'Richard White',
#  'Richard Womack',
#  'Rick Allen',
#  'Rick Beck',
#  'Rick Brattin',
#  'Rick Girdler',
#  'Rick Lewis',
#  'Rick McClure',
#  'Rick Scott',
#  'Ricky Hill',
#  'Riley Keaton',
#  'Riordan McClain',
#  'Rob Harris',
#  'Rob Standridge',
#  'Robert Aderholt',
#  'Robert Auth',
#  'Robert Duvall',
#  'Robert Good',
#  'Robert Heaton',
#  'Robert Henderson',
#  'Robert Ide',
#  'Robert Karnes',
#  'Robert May',
#  'Robert Mills',
#  'Robert Nichols',
#  'Robert Sampson',
#  'Robert Wittman',
#  'Robin Lundstrum',
#  'Rochelle Nguyen',
#  'Rocky De Witt',
#  'Rod Bockenfeld',
#  'Rodney Creech',
#  'Rodney Montoya',
#  'Roger Lynch',
#  'Roger Nutt',
#  'Roger Williams',
#  'Ron Estes',
#  'Ron Ferguson',
#  'Ronny Jackson',
#  'Roy Klopfenstein',
#  'Roy Magnuson',
#  'Rudolph Yakym III',
#  'Russell Webber',
#  'Rusty Crowe',
#  'Rusty Grills',
#  'Ryan Berger',
#  'Ryan Dotson',
#  'Ryan Guillen',
#  'Ryan Rose',
#  'Ryan Zinke',
#  'Sabi Kumar',
#  'Sam Harless',
#  'Sam Watson',
#  'Sandy Salmon',
#  'Sarah Fowler Arthur',
#  'Sarah Penn',
#  'Savannah Maddox',
#  'Scott Cepicky',
#  'Scott DeLano',
#  'Scott DesJarlais',
#  'Scott Dyk',
#  'Scott Fitzgerald',
#  'Scott Flippo',
#  'Scott Franklin',
#  'Scott Heiner',
#  'Scott Louser',
#  'Scott Meyer',
#  'Scott Moore',
#  'Scott Odenbach',
#  'Scott Richardson',
#  'Scott Sharp',
#  'Scott Smith',
#  'Scott Wiggam',
#  'Sean Bennett',
#  'Shane Baker',
#  'Shane Hudella',
#  'Shane Jett',
#  'Shane Mekeland',
#  'Shane Reeves',
#  'Shawn McPherson',
#  'Shawn Still',
#  'Shawn Vedaa',
#  'Shelby Slawson',
#  'Shelley Frommeyer',
#  'Shelly Boshart Davis',
#  'Shelly Echols',
#  'Skyler Wheeler',
#  'Sonia Eubanks Barker',
#  'Sonny Borrelli',
#  'Spencer Roach',
#  'Stacey Donato',
#  'Stacey Hobgood-Wilkes',
#  'Stacy Jones',
#  'Stan Gerdes',
#  'Stan Kitzman',
#  'Stan Lambert',
#  'Stan McClain',
#  'Stephanie Bice',
#  'Stephanie Klick',
#  'Stephen Allison',
#  'Stephen Meeks',
#  'Stephen Meredith',
#  'Stetson Painter',
#  'Steve Bratcher',
#  'Steve Carra',
#  'Steve Crowell',
#  'Steve Daines',
#  'Steve Demetriou',
#  'Steve Gooch',
#  'Steve Harshman',
#  'Steve Hollowell',
#  'Steve Hopkins',
#  'Steve Rawlings',
#  'Steve Scalise',
#  'Steve Toth',
#  'Steve Unger',
#  'Steven Bradley',
#  'Steven Doan',
#  'Steven Holt',
#  'Steven Long',
#  'Steven Rudy',
#  'Stewart Jones',
#  'SuAnn Olson',
#  'Susan Manchester',
#  'Susan Tyler Witten',
#  'Sylleste Davis',
#  'Tamara Trujillo',
#  'Tammy Nichols',
#  'Tan Parker',
#  'Tara Durant',
#  'Taylor Collins',
#  'Ted Budd',
#  'Ted Cruz',
#  'Terri Leo-Wilson',
#  'Terri Williams',
#  "Terry O'Donnell",
#  'Terry Wilson',
#  'Thaddeus Claggett',
#  'Thomas Beach',
#  'Thomas Davis',
#  'Thomas Gerhold',
#  'Thomas Hall',
#  'Thomas Huff',
#  'Thomas Jeneary',
#  'Thomas Patton',
#  'Tim Barhorst',
#  'Tim French',
#  'Tim Rudd',
#  'Tim Salazar',
#  'Tim Scott',
#  'Tim Walberg',
#  'Timmy Truett',
#  'Timothy Wesco',
#  'Tina Mulally',
#  'Todd Kirby',
#  'Todd Longanacre',
#  'Tom Cotton',
#  'Tom Emmer',
#  'Tom Gann',
#  'Tom McClintock',
#  'Tom Moore',
#  'Tom Oliverson',
#  'Tom Pischke',
#  'Tom Smith',
#  'Tom Tiffany',
#  'Tom Young',
#  'Tommy Tuberville',
#  'Tony Furman',
#  'Tony Randolph',
#  'Tony Tinderholt',
#  'Tracey Mann',
#  'Tracy Cramer',
#  'Tracy Richardson',
#  'Travis Clardy',
#  'Trent Ashby',
#  'Trent Kelly',
#  'Troy Balderson',
#  'Troy McKeown',
#  'Troy Nehls',
#  'Tyler Dees',
#  'Tyler McCaughn',
#  'Val Guest',
#  'Valoree Swanson',
#  'Vern Buchanan',
#  'Vicky Steiner',
#  'Virginia Foxx',
#  'Virgle Osborne',
#  'Vito Barbieri',
#  'Wade Andrews',
#  'Wade Williams',
#  'Walker Thomas',
#  'Walter Hudson',
#  'Walter Michel',
#  'Warren Davidson',
#  'Wayne Harper',
#  'Wendell Walker',
#  'Wendy Davis Schuler',
#  'Werner Reschke',
#  'Wesley Hunt',
#  'William Arnold',
#  'William Chumley',
#  'William Henderson',
#  'William Lamberth',
#  'William Metcalf',
#  'William Ridenour',
#  'William Shorma',
#  'William Timmons',
#  'Wren Williams',
#  'Zachary Nunn',
#  'Zack Gramlich']
